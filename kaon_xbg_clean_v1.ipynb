# %% [markdown]
# Variables of filenames

# %%
#PLAINTREE FILES NAMES
directory='/Users/julnow/gsi/cbm/ML/JupyterNotebooks/'
signalFileName = directory + 'PlainTree_500kSign.root'
backgroundFileName = directory + 'PlainTree_10kBckgr.root'
allFileName = directory + 'PlainTree_20kAll.root'

# %%
# !git clone https://github.com/shahidzk1/CBM_ML_Lambda_Library.git
# %cd CBM_ML_Lambda_Library
# !git pull origin main
# !pip install -r requirements.txt
# !python setup.py install
# Out:
# fatal: destination path 'CBM_ML_Lambda_Library' already exists and is not an empty directory.
# /Users/julnow/gsi/cbm/ML/JupyterNotebooks/CBM_ML_Lambda_Library
# hint: Pulling without specifying how to reconcile divergent branches is
# hint: discouraged. You can squelch this message by running one of the following
# hint: commands sometime before your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# From https://github.com/shahidzk1/CBM_ML_Lambda_Library
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Requirement already satisfied: uproot in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.21.1)
# Requirement already satisfied: scikit-learn in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (0.24.2)
# Requirement already satisfied: xgboost in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (0.80)
# Requirement already satisfied: bayesian-optimization in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: scipy>=0.14.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from bayesian-optimization->-r requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: joblib>=0.11 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 3)) (2021.1)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from uproot->-r requirements.txt (line 1)) (57.4.0)
# running install
# running bdist_egg
# running egg_info
# writing CBM_ML.egg-info/PKG-INFO
# writing dependency_links to CBM_ML.egg-info/dependency_links.txt
# writing top-level names to CBM_ML.egg-info/top_level.txt
# reading manifest file 'CBM_ML.egg-info/SOURCES.txt'
# writing manifest file 'CBM_ML.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-11.1-arm64/egg
# running install_lib
# running build_py
# creating build/bdist.macosx-11.1-arm64/egg
# creating build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/KFPF_lambda_cuts.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/__init__.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/plot_tools.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/root_functions.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/tree_importer.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/KFPF_lambda_cuts.py to KFPF_lambda_cuts.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/plot_tools.py to plot_tools.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/root_functions.py to root_functions.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/tree_importer.py to tree_importer.cpython-38.pyc
# creating build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/PKG-INFO -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/SOURCES.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/dependency_links.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/top_level.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/CBM_ML-0.1.0-py3.8.egg' and adding 'build/bdist.macosx-11.1-arm64/egg' to it
# removing 'build/bdist.macosx-11.1-arm64/egg' (and everything under it)
# Processing CBM_ML-0.1.0-py3.8.egg
# Removing /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/CBM_ML-0.1.0-py3.8.egg
# Copying CBM_ML-0.1.0-py3.8.egg to /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages
# CBM-ML 0.1.0 is already the active version in easy-install.pth
#
# Installed /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/CBM_ML-0.1.0-py3.8.egg
# Processing dependencies for CBM-ML==0.1.0
# Finished processing dependencies for CBM-ML==0.1.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
#from hipe4ml.model_handler import ModelHandler
#from hipe4ml.tree_handler import TreeHandler
from matplotlib.patches import ConnectionPatch
#from hipe4ml import plot_utils

import xgboost as xgb
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz

from sklearn.model_selection import cross_val_score
from scipy.stats import uniform

from numpy import sqrt, log, argmax

import weakref 
import itertools

from CBM_ML import tree_importer,  KFPF_lambda_cuts, plot_tools
from bayes_opt import BayesianOptimization

import gc, os

# %% [markdown]
# # Selecting Background and Signal
# We generate PlainTrees from: 100k events (signal) and 20k evenents (background) with Au-Au @12A GeV/c, DCMQGSM-SMM generator passed through CBM setup in GEANT4, without any cuts
#
# To omit imbalance classification problem (event though there are 5 times more events for background, the number of entries is much smaller for signal) we resample the data. We're deleting instances from the over-represented class (in our case the background) - it's called under-sampling, one of the resampling methods.
#
# So for training and testing we will get signal candidates from the 5 sigma region and  background from outside this region (3 times signal size).

# %%
#CUTS FOR MASS SELECTION
#5 sigma region for signal
lower5SigmaCutSign = 0.43485
upper5SigmaCutSign = 0.56135
#mean invariant mass
invMass = 0.4981
# "5sigma" (not acutal 5 sigma) region for background
lower5SigmaCutBckgr = 0.1
upper5SigmaCutBckgr = 2

# %%
# We import three root files into our jupyter notebook
#sign - before cleaning but after 5sigma seletion, signal - cleaned
#so that we dont have to reimport everything with each change
sign = tree_importer.tree_importer(signalFileName,'PlainTree',7)

# We only select lambda candidates in the 5 sigma region around the kaon mass peak
#we preserve the cleaned dataframe with a changed name
sign = sign[(sign['Candidates_generation']==1) & (sign['Candidates_mass']>lower5SigmaCutSign) & (sign['Candidates_mass']<upper5SigmaCutSign)]

# Similarly for the background, we select background candidates which are not in the 5 sigma region of the kaon peak
bckgr = tree_importer.tree_importer(backgroundFileName,'PlainTree',7)
#we preserve the cleaned dataframe with a changed name
bckgr = bckgr[(bckgr['Candidates_generation'] < 1)
                 & ((bckgr['Candidates_mass'] > lower5SigmaCutBckgr)
                 & (bckgr['Candidates_mass'] < lower5SigmaCutSign) | (bckgr['Candidates_mass']>upper5SigmaCutSign) 
                    & (bckgr['Candidates_mass'] < upper5SigmaCutBckgr))
             ].sample(n=3*(sign.shape[0])) #we select bckgr so that we have 4*more entries that for signal (before cleaning)

#Also call the garbage collector of python to collect unused items to free memory
gc.collect()
# Out:
# 2506

# %%
#we remove name prefixes 'Candidates' and do some renaming
bckgr.columns = bckgr.columns.str.replace('Candidates_', '')
bckgr.columns = bckgr.columns.str.replace('_', '')
sign.columns = sign.columns.str.replace('Candidates_', '')
sign.columns = sign.columns.str.replace('_', '')
#we also get rid of coordinates errors
sign = sign.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
bckgr = bckgr.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
#let's check the name prefixes 
sign.iloc[0:10,:]
# Out:
#     chi2geo  chi2primfirst  chi2primsecond   chi2topo  cosinefirst  \
# 0  0.000002   2.789146e+00    3.414697e+02   0.152363     0.998430
# 1  0.264513   1.474882e+06    1.260303e+06   1.848403     0.982548
# 2  0.064274   3.623920e+06    1.747746e+06   0.256590     0.927869
# 3  0.022654   1.723264e+05    2.411727e+05   0.406959     0.986660
# 4  1.538128   9.617859e+03    3.732512e+03   1.857859     0.905587
# 5  0.590288   1.296850e+06    1.223871e+06   2.634095     0.961413
# 6  0.721047   5.744036e+05    2.418638e+05  19.809374     0.974520
# 7  0.073615   1.446560e+05    1.016588e+05   0.687733     0.980289
# 8  0.744174   8.833737e+03    2.599425e+01   0.744472     0.999502
# 9  6.557718   1.101657e+06    4.705889e+03   2.715420     0.938120
#
#    cosinesecond  cosinetopo  distance       eta          l  ...        pT  \
# 0      0.978441    0.999726  0.038816  2.981088   0.603433  ...  0.336420
# 1      0.976238    0.999997  0.001687  2.536047  18.872398  ...  0.316806
# 2      0.975467    0.999997  0.003996  3.009254   4.463050  ...  0.130762
# 3      0.984264    1.000000  0.006170  7.433340   3.380137  ...  0.002865
# 4      0.998455    0.999995  0.049966  3.027495   2.391879  ...  0.159067
# 5      0.957558    0.999978  0.006462  1.802818   3.241289  ...  0.443765
# 6      0.893650    0.999967  0.046300  2.350879  18.618280  ...  0.229605
# 7      0.996563    0.999999  0.045747  3.050026  24.100300  ...  0.285753
# 8      0.995903    0.999988  0.091523  3.268460   3.470731  ...  0.556931
# 9      0.978224    0.999964  0.223624  3.030640   3.662582  ...  0.139211
#
#         phi        px        py        pz  rapidity         x         y  \
# 0  2.886740 -0.325554  0.084812  3.306750  2.410393 -0.123734 -0.177956
# 1 -0.179362  0.311724 -0.056519  1.988028  1.928081  3.109412 -0.435314
# 2  0.559173  0.110846  0.069367  1.322198  1.682555  0.525349  0.317982
# 3 -2.576989 -0.002420 -0.001533  2.387398  2.273262 -0.056460 -0.080025
# 4  2.112874 -0.082065  0.136263  1.638160  1.867915 -0.172525  0.114815
# 5  2.740511 -0.408547  0.173252  1.309525  1.432320 -0.970163  0.154506
# 6  2.428807 -0.173706  0.150149  1.193890  1.508402 -2.550717  2.168915
# 7  2.216071 -0.171857  0.228298  3.010206  2.362526 -1.384464  1.550338
# 8 -2.060090 -0.261759 -0.491584  7.304965  2.969631 -0.121596 -0.344261
# 9 -2.587030 -0.118347 -0.073304  1.438195  1.752917 -0.272607 -0.259571
#
#            z  issignal
# 0   0.600863       1.0
# 1  18.628889       1.0
# 2   4.439318       1.0
# 3   3.378509       1.0
# 4   2.379641       1.0
# 5   3.065898       1.0
# 6  18.284170       1.0
# 7  23.992416       1.0
# 8   3.460147       1.0
# 9   3.649118       1.0
#
# [10 rows x 23 columns]

# %% [markdown]
# The label 'issignal' tells us if an entry comes from signal (1) or background (0)

# %% [markdown]
# # Data Cleaning
# Sometimes a data set contains entries which are outliers or does not make sense. For example, infinite values or NaN entries. We clean the data by removing these entries.
#
# Similarly, CBM is a fixed target experiment so there are certain conditions which the data has to satisfy before it is considered as reliable data.So we apply certain limits on the data sets.
#
# The values of these cuts are described: https://drive.google.com/file/d/1tb0FBRq4KgVu-VQZgpjA8ONbIGVCNOnE/view?usp=sharing https://github.com/julnow/JupyterNotebooks/blob/kaon/CBM%20K-short%20data%20cleaning.pdf

# %%
#CUTS USED FOR DATA CLEANING
#mass cuts for both bckgr and sign
lowerMassCut = 0.279
upperMassCut = 1.5
#distance cuts
#DCA
lowerDcaCut = 0
upperDcaCut = 100
#l distance
lowerLCut = -5
upperLCut = 80
#loverdl
lowerLdlCut = -25
upperLdlCut = 15000
#coordinate cuts
absXCut = 50
absYCut = 50
lowerZCut = -1
upperZCut = 80
#momentums cuts
pzLowerCut = 0
pUpperCut = 20
ptUpperCut = 3
#chi2
#geo
lowerChi2GeoCut = 0
upperChi2GeoCut = 10000
#topo
lowerChi2TopoCut = 0
upperChi2TopoCut = 100000
#prim first
lowerChi2PrimFirstCut = 0
upperChi2PrimFirstCut = 3e7
#prim second
lowerChi2PrimSecondCut = 0
upperChi2PrimSecondCut = 3e7
#pseudorapidity cuts
lowerEtaCut = 1.
upperEtaCut = 6.5

# %%
def clean_df(df):
    # let's treat all the infinite, inf, values by nan and then we drop all the null entries
    with pd.option_context('mode.use_inf_as_na', True):
        df = df.dropna()
    #Experimental constraints
    is_good_mom = (df['pz'] > pzLowerCut) & (df['p']<pUpperCut) & (df['pT']<ptUpperCut)
    is_good_coord = (abs(df['x']) < absXCut) & (abs(df['y']) < absYCut) & (df['z']>lowerZCut) & (df['z']<upperZCut)
    is_good_params = (df['distance'] > lowerDcaCut) & (df['distance'] < upperDcaCut) & (df['chi2geo']>lowerChi2GeoCut) & (df['chi2geo'] < upperChi2GeoCut) & (df['chi2topo'] > lowerChi2TopoCut) & (df['chi2topo'] < upperChi2TopoCut) & (df['eta']>lowerEtaCut) & (df['eta']<upperEtaCut)& (df['l']>lowerLCut) & (df['l']<upperLCut) & (df['loverdl']>lowerLdlCut) & (df['loverdl']<upperLdlCut)
    is_good_daughters = (df['chi2primfirst']>lowerChi2PrimFirstCut) & (df['chi2primfirst'] < upperChi2PrimSecondCut) & (df['chi2primsecond']>lowerChi2PrimSecondCut) & (df['chi2primsecond']<upperChi2PrimFirstCut)
    is_good_mass = (df['mass']>lowerMassCut) & (df['mass']<upperMassCut)

    is_good_df = (is_good_mom) & (is_good_coord) & (is_good_params) & (is_good_daughters) & (is_good_mass)

    return df[is_good_df]

# %%
background = clean_df(bckgr)
signal = clean_df(sign)
del sign, bckgr

# %% [markdown]
# We'll also import and clean dataset of 10k events for both background and signal (for testing our algorhitm)

# %%
df_origin = tree_importer.tree_importer(allFileName,'PlainTree',7)
df_origin.columns = df_origin.columns.str.replace('Candidates_', '')
df_origin.columns = df_origin.columns.str.replace('_', '')
df_origin = df_origin.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
df_clean = clean_df(df_origin)
del df_origin
#lets shuffle data
df_clean= df_clean.sample(frac=1)
gc.collect()
#lets look at impoted tree
df_clean.iloc[0:10,:]
# Out:
#            chi2geo  chi2primfirst  chi2primsecond   chi2topo  cosinefirst  \
# 32389556  0.114022       0.178365        0.505226   0.226333     0.983136
# 59654705  1.621227       0.568932        1.300810   0.603530     0.996548
# 44923559  3.696224       3.726582        1.229620   1.554956     0.923507
# 51286855  5.454071      47.937824        0.011721  15.323415     0.999208
# 3563896   1.157254       3.562254        0.956293   0.935708     0.991822
# 53562687  3.544938       6.295291        2.127806   1.732017     0.974238
# 13745196  1.330041       2.695863        1.635750   1.425166     0.979432
# 30135878  0.397888       0.160175        0.971527   0.216774     0.996073
# 55989464  8.522973       0.394098       24.778355   5.779484     0.991927
# 35078746  0.415660       1.798835        3.228042   1.491412     0.966346
#
#           cosinesecond  cosinetopo  distance       eta         l  ...  \
# 32389556      0.945072    0.945595  0.005390  2.395934  0.012904  ...
# 59654705      0.980183   -0.952186  0.004035  2.670364 -0.001721  ...
# 44923559      0.920672    0.826343  0.007876  2.633664  0.002948  ...
# 51286855      0.968318    0.954244  0.063316  3.269734  0.086878  ...
# 3563896       0.977326    0.983680  0.002820  3.977292  0.008041  ...
# 53562687      0.999594   -0.999684  0.032798  2.925874 -0.121345  ...
# 13745196      0.997224   -0.885946  0.007616  2.275767 -0.008443  ...
# 30135878      0.995818    0.998048  0.002817  2.255353  0.018201  ...
# 55989464      0.990567   -0.975537  0.042697  3.153375 -0.075118  ...
# 35078746      0.983851   -0.844987  0.002781  2.183873 -0.006928  ...
#
#                 pT       phi        px        py        pz  rapidity  \
# 32389556  0.210908  1.622300 -0.010858  0.210629  1.148119  1.636387
# 59654705  0.636818  2.688719 -0.572623  0.278641  4.577445  2.301219
# 44923559  0.441248 -0.289494  0.422887 -0.125962  3.056282  1.525302
# 51286855  0.270103 -1.221282  0.092494 -0.253773  3.547333  2.472672
# 3563896   0.196445 -3.075757 -0.196019 -0.012924  5.240594  2.417518
# 53562687  0.222395  0.555682  0.188934  0.117319  2.067919  2.104250
# 13745196  0.416273 -0.753601  0.303558 -0.284843  2.004905  1.954555
# 30135878  0.479423 -2.648591 -0.422331 -0.226898  2.261394  2.048867
# 55989464  0.075574 -3.002894 -0.074848 -0.010448  0.883166  1.762528
# 35078746  0.635102 -0.366005  0.593035 -0.227295  2.784296  1.809297
#
#                  x         y         z  issignal
# 32389556  0.014353  0.079560  0.013092       0.0
# 59654705 -0.027993 -0.031501 -0.001170       0.0
# 44923559 -0.004468  0.070976  0.004991       0.0
# 51286855 -0.058145 -0.080932  0.088985       0.0
# 3563896  -0.033042 -0.124073  0.005919       0.0
# 53562687 -0.016903 -0.073320 -0.120449       0.0
# 13745196  0.089141 -0.149782 -0.007536       0.0
# 30135878  0.027785 -0.088707  0.017724       0.0
# 55989464 -0.061161  0.048262 -0.073762       0.0
# 35078746  0.030468 -0.021479 -0.007397       0.0
#
# [10 rows x 23 columns]

# %%
#Let's combine signal and background
df_scaled = pd.concat([signal, background])
# Let's shuffle the rows randomly
df_scaled = df_scaled.sample(frac=1)

# %%
print('size of:\nsignal: ' + str(len(signal)) + '\nbackground: ' + str(len(background)) 
      + '\nbackground to signal ratio: ' + str(round(len(background)/len(signal), 1))  
      + '\ntest set (both signal and background): ' + str(len(df_clean))
      + '\ntest set (background to signal ratio): ' 
      + str(round(len(df_clean.loc[df_clean['issignal'] == 0])/len(df_clean.loc[df_clean['issignal'] == 1]), 1)))
# Out:
# size of:
# signal: 450442
# background: 1247617
# background to signal ratio: 2.8
# test set (both signal and background): 59931407
# test set (background to signal ratio): 3261.5

# %% [markdown]
# # Selecting Background and Signal
# After cleaning, our training data set contains 238477 background candidates and 89987 signal candidates (background to signal ratio $\approx 2.7$). For testing, we'll use cleaned dataset containing 34200168 entries of signal and background (background to signal ratio $\approx 1871.3$)
#
# Here, we use under-sampling to tackle the problem with the classification of underrepresented class (normally, the signal is only approx. 0.05% of real data)

# %%
if not os.path.exists(directory+'img/xgb'):
    os.makedirs(directory+'img/xgb')
#lets draw sign to background ratio
def plt_sig_back(df):
    range1 = (lowerMassCut, upperMassCut)
    fig, axs = plt.subplots(figsize=(20, 10))
    #df_scaled['mass'].plot.hist(bins = 300, range=range1,grid=True,sharey=True)
    (df[df['issignal']==0])['mass'].plot.hist(bins = 300, facecolor='yellow',grid=True,range=range1, label='Background')
    (df[df['issignal']==1])['mass'].plot.hist(bins = 300, facecolor='magenta',grid=True, range=range1, label ='Signal')
    #plt.vlines(x=1.108,ymin=-1,ymax=48000, color='black', linestyle='-')
    #plt.vlines(x=1.1227,ymin=-1,ymax=48000, color='black', linestyle='-')
    plt.ylabel("Counts (log scale)", fontsize=15)
    plt.xlabel("Mass in GeV/$c^2$", fontsize= 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.title('Test and Train K-short Invariant Mass', fontsize = 15)
    plt.legend( fontsize = 15)
    axs.tick_params(axis='both', which='major', labelsize=18)
    plt.yscale("log")
    fig.tight_layout()
    fig.savefig(directory+'img/xgb/inv_mass_trainset.pdf')
    fig.savefig(directory+'img/xgb/inv_mass_trainset.png')

# %%
plt_sig_back(df_scaled)
gc.collect()
# Out:
# 2187

# %% [markdown]
# # Creating Train and Test sets
# To make machine learning algorithms more efficient on unseen data we divide our data into two sets. One set is for training the algorithm and the other is for testing the algorithm. If we don't do this then the algorithm can overfit and we will not capture the general trends in the data.

# %%
# The following columns will be used to predict whether a reconstructed candidate is a lambda particle or not
cuts = [ 'loverdl', 'distance', 'chi2geo', 'chi2topo', 'chi2primfirst', 'chi2primsecond']


x = df_scaled[cuts].copy()

# The MC information is saved in this y variable
y =pd.DataFrame(df_scaled['issignal'], dtype='int')

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=324)

#DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed. 
dtrain = xgb.DMatrix(x_train, label = y_train)
dtest=xgb.DMatrix(x_test, label = y_test)

# %% [markdown]
# ## Whole set
# We also select the selected variables from the 10k events data set

# %%
x_whole = df_clean[cuts].copy()
y_whole = pd.DataFrame(df_clean['issignal'], dtype='int')

# %% [markdown]
# <p style="font-family: Arial; font-size:3em;color:purple; font-style:bold"><br>XGB Boost
# <br></p><br>

# %%
#DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed. 
dtrain = xgb.DMatrix(x_train, label = y_train)
dtest = xgb.DMatrix(x_whole, label = y_whole)
dtest1=xgb.DMatrix(x_test, label = y_test)

# %% [markdown]
# ## Bayesian optimization
# In order to find the best parameters of XGB for our data we use Bayesian optimization. Grid search and and random search could also do the same job but bayesian is more time efficient. For further reading visit [the git page](https://github.com/fmfn/BayesianOptimization) of the bayesian optimization used here.
#
# ### Hyper parameters
# Some of the following hyper parameters will be tuned for our algorithm:
#
#
# *subsample* [default=1]
# Subsample ratio of the training instances. Setting it to 0.5 means that XGBoost would randomly sample half of the training data prior to growing trees. and this will prevent overfitting. Subsampling will occur once in every boosting iteration.
# range: (0,1]
#
# *eta* [default=0.3, alias: learning_rate]
# Step size shrinkage used in update to prevents overfitting. After each boosting step, we can directly get the weights of new features, and eta shrinks the feature weights to make the boosting process more conservative.
# range: [0,1]
#
#
# *gamma* [default=0, alias: min_split_loss]
# Minimum loss reduction required to make a further partition on a leaf node of the tree. The larger gamma is, the more conservative the algorithm will be.
# range: [0,∞]
#
#
# *alpha* [default=0, alias: reg_alpha]
# L1 regularization term on weights. Increasing this value will make model more conservative.
#
# *Lasso Regression* (Least Absolute Shrinkage and Selection Operator) adds “absolute value of magnitude” of coefficient as penalty term to the loss function.

# %%
#Bayesian Optimization function for xgboost
#specify the parameters you want to tune as keyword arguments
def bo_tune_xgb(max_depth, gamma, alpha, n_estimators ,learning_rate):
    params = {'max_depth': int(max_depth),
              'gamma': gamma,
              'alpha':alpha,
              'n_estimators': n_estimators,
              'learning_rate':learning_rate,
              'subsample': 0.8,
              'eta': 0.1,
              'eval_metric': 'auc', 'nthread' : 7}
    cv_result = xgb.cv(params, dtrain, num_boost_round=70, nfold=5)
    return  cv_result['test-auc-mean'].iloc[-1]

# %%
#Invoking the Bayesian Optimizer with the specified parameters to tune
xgb_bo = BayesianOptimization(bo_tune_xgb, {'max_depth': (4, 10),
                                             'gamma': (0, 1),
                                            'alpha': (2,20),
                                             'learning_rate':(0,1),
                                             'n_estimators':(100,500)
                                            })

# %%
#performing Bayesian optimization for 5 iterations with 8 steps of random exploration with an #acquisition function of expected improvement
xgb_bo.maximize(n_iter=5, init_points=5)
# Out:
# |   iter    |  target   |   alpha   |   gamma   | learni... | max_depth | n_esti... |
# -------------------------------------------------------------------------------------
# [12:00:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 4 pruned nodes, max_depth=7
# [12:00:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [12:00:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [12:00:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 2 pruned nodes, max_depth=7
# [12:00:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [12:00:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 6 pruned nodes, max_depth=7
# [12:00:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 4 pruned nodes, max_depth=7
# [12:00:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 6 pruned nodes, max_depth=7
# [12:00:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 6 pruned nodes, max_depth=7
# [12:00:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=7
# [12:00:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 6 pruned nodes, max_depth=7
# [12:00:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 2 pruned nodes, max_depth=7
# [12:00:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 10 pruned nodes, max_depth=7
# [12:00:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 6 pruned nodes, max_depth=7
# [12:00:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 12 pruned nodes, max_depth=7
# [12:00:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 10 pruned nodes, max_depth=7
# [12:00:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 4 pruned nodes, max_depth=7
# [12:00:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=7
# [12:00:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 10 pruned nodes, max_depth=7
# [12:00:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 12 pruned nodes, max_depth=7
# [12:00:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 14 pruned nodes, max_depth=7
# [12:00:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 14 pruned nodes, max_depth=7
# [12:00:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 14 pruned nodes, max_depth=7
# [12:00:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 2 pruned nodes, max_depth=7
# [12:01:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 18 pruned nodes, max_depth=7
# [12:01:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 22 pruned nodes, max_depth=7
# [12:01:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 30 pruned nodes, max_depth=7
# [12:01:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 24 pruned nodes, max_depth=7
# [12:01:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 10 pruned nodes, max_depth=7
# [12:01:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 22 pruned nodes, max_depth=7
# [12:01:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 14 pruned nodes, max_depth=7
# [12:01:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 24 pruned nodes, max_depth=7
# [12:01:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 24 pruned nodes, max_depth=7
# [12:01:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 28 pruned nodes, max_depth=7
# [12:01:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 34 pruned nodes, max_depth=7
# [12:01:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 42 pruned nodes, max_depth=7
# [12:01:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 10 pruned nodes, max_depth=7
# [12:01:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 32 pruned nodes, max_depth=7
# [12:01:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 26 pruned nodes, max_depth=7
# [12:01:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 40 pruned nodes, max_depth=7
# [12:01:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 30 pruned nodes, max_depth=7
# [12:01:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 40 pruned nodes, max_depth=7
# [12:01:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 48 pruned nodes, max_depth=7
# [12:01:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 46 pruned nodes, max_depth=7
# [12:01:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 44 pruned nodes, max_depth=7
# [12:01:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 28 pruned nodes, max_depth=7
# [12:01:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 40 pruned nodes, max_depth=7
# [12:01:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 30 pruned nodes, max_depth=7
# [12:01:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 64 pruned nodes, max_depth=7
# [12:01:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 44 pruned nodes, max_depth=7
# [12:01:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 56 pruned nodes, max_depth=7
# [12:01:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 66 pruned nodes, max_depth=7
# [12:01:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 50 pruned nodes, max_depth=7
# [12:01:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 76 pruned nodes, max_depth=7
# [12:01:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 40 pruned nodes, max_depth=7
# [12:01:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 22 pruned nodes, max_depth=7
# [12:01:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 68 pruned nodes, max_depth=7
# [12:01:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 58 pruned nodes, max_depth=7
# [12:01:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 68 pruned nodes, max_depth=7
# [12:01:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 54 pruned nodes, max_depth=7
# [12:01:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 38 pruned nodes, max_depth=7
# [12:01:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 58 pruned nodes, max_depth=7
# [12:01:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 68 pruned nodes, max_depth=7
# [12:01:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 92 pruned nodes, max_depth=7
# [12:01:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 44 pruned nodes, max_depth=7
# [12:01:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 52 pruned nodes, max_depth=7
# [12:01:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 66 pruned nodes, max_depth=7
# [12:01:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 60 pruned nodes, max_depth=7
# [12:01:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 40 pruned nodes, max_depth=7
# [12:01:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 44 pruned nodes, max_depth=7
# [12:01:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 48 pruned nodes, max_depth=7
# [12:01:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 44 pruned nodes, max_depth=7
# [12:01:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 26 pruned nodes, max_depth=7
# [12:01:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 52 pruned nodes, max_depth=7
# [12:01:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 60 pruned nodes, max_depth=7
# [12:01:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 68 pruned nodes, max_depth=7
# [12:01:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 46 pruned nodes, max_depth=7
# [12:01:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 50 pruned nodes, max_depth=7
# [12:01:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 52 pruned nodes, max_depth=7
# [12:01:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 82 pruned nodes, max_depth=7
# [12:01:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 50 pruned nodes, max_depth=7
# [12:01:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 38 pruned nodes, max_depth=7
# [12:01:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 118 pruned nodes, max_depth=7
# [12:01:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 58 pruned nodes, max_depth=7
# [12:01:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 30 pruned nodes, max_depth=7
# [12:01:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 54 pruned nodes, max_depth=7
# [12:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 46 pruned nodes, max_depth=7
# [12:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 32 pruned nodes, max_depth=7
# [12:01:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 38 pruned nodes, max_depth=7
# [12:01:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 86 pruned nodes, max_depth=7
# [12:01:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 40 pruned nodes, max_depth=7
# [12:01:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 58 pruned nodes, max_depth=7
# [12:01:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 38 pruned nodes, max_depth=7
# [12:01:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=7
# [12:01:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 64 pruned nodes, max_depth=7
# [12:01:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 66 pruned nodes, max_depth=7
# [12:01:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 48 pruned nodes, max_depth=7
# [12:01:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 64 pruned nodes, max_depth=7
# [12:01:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 64 pruned nodes, max_depth=7
# [12:01:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 50 pruned nodes, max_depth=7
# [12:01:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 68 pruned nodes, max_depth=7
# [12:01:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 50 pruned nodes, max_depth=7
# [12:01:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 82 pruned nodes, max_depth=7
# [12:02:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 48 pruned nodes, max_depth=7
# [12:02:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 28 pruned nodes, max_depth=7
# [12:02:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 36 pruned nodes, max_depth=7
# [12:02:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 58 pruned nodes, max_depth=7
# [12:02:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 54 pruned nodes, max_depth=7
# [12:02:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 50 pruned nodes, max_depth=7
# [12:02:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 52 pruned nodes, max_depth=7
# [12:02:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 58 pruned nodes, max_depth=7
# [12:02:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 64 pruned nodes, max_depth=7
# [12:02:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 68 pruned nodes, max_depth=7
# [12:02:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 60 pruned nodes, max_depth=7
# [12:02:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 58 pruned nodes, max_depth=7
# [12:02:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 64 pruned nodes, max_depth=7
# [12:02:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 34 pruned nodes, max_depth=7
# [12:02:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 90 pruned nodes, max_depth=7
# [12:02:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 90 pruned nodes, max_depth=7
# [12:02:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 58 pruned nodes, max_depth=7
# [12:02:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 66 pruned nodes, max_depth=7
# [12:02:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 70 pruned nodes, max_depth=7
# [12:02:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 40 pruned nodes, max_depth=7
# [12:02:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 48 pruned nodes, max_depth=7
# [12:02:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 38 pruned nodes, max_depth=7
# [12:02:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 110 pruned nodes, max_depth=7
# [12:02:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 56 pruned nodes, max_depth=7
# [12:02:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 106 pruned nodes, max_depth=7
# [12:02:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 78 pruned nodes, max_depth=7
# [12:02:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 110 pruned nodes, max_depth=7
# [12:02:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 74 pruned nodes, max_depth=7
# [12:02:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 78 pruned nodes, max_depth=7
# [12:02:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 48 pruned nodes, max_depth=5
# [12:02:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 50 pruned nodes, max_depth=7
# [12:02:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 62 pruned nodes, max_depth=7
# [12:02:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 58 pruned nodes, max_depth=7
# [12:02:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 62 pruned nodes, max_depth=7
# [12:02:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 62 pruned nodes, max_depth=7
# [12:17:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 84 pruned nodes, max_depth=7
# [12:17:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 72 pruned nodes, max_depth=7
# [12:17:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 60 pruned nodes, max_depth=7
# [12:17:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 50 pruned nodes, max_depth=7
# [12:17:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 46 pruned nodes, max_depth=7
# [12:17:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 76 pruned nodes, max_depth=7
# [12:17:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 58 pruned nodes, max_depth=7
# [12:17:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 76 pruned nodes, max_depth=7
# [12:17:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 34 pruned nodes, max_depth=7
# [12:17:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 56 pruned nodes, max_depth=7
# [12:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 78 pruned nodes, max_depth=7
# [12:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 54 pruned nodes, max_depth=7
# [12:17:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 72 pruned nodes, max_depth=7
# [12:17:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 64 pruned nodes, max_depth=7
# [12:17:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 60 pruned nodes, max_depth=7
# [12:17:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 60 pruned nodes, max_depth=7
# [12:17:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 62 pruned nodes, max_depth=7
# [12:17:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 62 pruned nodes, max_depth=7
# [12:17:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 68 pruned nodes, max_depth=7
# [12:17:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 54 pruned nodes, max_depth=7
# [12:17:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 40 pruned nodes, max_depth=7
# [12:17:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 74 pruned nodes, max_depth=7
# [12:17:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 90 pruned nodes, max_depth=7
# [12:17:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 70 pruned nodes, max_depth=7
# [12:17:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 68 pruned nodes, max_depth=7
# [12:17:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 64 pruned nodes, max_depth=7
# [12:17:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 88 pruned nodes, max_depth=7
# [12:17:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 108 pruned nodes, max_depth=7
# [12:17:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 84 pruned nodes, max_depth=7
# [12:17:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 90 pruned nodes, max_depth=7
# [12:17:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 48 pruned nodes, max_depth=7
# [12:17:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 88 pruned nodes, max_depth=7
# [12:17:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 98 pruned nodes, max_depth=7
# [12:17:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 88 pruned nodes, max_depth=7
# [12:17:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 112 pruned nodes, max_depth=7
# [12:17:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 72 pruned nodes, max_depth=7
# [12:17:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 94 pruned nodes, max_depth=7
# [12:17:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 70 pruned nodes, max_depth=7
# [12:17:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 70 pruned nodes, max_depth=7
# [12:17:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 32 pruned nodes, max_depth=7
# [12:17:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 108 pruned nodes, max_depth=7
# [12:17:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 66 pruned nodes, max_depth=7
# [12:17:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 64 pruned nodes, max_depth=7
# [12:17:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 94 pruned nodes, max_depth=7
# [12:17:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 84 pruned nodes, max_depth=7
# [12:18:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 68 pruned nodes, max_depth=7
# [12:18:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 68 pruned nodes, max_depth=7
# [12:18:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 46 pruned nodes, max_depth=7
# [12:18:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 88 pruned nodes, max_depth=7
# [12:18:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 38 pruned nodes, max_depth=7
# [12:18:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 78 pruned nodes, max_depth=7
# [12:18:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 60 pruned nodes, max_depth=7
# [12:18:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 60 pruned nodes, max_depth=7
# [12:18:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 28 pruned nodes, max_depth=7
# [12:18:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 82 pruned nodes, max_depth=7
# [12:18:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 96 pruned nodes, max_depth=7
# [12:18:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 84 pruned nodes, max_depth=7
# [12:18:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 98 pruned nodes, max_depth=7
# [12:18:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 70 pruned nodes, max_depth=7
# [12:18:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 62 pruned nodes, max_depth=7
# [12:18:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 50 pruned nodes, max_depth=7
# [12:18:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 80 pruned nodes, max_depth=7
# [12:18:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 88 pruned nodes, max_depth=7
# [12:18:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 90 pruned nodes, max_depth=7
# [12:18:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 62 pruned nodes, max_depth=7
# [12:18:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 72 pruned nodes, max_depth=7
# [12:18:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 100 pruned nodes, max_depth=7
# [12:18:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 44 pruned nodes, max_depth=7
# [12:18:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 78 pruned nodes, max_depth=7
# [12:18:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 58 pruned nodes, max_depth=7
# [12:18:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 52 pruned nodes, max_depth=7
# [12:18:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 32 pruned nodes, max_depth=7
# [12:18:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 84 pruned nodes, max_depth=7
# [12:18:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 82 pruned nodes, max_depth=7
# [12:18:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 96 pruned nodes, max_depth=7
# [12:18:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 52 pruned nodes, max_depth=7
# [12:18:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 80 pruned nodes, max_depth=7
# [12:18:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 92 pruned nodes, max_depth=7
# [12:18:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 74 pruned nodes, max_depth=6
# [12:18:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 96 pruned nodes, max_depth=6
# [12:18:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 144 pruned nodes, max_depth=7
# [12:18:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 62 pruned nodes, max_depth=7
# [12:18:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 60 pruned nodes, max_depth=7
# [12:18:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 96 pruned nodes, max_depth=7
# [12:18:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 80 pruned nodes, max_depth=7
# [12:18:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 60 pruned nodes, max_depth=7
# [12:18:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 58 pruned nodes, max_depth=7
# [12:18:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 72 pruned nodes, max_depth=7
# [12:18:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 66 pruned nodes, max_depth=7
# [12:18:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 68 pruned nodes, max_depth=7
# [12:18:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 92 pruned nodes, max_depth=7
# [12:18:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 40 pruned nodes, max_depth=7
# [12:18:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 50 pruned nodes, max_depth=7
# [12:18:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 116 pruned nodes, max_depth=7
# [12:18:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 84 pruned nodes, max_depth=7
# [12:18:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 52 pruned nodes, max_depth=7
# [12:18:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 78 pruned nodes, max_depth=7
# [12:18:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 82 pruned nodes, max_depth=7
# [12:18:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 48 pruned nodes, max_depth=7
# [12:18:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 62 pruned nodes, max_depth=7
# [12:18:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 118 pruned nodes, max_depth=7
# [12:18:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 94 pruned nodes, max_depth=7
# [12:18:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 82 pruned nodes, max_depth=7
# [12:18:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 98 pruned nodes, max_depth=7
# [12:18:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 60 pruned nodes, max_depth=7
# [12:18:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 80 pruned nodes, max_depth=7
# [12:18:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 74 pruned nodes, max_depth=7
# [12:18:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 90 pruned nodes, max_depth=7
# [12:18:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 32 pruned nodes, max_depth=7
# [12:18:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 96 pruned nodes, max_depth=7
# [12:18:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 82 pruned nodes, max_depth=7
# [12:18:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 78 pruned nodes, max_depth=7
# [12:18:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 42 pruned nodes, max_depth=7
# [12:18:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 110 pruned nodes, max_depth=6
# [12:18:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 88 pruned nodes, max_depth=7
# [12:18:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 102 pruned nodes, max_depth=7
# [12:18:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 44 pruned nodes, max_depth=7
# [12:18:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 88 pruned nodes, max_depth=7
# [12:18:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 108 pruned nodes, max_depth=7
# [12:18:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 88 pruned nodes, max_depth=7
# [12:18:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 62 pruned nodes, max_depth=7
# [12:18:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 72 pruned nodes, max_depth=7
# [12:18:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 114 pruned nodes, max_depth=7
# [12:18:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 74 pruned nodes, max_depth=6
# [12:19:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 94 pruned nodes, max_depth=7
# [12:19:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 58 pruned nodes, max_depth=7
# [12:19:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 66 pruned nodes, max_depth=7
# [12:19:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 122 pruned nodes, max_depth=7
# [12:19:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 84 pruned nodes, max_depth=7
# [12:19:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 34 pruned nodes, max_depth=7
# [12:19:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 24 pruned nodes, max_depth=7
# [12:19:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 60 pruned nodes, max_depth=7
# [12:19:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 104 pruned nodes, max_depth=7
# [12:19:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 112 pruned nodes, max_depth=7
# [12:19:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 90 pruned nodes, max_depth=7
# [12:19:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 54 pruned nodes, max_depth=7
# [12:19:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 82 pruned nodes, max_depth=7
# [12:19:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 84 pruned nodes, max_depth=7
# [12:19:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 108 pruned nodes, max_depth=7
# [12:19:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 44 pruned nodes, max_depth=7
# [12:19:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 84 pruned nodes, max_depth=7
# [12:19:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 120 pruned nodes, max_depth=7
# [12:19:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 76 pruned nodes, max_depth=7
# [12:19:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 50 pruned nodes, max_depth=7
# [12:19:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 92 pruned nodes, max_depth=7
# [12:19:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 98 pruned nodes, max_depth=7
# [12:19:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 60 pruned nodes, max_depth=7
# [12:19:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 56 pruned nodes, max_depth=7
# [12:19:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 114 pruned nodes, max_depth=6
# [12:19:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 58 pruned nodes, max_depth=7
# [12:19:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 100 pruned nodes, max_depth=7
# [12:19:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 114 pruned nodes, max_depth=7
# [12:19:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 114 pruned nodes, max_depth=7
# [12:19:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 76 pruned nodes, max_depth=7
# [12:19:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 58 pruned nodes, max_depth=7
# [12:19:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 90 pruned nodes, max_depth=7
# [12:19:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 46 pruned nodes, max_depth=7
# [12:19:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 52 pruned nodes, max_depth=7
# [12:19:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 82 pruned nodes, max_depth=7
# [12:19:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 100 pruned nodes, max_depth=7
# [12:19:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 84 pruned nodes, max_depth=7
# [12:19:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 84 pruned nodes, max_depth=7
# [12:19:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 82 pruned nodes, max_depth=7
# [12:19:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 76 pruned nodes, max_depth=7
# [12:19:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 66 pruned nodes, max_depth=7
# [12:19:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 88 pruned nodes, max_depth=7
# [12:19:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 102 pruned nodes, max_depth=7
# [12:19:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 78 pruned nodes, max_depth=7
# [12:19:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 60 pruned nodes, max_depth=7
# [12:19:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 66 pruned nodes, max_depth=7
# [12:19:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 102 pruned nodes, max_depth=7
# [12:19:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 82 pruned nodes, max_depth=6
# [12:19:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 102 pruned nodes, max_depth=7
# [12:19:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 78 pruned nodes, max_depth=6
# [12:19:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 66 pruned nodes, max_depth=3
# [12:19:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 68 pruned nodes, max_depth=7
# [12:19:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 100 pruned nodes, max_depth=7
# [12:19:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 108 pruned nodes, max_depth=7
# [12:19:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 120 pruned nodes, max_depth=7
# [12:19:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 106 pruned nodes, max_depth=7
# [12:19:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 62 pruned nodes, max_depth=7
# [12:19:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 100 pruned nodes, max_depth=7
# [12:19:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 114 pruned nodes, max_depth=7
# [12:19:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 98 pruned nodes, max_depth=7
# [12:19:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 118 pruned nodes, max_depth=7
# [12:19:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 88 pruned nodes, max_depth=7
# [12:19:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 104 pruned nodes, max_depth=7
# [12:19:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 86 pruned nodes, max_depth=5
# [12:19:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 98 pruned nodes, max_depth=7
# [12:19:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 92 pruned nodes, max_depth=7
# [12:19:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 78 pruned nodes, max_depth=7
# [12:19:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 108 pruned nodes, max_depth=7
# [12:19:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 88 pruned nodes, max_depth=7
# [12:19:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 56 pruned nodes, max_depth=7
# [12:19:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 60 pruned nodes, max_depth=7
# [12:19:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 54 pruned nodes, max_depth=7
# [12:19:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 76 pruned nodes, max_depth=7
# [12:19:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 76 pruned nodes, max_depth=7
# [12:19:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 82 pruned nodes, max_depth=7
# [12:19:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 104 pruned nodes, max_depth=7
# [12:19:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 74 pruned nodes, max_depth=7
# [12:19:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 70 pruned nodes, max_depth=7
# [12:19:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 114 pruned nodes, max_depth=5
# [12:20:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 92 pruned nodes, max_depth=7
# [12:20:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 84 pruned nodes, max_depth=7
# [12:20:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 78 pruned nodes, max_depth=7
# [12:20:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 82 pruned nodes, max_depth=7
# [12:20:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 122 pruned nodes, max_depth=7
# [12:20:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 80 pruned nodes, max_depth=7
# [12:20:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 76 pruned nodes, max_depth=7
# [12:20:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 62 pruned nodes, max_depth=5
# [12:20:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 82 pruned nodes, max_depth=7
# |  1        |  0.9967   |  11.21    |  0.121    |  0.5078   |  7.738    |  143.6    |
# [12:20:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 18 pruned nodes, max_depth=7
# [12:20:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 20 pruned nodes, max_depth=7
# [12:20:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 24 pruned nodes, max_depth=7
# [12:20:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 10 pruned nodes, max_depth=7
# [12:20:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 10 pruned nodes, max_depth=7
# [12:20:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 64 pruned nodes, max_depth=7
# [12:20:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 64 pruned nodes, max_depth=7
# [12:20:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 62 pruned nodes, max_depth=7
# [12:20:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 64 pruned nodes, max_depth=7
# [12:20:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 50 pruned nodes, max_depth=7
# [12:20:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 70 pruned nodes, max_depth=7
# [12:20:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 64 pruned nodes, max_depth=7
# [12:20:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 92 pruned nodes, max_depth=7
# [12:20:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 106 pruned nodes, max_depth=7
# [12:20:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 66 pruned nodes, max_depth=7
# [12:20:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 82 pruned nodes, max_depth=7
# [12:20:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 76 pruned nodes, max_depth=7
# [12:20:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 52 pruned nodes, max_depth=7
# [12:20:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 94 pruned nodes, max_depth=7
# [12:20:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 96 pruned nodes, max_depth=7
# [12:20:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 116 pruned nodes, max_depth=7
# [12:20:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 148 pruned nodes, max_depth=7
# [12:20:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 94 pruned nodes, max_depth=7
# [12:20:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 92 pruned nodes, max_depth=7
# [12:20:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 90 pruned nodes, max_depth=7
# [12:20:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 100 pruned nodes, max_depth=7
# [12:20:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 110 pruned nodes, max_depth=7
# [12:20:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 156 pruned nodes, max_depth=7
# [12:20:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 128 pruned nodes, max_depth=7
# [12:20:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 144 pruned nodes, max_depth=7
# [12:20:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 104 pruned nodes, max_depth=7
# [12:20:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 62 pruned nodes, max_depth=7
# [12:20:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 96 pruned nodes, max_depth=7
# [12:20:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 48 pruned nodes, max_depth=7
# [12:20:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 106 pruned nodes, max_depth=7
# [12:20:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 108 pruned nodes, max_depth=7
# [12:20:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 82 pruned nodes, max_depth=7
# [12:20:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 62 pruned nodes, max_depth=7
# [12:20:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 140 pruned nodes, max_depth=7
# [12:20:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 128 pruned nodes, max_depth=7
# [12:20:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 108 pruned nodes, max_depth=7
# [12:20:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 122 pruned nodes, max_depth=7
# [12:20:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 100 pruned nodes, max_depth=7
# [12:20:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 98 pruned nodes, max_depth=7
# [12:20:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 112 pruned nodes, max_depth=7
# [12:20:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 118 pruned nodes, max_depth=7
# [12:20:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 102 pruned nodes, max_depth=7
# [12:20:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 128 pruned nodes, max_depth=7
# [12:20:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 106 pruned nodes, max_depth=7
# [12:20:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 50 pruned nodes, max_depth=7
# [12:20:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 96 pruned nodes, max_depth=7
# [12:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 112 pruned nodes, max_depth=7
# [12:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 148 pruned nodes, max_depth=7
# [12:20:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 136 pruned nodes, max_depth=7
# [12:20:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 86 pruned nodes, max_depth=7
# [12:20:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 94 pruned nodes, max_depth=7
# [12:20:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 96 pruned nodes, max_depth=7
# [12:20:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 132 pruned nodes, max_depth=7
# [12:20:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 102 pruned nodes, max_depth=5
# [12:20:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 100 pruned nodes, max_depth=7
# [12:20:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 106 pruned nodes, max_depth=7
# [12:20:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 150 pruned nodes, max_depth=7
# [12:20:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 174 pruned nodes, max_depth=7
# [12:20:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 84 pruned nodes, max_depth=7
# [12:20:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 122 pruned nodes, max_depth=7
# [12:20:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 158 pruned nodes, max_depth=7
# [12:20:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 122 pruned nodes, max_depth=7
# [12:20:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 110 pruned nodes, max_depth=7
# [12:21:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 74 pruned nodes, max_depth=7
# [12:21:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 114 pruned nodes, max_depth=7
# [12:21:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 108 pruned nodes, max_depth=7
# ...
# [12:53:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 232 pruned nodes, max_depth=7
# [12:53:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 238 pruned nodes, max_depth=7
# [12:53:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 174 pruned nodes, max_depth=0
# [12:53:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 254 pruned nodes, max_depth=0
# [12:53:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 194 pruned nodes, max_depth=0
# [12:53:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 182 pruned nodes, max_depth=6
# [12:53:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 164 pruned nodes, max_depth=8
# [12:53:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 216 pruned nodes, max_depth=8
# [12:53:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 212 pruned nodes, max_depth=8
# [12:53:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 200 pruned nodes, max_depth=7
# [12:53:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 150 pruned nodes, max_depth=8
# [12:53:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 212 pruned nodes, max_depth=5
# [12:53:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 210 pruned nodes, max_depth=0
# [12:53:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 210 pruned nodes, max_depth=0
# [12:53:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 248 pruned nodes, max_depth=5
# [12:53:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 312 pruned nodes, max_depth=8
# [12:53:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 192 pruned nodes, max_depth=8
# [12:53:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 248 pruned nodes, max_depth=8
# [12:53:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 218 pruned nodes, max_depth=8
# [12:53:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 230 pruned nodes, max_depth=8
# [12:53:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 206 pruned nodes, max_depth=7
# [12:53:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 252 pruned nodes, max_depth=4
# [12:53:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 224 pruned nodes, max_depth=8
# [12:53:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 216 pruned nodes, max_depth=0
# [12:53:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 222 pruned nodes, max_depth=0
# [12:53:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 252 pruned nodes, max_depth=0
# [12:53:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 214 pruned nodes, max_depth=0
# [12:53:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 258 pruned nodes, max_depth=7
# [12:53:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 252 pruned nodes, max_depth=8
# [12:53:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 208 pruned nodes, max_depth=8
# [12:53:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 182 pruned nodes, max_depth=8
# [12:53:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 196 pruned nodes, max_depth=6
# [12:53:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 172 pruned nodes, max_depth=8
# [12:53:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 214 pruned nodes, max_depth=0
# [12:54:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 256 pruned nodes, max_depth=0
# [12:54:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 162 pruned nodes, max_depth=0
# [12:54:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 180 pruned nodes, max_depth=5
# [12:54:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 140 pruned nodes, max_depth=8
# [12:54:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 186 pruned nodes, max_depth=6
# [12:54:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 174 pruned nodes, max_depth=8
# [12:54:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 106 pruned nodes, max_depth=8
# [12:54:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 136 pruned nodes, max_depth=6
# [12:54:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 320 pruned nodes, max_depth=8
# [12:54:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 274 pruned nodes, max_depth=7
# [12:54:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 202 pruned nodes, max_depth=8
# [12:54:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 146 pruned nodes, max_depth=8
# [12:54:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 278 pruned nodes, max_depth=5
# [12:54:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 276 pruned nodes, max_depth=7
# [12:54:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 282 pruned nodes, max_depth=7
# [12:54:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 284 pruned nodes, max_depth=0
# [12:54:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 288 pruned nodes, max_depth=7
# [12:54:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 220 pruned nodes, max_depth=8
# [12:54:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 216 pruned nodes, max_depth=0
# [12:54:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 226 pruned nodes, max_depth=0
# [12:54:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 164 pruned nodes, max_depth=8
# [12:54:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 162 pruned nodes, max_depth=6
# [12:54:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 160 pruned nodes, max_depth=0
# [12:54:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 182 pruned nodes, max_depth=6
# [12:54:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 160 pruned nodes, max_depth=0
# [12:54:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 174 pruned nodes, max_depth=0
# [12:54:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 196 pruned nodes, max_depth=0
# [12:54:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 156 pruned nodes, max_depth=8
# [12:54:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 268 pruned nodes, max_depth=0
# [12:54:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 214 pruned nodes, max_depth=0
# [12:54:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 234 pruned nodes, max_depth=7
# [12:54:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 216 pruned nodes, max_depth=8
# [12:54:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 192 pruned nodes, max_depth=8
# [12:54:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 266 pruned nodes, max_depth=0
# [12:54:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 256 pruned nodes, max_depth=8
# [12:54:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 262 pruned nodes, max_depth=0
# [12:54:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 98 pruned nodes, max_depth=0
# [12:54:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 174 pruned nodes, max_depth=8
# [12:54:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 194 pruned nodes, max_depth=8
# [12:54:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 188 pruned nodes, max_depth=0
# [12:54:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 192 pruned nodes, max_depth=0
# [12:54:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 172 pruned nodes, max_depth=7
# [12:54:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 214 pruned nodes, max_depth=8
# [12:54:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 328 pruned nodes, max_depth=8
# [12:54:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 292 pruned nodes, max_depth=0
# [12:54:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 138 pruned nodes, max_depth=8
# [12:54:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 198 pruned nodes, max_depth=8
# [12:54:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 256 pruned nodes, max_depth=8
# [12:54:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 238 pruned nodes, max_depth=8
# [12:54:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 174 pruned nodes, max_depth=8
# [12:54:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 160 pruned nodes, max_depth=0
# [12:54:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 182 pruned nodes, max_depth=8
# [12:54:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 208 pruned nodes, max_depth=7
# [12:54:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 204 pruned nodes, max_depth=7
# [12:54:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 286 pruned nodes, max_depth=0
# [12:54:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 166 pruned nodes, max_depth=0
# [12:54:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 256 pruned nodes, max_depth=8
# [12:54:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 250 pruned nodes, max_depth=8
# [12:54:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 210 pruned nodes, max_depth=0
# [12:54:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 248 pruned nodes, max_depth=0
# [12:54:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 238 pruned nodes, max_depth=6
# [12:54:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 276 pruned nodes, max_depth=8
# [12:54:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 242 pruned nodes, max_depth=8
# [12:54:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 238 pruned nodes, max_depth=8
# [12:54:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 214 pruned nodes, max_depth=0
# [12:54:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 286 pruned nodes, max_depth=0
# [12:54:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 318 pruned nodes, max_depth=7
# [12:54:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 226 pruned nodes, max_depth=0
# [12:54:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 188 pruned nodes, max_depth=0
# [12:54:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 212 pruned nodes, max_depth=8
# [12:54:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 126 pruned nodes, max_depth=7
# [12:54:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 264 pruned nodes, max_depth=8
# [12:55:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [12:55:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 190 pruned nodes, max_depth=0
# [12:55:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 156 pruned nodes, max_depth=8
# [12:55:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 204 pruned nodes, max_depth=6
# [12:55:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 274 pruned nodes, max_depth=7
# [12:55:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 194 pruned nodes, max_depth=0
# [12:55:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 182 pruned nodes, max_depth=0
# [12:55:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 170 pruned nodes, max_depth=0
# [12:55:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 256 pruned nodes, max_depth=0
# [12:55:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 264 pruned nodes, max_depth=8
# [12:55:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 176 pruned nodes, max_depth=8
# [12:55:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 302 pruned nodes, max_depth=4
# [12:55:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 240 pruned nodes, max_depth=0
# [12:55:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 262 pruned nodes, max_depth=8
# [12:55:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 132 pruned nodes, max_depth=0
# [12:55:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 228 pruned nodes, max_depth=5
# [12:55:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 140 pruned nodes, max_depth=8
# [12:55:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 212 pruned nodes, max_depth=8
# [12:55:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 160 pruned nodes, max_depth=8
# [12:55:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 170 pruned nodes, max_depth=6
# [12:55:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 182 pruned nodes, max_depth=0
# [12:55:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 204 pruned nodes, max_depth=6
# [12:55:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 222 pruned nodes, max_depth=8
# [12:55:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 224 pruned nodes, max_depth=8
# [12:55:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 256 pruned nodes, max_depth=8
# [12:55:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 316 pruned nodes, max_depth=6
# [12:55:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 202 pruned nodes, max_depth=7
# [12:55:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 244 pruned nodes, max_depth=0
# [12:55:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 150 pruned nodes, max_depth=8
# [12:55:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 240 pruned nodes, max_depth=0
# [12:55:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 234 pruned nodes, max_depth=0
# [12:55:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 182 pruned nodes, max_depth=7
# [12:55:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 278 pruned nodes, max_depth=8
# |  10       |  0.9959   |  5.208    |  0.6505   |  0.9182   |  8.555    |  256.2    |
# =====================================================================================

# %%
# best target so far 0.997457
print(xgb_bo.max)
# Out:
# {'target': 0.9971631999999999, 'params': {'alpha': 5.060902058837366, 'gamma': 0.6154711687038477, 'learning_rate': 0.276567071549648, 'max_depth': 8.977122305112587, 'n_estimators': 257.36589166308926}}

# %% [markdown]
# # XGB models
# Now let's take the parameters selected by the bayesian optimization and apply them in our training and testing.

# %%
max_param = xgb_bo.max['params']
param= {'alpha': max_param['alpha'], 'gamma': max_param['gamma'], 'learning_rate': max_param['learning_rate'], 'max_depth': int(round(max_param['max_depth'],0)), 'n_estimators': int(round(max_param['n_estimators'],0)), 'objective': 'reg:logistic'}

# %%
#To train the algorithm using the parameters selected by bayesian optimization
bst = xgb.train(param, dtrain)
# Out:
# [12:55:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 24 pruned nodes, max_depth=9
# [12:55:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 30 pruned nodes, max_depth=9
# [12:55:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 38 pruned nodes, max_depth=9
# [12:55:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 46 pruned nodes, max_depth=9
# [12:55:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 36 pruned nodes, max_depth=9
# [12:55:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 354 extra nodes, 60 pruned nodes, max_depth=9
# [12:55:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 54 pruned nodes, max_depth=9
# [12:55:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 44 pruned nodes, max_depth=9
# [12:55:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 56 pruned nodes, max_depth=9
# [12:55:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 46 pruned nodes, max_depth=9

# %%
#We apply our model on the training data that was trained on the training data, this helps us to control overfitting
bst1= bst.predict(dtrain)

# %%
# We apply our trained model on test data and store the predictions in a bst_test dataframe
bst_test = pd.DataFrame(data=bst.predict(dtest1),  columns=["xgb_preds"])
y_test=y_test.set_index(np.arange(0,bst_test.shape[0]))
# We also store the MC information in this dataFrame
bst_test['issignal']=y_test['issignal']

# %%
#The following graph will show us that which features are important for the model
ax = xgb.plot_importance(bst)
plt.rcParams['figure.figsize'] = [5, 3]
plt.show()
ax.figure.tight_layout() 
ax.figure.savefig(directory+'img/xgb/feature_importance.pdf')
ax.figure.savefig(directory+'img/xgb/feature_importance.png')

# %% [markdown]
# ## AUC and ROC
#
# The function roc_curve computes the receiver operating characteristic curve, or ROC curve. Quoting Wikipedia :
#
# “A receiver operating characteristic (ROC), or simply ROC curve, is a graphical plot which illustrates the performance of a binary classifier system as its discrimination threshold is varied. It is created by plotting the fraction of true positives out of the positives (TPR = true positive rate) vs. the fraction of false positives out of the negatives (FPR = false positive rate), at various threshold settings. TPR is also known as sensitivity, and FPR is one minus the specificity or true negative rate.”
#
# This function requires the true binary value and the target scores, which can either be probability estimates of the positive class, confidence values, or binary decisions.
#
# Similarly, the function roc_auc_score computes Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.

# %% [markdown]
# To find the best threshold which results more signal to background ratio for lambda candidates we use the parameter S0 called the approximate median significance by the higgs boson  ML challenge (http://higgsml.lal.in2p3.fr/documentation,9.)

# %%
def AMS(y_true, y_predict, y_true1, y_predict1):
    roc_auc=roc_auc_score(y_true, y_predict)
    fpr, tpr, thresholds = roc_curve(y_true, y_predict,drop_intermediate=False ,pos_label=1)
    S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
    S0 = S0[~np.isnan(S0)]
    xi = argmax(S0)
    S0_best_threshold = (thresholds[xi])

    roc_auc1=roc_auc_score(y_true1, y_predict1)
    fpr1, tpr1, thresholds1 = roc_curve(y_true1, y_predict1,drop_intermediate=False ,pos_label=1)
    S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))
    S01 = S01[~np.isnan(S01)]
    xi1 = argmax(S01)
    S0_best_threshold1 = (thresholds[xi1])

    #plotting
    fig, axs = plt.subplots(figsize=(15, 10), dpi = 100)
    plt.plot(fpr, tpr, linestyle=':',color='darkorange',label='ROC curve train (area = %0.4f)' % roc_auc)
    plt.plot(fpr1, tpr1, color='green',label='ROC curve test (area = %0.4f)' % roc_auc1)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.scatter(fpr[xi], tpr[xi], marker='o', color='black', label= 'Best Threshold train set = '+"%.4f" % S0_best_threshold +'\n S0 = '+ "%.2f" % S0[xi])
    plt.scatter(fpr1[xi1], tpr1[xi1], marker='o', color='blue', label= 'Best Threshold test set = '+"%.4f" % S0_best_threshold1 +'\n S0 = '+ "%.2f" % S01[xi1])
    plt.xlabel('False Positive Rate', fontsize = 15)
    plt.ylabel('True Positive Rate', fontsize = 15)
    plt.legend(loc="lower right", fontsize = 15)
    plt.title('Receiver operating characteristic', fontsize = 15)
    plt.xlim([-0.01, 1.0])
    plt.ylim([0, 1.02])
    
    fig.tight_layout()
    plt.show()
    fig.savefig(directory+'img/xgb/ams.pdf')
    fig.savefig(directory+'img/xgb/ams.png')

    return S0_best_threshold, S0_best_threshold1

# %%
train_best, test_best = AMS(y_train, bst1, y_test, bst_test['xgb_preds'])
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_4277/3244003565.py:4: RuntimeWarning: invalid value encountered in true_divide
#   S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_4277/3244003565.py:11: RuntimeWarning: invalid value encountered in true_divide
#   S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))

# %% [markdown]
# When the AUC, best threshold and approximate median significance for train and test are nearly the same, we save that model and use it. This means that our model is general enough. In my opinion, if the test S0 is above 3.0 then it is a good enough model.

# %% [markdown]
# ## Applying the model on the 10k events data-set

# %%
df_clean['xgb_preds'] = bst.predict(dtest)

# %%
df_clean['xgb_preds'].hist(bins=300)
plt.yscale('log')

# %% [markdown]
# ## Confusion Matrix
#
# A **Confusion Matrix** $C$ is such that $C_{ij}$ is equal to the number of observations known to be in group $i$ and predicted to be in group $j$. Thus in binary classification, the count of true positives is $C_{00}$, false negatives $C_{01}$,false positives is $C_{10}$, and true neagtives is $C_{11}$.
#
# If $ y^{'}_{i} $ is the predicted value of the $ i$-th sample and $y_{i}$ is the corresponding true value, then the fraction of correct predictions over $ n_{samples}$ is defined as
# $$
# True \: positives (y,y^{'}) =  \sum_{i=1}^{n_{samples} } 1 (y^{'}_{i} = y_{i}=1)
# $$
#
# The following function prints and plots the confusion matrix. Normalization can be applied by setting `normalize=True`.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
#calculate efficency and false tu tru signal ratio
def confustion_stats(df, cm):
    all_signals = len(df.loc[df['issignal'] == 1])
    true_signal = cm[0][0]
    false_signal = cm[1][0]        
    reconstructed_signals = true_signal + false_signal
    false_to_true_signals = false_signal / true_signal
    efficiency = reconstructed_signals / all_signals * 100 #efficency in % for all
    efficiency_true = true_signal / all_signals * 100 #efficency in % for all
    print("Efficiency: " + str(round(efficiency, 2)) + "%")
    print("Efficiency of true signal candidates reconstruction: " + str(round(efficiency_true, 2)) + "%")
    print("False tu true reconstructed signal ratio: " + str(round(false_to_true_signals, 2)))

# %%
#lets take the best threshold and look at the confusion matrix
cut1 = test_best
df_clean['xgb_preds1'] = ((df_clean['xgb_preds']>cut1)*1)
cnf_matrix = confusion_matrix(y_whole, df_clean['xgb_preds1'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix, classes=['signal','background'], title='Confusion Matrix for XGB for cut > '+str(cut1))
fig.savefig(directory+'img/xgb/confusion_matrix_extreme_gradient_boosting_whole_data.pdf')
fig.savefig(directory+'img/xgb/confusion_matrix_extreme_gradient_boosting_whole_data.png')
# Out:
# Confusion matrix, without normalization
# [[   15524     2846]
#  [    2467 59910522]]

# %%
confustion_stats(df_clean, cnf_matrix)
# Out:
# Efficiency: 97.94%
# Efficiency of true signal candidates reconstruction: 84.51%
# False tu true reconstructed signal ratio: 0.16

# %%
# The following function will display the inavriant mass histogram of the original 10k event set along with the mass histoigram after we apply a cut
# on the probability prediction of xgb
def cut_visualization(cut, range1=(lowerMassCut, upperMassCut), bins1= 300 ):
    mask1 = df_clean['xgb_preds']>cut
    df3=df_clean[mask1]
    
    fig, ax2 = plt.subplots(figsize=(15, 10), dpi = 200)
    color = 'tab:blue'
    ax2.hist(df_clean['mass'],bins = bins1, range=range1, facecolor='blue',alpha = 0.35, label='before selection')
    ax2.set_ylabel('Counts', fontsize = 15, color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.legend( fontsize = 15, loc='upper left')
    
    color = 'tab:red'
    ax1 = ax2.twinx()
    ax1.hist(df3['mass'], bins = bins1, range=range1, facecolor='red',alpha = 0.35, label='XGB')
    ax1.set_xlabel('Mass in GeV', fontsize = 15)
    ax1.set_ylabel('Counts ', fontsize = 15, color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.legend( fontsize = 15,loc='upper right' )

    plt.title("The original sample's Invariant Mass along with mass after selection of XGB (with a cut > "+str(cut)+')', fontsize = 15)
    fig.tight_layout()
    fig.savefig(directory+'img/xgb/whole_sample_invmass_with_ML.pdf')
    fig.savefig(directory+'img/xgb/whole_sample_invmass_with_ML.png')

# %%
cut_visualization(test_best)

# %% [markdown]
# # Comparison with the manually optimized cuts of KFPF
# In the already existing Kalman Filter Particle Finder (KFPF) package for online reconstruction and selection of short-lived particles in CBM, these criteria have been manually optimized. These selection-cuts have been selected to maximize the signal to background ratio (S/B) of the $\Lambda$ for a certain energy on a collisions generator. The selection criteria mainly depends on the collision energy, decay channel and detector configuration.

# %%
#manually selected cuts
manCut_loverdl = 30
manCut_dca = 0.4
manCut_chi2topo = 20
manCut_chi2geo = 12

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
new_check_set= df_clean.copy()
new_check_set['new_signal']=0

mask1 = (new_check_set['loverdl'] > manCut_loverdl) & (new_check_set['distance'] < manCut_dca)

mask2 = (new_check_set['chi2topo'] < manCut_chi2topo) & (new_check_set['chi2geo'] < manCut_chi2geo) 

new_check_set = new_check_set[(mask1) & (mask2)] 

#After all these cuts, what is left is considered as signal, so we replace all the values in the 'new_signal'
# column by 1
new_check_set['new_signal'] = 1
cnf_matrix1 = confusion_matrix(new_check_set['issignal'], new_check_set['new_signal'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix1, classes=['signal','background'], title='Confusion Matrix for manually set cuts')
fig.savefig(directory+'img/xgb/confusion_matrix_for_manually_set_cuts.pdf')
fig.savefig(directory+'img/xgb/confusion_matrix_for_manually_set_cuts.png')
# Out:
# Confusion matrix, without normalization
# [[13611     0]
#  [11898     0]]

# %%
confustion_stats(df_clean, cnf_matrix1)
# Out:
# Efficiency: 138.86%
# Efficiency of true signal candidates reconstruction: 74.09%
# False tu true reconstructed signal ratio: 0.87

# %%
cut3 = test_best
mask1 = df_clean['xgb_preds']>cut3
df3=df_clean[mask1]

# %%
from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=300)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=300)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb/kaon_inv_mass_comparison.pdf')
fig.savefig(directory+'img/xgb/kaon_inv_mass_comparison.png')

# %%
#del x,y,x_test,y_test,x_whole,y_whole,dtest,dtrain,dtest1,df3,df_clean,df_scaled
gc.collect()
# Out:
# 4919

# %% [markdown]
# # Importing the final predictor to root
# We will use the treelite library to transport the final predictor of our model to root

# %%
#install treelite 
import treelite
#create an object out of your model, bst in our case
model = treelite.Model.from_xgboost(bst)
#use GCC compiler
toolchain = 'gcc'
#parallel_comp can be changed upto as many processors as one have
model.export_lib(toolchain=toolchain, libpath='./mymodel.so',
                 params={'parallel_comp': 8}, verbose=True)

# Operating system of the target machine
platform = 'unix'
# C compiler to use to compile prediction code on the target machine
toolchain = 'gcc'
# Save the source package as a zip archive named mymodel.zip
# Later, we'll use this package to produce the library mymodel.so.
model.export_srcpkg(platform=platform, toolchain=toolchain,
                    pkgpath='./mymodel.zip', libname='mymodel.so',
                    verbose=True)
# Out:
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/compiler/ast_native.cc:703: Using ASTNativeCompiler
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/compiler/ast/split.cc:29: Parallel compilation enabled; member trees will be divided into 8 translation units.
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:78: Code generation finished. Writing code to files...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file recipe.json...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file tu4.c...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file tu3.c...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file tu2.c...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file tu1.c...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file tu0.c...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file header.h...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file main.c...
# [12:58:21] /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/treelite/contrib/util.py:105: Compiling sources files in directory ./tmprbqoksxx into object files (*.o)...
# [12:58:21] /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/treelite/contrib/util.py:134: Generating dynamic shared library ./tmprbqoksxx/predictor.dylib...
# [12:58:21] /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/treelite/contrib/__init__.py:282: Generated shared library in 0.39 seconds
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/compiler/ast_native.cc:703: Using ASTNativeCompiler
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/compiler/ast/split.cc:24: Parallel compilation disabled; all member trees will be dumped to a single source file. This may increase compilation time and memory usage.
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:78: Code generation finished. Writing code to files...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file header.h...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file recipe.json...
# [12:58:21] /private/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/pip-install-oxnatwgb/treelite_e3dfb08a68dd4d41abc56837b93249cb/build/temp.macosx-11.1-arm64-3.8/treelite/src/c_api/c_api.cc:83: Writing file main.c...

# %%
# !unzip mymodel.zip
# Out:
# Archive:  mymodel.zip
# replace mymodel/header.h? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
#Build the source package (using GNU Make or NMake).
# %cd mymodel 
# !make

# !ls
# Out:
# /Users/julnow/gsi/cbm/ML/JupyterNotebooks/CBM_ML_Lambda_Library/mymodel
# make: `mymodel.so' is up to date.
# CBM_ML_Lambda_Library main.c                recipe.json
# Makefile              main.o
# header.h              mymodel.so

# %% [markdown]
# If one wants to transfer this model to a different computer, target machine, then one should follow the following commands in command prompt

# %%
sftp john@lxpool.gsi.de
sftp> put mymodel.zip
sftp> quit
# Out:
#   File "/var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_4277/1897124503.py", line 1
#     sftp john@lxpool.gsi.de
#          ^
# SyntaxError: invalid syntax

# %%
ssh john@lxpool.gsi.de
unzip mymodel.zip
cd mymodel
make -j8

# %% [markdown]
# The following C++ code can be the applied as a macro on some new data file

# %%
# %%writefile test.cpp
# #include "TROOT.h"
# #include "TFile.h"
# #include "TTree.h"
# #include "TH1F.h"
# #include <vector>
# #include "TString.h"
# #include "TMath.h"
# #include "TH1.h"
# #include "TF1.h"
# #include "TCanvas.h"
#
# #include <stdio.h>
# #include <stdlib.h>
# #include "main.c"
#
#
#
# void python_to_root(){
#   TCanvas* c1 = new TCanvas();
#   //c1->Divide(2,1);
#
#   //c1->cd(1);
#
#   /* Open the root file*/
#   TFile *f = new TFile("/gdrive/My Drive/presentations/treelite/10k_events_PFSimplePlainTree.root","UPDATE");
#   TTree *t1 = (TTree*)f->Get("PlainTree");
#
#
#   Float_t  LambdaCandidates_chi2primneg, LambdaCandidates_chi2primpos, LambdaCandidates_ldl, LambdaCandidates_distance, LambdaCandidates_chi2geo, LambdaCandidates_mass;
#
#   t1->SetBranchAddress("LambdaCandidates_chi2primneg",&LambdaCandidates_chi2primneg);
#   t1->SetBranchAddress("LambdaCandidates_chi2primpos",&LambdaCandidates_chi2primpos);
#   t1->SetBranchAddress("LambdaCandidates_ldl",&LambdaCandidates_ldl);
#   t1->SetBranchAddress("LambdaCandidates_distance",&LambdaCandidates_distance);
#   t1->SetBranchAddress("LambdaCandidates_chi2geo",&LambdaCandidates_chi2geo);
#   t1->SetBranchAddress("LambdaCandidates_mass",&LambdaCandidates_mass);
#
#
#   std::vector<float> output{};
#
#   const long n_entries = t1->GetEntries();
#   output.reserve(n_entries);
#
#   const size_t n_features = 5;
#   union Entry input[n_features];
#
#   //let's create a new branch which will store the probability returened for each proton-pion pair by our model
#   Float_t probab;
#   TBranch *bpt = t1->Branch("probab",&probab,"probabilities");
#   t1->SetBranchAddress("probab",&probab);
#
#   TH1F *h = new TH1F("h_prob", "This is the #Lambda invariant mass after the cut >0.918080", 300, 1.04, 1.4);
#   h->GetXaxis()->SetTitle("[GeV]");
#
#   for (long i = 0; i < n_entries; i++)
#    {
#      t1->GetEntry(i);
#
#     input[0].fvalue = LambdaCandidates_chi2primneg;
#     input[1].fvalue = LambdaCandidates_chi2primpos;
#     input[2].fvalue = LambdaCandidates_ldl;
#     input[3].fvalue = LambdaCandidates_distance;
#     input[4].fvalue = LambdaCandidates_chi2geo;
#
#     output.push_back(predict(input, 0));
#     probab= output.at(i);
#
#     if(probab > 0.918080){
#     h->Fill(LambdaCandidates_mass);}
#   }
#
#   h->Draw();
#
#
#
# }

# %%
# Installing root
# !mkdir -p APPS
# !pwd
# !cd APPS && wget https://root.cern/download/root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz 
# !cd APPS && tar -xf root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
