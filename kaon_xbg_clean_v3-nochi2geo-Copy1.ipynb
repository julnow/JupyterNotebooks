# %% [markdown]
# Variables of filenames

# %% [markdown]
# Background comes from URQMD, signal from DCM, for test dataset for both bckgr and sign generated in urqmd

# %% [markdown]
# 4:1 background/signal ratio before cleaning, 5M sign, 15k bckgr, 30k ALL, nochi2geo

# %%
#PLAINTREE FILES NAMES
directory='/Users/julnow/gsi/cbm/ML/JupyterNotebooks/'
signalFileName = directory + 'PlainTree_5MSign.root'
#backgroundFileName = directory + 'PlainTree_15kBckgr_URQMD.root'
allFileName = directory + 'PlainTree_30kAll_URQMD.root'

# %%
# %%capture
# !git clone https://github.com/shahidzk1/CBM_ML_Lambda_Library.git
# %cd CBM_ML_Lambda_Library
# !git pull origin main
# !pip install -r requirements.txt
# !python setup.py install

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
#from hipe4ml.model_handler import ModelHandler
#from hipe4ml.tree_handler import TreeHandler
from matplotlib.patches import ConnectionPatch
#from hipe4ml import plot_utils

import xgboost as xgb
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz

from sklearn.model_selection import cross_val_score
from scipy.stats import uniform

from numpy import sqrt, log, argmax

import weakref 
import itertools

from CBM_ML import tree_importer,  KFPF_lambda_cuts, plot_tools
from bayes_opt import BayesianOptimization
from bayes_opt import SequentialDomainReductionTransformer

import gc, os

# %% [markdown]
# # Selecting Background and Signal
# We generate PlainTrees from: 100k events (signal) and 20k evenents (background) with Au-Au @12A GeV/c, DCMQGSM-SMM generator passed through CBM setup in GEANT4, without any cuts
#
# To omit imbalance classification problem (event though there are 5 times more events for background, the number of entries is much smaller for signal) we resample the data. We're deleting instances from the over-represented class (in our case the background) - it's called under-sampling, one of the resampling methods.
#
# So for training and testing we will get signal candidates from the 5 sigma region and  background from outside this region (3 times signal size).

# %%
#CUTS FOR MASS SELECTION
#5 sigma region for signal
lower5SigmaCutSign = 0.43485
upper5SigmaCutSign = 0.56135
#mean invariant mass
invMass = 0.4981
# "5sigma" (not acutal 5 sigma) region for background
lower5SigmaCutBckgr = 0.279
upper5SigmaCutBckgr = 1

# %%
# We import three root files into our jupyter notebook
#sign - before cleaning but after 5sigma seletion, signal - cleaned
#so that we dont have to reimport everything with each change
sign = tree_importer.tree_importer(signalFileName,'PlainTree',7)

# We only select lambda candidates in the 5 sigma region around the kaon mass peak
#we preserve the cleaned dataframe with a changed name
sign = sign[(sign['Candidates_generation']==1) & (sign['Candidates_mass']>lower5SigmaCutSign) & (sign['Candidates_mass']<upper5SigmaCutSign)]

# Similarly for the background, we select background candidates which are not in the 5 sigma region of the kaon peak
bckgr = tree_importer.tree_importer(allFileName,'PlainTree',7)
#we preserve the cleaned dataframe with a changed name
bckgr = bckgr[(bckgr['Candidates_generation'] < 1)
                 & ((bckgr['Candidates_mass'] > lower5SigmaCutBckgr)
                 & (bckgr['Candidates_mass'] < lower5SigmaCutSign) | (bckgr['Candidates_mass']>upper5SigmaCutSign) 
                    & (bckgr['Candidates_mass'] < upper5SigmaCutBckgr))
             ].sample(n=4*(sign.shape[0])) #we select bckgr so that we have 4*more entries that for signal (before cleaning)

#Also call the garbage collector of python to collect unused items to free memory
gc.collect()
# Out:
# 2506

# %%
#we remove name prefixes 'Candidates' and do some renaming
bckgr.columns = bckgr.columns.str.replace('Candidates_', '')
bckgr.columns = bckgr.columns.str.replace('_', '')
sign.columns = sign.columns.str.replace('Candidates_', '')
sign.columns = sign.columns.str.replace('_', '')
#we also get rid of coordinates errors
sign = sign.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
bckgr = bckgr.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
#let's check the name prefixes 
sign.iloc[0:10,:]
# Out:
#     chi2geo  chi2primfirst  chi2primsecond  chi2topo  cosinefirst  \
# 0  1.055125   1.191851e+03    2.418227e+03  1.382537     0.992775
# 1  1.675698   1.191851e+03    2.562767e+00  1.478705     0.992461
# 2  0.884655   7.708000e+05    6.868500e+03  0.525167     0.986342
# 3  0.005968   7.835867e+03    6.868500e+03  1.604101     0.986588
# 4  0.048226   1.085611e+07    9.202689e+05  0.103476     0.928590
# 5  1.564517   1.755055e+06    3.325792e+06  3.620159     0.986431
# 6  0.265824   1.272178e+06    1.287558e+04  6.075241     0.995461
# 7  0.022228   1.088933e+05    6.886050e+06  0.706851     0.992894
# 8  0.339643   1.089560e+05    5.384653e+05  1.219999     0.984684
# 9  0.230005   2.651816e+03    5.384653e+05  0.681214     0.984095
#
#    cosinesecond  cosinetopo  distance       eta          l  ...        pT  \
# 0      0.978738    0.999984  0.010199  1.767213   0.831264  ...  0.858095
# 1      0.979261    0.995678  0.176995  1.760604   0.462111  ...  0.872880
# 2      0.971431    0.999988  0.621583  3.087167   6.618644  ...  0.189899
# 3      0.972632    0.999912  0.122127  3.098664   6.632589  ...  0.185934
# 4      0.993457    1.000000  0.000261  2.737351   7.693739  ...  0.224500
# 5      0.917482    0.999995  0.005039  2.155051   6.028908  ...  0.337338
# 6      0.924863    0.999973  0.357877  2.018910  12.209123  ...  0.487980
# 7      0.945111    0.999997  0.002335  2.561906   4.082486  ...  0.296266
# 8      0.943475    0.999985  0.009880  2.285058   2.682313  ...  0.328416
# 9      0.943596    0.999702  0.039568  2.292220   2.849284  ...  0.322286
#
#         phi        px        py        pz  rapidity         x         y  \
# 0 -1.419017  0.129742 -0.848230  2.438579  1.629621 -0.138814 -0.281002
# 1 -1.416307  0.134315 -0.862485  2.463272  1.624846 -0.118300 -0.178443
# 2 -2.975034 -0.187271 -0.031483  2.076483  2.065397 -0.803517 -0.114543
# 3 -2.957098 -0.182778 -0.034110  2.056715  2.062181 -0.830276 -0.054652
# 4  2.629986 -0.195755  0.109911  1.726547  1.875214 -1.039354  0.486576
# 5  0.300585  0.322212  0.099879  1.435782  1.604478  1.300065  0.455394
# 6  0.198032  0.478443  0.096005  1.804870  1.678201  3.072731  0.596965
# 7  0.904720  0.183064  0.232940  1.908443  1.902381  0.388764  0.523826
# 8  0.141954  0.325112  0.046463  1.596834  1.708246  0.522859  0.109796
# 9  0.141475  0.319066  0.045444  1.578531  1.704835  0.505560  0.086819
#
#            z  issignal
# 0   0.784715       1.0
# 1   0.427863       1.0
# 2   6.589974       1.0
# 3   6.602469       1.0
# 4   7.631403       1.0
# 5   5.872846       1.0
# 6  11.803755       1.0
# 7   4.035477       1.0
# 8   2.630366       1.0
# 9   2.805001       1.0
#
# [10 rows x 23 columns]

# %% [markdown]
# The label 'issignal' tells us if an entry comes from signal (1) or background (0)

# %% [markdown]
# # Data Cleaning
# Sometimes a data set contains entries which are outliers or does not make sense. For example, infinite values or NaN entries. We clean the data by removing these entries.
#
# Similarly, CBM is a fixed target experiment so there are certain conditions which the data has to satisfy before it is considered as reliable data.So we apply certain limits on the data sets.
#
# The values of these cuts are described: https://drive.google.com/file/d/1tb0FBRq4KgVu-VQZgpjA8ONbIGVCNOnE/view?usp=sharing https://github.com/julnow/JupyterNotebooks/blob/kaon/CBM%20K-short%20data%20cleaning.pdf

# %%
#CUTS USED FOR DATA CLEANING
#mass cuts for both bckgr and sign
lowerMassCut = 0.279
upperMassCut = 1
#distance cuts
#DCA
lowerDcaCut = 0
upperDcaCut = 100
#l distance
lowerLCut = -5
upperLCut = 80
#loverdl
lowerLdlCut = -25
upperLdlCut = 15000
#coordinate cuts
absXCut = 50
absYCut = 50
lowerZCut = -1
upperZCut = 80
#momentums cuts
pzLowerCut = 0
pUpperCut = 20
ptUpperCut = 3
#chi2
#geo
lowerChi2GeoCut = 0
upperChi2GeoCut = 10000
#topo
lowerChi2TopoCut = 0
upperChi2TopoCut = 100000
#prim first
lowerChi2PrimFirstCut = 0
upperChi2PrimFirstCut = 3e7
#prim second
lowerChi2PrimSecondCut = 0
upperChi2PrimSecondCut = 3e7
#pseudorapidity cuts
lowerEtaCut = 1.
upperEtaCut = 6.5

# %%
def clean_df(df):
    # let's treat all the infinite, inf, values by nan and then we drop all the null entries
    with pd.option_context('mode.use_inf_as_na', True):
        df = df.dropna()
    #Experimental constraints
    is_good_mom = (df['pz'] > pzLowerCut) & (df['p']<pUpperCut) & (df['pT']<ptUpperCut)
    is_good_coord = (abs(df['x']) < absXCut) & (abs(df['y']) < absYCut) & (df['z']>lowerZCut) & (df['z']<upperZCut)
    is_good_params = (df['distance'] > lowerDcaCut) & (df['distance'] < upperDcaCut) & (df['chi2geo']>lowerChi2GeoCut) & (df['chi2geo'] < upperChi2GeoCut) & (df['chi2topo'] > lowerChi2TopoCut) & (df['chi2topo'] < upperChi2TopoCut) & (df['eta']>lowerEtaCut) & (df['eta']<upperEtaCut)& (df['l']>lowerLCut) & (df['l']<upperLCut) & (df['loverdl']>lowerLdlCut) & (df['loverdl']<upperLdlCut)
    is_good_daughters = (df['chi2primfirst']>lowerChi2PrimFirstCut) & (df['chi2primfirst'] < upperChi2PrimSecondCut) & (df['chi2primsecond']>lowerChi2PrimSecondCut) & (df['chi2primsecond']<upperChi2PrimFirstCut)
    is_good_mass = (df['mass']>lowerMassCut) & (df['mass']<upperMassCut)

    is_good_df = (is_good_mom) & (is_good_coord) & (is_good_params) & (is_good_daughters) & (is_good_mass)

    return df[is_good_df]

# %%
background = clean_df(bckgr)
signal = clean_df(sign)
print('size of:\nsignal: ' + str(len(signal)) + '\nbackground: ' + str(len(background)) 
      + '\nbackground to signal ratio: ' + str(round(len(background)/len(signal), 1)))
del sign, bckgr
# Out:
# size of:
# signal: 4521056
# background: 16713310
# background to signal ratio: 3.7

# %% [markdown]
# We'll also import and clean dataset of 10k events for both background and signal (for testing our algorhitm)

# %%
#Let's combine signal and background
df_scaled = pd.concat([signal, background])
del signal, background
gc.collect()
# Out:
# 22

# %% [markdown]
# # Selecting Background and Signal
# After cleaning, our training data set contains 450442 background candidates and 1638402 signal candidates (background to signal ratio $\approx 3.6$). For testing, we'll use cleaned dataset containing 28740227 entries of signal and background (background to signal ratio $\approx 1985.1$)
#
# Here, we use under-sampling to tackle the problem with the classification of underrepresented class (normally, the signal is only approx. 0.05% of real data)

# %%
if not os.path.exists(directory+'img/xgb_v3_nochi2geo'):
    os.makedirs(directory+'img/xgb_v3_nochi2geo')
#lets draw sign to background ratio
def plt_sig_back(df):
    range1 = (lowerMassCut, upperMassCut)
    fig, axs = plt.subplots(figsize=(20, 10))
    #df_scaled['mass'].plot.hist(bins = 300, range=range1,grid=True,sharey=True)
    (df[df['issignal']==0])['mass'].plot.hist(bins = 300, facecolor='yellow',grid=True,range=range1, label='Background')
    (df[df['issignal']==1])['mass'].plot.hist(bins = 300, facecolor='magenta',grid=True, range=range1, label ='Signal')
    #plt.vlines(x=1.108,ymin=-1,ymax=48000, color='black', linestyle='-')
    #plt.vlines(x=1.1227,ymin=-1,ymax=48000, color='black', linestyle='-')
    plt.ylabel("Counts (log scale)", fontsize=15)
    plt.xlabel("Mass in GeV/$c^2$", fontsize= 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.title('Test and Train K-short Invariant Mass', fontsize = 15)
    plt.legend( fontsize = 15)
    axs.tick_params(axis='both', which='major', labelsize=18)
    plt.yscale("log")
    fig.tight_layout()
    fig.savefig(directory+'img/xgb_v3_nochi2geo/inv_mass_trainset.pdf')
    fig.savefig(directory+'img/xgb_v3_nochi2geo/inv_mass_trainset.png')

# %%
plt_sig_back(df_scaled)
gc.collect()
# Out:
# 0

# %% [markdown]
# # Creating Train and Test sets
# To make machine learning algorithms more efficient on unseen data we divide our data into two sets. One set is for training the algorithm and the other is for testing the algorithm. If we don't do this then the algorithm can overfit and we will not capture the general trends in the data.

# %%
# The following columns will be used to predict whether a reconstructed candidate is a lambda particle or not
cuts = [ 'loverdl', 'distance', 'chi2topo', 'chi2primfirst', 'chi2primsecond']#'chi2geo', 


x = df_scaled[cuts].copy()

# The MC information is saved in this y variable
y =pd.DataFrame(df_scaled['issignal'], dtype='int')

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=324)
del df_scaled, x, y

#DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed. 
dtrain = xgb.DMatrix(x_train, label = y_train)
dtest1=xgb.DMatrix(x_test, label = y_test)
del x_train, x_test
gc.collect()
# Out:
# 44635

# %% [markdown]
# ## Bayesian optimization
# In order to find the best parameters of XGB for our data we use Bayesian optimization. Grid search and and random search could also do the same job but bayesian is more time efficient. For further reading visit [the git page](https://github.com/fmfn/BayesianOptimization) of the bayesian optimization used here.
#
# ### Hyper parameters
# Some of the following hyper parameters will be tuned for our algorithm:
#
#
# *subsample* [default=1]
# Subsample ratio of the training instances. Setting it to 0.5 means that XGBoost would randomly sample half of the training data prior to growing trees. and this will prevent overfitting. Subsampling will occur once in every boosting iteration.
# range: (0,1]
#
# *eta* [default=0.3, alias: learning_rate]
# Step size shrinkage used in update to prevents overfitting. After each boosting step, we can directly get the weights of new features, and eta shrinks the feature weights to make the boosting process more conservative.
# range: [0,1]
#
#
# *gamma* [default=0, alias: min_split_loss]
# Minimum loss reduction required to make a further partition on a leaf node of the tree. The larger gamma is, the more conservative the algorithm will be.
# range: [0,∞]
#
#
# *alpha* [default=0, alias: reg_alpha]
# L1 regularization term on weights. Increasing this value will make model more conservative.
#
# *Lasso Regression* (Least Absolute Shrinkage and Selection Operator) adds “absolute value of magnitude” of coefficient as penalty term to the loss function.

# %%
#Bayesian Optimization function for xgboost
#specify the parameters you want to tune as keyword arguments
def bo_tune_xgb(max_depth, gamma, alpha, n_estimators ,learning_rate):
    params = {'max_depth': int(max_depth),
              'gamma': gamma,
              'alpha':alpha,
              'n_estimators': n_estimators,
              'learning_rate':learning_rate,
              'subsample': 0.8,
              'eta': 0.1,
              'eval_metric': 'auc', 'nthread' : 15}
    cv_result = xgb.cv(params, dtrain, num_boost_round=70, nfold=5)
    return  cv_result['test-auc-mean'].iloc[-1]

bounds_transformer = SequentialDomainReductionTransformer()

# %%
#Invoking the Bayesian Optimizer with the specified parameters to tune
xgb_bo = BayesianOptimization(bo_tune_xgb, {'max_depth': (6, 16),
                                             'gamma': (0, 1),
                                            'alpha': (2,12),
                                             'learning_rate':(0,.5),
                                             'n_estimators':(300,1000)
                                            },
                             bounds_transformer=bounds_transformer)

# %%
#performing Bayesian optimization for 5 iterations with 8 steps of random exploration with an #acquisition function of expected improvement
xgb_bo.maximize(n_iter=5, init_points=5)
# Out:
# |   iter    |  target   |   alpha   |   gamma   | learni... | max_depth | n_esti... |
# -------------------------------------------------------------------------------------
# [01:06:09] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [01:06:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 604 extra nodes, 4 pruned nodes, max_depth=9
# [01:06:31] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [01:06:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 618 extra nodes, 8 pruned nodes, max_depth=9
# [01:06:54] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [01:07:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 600 extra nodes, 10 pruned nodes, max_depth=9
# [01:07:17] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [01:07:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 606 extra nodes, 4 pruned nodes, max_depth=9
# [01:07:40] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [01:08:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 594 extra nodes, 6 pruned nodes, max_depth=9
# [01:08:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 592 extra nodes, 8 pruned nodes, max_depth=9
# [01:08:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 596 extra nodes, 10 pruned nodes, max_depth=9
# [01:08:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 544 extra nodes, 2 pruned nodes, max_depth=9
# [01:09:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 574 extra nodes, 10 pruned nodes, max_depth=9
# [01:09:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 592 extra nodes, 2 pruned nodes, max_depth=9
# [01:09:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 556 extra nodes, 8 pruned nodes, max_depth=9
# [01:10:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 562 extra nodes, 4 pruned nodes, max_depth=9
# [01:10:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 6 pruned nodes, max_depth=9
# [01:10:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 4 pruned nodes, max_depth=9
# [01:10:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 526 extra nodes, 6 pruned nodes, max_depth=9
# [01:11:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 518 extra nodes, 8 pruned nodes, max_depth=9
# [01:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 18 pruned nodes, max_depth=9
# [01:11:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 526 extra nodes, 12 pruned nodes, max_depth=9
# [01:11:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 14 pruned nodes, max_depth=9
# [01:12:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 494 extra nodes, 14 pruned nodes, max_depth=9
# [01:12:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 18 pruned nodes, max_depth=9
# [01:12:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 18 pruned nodes, max_depth=9
# [01:13:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 12 pruned nodes, max_depth=9
# [01:13:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 10 pruned nodes, max_depth=9
# [01:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 494 extra nodes, 14 pruned nodes, max_depth=9
# [01:13:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 14 pruned nodes, max_depth=9
# [01:14:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 492 extra nodes, 26 pruned nodes, max_depth=9
# [01:14:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 20 pruned nodes, max_depth=9
# [01:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 466 extra nodes, 18 pruned nodes, max_depth=9
# [01:15:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 24 pruned nodes, max_depth=9
# [01:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 30 pruned nodes, max_depth=9
# [01:15:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 10 pruned nodes, max_depth=9
# [01:15:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 466 extra nodes, 26 pruned nodes, max_depth=9
# [01:16:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 22 pruned nodes, max_depth=9
# [01:16:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 40 pruned nodes, max_depth=9
# [01:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 12 pruned nodes, max_depth=9
# [01:17:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 42 pruned nodes, max_depth=9
# [01:17:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 28 pruned nodes, max_depth=9
# [01:17:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 20 pruned nodes, max_depth=9
# [01:18:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 30 pruned nodes, max_depth=9
# [01:18:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 38 pruned nodes, max_depth=9
# [01:18:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 26 pruned nodes, max_depth=9
# [01:19:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 498 extra nodes, 34 pruned nodes, max_depth=9
# [01:19:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 52 pruned nodes, max_depth=9
# [01:19:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 38 pruned nodes, max_depth=9
# [01:20:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 46 pruned nodes, max_depth=9
# [01:20:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 50 pruned nodes, max_depth=9
# [01:20:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 52 pruned nodes, max_depth=9
# [01:20:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 26 pruned nodes, max_depth=9
# [01:21:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 44 pruned nodes, max_depth=9
# [01:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 76 pruned nodes, max_depth=9
# [01:21:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 58 pruned nodes, max_depth=9
# [01:22:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 42 pruned nodes, max_depth=9
# [01:22:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 72 pruned nodes, max_depth=9
# [01:22:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 60 pruned nodes, max_depth=9
# [01:23:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 66 pruned nodes, max_depth=9
# [01:23:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 54 pruned nodes, max_depth=9
# [01:23:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 66 pruned nodes, max_depth=9
# [01:24:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 466 extra nodes, 52 pruned nodes, max_depth=9
# [01:24:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 78 pruned nodes, max_depth=9
# [01:24:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 60 pruned nodes, max_depth=9
# [01:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 98 pruned nodes, max_depth=9
# [01:25:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 88 pruned nodes, max_depth=9
# [01:25:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 58 pruned nodes, max_depth=9
# [01:26:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 72 pruned nodes, max_depth=9
# [01:26:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 94 pruned nodes, max_depth=9
# [01:26:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 60 pruned nodes, max_depth=9
# [01:27:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 464 extra nodes, 106 pruned nodes, max_depth=9
# [01:27:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 116 pruned nodes, max_depth=9
# [01:27:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 102 pruned nodes, max_depth=9
# [01:28:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 90 pruned nodes, max_depth=9
# [01:28:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 134 pruned nodes, max_depth=9
# [01:28:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 108 pruned nodes, max_depth=9
# [01:29:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 78 pruned nodes, max_depth=9
# [01:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 70 pruned nodes, max_depth=9
# [01:30:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 504 extra nodes, 122 pruned nodes, max_depth=9
# [01:30:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 548 extra nodes, 114 pruned nodes, max_depth=9
# [01:30:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 94 pruned nodes, max_depth=9
# [01:31:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 106 pruned nodes, max_depth=9
# [01:31:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 144 pruned nodes, max_depth=9
# [01:31:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 92 pruned nodes, max_depth=9
# [01:32:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 164 pruned nodes, max_depth=9
# [01:32:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 116 pruned nodes, max_depth=9
# [01:32:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 60 pruned nodes, max_depth=9
# [01:33:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 152 pruned nodes, max_depth=9
# [01:33:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 126 pruned nodes, max_depth=9
# [01:33:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 112 pruned nodes, max_depth=9
# [01:34:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 128 pruned nodes, max_depth=9
# [01:34:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 96 pruned nodes, max_depth=9
# [01:34:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 112 pruned nodes, max_depth=9
# [01:35:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 138 pruned nodes, max_depth=9
# [01:35:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 94 pruned nodes, max_depth=9
# [01:35:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 96 pruned nodes, max_depth=9
# [01:36:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 152 pruned nodes, max_depth=9
# [01:36:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 136 pruned nodes, max_depth=9
# [01:36:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 524 extra nodes, 138 pruned nodes, max_depth=9
# [01:37:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 170 pruned nodes, max_depth=9
# [01:37:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 146 pruned nodes, max_depth=9
# [01:37:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 100 pruned nodes, max_depth=9
# [01:38:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 142 pruned nodes, max_depth=9
# [01:38:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 486 extra nodes, 200 pruned nodes, max_depth=9
# [01:39:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 224 pruned nodes, max_depth=9
# [01:39:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 76 pruned nodes, max_depth=9
# [01:39:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 106 pruned nodes, max_depth=9
# [01:39:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 224 pruned nodes, max_depth=9
# [01:40:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 82 pruned nodes, max_depth=9
# [01:40:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 94 pruned nodes, max_depth=9
# [01:40:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 54 pruned nodes, max_depth=9
# [01:41:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 176 pruned nodes, max_depth=9
# [01:41:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 70 pruned nodes, max_depth=9
# [01:41:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 58 pruned nodes, max_depth=9
# [01:42:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 118 pruned nodes, max_depth=9
# [01:42:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 116 pruned nodes, max_depth=9
# [01:42:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 64 pruned nodes, max_depth=9
# [01:43:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 184 pruned nodes, max_depth=9
# [01:43:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 90 pruned nodes, max_depth=9
# [01:43:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 116 pruned nodes, max_depth=9
# [01:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 98 pruned nodes, max_depth=9
# [01:44:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 102 pruned nodes, max_depth=9
# [01:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 116 pruned nodes, max_depth=9
# [01:45:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 60 pruned nodes, max_depth=9
# [01:45:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 48 pruned nodes, max_depth=9
# [01:45:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 396 extra nodes, 118 pruned nodes, max_depth=9
# [01:46:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 114 pruned nodes, max_depth=9
# [01:46:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 46 pruned nodes, max_depth=9
# [01:46:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 134 pruned nodes, max_depth=9
# [01:47:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 206 pruned nodes, max_depth=9
# [01:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 184 pruned nodes, max_depth=9
# [01:47:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 114 pruned nodes, max_depth=9
# [01:48:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 104 pruned nodes, max_depth=9
# [01:48:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 90 pruned nodes, max_depth=9
# [01:48:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 158 pruned nodes, max_depth=9
# [01:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 86 pruned nodes, max_depth=9
# [01:49:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 130 pruned nodes, max_depth=9
# [01:49:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 108 pruned nodes, max_depth=9
# [01:50:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 148 pruned nodes, max_depth=9
# [01:50:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 86 pruned nodes, max_depth=9
# [01:50:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 66 pruned nodes, max_depth=9
# [01:51:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 262 pruned nodes, max_depth=9
# [01:51:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 156 pruned nodes, max_depth=9
# [01:51:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 166 pruned nodes, max_depth=9
# [01:52:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 56 pruned nodes, max_depth=9
# [01:52:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 148 pruned nodes, max_depth=9
# [01:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 110 pruned nodes, max_depth=9
# [01:53:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 146 pruned nodes, max_depth=9
# [01:53:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 122 pruned nodes, max_depth=9
# [01:53:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 132 pruned nodes, max_depth=9
# [01:54:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 94 pruned nodes, max_depth=9
# [01:54:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 68 pruned nodes, max_depth=9
# [01:54:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 160 pruned nodes, max_depth=9
# [01:55:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 200 pruned nodes, max_depth=9
# [01:55:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 154 pruned nodes, max_depth=9
# [01:55:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 124 pruned nodes, max_depth=9
# [01:56:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 156 pruned nodes, max_depth=9
# [01:56:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 210 pruned nodes, max_depth=9
# [01:56:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 234 pruned nodes, max_depth=9
# [01:57:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 162 pruned nodes, max_depth=9
# [01:57:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 166 pruned nodes, max_depth=9
# [01:57:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 206 pruned nodes, max_depth=9
# [01:58:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 116 pruned nodes, max_depth=9
# [01:58:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 78 pruned nodes, max_depth=9
# [01:58:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 74 pruned nodes, max_depth=9
# [01:59:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 58 pruned nodes, max_depth=9
# [01:59:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 132 pruned nodes, max_depth=9
# [01:59:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 44 pruned nodes, max_depth=9
# [02:00:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 126 pruned nodes, max_depth=9
# [02:00:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 180 pruned nodes, max_depth=9
# [02:00:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 94 pruned nodes, max_depth=9
# [02:00:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 104 pruned nodes, max_depth=9
# [02:01:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 144 pruned nodes, max_depth=9
# [02:01:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 110 pruned nodes, max_depth=9
# [02:02:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 122 pruned nodes, max_depth=9
# [02:02:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 82 pruned nodes, max_depth=9
# [02:02:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 152 pruned nodes, max_depth=9
# [02:02:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 78 pruned nodes, max_depth=9
# [02:03:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 144 pruned nodes, max_depth=9
# [02:03:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 186 pruned nodes, max_depth=9
# [02:03:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 102 pruned nodes, max_depth=9
# [02:04:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 96 pruned nodes, max_depth=9
# [02:04:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 182 pruned nodes, max_depth=9
# [02:04:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 84 pruned nodes, max_depth=9
# [02:05:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 152 pruned nodes, max_depth=9
# [02:05:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 80 pruned nodes, max_depth=9
# [02:05:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 88 pruned nodes, max_depth=9
# [02:06:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 106 pruned nodes, max_depth=9
# [02:06:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 246 pruned nodes, max_depth=9
# [02:06:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 164 pruned nodes, max_depth=9
# [02:07:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 172 pruned nodes, max_depth=9
# [02:07:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 134 pruned nodes, max_depth=9
# [02:07:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 176 pruned nodes, max_depth=9
# [02:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 152 pruned nodes, max_depth=9
# [02:08:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 118 pruned nodes, max_depth=9
# [02:08:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 114 pruned nodes, max_depth=9
# [02:09:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 150 pruned nodes, max_depth=9
# [02:09:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 110 pruned nodes, max_depth=9
# [02:09:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 142 pruned nodes, max_depth=9
# [02:10:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 86 pruned nodes, max_depth=9
# [02:10:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 90 pruned nodes, max_depth=9
# [02:10:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 106 pruned nodes, max_depth=9
# [02:11:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 112 pruned nodes, max_depth=9
# [02:11:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 162 pruned nodes, max_depth=9
# [02:11:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 78 pruned nodes, max_depth=9
# [02:12:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 112 pruned nodes, max_depth=9
# [02:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 230 pruned nodes, max_depth=9
# [02:12:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 104 pruned nodes, max_depth=9
# [02:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 162 pruned nodes, max_depth=9
# [02:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 110 pruned nodes, max_depth=9
# [02:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 180 pruned nodes, max_depth=9
# [02:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 186 pruned nodes, max_depth=9
# [02:14:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 84 pruned nodes, max_depth=9
# [02:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 40 pruned nodes, max_depth=9
# [02:15:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 190 pruned nodes, max_depth=9
# [02:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 182 pruned nodes, max_depth=9
# [02:15:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 120 pruned nodes, max_depth=9
# [02:16:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 114 pruned nodes, max_depth=9
# [02:16:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 74 pruned nodes, max_depth=9
# [02:16:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 86 pruned nodes, max_depth=9
# [02:17:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 82 pruned nodes, max_depth=9
# [02:17:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 112 pruned nodes, max_depth=9
# [02:17:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 120 pruned nodes, max_depth=9
# [02:18:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 160 pruned nodes, max_depth=9
# [02:18:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 116 pruned nodes, max_depth=9
# [02:18:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 82 pruned nodes, max_depth=9
# [02:19:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 160 pruned nodes, max_depth=9
# [02:19:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 92 pruned nodes, max_depth=9
# [02:19:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 174 pruned nodes, max_depth=9
# [02:20:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 80 pruned nodes, max_depth=9
# [02:20:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 130 pruned nodes, max_depth=9
# [02:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 180 pruned nodes, max_depth=9
# [02:21:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 58 pruned nodes, max_depth=9
# [02:21:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 76 pruned nodes, max_depth=9
# [02:21:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 114 pruned nodes, max_depth=9
# [02:22:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 108 pruned nodes, max_depth=9
# [02:22:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 90 pruned nodes, max_depth=9
# [02:22:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 132 pruned nodes, max_depth=9
# [02:23:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 260 pruned nodes, max_depth=9
# [02:23:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 92 pruned nodes, max_depth=9
# [02:23:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 108 pruned nodes, max_depth=9
# [02:24:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 124 pruned nodes, max_depth=9
# [02:24:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 116 pruned nodes, max_depth=9
# [02:24:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 106 pruned nodes, max_depth=9
# [02:25:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 216 pruned nodes, max_depth=9
# [02:25:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 186 pruned nodes, max_depth=9
# [02:25:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 110 pruned nodes, max_depth=9
# [02:26:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 76 pruned nodes, max_depth=9
# [02:26:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 112 pruned nodes, max_depth=9
# [02:27:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 148 pruned nodes, max_depth=9
# [02:27:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 112 pruned nodes, max_depth=9
# [02:27:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 94 pruned nodes, max_depth=9
# [02:27:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 144 pruned nodes, max_depth=9
# [02:28:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 124 pruned nodes, max_depth=9
# [02:28:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 106 pruned nodes, max_depth=9
# [02:29:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 118 pruned nodes, max_depth=9
# [02:29:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 140 pruned nodes, max_depth=9
# [02:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 110 pruned nodes, max_depth=9
# [02:30:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 84 pruned nodes, max_depth=9
# [02:30:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 72 pruned nodes, max_depth=9
# [02:30:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 154 pruned nodes, max_depth=9
# [02:30:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 72 pruned nodes, max_depth=9
# [02:31:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 82 pruned nodes, max_depth=9
# [02:31:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 212 pruned nodes, max_depth=9
# [02:32:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 212 pruned nodes, max_depth=9
# [02:32:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 114 pruned nodes, max_depth=9
# [02:32:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 122 pruned nodes, max_depth=9
# [02:32:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 136 pruned nodes, max_depth=9
# [02:33:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 138 pruned nodes, max_depth=9
# [02:33:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 128 pruned nodes, max_depth=9
# [02:33:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 286 extra nodes, 114 pruned nodes, max_depth=9
# [02:34:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 176 pruned nodes, max_depth=9
# [02:34:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 104 pruned nodes, max_depth=9
# [02:34:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 90 pruned nodes, max_depth=9
# [02:35:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 94 pruned nodes, max_depth=9
# [02:35:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 136 pruned nodes, max_depth=9
# [02:35:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 96 pruned nodes, max_depth=9
# [02:36:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 228 pruned nodes, max_depth=9
# [02:36:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 138 pruned nodes, max_depth=9
# [02:36:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 110 pruned nodes, max_depth=9
# [02:37:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 120 pruned nodes, max_depth=9
# [02:37:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 66 pruned nodes, max_depth=9
# [02:37:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 128 pruned nodes, max_depth=9
# [02:38:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 122 pruned nodes, max_depth=9
# [02:38:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 160 pruned nodes, max_depth=9
# [02:38:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 128 pruned nodes, max_depth=9
# [02:39:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 140 pruned nodes, max_depth=9
# [02:39:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 220 pruned nodes, max_depth=9
# [02:39:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 110 pruned nodes, max_depth=9
# [02:40:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 62 pruned nodes, max_depth=9
# [02:40:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 154 pruned nodes, max_depth=9
# [02:40:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 106 pruned nodes, max_depth=9
# [02:40:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 54 pruned nodes, max_depth=9
# [02:41:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 104 pruned nodes, max_depth=9
# [02:41:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 128 pruned nodes, max_depth=9
# [02:41:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 82 pruned nodes, max_depth=9
# [02:42:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 174 pruned nodes, max_depth=9
# [02:42:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 114 pruned nodes, max_depth=9
# [02:43:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 216 pruned nodes, max_depth=9
# [02:43:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 184 pruned nodes, max_depth=9
# [02:43:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 108 pruned nodes, max_depth=9
# [02:43:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 84 pruned nodes, max_depth=9
# [02:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 188 pruned nodes, max_depth=9
# [02:44:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 156 pruned nodes, max_depth=9
# [02:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 116 pruned nodes, max_depth=9
# [02:45:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 44 pruned nodes, max_depth=9
# [02:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 94 pruned nodes, max_depth=9
# [02:45:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 144 pruned nodes, max_depth=9
# [02:46:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 118 pruned nodes, max_depth=9
# [02:46:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 152 pruned nodes, max_depth=9
# [02:46:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 110 pruned nodes, max_depth=9
# [02:47:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 160 pruned nodes, max_depth=9
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 116 pruned nodes, max_depth=9
# [02:47:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 306 extra nodes, 130 pruned nodes, max_depth=9
# [02:48:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 50 pruned nodes, max_depth=9
# [02:48:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 62 pruned nodes, max_depth=9
# [02:48:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 136 pruned nodes, max_depth=9
# [02:49:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 146 pruned nodes, max_depth=9
# [02:49:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 136 pruned nodes, max_depth=9
# [02:49:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 166 pruned nodes, max_depth=9
# [02:50:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 62 pruned nodes, max_depth=9
# [02:50:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 102 pruned nodes, max_depth=9
# [02:50:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 108 pruned nodes, max_depth=9
# [02:51:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 126 pruned nodes, max_depth=9
# [02:51:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 84 pruned nodes, max_depth=9
# [02:51:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 134 pruned nodes, max_depth=9
# [02:52:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 128 pruned nodes, max_depth=9
# [02:52:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 88 pruned nodes, max_depth=9
# [02:52:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 96 pruned nodes, max_depth=9
# [02:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 138 pruned nodes, max_depth=9
# [02:53:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 114 pruned nodes, max_depth=9
# [02:53:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 114 pruned nodes, max_depth=9
# [02:54:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 124 pruned nodes, max_depth=9
# [02:54:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 126 pruned nodes, max_depth=9
# [02:54:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 118 pruned nodes, max_depth=9
# [02:55:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 188 pruned nodes, max_depth=9
# [02:55:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 82 pruned nodes, max_depth=9
# [02:55:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 216 pruned nodes, max_depth=9
# [02:56:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 124 pruned nodes, max_depth=9
# [02:56:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 142 pruned nodes, max_depth=9
# [02:56:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 174 pruned nodes, max_depth=9
# [02:56:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 128 pruned nodes, max_depth=9
# [02:57:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 190 pruned nodes, max_depth=9
# [02:57:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 106 pruned nodes, max_depth=9
# [02:58:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 136 pruned nodes, max_depth=9
# [02:58:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 96 pruned nodes, max_depth=9
# [02:58:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 136 pruned nodes, max_depth=9
# [02:58:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 122 pruned nodes, max_depth=9
# [02:59:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 86 pruned nodes, max_depth=9
# [02:59:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 112 pruned nodes, max_depth=9
# [02:59:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 134 pruned nodes, max_depth=9
# [03:00:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 108 pruned nodes, max_depth=9
# [03:00:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 110 pruned nodes, max_depth=9
# |  1        |  0.9973   |  9.896    |  0.06011  |  0.3369   |  9.337    |  690.4    |
# [03:01:03] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [03:01:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1140 extra nodes, 200 pruned nodes, max_depth=11
# [03:01:27] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [03:01:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1146 extra nodes, 188 pruned nodes, max_depth=11
# [03:01:51] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [03:02:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1168 extra nodes, 198 pruned nodes, max_depth=11
# [03:02:15] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [03:02:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1146 extra nodes, 186 pruned nodes, max_depth=11
# [03:02:40] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [03:03:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1120 extra nodes, 190 pruned nodes, max_depth=11
# [03:03:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1128 extra nodes, 236 pruned nodes, max_depth=11
# [03:03:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1150 extra nodes, 210 pruned nodes, max_depth=11
# [03:04:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1096 extra nodes, 254 pruned nodes, max_depth=11
# [03:04:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1116 extra nodes, 260 pruned nodes, max_depth=11
# [03:04:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1096 extra nodes, 168 pruned nodes, max_depth=11
# [03:05:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1126 extra nodes, 230 pruned nodes, max_depth=11
# [03:05:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1170 extra nodes, 242 pruned nodes, max_depth=11
# [03:05:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1134 extra nodes, 262 pruned nodes, max_depth=11
# [03:05:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1098 extra nodes, 292 pruned nodes, max_depth=11
# [03:06:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1116 extra nodes, 264 pruned nodes, max_depth=11
# [03:06:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1098 extra nodes, 244 pruned nodes, max_depth=11
# [03:06:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1106 extra nodes, 256 pruned nodes, max_depth=11
# [03:07:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1078 extra nodes, 272 pruned nodes, max_depth=11
# [03:07:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1104 extra nodes, 254 pruned nodes, max_depth=11
# [03:07:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1052 extra nodes, 262 pruned nodes, max_depth=11
# [03:08:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1064 extra nodes, 280 pruned nodes, max_depth=11
# [03:08:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1072 extra nodes, 274 pruned nodes, max_depth=11
# [03:08:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1084 extra nodes, 292 pruned nodes, max_depth=11
# [03:09:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1054 extra nodes, 264 pruned nodes, max_depth=11
# [03:09:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1078 extra nodes, 228 pruned nodes, max_depth=11
# [03:09:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1004 extra nodes, 274 pruned nodes, max_depth=11
# [03:10:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1002 extra nodes, 322 pruned nodes, max_depth=11
# [03:10:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 982 extra nodes, 282 pruned nodes, max_depth=11
# [03:10:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1042 extra nodes, 284 pruned nodes, max_depth=11
# [03:11:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1026 extra nodes, 310 pruned nodes, max_depth=11
# [03:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 996 extra nodes, 338 pruned nodes, max_depth=11
# [03:11:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1002 extra nodes, 282 pruned nodes, max_depth=11
# [03:12:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1026 extra nodes, 308 pruned nodes, max_depth=11
# [03:12:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1022 extra nodes, 284 pruned nodes, max_depth=11
# [03:12:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 970 extra nodes, 314 pruned nodes, max_depth=11
# [03:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1008 extra nodes, 348 pruned nodes, max_depth=11
# [03:13:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 980 extra nodes, 276 pruned nodes, max_depth=11
# [03:13:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1008 extra nodes, 310 pruned nodes, max_depth=11
# [03:14:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 948 extra nodes, 272 pruned nodes, max_depth=11
# [03:14:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 950 extra nodes, 312 pruned nodes, max_depth=11
# [03:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 918 extra nodes, 296 pruned nodes, max_depth=11
# [03:15:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 902 extra nodes, 310 pruned nodes, max_depth=11
# [03:15:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 924 extra nodes, 312 pruned nodes, max_depth=11
# [03:15:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 944 extra nodes, 344 pruned nodes, max_depth=11
# [03:16:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 930 extra nodes, 312 pruned nodes, max_depth=11
# [03:16:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 966 extra nodes, 348 pruned nodes, max_depth=11
# [03:16:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 956 extra nodes, 318 pruned nodes, max_depth=11
# [03:17:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 888 extra nodes, 356 pruned nodes, max_depth=11
# [03:17:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 848 extra nodes, 280 pruned nodes, max_depth=11
# [03:17:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 928 extra nodes, 318 pruned nodes, max_depth=11
# ...
# [10:41:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 862 extra nodes, 902 pruned nodes, max_depth=15
# [10:41:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 466 extra nodes, 446 pruned nodes, max_depth=15
# [10:42:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 962 extra nodes, 1322 pruned nodes, max_depth=15
# [10:43:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 762 extra nodes, 632 pruned nodes, max_depth=15
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1030 extra nodes, 1044 pruned nodes, max_depth=15
# [10:44:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 906 extra nodes, 792 pruned nodes, max_depth=15
# [10:44:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 772 extra nodes, 760 pruned nodes, max_depth=15
# [10:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 694 extra nodes, 1242 pruned nodes, max_depth=15
# [10:45:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 488 extra nodes, 328 pruned nodes, max_depth=15
# [10:46:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 978 extra nodes, 822 pruned nodes, max_depth=15
# [10:47:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1030 extra nodes, 888 pruned nodes, max_depth=15
# [10:47:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 488 pruned nodes, max_depth=15
# [10:48:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 666 extra nodes, 694 pruned nodes, max_depth=15
# [10:48:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 476 extra nodes, 396 pruned nodes, max_depth=15
# [10:49:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 482 pruned nodes, max_depth=15
# [10:50:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1216 extra nodes, 1574 pruned nodes, max_depth=15
# [10:50:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 970 extra nodes, 770 pruned nodes, max_depth=15
# [10:51:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 484 extra nodes, 288 pruned nodes, max_depth=15
# [10:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 638 extra nodes, 1044 pruned nodes, max_depth=15
# [10:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 792 extra nodes, 666 pruned nodes, max_depth=15
# [10:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 958 extra nodes, 768 pruned nodes, max_depth=15
# [10:53:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 892 extra nodes, 694 pruned nodes, max_depth=15
# [10:54:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 364 pruned nodes, max_depth=15
# [10:55:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 394 pruned nodes, max_depth=15
# [10:55:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 472 extra nodes, 718 pruned nodes, max_depth=15
# [10:56:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 902 extra nodes, 974 pruned nodes, max_depth=15
# [10:57:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 416 pruned nodes, max_depth=15
# [10:57:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 762 extra nodes, 1152 pruned nodes, max_depth=15
# [10:58:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 826 extra nodes, 580 pruned nodes, max_depth=15
# [10:59:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 852 extra nodes, 694 pruned nodes, max_depth=15
# [10:59:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 500 pruned nodes, max_depth=15
# [11:00:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 770 extra nodes, 582 pruned nodes, max_depth=15
# [11:00:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 606 pruned nodes, max_depth=15
# [11:01:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 522 extra nodes, 1014 pruned nodes, max_depth=15
# [11:02:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 214 pruned nodes, max_depth=15
# [11:02:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1134 extra nodes, 1028 pruned nodes, max_depth=15
# [11:03:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 456 pruned nodes, max_depth=15
# [11:03:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 366 pruned nodes, max_depth=15
# [11:04:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 816 extra nodes, 630 pruned nodes, max_depth=15
# [11:05:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 680 extra nodes, 710 pruned nodes, max_depth=15
# [11:05:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1050 extra nodes, 874 pruned nodes, max_depth=15
# [11:06:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 318 pruned nodes, max_depth=15
# [11:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 932 extra nodes, 926 pruned nodes, max_depth=15
# [11:07:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 380 pruned nodes, max_depth=15
# [11:08:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 590 extra nodes, 532 pruned nodes, max_depth=15
# [11:08:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 514 pruned nodes, max_depth=15
# [11:09:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 576 extra nodes, 492 pruned nodes, max_depth=15
# [11:09:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1180 extra nodes, 734 pruned nodes, max_depth=15
# [11:10:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 820 extra nodes, 788 pruned nodes, max_depth=15
# [11:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 374 pruned nodes, max_depth=15
# [11:11:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 654 extra nodes, 962 pruned nodes, max_depth=15
# [11:12:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 770 extra nodes, 898 pruned nodes, max_depth=15
# [11:12:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 824 extra nodes, 720 pruned nodes, max_depth=15
# [11:13:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 724 extra nodes, 742 pruned nodes, max_depth=15
# [11:13:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 354 extra nodes, 374 pruned nodes, max_depth=15
# [11:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 512 pruned nodes, max_depth=15
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 882 extra nodes, 1124 pruned nodes, max_depth=15
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 772 extra nodes, 648 pruned nodes, max_depth=15
# [11:15:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 278 pruned nodes, max_depth=15
# [11:16:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 696 extra nodes, 818 pruned nodes, max_depth=15
# [11:17:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 826 extra nodes, 960 pruned nodes, max_depth=15
# [11:17:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 762 extra nodes, 708 pruned nodes, max_depth=15
# [11:18:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 354 pruned nodes, max_depth=15
# [11:18:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 820 extra nodes, 812 pruned nodes, max_depth=15
# [11:19:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 524 extra nodes, 474 pruned nodes, max_depth=15
# [11:19:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 650 extra nodes, 584 pruned nodes, max_depth=15
# [11:20:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 872 extra nodes, 914 pruned nodes, max_depth=15
# [11:21:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 758 extra nodes, 778 pruned nodes, max_depth=15
# [11:21:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 484 extra nodes, 642 pruned nodes, max_depth=15
# [11:22:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1256 extra nodes, 1156 pruned nodes, max_depth=15
# [11:22:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 494 extra nodes, 576 pruned nodes, max_depth=15
# [11:23:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1104 extra nodes, 896 pruned nodes, max_depth=15
# [11:23:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 580 extra nodes, 470 pruned nodes, max_depth=15
# [11:24:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 544 extra nodes, 554 pruned nodes, max_depth=15
# [11:24:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 464 extra nodes, 348 pruned nodes, max_depth=15
# [11:25:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 754 extra nodes, 680 pruned nodes, max_depth=15
# [11:26:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1136 extra nodes, 1038 pruned nodes, max_depth=15
# [11:26:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 906 extra nodes, 882 pruned nodes, max_depth=15
# [11:27:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 632 extra nodes, 468 pruned nodes, max_depth=15
# [11:27:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1310 extra nodes, 1358 pruned nodes, max_depth=15
# [11:28:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 810 extra nodes, 754 pruned nodes, max_depth=15
# [11:29:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 560 extra nodes, 848 pruned nodes, max_depth=15
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 810 extra nodes, 946 pruned nodes, max_depth=15
# [11:30:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 372 pruned nodes, max_depth=15
# [11:30:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1038 extra nodes, 858 pruned nodes, max_depth=15
# [11:31:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 814 extra nodes, 678 pruned nodes, max_depth=15
# [11:31:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 330 pruned nodes, max_depth=15
# [11:32:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 940 extra nodes, 726 pruned nodes, max_depth=15
# [11:33:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 784 extra nodes, 756 pruned nodes, max_depth=15
# [11:33:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 888 extra nodes, 842 pruned nodes, max_depth=15
# [11:34:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 812 extra nodes, 806 pruned nodes, max_depth=15
# [11:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 754 extra nodes, 602 pruned nodes, max_depth=15
# [11:35:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 602 extra nodes, 458 pruned nodes, max_depth=15
# [11:36:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 692 extra nodes, 674 pruned nodes, max_depth=15
# [11:36:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 910 extra nodes, 514 pruned nodes, max_depth=15
# [11:37:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 842 extra nodes, 640 pruned nodes, max_depth=15
# [11:37:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 844 extra nodes, 756 pruned nodes, max_depth=15
# [11:38:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 428 extra nodes, 464 pruned nodes, max_depth=15
# [11:39:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 600 pruned nodes, max_depth=15
# [11:39:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 964 extra nodes, 1004 pruned nodes, max_depth=15
# [11:40:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 464 pruned nodes, max_depth=15
# [11:40:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 786 extra nodes, 832 pruned nodes, max_depth=15
# [11:41:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 536 pruned nodes, max_depth=15
# [11:41:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 856 extra nodes, 898 pruned nodes, max_depth=15
# [11:42:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 580 pruned nodes, max_depth=15
# [11:42:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 314 pruned nodes, max_depth=15
# [11:43:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 784 extra nodes, 658 pruned nodes, max_depth=15
# [11:44:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 638 extra nodes, 546 pruned nodes, max_depth=15
# [11:44:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 428 extra nodes, 832 pruned nodes, max_depth=15
# [11:45:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 442 pruned nodes, max_depth=15
# [11:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 302 pruned nodes, max_depth=15
# [11:46:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1094 extra nodes, 696 pruned nodes, max_depth=15
# [11:47:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 536 extra nodes, 598 pruned nodes, max_depth=15
# [11:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 586 extra nodes, 566 pruned nodes, max_depth=15
# [11:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 952 extra nodes, 754 pruned nodes, max_depth=15
# [11:48:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 380 pruned nodes, max_depth=15
# [11:49:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 796 pruned nodes, max_depth=15
# [11:49:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 696 extra nodes, 622 pruned nodes, max_depth=15
# [11:50:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 880 extra nodes, 830 pruned nodes, max_depth=15
# [11:50:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 254 pruned nodes, max_depth=15
# [11:51:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 822 extra nodes, 710 pruned nodes, max_depth=15
# [11:52:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 520 pruned nodes, max_depth=15
# [11:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 524 pruned nodes, max_depth=15
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 428 extra nodes, 344 pruned nodes, max_depth=15
# [11:53:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 536 extra nodes, 598 pruned nodes, max_depth=15
# [11:54:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 446 pruned nodes, max_depth=15
# [11:54:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 974 extra nodes, 934 pruned nodes, max_depth=15
# [11:55:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 540 extra nodes, 514 pruned nodes, max_depth=15
# [11:56:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 862 extra nodes, 672 pruned nodes, max_depth=15
# [11:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 830 extra nodes, 902 pruned nodes, max_depth=15
# [11:57:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 686 extra nodes, 792 pruned nodes, max_depth=15
# [11:57:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 540 extra nodes, 648 pruned nodes, max_depth=15
# [11:58:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 550 extra nodes, 378 pruned nodes, max_depth=15
# [11:58:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 852 extra nodes, 932 pruned nodes, max_depth=15
# [11:59:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 694 extra nodes, 632 pruned nodes, max_depth=15
# [11:59:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 534 extra nodes, 584 pruned nodes, max_depth=15
# [12:00:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 642 extra nodes, 806 pruned nodes, max_depth=15

# %%
# best target so far 0.9974344
print(xgb_bo.max)

# %% [markdown]
# {'target': 0.997437, 'params': {'alpha': 4.518524359415941, 'gamma': 0.6156693234583547, 'learning_rate': 0.17259291537998744, 'max_depth': 9.947095447639079, 'n_estimators': 685.9050232008782}}

# %% [markdown]
# # XGB models
# Now let's take the parameters selected by the bayesian optimization and apply them in our training and testing.

# %%
max_param = xgb_bo.max['params']
param= {'alpha': max_param['alpha'], 'gamma': max_param['gamma'], 'learning_rate': max_param['learning_rate'], 'max_depth': int(round(max_param['max_depth'],0)), 'n_estimators': int(round(max_param['n_estimators'],0)), 'objective': 'reg:logistic'}

# %%
#To train the algorithm using the parameters selected by bayesian optimization
bst = xgb.train(param, dtrain)

# %%
#We apply our model on the training data that was trained on the training data, this helps us to control overfitting
bst1= bst.predict(dtrain)

# %%
del dtrain 
gc.collect()

# %%
# We apply our trained model on test data and store the predictions in a bst_test dataframe
bst_test = pd.DataFrame(data=bst.predict(dtest1),  columns=["xgb_preds"])
y_test=y_test.set_index(np.arange(0,bst_test.shape[0]))
# We also store the MC information in this dataFrame
bst_test['issignal']=y_test['issignal']

# %% [markdown]
# ## Whole set
# We also select the selected variables from the 10k events data set

# %%
df_origin = tree_importer.tree_importer(allFileName,'PlainTree',7)
df_origin.columns = df_origin.columns.str.replace('Candidates_', '')
df_origin.columns = df_origin.columns.str.replace('_', '')
df_origin = df_origin.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
df_clean = clean_df(df_origin)
del df_origin
gc.collect()
#lets look at impoted tree
df_clean.iloc[0:10,:]
print('test set (background to signal ratio): ' 
      + str(round(len(df_clean.loc[df_clean['issignal'] == 0])/len(df_clean.loc[df_clean['issignal'] == 1]), 1))
      + '\ntest set (both signal and background): ' + str(len(df_clean)))

# %%
x_whole = df_clean[cuts].copy()
y_whole = pd.DataFrame(df_clean['issignal'], dtype='int')
dtest = xgb.DMatrix(x_whole, label = y_whole)
del x_whole
gc.collect()

# %%
#The following graph will show us that which features are important for the model
ax = xgb.plot_importance(bst)
plt.rcParams['figure.figsize'] = [5, 3]
plt.show()
ax.figure.tight_layout() 
ax.figure.savefig(directory+'img/xgb_v3_nochi2geo/feature_importance.pdf')
ax.figure.savefig(directory+'img/xgb_v3_nochi2geo/feature_importance.png')

# %% [markdown]
# ## AUC and ROC
#
# The function roc_curve computes the receiver operating characteristic curve, or ROC curve. Quoting Wikipedia :
#
# “A receiver operating characteristic (ROC), or simply ROC curve, is a graphical plot which illustrates the performance of a binary classifier system as its discrimination threshold is varied. It is created by plotting the fraction of true positives out of the positives (TPR = true positive rate) vs. the fraction of false positives out of the negatives (FPR = false positive rate), at various threshold settings. TPR is also known as sensitivity, and FPR is one minus the specificity or true negative rate.”
#
# This function requires the true binary value and the target scores, which can either be probability estimates of the positive class, confidence values, or binary decisions.
#
# Similarly, the function roc_auc_score computes Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.

# %% [markdown]
# To find the best threshold which results more signal to background ratio for lambda candidates we use the parameter S0 called the approximate median significance by the higgs boson  ML challenge (http://higgsml.lal.in2p3.fr/documentation,9.)

# %%
def AMS(y_true, y_predict, y_true1, y_predict1):
    roc_auc=roc_auc_score(y_true, y_predict)
    fpr, tpr, thresholds = roc_curve(y_true, y_predict,drop_intermediate=False ,pos_label=1)
    S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
    S0 = S0[~np.isnan(S0)]
    xi = argmax(S0)
    S0_best_threshold = (thresholds[xi])

    roc_auc1=roc_auc_score(y_true1, y_predict1)
    fpr1, tpr1, thresholds1 = roc_curve(y_true1, y_predict1,drop_intermediate=False ,pos_label=1)
    S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))
    S01 = S01[~np.isnan(S01)]
    xi1 = argmax(S01)
    S0_best_threshold1 = (thresholds[xi1])

    #plotting
    fig, axs = plt.subplots(figsize=(15, 10), dpi = 100)
    plt.plot(fpr, tpr, linestyle=':',color='darkorange',label='ROC curve train (area = %0.4f)' % roc_auc)
    plt.plot(fpr1, tpr1, color='green',label='ROC curve test (area = %0.4f)' % roc_auc1)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.scatter(fpr[xi], tpr[xi], marker='o', color='black', label= 'Best Threshold train set = '+"%.4f" % S0_best_threshold +'\n S0 = '+ "%.2f" % S0[xi])
    plt.scatter(fpr1[xi1], tpr1[xi1], marker='o', color='blue', label= 'Best Threshold test set = '+"%.4f" % S0_best_threshold1 +'\n S0 = '+ "%.2f" % S01[xi1])
    plt.xlabel('False Positive Rate', fontsize = 15)
    plt.ylabel('True Positive Rate', fontsize = 15)
    plt.legend(loc="lower right", fontsize = 15)
    plt.title('Receiver operating characteristic', fontsize = 15)
    plt.xlim([-0.01, 1.0])
    plt.ylim([0, 1.02])
    
    fig.tight_layout()
    plt.show()
    fig.savefig(directory+'img/xgb_v3_nochi2geo/ams.pdf')
    fig.savefig(directory+'img/xgb_v3_nochi2geo/ams.png')

    return S0_best_threshold, S0_best_threshold1

# %%
train_best, test_best = AMS(y_train, bst1, y_test, bst_test['xgb_preds'])

# %%
def preds_prob(df, preds, true, dataset):
    if dataset =='train':
        label1 = 'XGB Predictions on the training data set'
    else:
        label1 = 'XGB Predictions on the test data set'
    fig, ax = plt.subplots(figsize=(12, 8))
    bins1=100
    plt.hist(df[preds], bins=bins1,facecolor='green',alpha = 0.3, label=label1)
    TP = df[(df[true]==1)]
    TN = df[(df[true]==0)]
    #TP[preds].plot.hist(ax=ax, bins=bins1,facecolor='blue', histtype='stepfilled',alpha = 0.3, label='True Positives/signal in predictions')
    hist, bins = np.histogram(TP[preds], bins=bins1)
    err = np.sqrt(hist)
    center = (bins[:-1] + bins[1:]) / 2

    
    hist1, bins1 = np.histogram(TN[preds], bins=bins1)
    err1 = np.sqrt(hist1)
    plt.errorbar(center, hist1, yerr=err1, fmt='o',
                 c='Red', label='Background in predictions')
    
    plt.errorbar(center, hist, yerr=err, fmt='o',
                 c='blue', label='Signal in predictions')
    
    ax.set_yscale('log')
    plt.xlabel('Probability',fontsize=18)
    plt.ylabel('Counts', fontsize=18)
    plt.legend(fontsize=18)
    ax.set_xticks(np.arange(0,1.1,0.1))
    ax.tick_params(axis='both', which='major', labelsize=18)
    ax.tick_params(axis='both', which='minor', labelsize=16)
    plt.show()
    fig.tight_layout()
    fig.savefig('test_best.png')
preds_prob(bst_test,'xgb_preds', 'issignal','test')

# %% [markdown]
# When the AUC, best threshold and approximate median significance for train and test are nearly the same, we save that model and use it. This means that our model is general enough. In my opinion, if the test S0 is above 3.0 then it is a good enough model.

# %% [markdown]
# ## Applying the model on the 10k events data-set

# %%
df_clean['xgb_preds'] = bst.predict(dtest)

# %%
df_clean['xgb_preds'].hist(bins=300)
plt.yscale('log')

# %% [markdown]
# ## Confusion Matrix
#
# A **Confusion Matrix** $C$ is such that $C_{ij}$ is equal to the number of observations known to be in group $i$ and predicted to be in group $j$. Thus in binary classification, the count of true positives is $C_{00}$, false negatives $C_{01}$,false positives is $C_{10}$, and true neagtives is $C_{11}$.
#
# If $ y^{'}_{i} $ is the predicted value of the $ i$-th sample and $y_{i}$ is the corresponding true value, then the fraction of correct predictions over $ n_{samples}$ is defined as
# $$
# True \: positives (y,y^{'}) =  \sum_{i=1}^{n_{samples} } 1 (y^{'}_{i} = y_{i}=1)
# $$
#
# The following function prints and plots the confusion matrix. Normalization can be applied by setting `normalize=True`.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
#calculate efficency and false tu tru signal ratio
def confustion_stats(df, cm):
    all_signals = len(df.loc[df['issignal'] == 1])
    true_signal = cm[0][0]
    false_signal = cm[1][0]        
    reconstructed_signals = true_signal + false_signal
    false_to_true_signals = false_signal / true_signal
    efficiency = reconstructed_signals / all_signals * 100 #efficency in % for all
    efficiency_true = true_signal / all_signals * 100 #efficency in % for all
    print("Efficiency: " + str(round(efficiency, 2)) + "%")
    print("Efficiency of true signal candidates reconstruction: " + str(round(efficiency_true, 2)) + "%")
    print("False tu true reconstructed signal ratio: " + str(round(false_to_true_signals, 2)))

# %%
#lets take the best threshold and look at the confusion matrix
cut1 = test_best
df_clean['xgb_preds1'] = ((df_clean['xgb_preds']>cut1)*1)
cnf_matrix = confusion_matrix(y_whole, df_clean['xgb_preds1'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix, classes=['signal','background'], title='Confusion Matrix for XGB for cut > '+str(cut1))
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_extreme_gradient_boosting_whole_data.pdf')
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_extreme_gradient_boosting_whole_data.png')

# %%
confustion_stats(df_clean, cnf_matrix)

# %%
# The following function will display the inavriant mass histogram of the original 10k event set along with the mass histoigram after we apply a cut
# on the probability prediction of xgb
def cut_visualization(cut, range1=(lowerMassCut, upperMassCut), bins1= 300 ):
    mask1 = df_clean['xgb_preds']>cut
    df3=df_clean[mask1]
    
    fig, ax2 = plt.subplots(figsize=(15, 10), dpi = 200)
    color = 'tab:blue'
    ax2.hist(df_clean['mass'],bins = bins1, range=range1, facecolor='blue',alpha = 0.35, label='before selection')
    ax2.set_ylabel('Counts', fontsize = 15, color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.legend( fontsize = 15, loc='upper left')
    
    color = 'tab:red'
    ax1 = ax2.twinx()
    ax1.hist(df3['mass'], bins = bins1, range=range1, facecolor='red',alpha = 0.35, label='XGB')
    ax1.set_xlabel('Mass in GeV', fontsize = 15)
    ax1.set_ylabel('Counts ', fontsize = 15, color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.legend( fontsize = 15,loc='upper right' )

    plt.title("The original sample's Invariant Mass along with mass after selection of XGB (with a cut > "+str(cut)+')', fontsize = 15)
    fig.tight_layout()
    fig.savefig(directory+'img/xgb_v3_nochi2geo/whole_sample_invmass_with_ML.pdf')
    fig.savefig(directory+'img/xgb_v3_nochi2geo/whole_sample_invmass_with_ML.png')

# %%
cut_visualization(test_best)

# %% [markdown]
# # Comparison with the manually optimized cuts of KFPF
# In the already existing Kalman Filter Particle Finder (KFPF) package for online reconstruction and selection of short-lived particles in CBM, these criteria have been manually optimized. These selection-cuts have been selected to maximize the signal to background ratio (S/B) of the $\Lambda$ for a certain energy on a collisions generator. The selection criteria mainly depends on the collision energy, decay channel and detector configuration.

# %%
#manually selected cuts
manCut_loverdl = 30
manCut_dca = 0.4
manCut_chi2topo = 20
manCut_chi2geo = 12

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
new_check_set= df_clean.copy()
new_check_set['new_signal']=0

mask1 = (new_check_set['loverdl'] > manCut_loverdl) & (new_check_set['distance'] < manCut_dca)

mask2 = (new_check_set['chi2topo'] < manCut_chi2topo) & (new_check_set['chi2geo'] < manCut_chi2geo) 

new_check_set = new_check_set[(mask1) & (mask2)] 

#After all these cuts, what is left is considered as signal, so we replace all the values in the 'new_signal'
# column by 1
new_check_set['new_signal'] = 1
cnf_matrix1 = confusion_matrix(new_check_set['issignal'], new_check_set['new_signal'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix1, classes=['signal','background'], title='Confusion Matrix for manually set cuts')
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_for_manually_set_cuts.pdf')
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_for_manually_set_cuts.png')

# %%
confustion_stats(df_clean, cnf_matrix1)

# %%
cut3 = test_best
mask1 = df_clean['xgb_preds']>cut3
df3=df_clean[mask1]

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=200)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=200)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
#axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
from matplotlib import gridspec

range1= (0.4, 0.6)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 100, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 100, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables (close up)", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=100)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=100)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison_closeup.png')
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison_closeup.pdf')

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
axs[0].set_yscale('log')
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=300)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=300)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].set_ylim([0.,2.])
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
mask1 = df_clean['xgb_preds']>test_best
df3_base=df_clean[mask1]
fig, axs = plt.subplots(figsize=(12, 8))

range1= (1.105, 1.14)
bins1 = 150

df3_base['mass'].plot.hist(bins = bins1, range=range1, facecolor='red',alpha = 0.3,grid=True,sharey=True, label='XGB selected K-short')
df3_base[df3_base['issignal']==0]['mass'].plot.hist(bins = bins1, range=range1,facecolor='green',alpha = 0.3,grid=True,sharey=True, label ='\n False positives = \n (MC =0)\n background in \n the distribution')

plt.legend( fontsize = 18, loc='upper right')
plt.title("XGB selected $\Lambda$ candidates with a cut of %.3f "%test_best +"on the XGB probability distribution", fontsize = 18)
axs.set_xlabel("Mass (GeV/${c^2}$)", fontsize = 18)
plt.ylabel("Counts", fontsize = 18)
axs.text(1.123, 400, 'CBM Performance', fontsize=18)
axs.tick_params(labelsize=18)
fig.tight_layout()

# %%
from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True, gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 100,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 100,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("log (counts)", fontsize = 18)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 18, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 18)
#axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=18)
axs[0].set_yscale('log')
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3_base['mass'],range=(lowerMassCut, upperMassCut), bins=300)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=300)


#makes sense to have only positive values
diff = (hist1 - hist2)
#axs[1].bar((bins[:-1] + bins[1:]) / 2, # this is what makes it comparable
# ns / ns1, # maybe check for div-by-zero!
# width=0.001)
axs[1].hlines(y=1, xmin=lowerMassCut, xmax=upperMassCut, colors='r', linestyles='solid', label='')
center = (bins[:-1] + bins[1:]) / 2
plt.errorbar(center, ns / ns1, fmt='o',
                 c='Blue', label='Background in predictions')


    
    
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 18)
axs[1].set_ylabel("XGB / KFPF", fontsize = 18)
#axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=18)

plt.show()
fig.tight_layout()
#fig.savefig("whole_sample_invmass_with_ML.png")

# %%
from matplotlib import gridspec

left = .42
right = .55
range1= (left, right)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True, gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 50,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 50,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("log (counts)", fontsize = 18)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 18, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 18)
#axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=18)
axs[0].set_yscale('log')
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3_base['mass'],range=(left, right), bins=50)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(left, right), bins=50)


#makes sense to have only positive values
diff = (hist1 - hist2)
#axs[1].bar((bins[:-1] + bins[1:]) / 2, # this is what makes it comparable
# ns / ns1, # maybe check for div-by-zero!
# width=0.001)
axs[1].hlines(y=1, xmin=left, xmax=right, colors='r', linestyles='solid', label='')
center = (bins[:-1] + bins[1:]) / 2
plt.errorbar(center, ns / ns1, fmt='o',
                 c='Blue', label='Background in predictions')


    
    
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 18)
axs[1].set_ylabel("XGB / KFPF", fontsize = 18)
#axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=18)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/circle_kshort_invmass_with_ML.png')

# %%
from matplotlib import gridspec

left = .44
right = .55
range1= (left, right)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True, gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 50,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 50,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("log (counts)", fontsize = 18)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 18, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 18)
#axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=18)
axs[0].set_yscale('log')
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3_base['mass'],range=(left, right), bins=50)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(left, right), bins=50)


#makes sense to have only positive values
diff = (hist1 - hist2)
#axs[1].bar((bins[:-1] + bins[1:]) / 2, # this is what makes it comparable
# ns / ns1, # maybe check for div-by-zero!
# width=0.001)
axs[1].hlines(y=1, xmin=left, xmax=right, colors='r', linestyles='solid', label='')
center = (bins[:-1] + bins[1:]) / 2
plt.errorbar(center, ns / ns1, fmt='o',
                 c='Blue', label='Background in predictions')


    
    
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 18)
axs[1].set_ylabel("XGB / KFPF", fontsize = 18)
#axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=18)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/circle_kshort_invmass_with_ML.png')

# %%
par = 'loverdl'
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','after selection', 'man selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'distance'
ranges = (0,5)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'chi2topo'
ranges = (0,100)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'chi2geo'
ranges = (0,100)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'chi2primfirst'
ranges = (0,100)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'chi2primsecond'
ranges = (0,100)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
#del x,y,x_test,y_test,x_whole,y_whole,
#del dtest,dtrain,dtest1,df3,df_clean,df_scaled
gc.collect()

# %% [markdown]
# # Importing the final predictor to root
# We will use the treelite library to transport the final predictor of our model to root

# %% [raw]
# #install treelite
# import treelite
# #create an object out of your model, bst in our case
# model = treelite.Model.from_xgboost(bst)
# #use GCC compiler
# toolchain = 'gcc'
# #parallel_comp can be changed upto as many processors as one have
# model.export_lib(toolchain=toolchain, libpath='./mymodel.so',
#                  params={'parallel_comp': 8}, verbose=True)
#
# # Operating system of the target machine
# platform = 'unix'
# # C compiler to use to compile prediction code on the target machine
# toolchain = 'gcc'
# # Save the source package as a zip archive named mymodel.zip
# # Later, we'll use this package to produce the library mymodel.so.
# model.export_srcpkg(platform=platform, toolchain=toolchain,
#                     pkgpath='./mymodel.zip', libname='mymodel.so',
#                     verbose=True)

# %% [raw]
# !unzip mymodel.zip

# %% [raw]
# #Build the source package (using GNU Make or NMake).
# %cd mymodel
# !make
#
# !ls

# %% [raw]
# If one wants to transfer this model to a different computer, target machine, then one should follow the following commands in command prompt

# %% [raw]
# sftp john@lxpool.gsi.de
# sftp> put mymodel.zip
# sftp> quit

# %% [raw]
# ssh john@lxpool.gsi.de
# unzip mymodel.zip
# cd mymodel
# make -j8

# %% [raw]
# The following C++ code can be the applied as a macro on some new data file

# %% [raw]
# %%writefile test.cpp
# #include "TROOT.h"
# #include "TFile.h"
# #include "TTree.h"
# #include "TH1F.h"
# #include <vector>
# #include "TString.h"
# #include "TMath.h"
# #include "TH1.h"
# #include "TF1.h"
# #include "TCanvas.h"
#
# #include <stdio.h>
# #include <stdlib.h>
# #include "main.c"
#
#
#
# void python_to_root(){
#   TCanvas* c1 = new TCanvas();
#   //c1->Divide(2,1);
#
#   //c1->cd(1);
#
#   /* Open the root file*/
#   TFile *f = new TFile("/gdrive/My Drive/presentations/treelite/10k_events_PFSimplePlainTree.root","UPDATE");
#   TTree *t1 = (TTree*)f->Get("PlainTree");
#
#
#   Float_t  LambdaCandidates_chi2primneg, LambdaCandidates_chi2primpos, LambdaCandidates_ldl, LambdaCandidates_distance, LambdaCandidates_chi2geo, LambdaCandidates_mass;
#
#   t1->SetBranchAddress("LambdaCandidates_chi2primneg",&LambdaCandidates_chi2primneg);
#   t1->SetBranchAddress("LambdaCandidates_chi2primpos",&LambdaCandidates_chi2primpos);
#   t1->SetBranchAddress("LambdaCandidates_ldl",&LambdaCandidates_ldl);
#   t1->SetBranchAddress("LambdaCandidates_distance",&LambdaCandidates_distance);
#   t1->SetBranchAddress("LambdaCandidates_chi2geo",&LambdaCandidates_chi2geo);
#   t1->SetBranchAddress("LambdaCandidates_mass",&LambdaCandidates_mass);
#
#
#   std::vector<float> output{};
#
#   const long n_entries = t1->GetEntries();
#   output.reserve(n_entries);
#
#   const size_t n_features = 5;
#   union Entry input[n_features];
#
#   //let's create a new branch which will store the probability returened for each proton-pion pair by our model
#   Float_t probab;
#   TBranch *bpt = t1->Branch("probab",&probab,"probabilities");
#   t1->SetBranchAddress("probab",&probab);
#
#   TH1F *h = new TH1F("h_prob", "This is the #Lambda invariant mass after the cut >0.918080", 300, 1.04, 1.4);
#   h->GetXaxis()->SetTitle("[GeV]");
#
#   for (long i = 0; i < n_entries; i++)
#    {
#      t1->GetEntry(i);
#
#     input[0].fvalue = LambdaCandidates_chi2primneg;
#     input[1].fvalue = LambdaCandidates_chi2primpos;
#     input[2].fvalue = LambdaCandidates_ldl;
#     input[3].fvalue = LambdaCandidates_distance;
#     input[4].fvalue = LambdaCandidates_chi2geo;
#
#     output.push_back(predict(input, 0));
#     probab= output.at(i);
#
#     if(probab > 0.918080){
#     h->Fill(LambdaCandidates_mass);}
#   }
#
#   h->Draw();
#
#
#
# }

# %% [raw]
# # Installing root
# !mkdir -p APPS
# !pwd
# !cd APPS && wget https://root.cern/download/root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
# !cd APPS && tar -xf root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
