# %% [markdown]
# Variables of filenames

# %% [markdown]
# Background comes from URQMD, signal from DCM, for test dataset for both bckgr and sign generated in urqmd

# %% [markdown]
# 4:1 background/signal ratio before cleaning, no chi2geo

# %%
#PLAINTREE FILES NAMES
directory='/Users/julnow/gsi/cbm/ML/JupyterNotebooks/'
signalFileName = directory + 'PlainTree_500kSign.root'
backgroundFileName = directory + 'PlainTree_6kBckgr_URQMD.root'
allFileName = directory + 'PlainTree_15kAll_URQMD.root'

# %%
# !git clone https://github.com/shahidzk1/CBM_ML_Lambda_Library.git
# %cd CBM_ML_Lambda_Library
# !git pull origin main
# !pip install -r requirements.txt
# !python setup.py install
# Out:
# fatal: destination path 'CBM_ML_Lambda_Library' already exists and is not an empty directory.
# /Users/julnow/gsi/cbm/ML/JupyterNotebooks/CBM_ML_Lambda_Library
# hint: Pulling without specifying how to reconcile divergent branches is
# hint: discouraged. You can squelch this message by running one of the following
# hint: commands sometime before your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# From https://github.com/shahidzk1/CBM_ML_Lambda_Library
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Requirement already satisfied: uproot in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.21.1)
# Requirement already satisfied: scikit-learn in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (0.24.2)
# Requirement already satisfied: xgboost in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (0.80)
# Requirement already satisfied: bayesian-optimization in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: scipy>=0.14.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from bayesian-optimization->-r requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: joblib>=0.11 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 3)) (2021.1)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from uproot->-r requirements.txt (line 1)) (57.4.0)
# running install
# running bdist_egg
# running egg_info
# writing CBM_ML.egg-info/PKG-INFO
# writing dependency_links to CBM_ML.egg-info/dependency_links.txt
# writing top-level names to CBM_ML.egg-info/top_level.txt
# reading manifest file 'CBM_ML.egg-info/SOURCES.txt'
# writing manifest file 'CBM_ML.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-11.1-arm64/egg
# running install_lib
# running build_py
# creating build/bdist.macosx-11.1-arm64/egg
# creating build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/KFPF_lambda_cuts.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/__init__.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/plot_tools.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/root_functions.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/tree_importer.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/KFPF_lambda_cuts.py to KFPF_lambda_cuts.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/plot_tools.py to plot_tools.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/root_functions.py to root_functions.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/tree_importer.py to tree_importer.cpython-38.pyc
# creating build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/PKG-INFO -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/SOURCES.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/dependency_links.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/top_level.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/CBM_ML-0.1.0-py3.8.egg' and adding 'build/bdist.macosx-11.1-arm64/egg' to it
# removing 'build/bdist.macosx-11.1-arm64/egg' (and everything under it)
# Processing CBM_ML-0.1.0-py3.8.egg
# Removing /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/CBM_ML-0.1.0-py3.8.egg
# Copying CBM_ML-0.1.0-py3.8.egg to /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages
# CBM-ML 0.1.0 is already the active version in easy-install.pth
#
# Installed /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/CBM_ML-0.1.0-py3.8.egg
# Processing dependencies for CBM-ML==0.1.0
# Finished processing dependencies for CBM-ML==0.1.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
#from hipe4ml.model_handler import ModelHandler
#from hipe4ml.tree_handler import TreeHandler
from matplotlib.patches import ConnectionPatch
#from hipe4ml import plot_utils

import xgboost as xgb
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz

from sklearn.model_selection import cross_val_score
from scipy.stats import uniform

from numpy import sqrt, log, argmax

import weakref 
import itertools

from CBM_ML import tree_importer,  KFPF_lambda_cuts, plot_tools
from bayes_opt import BayesianOptimization

import gc, os

# %% [markdown]
# # Selecting Background and Signal
# We generate PlainTrees from: 100k events (signal) and 20k evenents (background) with Au-Au @12A GeV/c, DCMQGSM-SMM generator passed through CBM setup in GEANT4, without any cuts
#
# To omit imbalance classification problem (event though there are 5 times more events for background, the number of entries is much smaller for signal) we resample the data. We're deleting instances from the over-represented class (in our case the background) - it's called under-sampling, one of the resampling methods.
#
# So for training and testing we will get signal candidates from the 5 sigma region and  background from outside this region (3 times signal size).

# %%
#CUTS FOR MASS SELECTION
#5 sigma region for signal
lower5SigmaCutSign = 0.43485
upper5SigmaCutSign = 0.56135
#mean invariant mass
invMass = 0.4981
# "5sigma" (not acutal 5 sigma) region for background
lower5SigmaCutBckgr = 0.1
upper5SigmaCutBckgr = 2

# %%
# We import three root files into our jupyter notebook
#sign - before cleaning but after 5sigma seletion, signal - cleaned
#so that we dont have to reimport everything with each change
sign = tree_importer.tree_importer(signalFileName,'PlainTree',7)

# We only select lambda candidates in the 5 sigma region around the kaon mass peak
#we preserve the cleaned dataframe with a changed name
sign = sign[(sign['Candidates_generation']==1) & (sign['Candidates_mass']>lower5SigmaCutSign) & (sign['Candidates_mass']<upper5SigmaCutSign)]

# Similarly for the background, we select background candidates which are not in the 5 sigma region of the kaon peak
bckgr = tree_importer.tree_importer(backgroundFileName,'PlainTree',7)
#we preserve the cleaned dataframe with a changed name
bckgr = bckgr[(bckgr['Candidates_generation'] < 1)
                 & ((bckgr['Candidates_mass'] > lower5SigmaCutBckgr)
                 & (bckgr['Candidates_mass'] < lower5SigmaCutSign) | (bckgr['Candidates_mass']>upper5SigmaCutSign) 
                    & (bckgr['Candidates_mass'] < upper5SigmaCutBckgr))
             ].sample(n=4*(sign.shape[0])) #we select bckgr so that we have 4*more entries that for signal (before cleaning)

#Also call the garbage collector of python to collect unused items to free memory
gc.collect()
# Out:
# 2506

# %%
#we remove name prefixes 'Candidates' and do some renaming
bckgr.columns = bckgr.columns.str.replace('Candidates_', '')
bckgr.columns = bckgr.columns.str.replace('_', '')
sign.columns = sign.columns.str.replace('Candidates_', '')
sign.columns = sign.columns.str.replace('_', '')
#we also get rid of coordinates errors
sign = sign.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
bckgr = bckgr.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
#let's check the name prefixes 
sign.iloc[0:10,:]
# Out:
#     chi2geo  chi2primfirst  chi2primsecond   chi2topo  cosinefirst  \
# 0  0.000002   2.789146e+00    3.414697e+02   0.152363     0.998430
# 1  0.264513   1.474882e+06    1.260303e+06   1.848403     0.982548
# 2  0.064274   3.623920e+06    1.747746e+06   0.256590     0.927869
# 3  0.022654   1.723264e+05    2.411727e+05   0.406959     0.986660
# 4  1.538128   9.617859e+03    3.732512e+03   1.857859     0.905587
# 5  0.590288   1.296850e+06    1.223871e+06   2.634095     0.961413
# 6  0.721047   5.744036e+05    2.418638e+05  19.809374     0.974520
# 7  0.073615   1.446560e+05    1.016588e+05   0.687733     0.980289
# 8  0.744174   8.833737e+03    2.599425e+01   0.744472     0.999502
# 9  6.557718   1.101657e+06    4.705889e+03   2.715420     0.938120
#
#    cosinesecond  cosinetopo  distance       eta          l  ...        pT  \
# 0      0.978441    0.999726  0.038816  2.981088   0.603433  ...  0.336420
# 1      0.976238    0.999997  0.001687  2.536047  18.872398  ...  0.316806
# 2      0.975467    0.999997  0.003996  3.009254   4.463050  ...  0.130762
# 3      0.984264    1.000000  0.006170  7.433340   3.380137  ...  0.002865
# 4      0.998455    0.999995  0.049966  3.027495   2.391879  ...  0.159067
# 5      0.957558    0.999978  0.006462  1.802818   3.241289  ...  0.443765
# 6      0.893650    0.999967  0.046300  2.350879  18.618280  ...  0.229605
# 7      0.996563    0.999999  0.045747  3.050026  24.100300  ...  0.285753
# 8      0.995903    0.999988  0.091523  3.268460   3.470731  ...  0.556931
# 9      0.978224    0.999964  0.223624  3.030640   3.662582  ...  0.139211
#
#         phi        px        py        pz  rapidity         x         y  \
# 0  2.886740 -0.325554  0.084812  3.306750  2.410393 -0.123734 -0.177956
# 1 -0.179362  0.311724 -0.056519  1.988028  1.928081  3.109412 -0.435314
# 2  0.559173  0.110846  0.069367  1.322198  1.682555  0.525349  0.317982
# 3 -2.576989 -0.002420 -0.001533  2.387398  2.273262 -0.056460 -0.080025
# 4  2.112874 -0.082065  0.136263  1.638160  1.867915 -0.172525  0.114815
# 5  2.740511 -0.408547  0.173252  1.309525  1.432320 -0.970163  0.154506
# 6  2.428807 -0.173706  0.150149  1.193890  1.508402 -2.550717  2.168915
# 7  2.216071 -0.171857  0.228298  3.010206  2.362526 -1.384464  1.550338
# 8 -2.060090 -0.261759 -0.491584  7.304965  2.969631 -0.121596 -0.344261
# 9 -2.587030 -0.118347 -0.073304  1.438195  1.752917 -0.272607 -0.259571
#
#            z  issignal
# 0   0.600863       1.0
# 1  18.628889       1.0
# 2   4.439318       1.0
# 3   3.378509       1.0
# 4   2.379641       1.0
# 5   3.065898       1.0
# 6  18.284170       1.0
# 7  23.992416       1.0
# 8   3.460147       1.0
# 9   3.649118       1.0
#
# [10 rows x 23 columns]

# %% [markdown]
# The label 'issignal' tells us if an entry comes from signal (1) or background (0)

# %% [markdown]
# # Data Cleaning
# Sometimes a data set contains entries which are outliers or does not make sense. For example, infinite values or NaN entries. We clean the data by removing these entries.
#
# Similarly, CBM is a fixed target experiment so there are certain conditions which the data has to satisfy before it is considered as reliable data.So we apply certain limits on the data sets.
#
# The values of these cuts are described: https://drive.google.com/file/d/1tb0FBRq4KgVu-VQZgpjA8ONbIGVCNOnE/view?usp=sharing https://github.com/julnow/JupyterNotebooks/blob/kaon/CBM%20K-short%20data%20cleaning.pdf

# %%
#CUTS USED FOR DATA CLEANING
#mass cuts for both bckgr and sign
lowerMassCut = 0.279
upperMassCut = 1.5
#distance cuts
#DCA
lowerDcaCut = 0
upperDcaCut = 100
#l distance
lowerLCut = -5
upperLCut = 80
#loverdl
lowerLdlCut = -25
upperLdlCut = 15000
#coordinate cuts
absXCut = 50
absYCut = 50
lowerZCut = -1
upperZCut = 80
#momentums cuts
pzLowerCut = 0
pUpperCut = 20
ptUpperCut = 3
#chi2
#geo
lowerChi2GeoCut = 0
upperChi2GeoCut = 10000
#topo
lowerChi2TopoCut = 0
upperChi2TopoCut = 100000
#prim first
lowerChi2PrimFirstCut = 0
upperChi2PrimFirstCut = 3e7
#prim second
lowerChi2PrimSecondCut = 0
upperChi2PrimSecondCut = 3e7
#pseudorapidity cuts
lowerEtaCut = 1.
upperEtaCut = 6.5

# %%
def clean_df(df):
    # let's treat all the infinite, inf, values by nan and then we drop all the null entries
    with pd.option_context('mode.use_inf_as_na', True):
        df = df.dropna()
    #Experimental constraints
    is_good_mom = (df['pz'] > pzLowerCut) & (df['p']<pUpperCut) & (df['pT']<ptUpperCut)
    is_good_coord = (abs(df['x']) < absXCut) & (abs(df['y']) < absYCut) & (df['z']>lowerZCut) & (df['z']<upperZCut)
    is_good_params = (df['distance'] > lowerDcaCut) & (df['distance'] < upperDcaCut) & (df['chi2geo']>lowerChi2GeoCut) & (df['chi2geo'] < upperChi2GeoCut) & (df['chi2topo'] > lowerChi2TopoCut) & (df['chi2topo'] < upperChi2TopoCut) & (df['eta']>lowerEtaCut) & (df['eta']<upperEtaCut)& (df['l']>lowerLCut) & (df['l']<upperLCut) & (df['loverdl']>lowerLdlCut) & (df['loverdl']<upperLdlCut)
    is_good_daughters = (df['chi2primfirst']>lowerChi2PrimFirstCut) & (df['chi2primfirst'] < upperChi2PrimSecondCut) & (df['chi2primsecond']>lowerChi2PrimSecondCut) & (df['chi2primsecond']<upperChi2PrimFirstCut)
    is_good_mass = (df['mass']>lowerMassCut) & (df['mass']<upperMassCut)

    is_good_df = (is_good_mom) & (is_good_coord) & (is_good_params) & (is_good_daughters) & (is_good_mass)

    return df[is_good_df]

# %%
background = clean_df(bckgr)
signal = clean_df(sign)
del sign, bckgr

# %% [markdown]
# We'll also import and clean dataset of 10k events for both background and signal (for testing our algorhitm)

# %%
df_origin = tree_importer.tree_importer(allFileName,'PlainTree',7)
df_origin.columns = df_origin.columns.str.replace('Candidates_', '')
df_origin.columns = df_origin.columns.str.replace('_', '')
df_origin = df_origin.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
df_clean = clean_df(df_origin)
del df_origin
#lets shuffle data
df_clean= df_clean.sample(frac=1)
gc.collect()
#lets look at impoted tree
df_clean.iloc[0:10,:]
# Out:
#               chi2geo  chi2primfirst  chi2primsecond    chi2topo  cosinefirst  \
# 20529231     0.058598       0.347104        0.060178    0.078833     0.908956
# 8866593      0.000765      10.795166        2.382978    2.756210     0.977813
# 8844507      2.111303       0.824381        2.091223    0.958893     0.991982
# 29404777     7.006760       0.559341        9.425152    2.856446     0.990966
# 28748490     0.085028      10.248253        0.467936    2.542221     0.958215
# 11054786  1078.665039       0.200473   106834.187500  863.437805     0.986928
# 18443611     0.000157       1.356690        0.756038    0.545769     0.982051
# 6366208   1384.647583       2.985397    25850.406250  650.010681     0.990942
# 10513002     4.846524       0.645496       12.908857    4.195660     0.985434
# 25553712     0.875166       0.466153        1.631314    0.652687     0.993621
#
#           cosinesecond  cosinetopo  distance       eta         l  ...  \
# 20529231      0.988067    0.991199  0.001876  3.319024  0.007827  ...
# 8866593       0.872467   -0.852357  0.003841  1.503690 -0.387192  ...
# 8844507       0.998448    0.939067  0.005684  2.637174  0.003777  ...
# 29404777      0.962811    0.992071  0.034862  1.691344  0.055330  ...
# 28748490      0.961914   -0.935929  0.015145  1.957424 -0.202700  ...
# 11054786      0.677126    0.931048  0.755825  1.490077  1.133331  ...
# 18443611      0.935671   -0.933373  0.000041  2.642886 -0.004387  ...
# 6366208       0.986724    0.658240  3.911966  2.015799  0.795116  ...
# 10513002      0.843078    0.983047  0.101397  3.424634  0.179790  ...
# 25553712      0.999221   -0.993715  0.005496  2.577929 -0.014939  ...
#
#                 pT       phi        px        py        pz  rapidity  \
# 20529231  0.186508 -1.989410 -0.075814 -0.170404  2.573553  1.916139
# 8866593   0.456546 -2.382143 -0.331094 -0.314342  0.976082  1.182802
# 8844507   0.472178  1.826869 -0.119595  0.456782  3.282131  2.358115
# 29404777  0.477090 -2.171531 -0.269674 -0.393562  1.250571  1.453285
# 28748490  0.092964  2.447266 -0.071442  0.059485  0.322579  0.909607
# 11054786  0.612421 -2.388225 -0.446693 -0.418956  1.289783  1.156784
# 18443611  0.651626 -0.474004  0.579783 -0.297436  4.555685  1.878544
# 6366208   1.117124  0.585319  0.931163  0.617172  4.118568  1.888879
# 10513002  0.095360 -2.688073 -0.085720 -0.041780  1.462772  1.650519
# 25553712  0.514648 -1.754201 -0.093861 -0.506016  3.369374  2.352997
#
#                  x         y         z  issignal
# 20529231  0.047681 -0.108452  0.009363       0.0
# 8866593  -0.141745  0.100145 -0.445254       0.0
# 8844507  -0.154059  0.099710  0.005042       0.0
# 29404777  0.065951 -0.156949  0.051469       0.0
# 28748490 -0.007215 -0.114987 -0.199241       0.0
# 11054786 -0.452670  0.116768  1.065520       0.0
# 18443611 -0.117049  0.103485 -0.004929       0.0
# 6366208  -0.414006  0.770008  0.817450       0.0
# 10513002 -0.023322  0.021514  0.176228       0.0
# 25553712 -0.192159 -0.142232 -0.016392       0.0
#
# [10 rows x 23 columns]

# %%
#Let's combine signal and background
df_scaled = pd.concat([signal, background])
# Let's shuffle the rows randomly
df_scaled = df_scaled.sample(frac=1)

# %%
print('size of:\nsignal: ' + str(len(signal)) + '\nbackground: ' + str(len(background)) 
      + '\nbackground to signal ratio: ' + str(round(len(background)/len(signal), 1))  
      + '\ntest set (both signal and background): ' + str(len(df_clean))
      + '\ntest set (background to signal ratio): ' 
      + str(round(len(df_clean.loc[df_clean['issignal'] == 0])/len(df_clean.loc[df_clean['issignal'] == 1]), 1)))
# Out:
# size of:
# signal: 450442
# background: 1637688
# background to signal ratio: 3.6
# test set (both signal and background): 28740227
# test set (background to signal ratio): 1985.1

# %% [markdown]
# # Selecting Background and Signal
# After cleaning, our training data set contains 450442 background candidates and 1638402 signal candidates (background to signal ratio $\approx 3.6$). For testing, we'll use cleaned dataset containing 28740227 entries of signal and background (background to signal ratio $\approx 1985.1$)
#
# Here, we use under-sampling to tackle the problem with the classification of underrepresented class (normally, the signal is only approx. 0.05% of real data)

# %%
if not os.path.exists(directory+'img/xgb2nochi2geo'):
    os.makedirs(directory+'img/xgb2nochi2geo')
#lets draw sign to background ratio
def plt_sig_back(df):
    range1 = (lowerMassCut, upperMassCut)
    fig, axs = plt.subplots(figsize=(20, 10))
    #df_scaled['mass'].plot.hist(bins = 300, range=range1,grid=True,sharey=True)
    (df[df['issignal']==0])['mass'].plot.hist(bins = 300, facecolor='yellow',grid=True,range=range1, label='Background')
    (df[df['issignal']==1])['mass'].plot.hist(bins = 300, facecolor='magenta',grid=True, range=range1, label ='Signal')
    #plt.vlines(x=1.108,ymin=-1,ymax=48000, color='black', linestyle='-')
    #plt.vlines(x=1.1227,ymin=-1,ymax=48000, color='black', linestyle='-')
    plt.ylabel("Counts (log scale)", fontsize=15)
    plt.xlabel("Mass in GeV/$c^2$", fontsize= 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.title('Test and Train K-short Invariant Mass', fontsize = 15)
    plt.legend( fontsize = 15)
    axs.tick_params(axis='both', which='major', labelsize=18)
    plt.yscale("log")
    fig.tight_layout()
    fig.savefig(directory+'img/xgb2nochi2geo/inv_mass_trainset.pdf')
    fig.savefig(directory+'img/xgb2nochi2geo/inv_mass_trainset.png')

# %%
plt_sig_back(df_scaled)
gc.collect()
# Out:
# 2197

# %% [markdown]
# # Creating Train and Test sets
# To make machine learning algorithms more efficient on unseen data we divide our data into two sets. One set is for training the algorithm and the other is for testing the algorithm. If we don't do this then the algorithm can overfit and we will not capture the general trends in the data.

# %%
# The following columns will be used to predict whether a reconstructed candidate is a lambda particle or not
cuts = [ 'loverdl', 'distance', 'chi2topo', 'chi2primfirst', 'chi2primsecond'] # 'chi2geo',


x = df_scaled[cuts].copy()

# The MC information is saved in this y variable
y =pd.DataFrame(df_scaled['issignal'], dtype='int')

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=324)

#DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed. 
dtrain = xgb.DMatrix(x_train, label = y_train)
dtest=xgb.DMatrix(x_test, label = y_test)

# %% [markdown]
# ## Whole set
# We also select the selected variables from the 10k events data set

# %%
x_whole = df_clean[cuts].copy()
y_whole = pd.DataFrame(df_clean['issignal'], dtype='int')

# %% [markdown]
# <p style="font-family: Arial; font-size:3em;color:purple; font-style:bold"><br>XGB Boost
# <br></p><br>

# %%
#DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed. 
dtrain = xgb.DMatrix(x_train, label = y_train)
dtest = xgb.DMatrix(x_whole, label = y_whole)
dtest1=xgb.DMatrix(x_test, label = y_test)

# %% [markdown]
# ## Bayesian optimization
# In order to find the best parameters of XGB for our data we use Bayesian optimization. Grid search and and random search could also do the same job but bayesian is more time efficient. For further reading visit [the git page](https://github.com/fmfn/BayesianOptimization) of the bayesian optimization used here.
#
# ### Hyper parameters
# Some of the following hyper parameters will be tuned for our algorithm:
#
#
# *subsample* [default=1]
# Subsample ratio of the training instances. Setting it to 0.5 means that XGBoost would randomly sample half of the training data prior to growing trees. and this will prevent overfitting. Subsampling will occur once in every boosting iteration.
# range: (0,1]
#
# *eta* [default=0.3, alias: learning_rate]
# Step size shrinkage used in update to prevents overfitting. After each boosting step, we can directly get the weights of new features, and eta shrinks the feature weights to make the boosting process more conservative.
# range: [0,1]
#
#
# *gamma* [default=0, alias: min_split_loss]
# Minimum loss reduction required to make a further partition on a leaf node of the tree. The larger gamma is, the more conservative the algorithm will be.
# range: [0,∞]
#
#
# *alpha* [default=0, alias: reg_alpha]
# L1 regularization term on weights. Increasing this value will make model more conservative.
#
# *Lasso Regression* (Least Absolute Shrinkage and Selection Operator) adds “absolute value of magnitude” of coefficient as penalty term to the loss function.

# %%
#Bayesian Optimization function for xgboost
#specify the parameters you want to tune as keyword arguments
def bo_tune_xgb(max_depth, gamma, alpha, n_estimators ,learning_rate):
    params = {'max_depth': int(max_depth),
              'gamma': gamma,
              'alpha':alpha,
              'n_estimators': n_estimators,
              'learning_rate':learning_rate,
              'subsample': 0.8,
              'eta': 0.1,
              'eval_metric': 'auc', 'nthread' : 7}
    cv_result = xgb.cv(params, dtrain, num_boost_round=70, nfold=5)
    return  cv_result['test-auc-mean'].iloc[-1]

# %%
#Invoking the Bayesian Optimizer with the specified parameters to tune
xgb_bo = BayesianOptimization(bo_tune_xgb, {'max_depth': (4, 10),
                                             'gamma': (0, 1),
                                            'alpha': (2,20),
                                             'learning_rate':(0,1),
                                             'n_estimators':(100,500)
                                            })

# %%
#performing Bayesian optimization for 5 iterations with 8 steps of random exploration with an #acquisition function of expected improvement
xgb_bo.maximize(n_iter=5, init_points=5)
# Out:
# |   iter    |  target   |   alpha   |   gamma   | learni... | max_depth | n_esti... |
# -------------------------------------------------------------------------------------
# [12:44:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 80 pruned nodes, max_depth=9
# [12:44:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 40 pruned nodes, max_depth=9
# [12:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 62 pruned nodes, max_depth=9
# [12:44:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 76 pruned nodes, max_depth=9
# [12:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 58 pruned nodes, max_depth=9
# [12:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 118 pruned nodes, max_depth=9
# [12:44:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 94 pruned nodes, max_depth=9
# [12:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 76 pruned nodes, max_depth=9
# [12:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 88 pruned nodes, max_depth=9
# [12:44:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 110 pruned nodes, max_depth=9
# [12:44:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 106 pruned nodes, max_depth=9
# [12:44:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 90 pruned nodes, max_depth=9
# [12:44:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 100 pruned nodes, max_depth=9
# [12:44:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 106 pruned nodes, max_depth=9
# [12:44:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 102 pruned nodes, max_depth=9
# [12:44:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 120 pruned nodes, max_depth=9
# [12:44:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 116 pruned nodes, max_depth=9
# [12:44:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 90 pruned nodes, max_depth=9
# [12:44:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 98 pruned nodes, max_depth=9
# [12:44:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 142 pruned nodes, max_depth=9
# [12:44:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 156 pruned nodes, max_depth=9
# [12:44:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 306 extra nodes, 170 pruned nodes, max_depth=9
# [12:44:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 154 pruned nodes, max_depth=9
# [12:44:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 124 pruned nodes, max_depth=9
# [12:44:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 142 pruned nodes, max_depth=9
# [12:44:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 180 pruned nodes, max_depth=9
# [12:44:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 204 pruned nodes, max_depth=9
# [12:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 154 pruned nodes, max_depth=9
# [12:44:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 164 pruned nodes, max_depth=9
# [12:44:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 182 pruned nodes, max_depth=9
# [12:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 154 pruned nodes, max_depth=9
# [12:44:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 212 pruned nodes, max_depth=9
# [12:44:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 272 extra nodes, 292 pruned nodes, max_depth=9
# [12:44:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 238 pruned nodes, max_depth=9
# [12:44:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 272 pruned nodes, max_depth=9
# [12:44:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 266 pruned nodes, max_depth=9
# [12:44:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 252 pruned nodes, max_depth=9
# [12:44:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 268 pruned nodes, max_depth=9
# [12:44:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 194 pruned nodes, max_depth=9
# [12:44:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 248 pruned nodes, max_depth=9
# [12:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 272 extra nodes, 296 pruned nodes, max_depth=9
# [12:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 224 pruned nodes, max_depth=9
# [12:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 202 pruned nodes, max_depth=9
# [12:44:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 236 pruned nodes, max_depth=9
# [12:44:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 254 pruned nodes, max_depth=9
# [12:44:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 290 pruned nodes, max_depth=9
# [12:44:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 292 pruned nodes, max_depth=9
# [12:44:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 278 pruned nodes, max_depth=9
# [12:44:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 326 pruned nodes, max_depth=9
# [12:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 302 pruned nodes, max_depth=9
# [12:44:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 222 pruned nodes, max_depth=9
# [12:44:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 260 pruned nodes, max_depth=9
# [12:45:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 208 pruned nodes, max_depth=9
# [12:45:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 234 pruned nodes, max_depth=9
# [12:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 296 pruned nodes, max_depth=9
# [12:45:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 248 pruned nodes, max_depth=9
# [12:45:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 246 pruned nodes, max_depth=9
# [12:45:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 314 pruned nodes, max_depth=9
# [12:45:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 256 pruned nodes, max_depth=9
# [12:45:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 298 pruned nodes, max_depth=9
# [12:45:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 238 pruned nodes, max_depth=9
# [12:45:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 208 pruned nodes, max_depth=9
# [12:45:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 296 pruned nodes, max_depth=9
# [12:45:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 326 pruned nodes, max_depth=9
# [12:45:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 254 pruned nodes, max_depth=9
# [12:45:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 382 pruned nodes, max_depth=9
# [12:45:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 442 pruned nodes, max_depth=9
# [12:45:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 310 pruned nodes, max_depth=9
# [12:45:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 214 pruned nodes, max_depth=9
# [12:45:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 242 pruned nodes, max_depth=9
# [12:45:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 234 pruned nodes, max_depth=9
# [12:45:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 336 pruned nodes, max_depth=9
# [12:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 174 pruned nodes, max_depth=9
# [12:45:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 232 pruned nodes, max_depth=9
# [12:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 210 pruned nodes, max_depth=9
# [12:45:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 280 pruned nodes, max_depth=9
# [12:45:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 288 pruned nodes, max_depth=9
# [12:45:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 384 pruned nodes, max_depth=9
# [12:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 274 pruned nodes, max_depth=9
# [12:45:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 318 pruned nodes, max_depth=9
# [12:45:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 246 pruned nodes, max_depth=9
# [12:45:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 298 pruned nodes, max_depth=9
# [12:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 252 pruned nodes, max_depth=9
# [12:45:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 218 pruned nodes, max_depth=9
# [12:45:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 230 pruned nodes, max_depth=9
# [12:45:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 326 pruned nodes, max_depth=9
# [12:45:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 220 pruned nodes, max_depth=9
# [12:45:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 338 pruned nodes, max_depth=9
# [12:45:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 188 pruned nodes, max_depth=9
# [12:45:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 174 pruned nodes, max_depth=9
# [12:45:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 280 pruned nodes, max_depth=9
# [12:45:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 306 pruned nodes, max_depth=9
# [12:45:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 270 pruned nodes, max_depth=9
# [12:45:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 340 pruned nodes, max_depth=9
# [12:45:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 214 pruned nodes, max_depth=9
# [12:45:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 116 pruned nodes, max_depth=9
# [12:45:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 150 pruned nodes, max_depth=9
# [12:45:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 256 pruned nodes, max_depth=9
# [12:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 188 pruned nodes, max_depth=9
# [12:45:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 332 pruned nodes, max_depth=9
# [12:45:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 270 pruned nodes, max_depth=9
# [12:45:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 398 pruned nodes, max_depth=9
# [12:45:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 338 pruned nodes, max_depth=9
# [12:45:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 346 pruned nodes, max_depth=9
# [12:45:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 404 pruned nodes, max_depth=9
# [12:45:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 192 pruned nodes, max_depth=9
# [12:45:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 210 pruned nodes, max_depth=9
# [12:45:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 242 pruned nodes, max_depth=9
# [12:45:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 192 pruned nodes, max_depth=9
# [12:45:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 306 pruned nodes, max_depth=9
# [12:46:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 306 pruned nodes, max_depth=9
# [12:46:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 292 pruned nodes, max_depth=9
# [12:46:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 228 pruned nodes, max_depth=9
# [12:46:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 234 pruned nodes, max_depth=9
# [12:46:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 186 pruned nodes, max_depth=9
# [12:46:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 274 pruned nodes, max_depth=9
# [12:46:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 202 pruned nodes, max_depth=9
# [12:46:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 150 pruned nodes, max_depth=7
# [12:46:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 190 pruned nodes, max_depth=9
# [12:46:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 260 pruned nodes, max_depth=9
# [12:46:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 330 pruned nodes, max_depth=9
# [12:46:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 306 pruned nodes, max_depth=9
# [12:46:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 106 pruned nodes, max_depth=9
# [12:46:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 244 pruned nodes, max_depth=9
# [12:46:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 240 pruned nodes, max_depth=9
# [12:46:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 168 pruned nodes, max_depth=9
# [12:46:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 172 pruned nodes, max_depth=9
# [12:46:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 246 pruned nodes, max_depth=9
# [12:46:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 304 pruned nodes, max_depth=9
# [12:46:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 254 pruned nodes, max_depth=9
# [12:46:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 210 pruned nodes, max_depth=9
# [12:46:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 298 pruned nodes, max_depth=9
# [12:46:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 224 pruned nodes, max_depth=9
# [12:46:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 296 pruned nodes, max_depth=9
# [12:46:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 166 pruned nodes, max_depth=9
# [12:46:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 260 pruned nodes, max_depth=9
# [12:46:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 250 pruned nodes, max_depth=9
# [12:46:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 166 pruned nodes, max_depth=9
# [12:46:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 172 pruned nodes, max_depth=9
# [12:46:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 186 pruned nodes, max_depth=9
# [12:46:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 332 pruned nodes, max_depth=9
# [12:46:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 286 pruned nodes, max_depth=9
# [12:46:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 334 pruned nodes, max_depth=9
# [12:46:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 156 pruned nodes, max_depth=9
# [12:46:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 344 pruned nodes, max_depth=9
# [12:46:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 192 pruned nodes, max_depth=9
# [12:46:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 134 pruned nodes, max_depth=9
# [12:46:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 242 pruned nodes, max_depth=9
# [12:46:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 106 pruned nodes, max_depth=9
# [12:46:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 238 pruned nodes, max_depth=9
# [12:46:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 270 pruned nodes, max_depth=9
# [12:46:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 254 pruned nodes, max_depth=9
# [12:46:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 300 pruned nodes, max_depth=9
# [12:46:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 296 pruned nodes, max_depth=9
# [12:46:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 198 pruned nodes, max_depth=9
# [12:46:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 128 pruned nodes, max_depth=9
# [12:46:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 290 pruned nodes, max_depth=9
# [12:46:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 164 pruned nodes, max_depth=9
# [12:46:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 288 pruned nodes, max_depth=9
# [12:46:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 200 pruned nodes, max_depth=9
# [12:46:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 202 pruned nodes, max_depth=9
# [12:46:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 232 pruned nodes, max_depth=9
# [12:46:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 278 pruned nodes, max_depth=9
# [12:46:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 220 pruned nodes, max_depth=9
# [12:46:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 140 pruned nodes, max_depth=9
# [12:46:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 172 pruned nodes, max_depth=9
# [12:46:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 202 pruned nodes, max_depth=9
# [12:46:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 202 pruned nodes, max_depth=9
# [12:46:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 266 pruned nodes, max_depth=9
# [12:46:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 290 pruned nodes, max_depth=9
# [12:47:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 236 pruned nodes, max_depth=9
# [12:47:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 196 pruned nodes, max_depth=9
# [12:47:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 276 pruned nodes, max_depth=9
# [12:47:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 334 pruned nodes, max_depth=8
# [12:47:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 218 pruned nodes, max_depth=9
# [12:47:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 268 pruned nodes, max_depth=9
# [12:47:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 228 pruned nodes, max_depth=9
# [12:47:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 226 pruned nodes, max_depth=9
# [12:47:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 162 pruned nodes, max_depth=9
# [12:47:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 250 pruned nodes, max_depth=9
# [12:47:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 208 pruned nodes, max_depth=9
# [12:47:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 278 pruned nodes, max_depth=9
# [12:47:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 242 pruned nodes, max_depth=9
# [12:47:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 186 pruned nodes, max_depth=9
# [12:47:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 210 pruned nodes, max_depth=9
# [12:47:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 208 pruned nodes, max_depth=9
# [12:47:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 160 pruned nodes, max_depth=9
# [12:47:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 254 pruned nodes, max_depth=9
# [12:47:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 316 pruned nodes, max_depth=9
# [12:47:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 244 pruned nodes, max_depth=9
# [12:47:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 206 pruned nodes, max_depth=9
# [12:47:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 152 pruned nodes, max_depth=9
# [12:47:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 250 pruned nodes, max_depth=9
# [12:47:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 162 pruned nodes, max_depth=9
# [12:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 170 pruned nodes, max_depth=9
# [12:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 254 pruned nodes, max_depth=9
# [12:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 180 pruned nodes, max_depth=8
# [12:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 162 pruned nodes, max_depth=9
# [12:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 278 pruned nodes, max_depth=9
# [12:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 196 pruned nodes, max_depth=9
# [12:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 214 pruned nodes, max_depth=9
# [12:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 216 pruned nodes, max_depth=9
# [12:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 218 pruned nodes, max_depth=9
# [12:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 318 pruned nodes, max_depth=9
# [12:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 308 pruned nodes, max_depth=9
# [12:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 316 pruned nodes, max_depth=9
# [12:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 288 pruned nodes, max_depth=9
# [12:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 172 pruned nodes, max_depth=9
# [12:47:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 168 pruned nodes, max_depth=9
# [12:47:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 276 pruned nodes, max_depth=9
# [12:47:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 160 pruned nodes, max_depth=9
# [12:47:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 296 pruned nodes, max_depth=9
# [12:47:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 272 pruned nodes, max_depth=9
# [12:47:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 264 pruned nodes, max_depth=9
# [12:47:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 108 pruned nodes, max_depth=0
# [12:47:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 92 pruned nodes, max_depth=6
# [12:47:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 346 pruned nodes, max_depth=9
# [12:47:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 176 pruned nodes, max_depth=9
# [12:47:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 174 pruned nodes, max_depth=9
# [12:47:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 200 pruned nodes, max_depth=7
# [12:47:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 160 pruned nodes, max_depth=9
# [12:47:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 198 pruned nodes, max_depth=9
# [12:47:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 202 pruned nodes, max_depth=8
# [12:47:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 284 pruned nodes, max_depth=9
# [12:47:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 194 pruned nodes, max_depth=9
# [12:47:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 194 pruned nodes, max_depth=9
# [12:47:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 296 pruned nodes, max_depth=9
# [12:47:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 216 pruned nodes, max_depth=9
# [12:47:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 244 pruned nodes, max_depth=9
# [12:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 324 pruned nodes, max_depth=9
# [12:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 154 pruned nodes, max_depth=9
# [12:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 332 pruned nodes, max_depth=9
# [12:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 206 pruned nodes, max_depth=9
# [12:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 202 pruned nodes, max_depth=9
# [12:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 190 pruned nodes, max_depth=9
# [12:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 292 pruned nodes, max_depth=9
# [12:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 120 pruned nodes, max_depth=9
# [12:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 320 pruned nodes, max_depth=9
# [12:48:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 210 pruned nodes, max_depth=9
# [12:48:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 290 pruned nodes, max_depth=9
# [12:48:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 212 pruned nodes, max_depth=8
# [12:48:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 274 pruned nodes, max_depth=9
# [12:48:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 246 pruned nodes, max_depth=9
# [12:48:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 340 pruned nodes, max_depth=9
# [12:48:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 210 pruned nodes, max_depth=9
# [12:48:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 292 pruned nodes, max_depth=9
# [12:48:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 210 pruned nodes, max_depth=9
# [12:48:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 228 pruned nodes, max_depth=9
# [12:48:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 234 pruned nodes, max_depth=9
# [12:48:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 294 pruned nodes, max_depth=9
# [12:48:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 216 pruned nodes, max_depth=9
# [12:48:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 316 pruned nodes, max_depth=9
# [12:48:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 138 pruned nodes, max_depth=9
# [12:48:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 204 pruned nodes, max_depth=9
# [12:48:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 210 pruned nodes, max_depth=9
# [12:48:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 232 pruned nodes, max_depth=9
# [12:48:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 200 pruned nodes, max_depth=5
# [12:48:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 282 pruned nodes, max_depth=9
# [12:48:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 278 pruned nodes, max_depth=9
# [12:48:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 334 pruned nodes, max_depth=9
# [12:48:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 196 pruned nodes, max_depth=9
# [12:48:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 254 pruned nodes, max_depth=9
# [12:48:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 198 pruned nodes, max_depth=9
# [12:48:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 188 pruned nodes, max_depth=8
# [12:48:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 190 pruned nodes, max_depth=9
# [12:48:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 268 pruned nodes, max_depth=9
# [12:48:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 288 pruned nodes, max_depth=9
# [12:48:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 172 pruned nodes, max_depth=9
# [12:48:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 118 pruned nodes, max_depth=9
# [12:48:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 270 pruned nodes, max_depth=9
# [12:48:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 188 pruned nodes, max_depth=9
# [12:48:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 274 pruned nodes, max_depth=9
# [12:48:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 174 pruned nodes, max_depth=9
# [12:48:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 256 pruned nodes, max_depth=9
# [12:48:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 300 pruned nodes, max_depth=9
# [12:48:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 204 pruned nodes, max_depth=9
# [12:48:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 272 pruned nodes, max_depth=9
# [12:48:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 120 pruned nodes, max_depth=9
# [12:48:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 192 pruned nodes, max_depth=9
# [12:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 150 pruned nodes, max_depth=9
# [12:48:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 268 pruned nodes, max_depth=9
# [12:48:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 230 pruned nodes, max_depth=9
# [12:48:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 252 pruned nodes, max_depth=9
# [12:48:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 268 pruned nodes, max_depth=9
# [12:48:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 202 pruned nodes, max_depth=8
# [12:48:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 288 pruned nodes, max_depth=9
# [12:48:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 312 pruned nodes, max_depth=9
# [12:48:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 124 pruned nodes, max_depth=9
# [12:48:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 226 pruned nodes, max_depth=9
# [12:48:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 340 pruned nodes, max_depth=9
# [12:48:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 174 pruned nodes, max_depth=9
# [12:48:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 206 pruned nodes, max_depth=8
# [12:48:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 232 pruned nodes, max_depth=9
# [12:48:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 268 pruned nodes, max_depth=8
# [12:49:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 232 pruned nodes, max_depth=9
# [12:49:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 166 pruned nodes, max_depth=9
# [12:49:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 238 pruned nodes, max_depth=9
# [12:49:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 440 pruned nodes, max_depth=9
# [12:49:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 304 pruned nodes, max_depth=9
# [12:49:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 226 pruned nodes, max_depth=9
# [12:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 368 pruned nodes, max_depth=9
# [12:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 338 pruned nodes, max_depth=9
# [12:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 148 pruned nodes, max_depth=9
# [12:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 270 pruned nodes, max_depth=9
# [12:49:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 308 pruned nodes, max_depth=9
# [12:49:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 308 pruned nodes, max_depth=9
# [12:49:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 252 pruned nodes, max_depth=9
# [12:49:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 212 pruned nodes, max_depth=9
# [12:49:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 258 pruned nodes, max_depth=9
# [12:49:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 238 pruned nodes, max_depth=9
# [12:49:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 190 pruned nodes, max_depth=9
# [12:49:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 212 pruned nodes, max_depth=9
# [12:49:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 202 pruned nodes, max_depth=9
# [12:49:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 314 pruned nodes, max_depth=9
# [12:49:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 300 pruned nodes, max_depth=9
# [12:49:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 224 pruned nodes, max_depth=8
# [12:49:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 220 pruned nodes, max_depth=9
# [12:49:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 232 pruned nodes, max_depth=9
# [12:49:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 294 pruned nodes, max_depth=9
# [12:49:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 302 pruned nodes, max_depth=9
# [12:49:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 214 pruned nodes, max_depth=9
# [12:49:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 154 pruned nodes, max_depth=9
# [12:49:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 386 pruned nodes, max_depth=9
# [12:49:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 144 pruned nodes, max_depth=9
# [12:49:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 226 pruned nodes, max_depth=9
# [12:49:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 220 pruned nodes, max_depth=9
# [12:49:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 340 pruned nodes, max_depth=9
# [12:49:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 140 pruned nodes, max_depth=9
# [12:49:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 302 pruned nodes, max_depth=9
# [12:49:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 166 pruned nodes, max_depth=9
# [12:49:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 334 pruned nodes, max_depth=9
# [12:49:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 308 pruned nodes, max_depth=9
# [12:49:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 136 pruned nodes, max_depth=9
# [12:49:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 296 pruned nodes, max_depth=9
# [12:49:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 202 pruned nodes, max_depth=9
# [12:49:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 312 pruned nodes, max_depth=9
# [12:49:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 198 pruned nodes, max_depth=9
# [12:49:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 274 pruned nodes, max_depth=9
# [12:49:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 194 pruned nodes, max_depth=9
# [12:49:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 346 pruned nodes, max_depth=9
# [12:49:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 144 pruned nodes, max_depth=9
# [12:49:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 186 pruned nodes, max_depth=9
# [12:49:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 230 pruned nodes, max_depth=9
# [12:49:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 194 pruned nodes, max_depth=9
# [12:49:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 288 pruned nodes, max_depth=9
# [12:49:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 188 pruned nodes, max_depth=9
# [12:49:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 238 pruned nodes, max_depth=9
# [12:49:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 336 pruned nodes, max_depth=9
# [12:49:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 282 pruned nodes, max_depth=9
# [12:49:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 206 pruned nodes, max_depth=9
# |  1        |  0.9965   |  2.136    |  0.2323   |  0.4041   |  9.553    |  486.0    |
# [12:50:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 6 pruned nodes, max_depth=7
# [12:50:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 4 pruned nodes, max_depth=7
# [12:50:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 6 pruned nodes, max_depth=7
# [12:50:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 6 pruned nodes, max_depth=7
# [12:50:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 6 pruned nodes, max_depth=7
# [12:50:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 14 pruned nodes, max_depth=7
# [12:50:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 16 pruned nodes, max_depth=7
# [12:50:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 16 pruned nodes, max_depth=7
# [12:50:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 4 pruned nodes, max_depth=7
# [12:50:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 10 pruned nodes, max_depth=7
# [12:50:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 16 pruned nodes, max_depth=7
# [12:50:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 8 pruned nodes, max_depth=7
# [12:50:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 18 pruned nodes, max_depth=7
# [12:50:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 8 pruned nodes, max_depth=7
# [12:50:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 16 pruned nodes, max_depth=7
# [12:50:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 4 pruned nodes, max_depth=7
# [12:50:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 10 pruned nodes, max_depth=7
# [12:50:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 12 pruned nodes, max_depth=7
# [12:50:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 14 pruned nodes, max_depth=7
# [12:50:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 16 pruned nodes, max_depth=7
# [12:50:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 26 pruned nodes, max_depth=7
# [12:50:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 8 pruned nodes, max_depth=7
# [12:50:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 10 pruned nodes, max_depth=7
# [12:50:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 4 pruned nodes, max_depth=7
# [12:50:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 20 pruned nodes, max_depth=7
# [12:50:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 18 pruned nodes, max_depth=7
# [12:50:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 16 pruned nodes, max_depth=7
# [12:50:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 20 pruned nodes, max_depth=7
# [12:50:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 16 pruned nodes, max_depth=7
# [12:50:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 16 pruned nodes, max_depth=7
# [12:50:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 36 pruned nodes, max_depth=7
# [12:50:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 40 pruned nodes, max_depth=7
# [12:50:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 12 pruned nodes, max_depth=7
# [12:50:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 30 pruned nodes, max_depth=7
# [12:50:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 22 pruned nodes, max_depth=7
# [12:50:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 32 pruned nodes, max_depth=7
# [12:50:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 24 pruned nodes, max_depth=7
# [12:50:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 26 pruned nodes, max_depth=7
# [12:50:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 24 pruned nodes, max_depth=7
# [12:50:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 20 pruned nodes, max_depth=7
# [12:50:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 36 pruned nodes, max_depth=7
# [12:50:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 36 pruned nodes, max_depth=7
# [12:50:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 28 pruned nodes, max_depth=7
# [12:50:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 46 pruned nodes, max_depth=7
# [12:50:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 48 pruned nodes, max_depth=7
# [12:50:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 46 pruned nodes, max_depth=7
# [12:50:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 52 pruned nodes, max_depth=7
# [12:50:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 26 pruned nodes, max_depth=7
# [12:50:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 40 pruned nodes, max_depth=7
# [12:50:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 46 pruned nodes, max_depth=7
# [12:50:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 74 pruned nodes, max_depth=7
# [12:50:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 30 pruned nodes, max_depth=7
# [12:50:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 54 pruned nodes, max_depth=7
# [12:50:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 56 pruned nodes, max_depth=7
# [12:50:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 44 pruned nodes, max_depth=7
# [12:50:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 56 pruned nodes, max_depth=7
# [12:50:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 56 pruned nodes, max_depth=7
# [12:50:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 60 pruned nodes, max_depth=7
# [12:50:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 58 pruned nodes, max_depth=7
# [12:50:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 36 pruned nodes, max_depth=7
# [12:50:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 52 pruned nodes, max_depth=7
# [12:50:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 50 pruned nodes, max_depth=7
# [12:50:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 52 pruned nodes, max_depth=7
# [12:50:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 56 pruned nodes, max_depth=7
# [12:50:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 62 pruned nodes, max_depth=7
# [12:50:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 84 pruned nodes, max_depth=7
# [12:50:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 56 pruned nodes, max_depth=7
# ...
# [13:31:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 64 pruned nodes, max_depth=6
# [13:32:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 58 pruned nodes, max_depth=7
# [13:32:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 52 pruned nodes, max_depth=7
# [13:32:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 62 pruned nodes, max_depth=7
# [13:32:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 48 pruned nodes, max_depth=7
# [13:32:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 56 pruned nodes, max_depth=7
# [13:32:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 42 pruned nodes, max_depth=7
# [13:32:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 56 pruned nodes, max_depth=7
# [13:32:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 62 pruned nodes, max_depth=7
# [13:32:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 62 pruned nodes, max_depth=7
# [13:32:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 40 pruned nodes, max_depth=7
# [13:32:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 62 pruned nodes, max_depth=7
# [13:32:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 60 pruned nodes, max_depth=7
# [13:32:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 36 pruned nodes, max_depth=7
# [13:32:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 52 pruned nodes, max_depth=7
# [13:32:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 56 pruned nodes, max_depth=7
# [13:32:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 48 pruned nodes, max_depth=7
# [13:32:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 38 pruned nodes, max_depth=7
# [13:32:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 72 pruned nodes, max_depth=7
# [13:32:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 50 pruned nodes, max_depth=7
# [13:32:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 18 pruned nodes, max_depth=7
# [13:32:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 52 pruned nodes, max_depth=7
# [13:32:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 34 pruned nodes, max_depth=7
# [13:32:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 52 pruned nodes, max_depth=7
# [13:32:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 60 pruned nodes, max_depth=7
# [13:32:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 64 pruned nodes, max_depth=7
# [13:32:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 50 pruned nodes, max_depth=7
# [13:32:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 72 pruned nodes, max_depth=7
# [13:32:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 70 pruned nodes, max_depth=7
# [13:32:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 62 pruned nodes, max_depth=7
# [13:32:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 38 pruned nodes, max_depth=7
# [13:32:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 44 pruned nodes, max_depth=7
# [13:32:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 42 pruned nodes, max_depth=7
# [13:32:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 50 pruned nodes, max_depth=7
# [13:32:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 66 pruned nodes, max_depth=7
# [13:32:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 48 pruned nodes, max_depth=7
# [13:32:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 66 pruned nodes, max_depth=7
# [13:32:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 46 pruned nodes, max_depth=7
# [13:32:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 48 pruned nodes, max_depth=6
# [13:32:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 48 pruned nodes, max_depth=7
# [13:32:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 90 pruned nodes, max_depth=7
# [13:32:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 66 pruned nodes, max_depth=7
# [13:32:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 64 pruned nodes, max_depth=7
# [13:32:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 58 pruned nodes, max_depth=7
# [13:32:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 50 pruned nodes, max_depth=7
# [13:32:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 32 pruned nodes, max_depth=7
# [13:32:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 42 pruned nodes, max_depth=7
# [13:32:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 52 pruned nodes, max_depth=7
# [13:32:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 56 pruned nodes, max_depth=7
# [13:32:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 80 pruned nodes, max_depth=6
# [13:32:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 72 pruned nodes, max_depth=7
# [13:32:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 56 pruned nodes, max_depth=7
# [13:32:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 66 pruned nodes, max_depth=7
# [13:32:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 40 pruned nodes, max_depth=7
# [13:32:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 58 pruned nodes, max_depth=7
# [13:32:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 52 pruned nodes, max_depth=7
# [13:32:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 32 pruned nodes, max_depth=7
# [13:32:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 56 pruned nodes, max_depth=7
# [13:32:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 50 pruned nodes, max_depth=7
# [13:32:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 50 pruned nodes, max_depth=7
# [13:32:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 54 pruned nodes, max_depth=7
# [13:32:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 50 pruned nodes, max_depth=7
# [13:32:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 52 pruned nodes, max_depth=7
# [13:33:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 50 pruned nodes, max_depth=7
# [13:33:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 58 pruned nodes, max_depth=7
# [13:33:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 44 pruned nodes, max_depth=7
# [13:33:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 64 pruned nodes, max_depth=7
# [13:33:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 40 pruned nodes, max_depth=7
# [13:33:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 64 pruned nodes, max_depth=7
# [13:33:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 72 pruned nodes, max_depth=7
# [13:33:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 46 pruned nodes, max_depth=7
# [13:33:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 66 pruned nodes, max_depth=7
# [13:33:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 50 pruned nodes, max_depth=7
# [13:33:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 92 pruned nodes, max_depth=7
# [13:33:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 52 pruned nodes, max_depth=7
# [13:33:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 52 pruned nodes, max_depth=7
# [13:33:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 50 pruned nodes, max_depth=7
# [13:33:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 38 pruned nodes, max_depth=7
# [13:33:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 94 pruned nodes, max_depth=7
# [13:33:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 64 pruned nodes, max_depth=7
# [13:33:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 44 pruned nodes, max_depth=7
# [13:33:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 60 pruned nodes, max_depth=7
# [13:33:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 72 pruned nodes, max_depth=7
# [13:33:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 42 pruned nodes, max_depth=7
# [13:33:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 42 pruned nodes, max_depth=7
# [13:33:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 32 pruned nodes, max_depth=7
# [13:33:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 88 pruned nodes, max_depth=7
# [13:33:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 84 pruned nodes, max_depth=7
# [13:33:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 72 pruned nodes, max_depth=7
# [13:33:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 78 pruned nodes, max_depth=4
# [13:33:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 42 pruned nodes, max_depth=7
# [13:33:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 40 pruned nodes, max_depth=7
# [13:33:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 36 pruned nodes, max_depth=7
# [13:33:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 54 pruned nodes, max_depth=6
# [13:33:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 50 pruned nodes, max_depth=7
# [13:33:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 48 pruned nodes, max_depth=7
# [13:33:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 24 pruned nodes, max_depth=7
# [13:33:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 92 pruned nodes, max_depth=7
# [13:33:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 48 pruned nodes, max_depth=7
# [13:33:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 78 pruned nodes, max_depth=7
# [13:33:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 106 pruned nodes, max_depth=7
# [13:33:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 52 pruned nodes, max_depth=7
# [13:33:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 68 pruned nodes, max_depth=0
# [13:33:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 60 pruned nodes, max_depth=7
# [13:33:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 64 pruned nodes, max_depth=6
# [13:33:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 60 pruned nodes, max_depth=7
# [13:33:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 38 pruned nodes, max_depth=7
# [13:33:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 44 pruned nodes, max_depth=7
# [13:33:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 36 pruned nodes, max_depth=7
# [13:33:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 48 pruned nodes, max_depth=7
# [13:33:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 42 pruned nodes, max_depth=7
# [13:33:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 46 pruned nodes, max_depth=5
# [13:33:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 70 pruned nodes, max_depth=7
# [13:33:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 56 pruned nodes, max_depth=7
# [13:33:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 60 pruned nodes, max_depth=7
# [13:33:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 78 pruned nodes, max_depth=7
# [13:33:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 84 pruned nodes, max_depth=7
# [13:33:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 48 pruned nodes, max_depth=7
# [13:33:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 48 pruned nodes, max_depth=7
# [13:33:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 60 pruned nodes, max_depth=7
# [13:33:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 70 pruned nodes, max_depth=7
# [13:33:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 82 pruned nodes, max_depth=7
# [13:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 62 pruned nodes, max_depth=7
# [13:33:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 48 pruned nodes, max_depth=7
# [13:33:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 78 pruned nodes, max_depth=7
# [13:34:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 62 pruned nodes, max_depth=7
# [13:34:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 50 pruned nodes, max_depth=7
# [13:34:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 58 pruned nodes, max_depth=7
# [13:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 52 pruned nodes, max_depth=7
# [13:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 36 pruned nodes, max_depth=7
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 38 pruned nodes, max_depth=7
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 72 pruned nodes, max_depth=7
# [13:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 52 pruned nodes, max_depth=7
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 78 pruned nodes, max_depth=7
# [13:34:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 52 pruned nodes, max_depth=7
# [13:34:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 24 pruned nodes, max_depth=7
# [13:34:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 50 pruned nodes, max_depth=7
# [13:34:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 68 pruned nodes, max_depth=7
# [13:34:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 50 pruned nodes, max_depth=7
# [13:34:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 74 pruned nodes, max_depth=7
# |  10       |  0.9971   |  16.44    |  0.1604   |  0.1693   |  7.992    |  365.9    |
# =====================================================================================

# %%
# best target so far 0.9974344
print(xgb_bo.max)
# Out:
# {'target': 0.9971880000000001, 'params': {'alpha': 17.233922395612648, 'gamma': 0.22032087441248616, 'learning_rate': 0.1272880194063747, 'max_depth': 7.597241992365195, 'n_estimators': 365.8938238457542}}

# %% [markdown]
# # XGB models
# Now let's take the parameters selected by the bayesian optimization and apply them in our training and testing.

# %%
max_param = xgb_bo.max['params']
param= {'alpha': max_param['alpha'], 'gamma': max_param['gamma'], 'learning_rate': max_param['learning_rate'], 'max_depth': int(round(max_param['max_depth'],0)), 'n_estimators': int(round(max_param['n_estimators'],0)), 'objective': 'reg:logistic'}

# %%
#To train the algorithm using the parameters selected by bayesian optimization
bst = xgb.train(param, dtrain)
# Out:
# [13:34:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 2 pruned nodes, max_depth=8
# [13:34:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 12 pruned nodes, max_depth=8
# [13:34:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=8
# [13:34:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 2 pruned nodes, max_depth=8
# [13:34:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 10 pruned nodes, max_depth=8
# [13:34:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=8
# [13:34:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 18 pruned nodes, max_depth=8
# [13:34:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 6 pruned nodes, max_depth=8
# [13:34:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 6 pruned nodes, max_depth=8
# [13:34:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 6 pruned nodes, max_depth=8

# %%
#We apply our model on the training data that was trained on the training data, this helps us to control overfitting
bst1= bst.predict(dtrain)

# %%
# We apply our trained model on test data and store the predictions in a bst_test dataframe
bst_test = pd.DataFrame(data=bst.predict(dtest1),  columns=["xgb_preds"])
y_test=y_test.set_index(np.arange(0,bst_test.shape[0]))
# We also store the MC information in this dataFrame
bst_test['issignal']=y_test['issignal']

# %%
#The following graph will show us that which features are important for the model
ax = xgb.plot_importance(bst)
plt.rcParams['figure.figsize'] = [5, 3]
plt.show()
ax.figure.tight_layout() 
ax.figure.savefig(directory+'img/xgb2nochi2geo/feature_importance.pdf')
ax.figure.savefig(directory+'img/xgb2nochi2geo/feature_importance.png')

# %% [markdown]
# ## AUC and ROC
#
# The function roc_curve computes the receiver operating characteristic curve, or ROC curve. Quoting Wikipedia :
#
# “A receiver operating characteristic (ROC), or simply ROC curve, is a graphical plot which illustrates the performance of a binary classifier system as its discrimination threshold is varied. It is created by plotting the fraction of true positives out of the positives (TPR = true positive rate) vs. the fraction of false positives out of the negatives (FPR = false positive rate), at various threshold settings. TPR is also known as sensitivity, and FPR is one minus the specificity or true negative rate.”
#
# This function requires the true binary value and the target scores, which can either be probability estimates of the positive class, confidence values, or binary decisions.
#
# Similarly, the function roc_auc_score computes Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.

# %% [markdown]
# To find the best threshold which results more signal to background ratio for lambda candidates we use the parameter S0 called the approximate median significance by the higgs boson  ML challenge (http://higgsml.lal.in2p3.fr/documentation,9.)

# %%
def AMS(y_true, y_predict, y_true1, y_predict1):
    roc_auc=roc_auc_score(y_true, y_predict)
    fpr, tpr, thresholds = roc_curve(y_true, y_predict,drop_intermediate=False ,pos_label=1)
    S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
    S0 = S0[~np.isnan(S0)]
    xi = argmax(S0)
    S0_best_threshold = (thresholds[xi])

    roc_auc1=roc_auc_score(y_true1, y_predict1)
    fpr1, tpr1, thresholds1 = roc_curve(y_true1, y_predict1,drop_intermediate=False ,pos_label=1)
    S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))
    S01 = S01[~np.isnan(S01)]
    xi1 = argmax(S01)
    S0_best_threshold1 = (thresholds[xi1])

    #plotting
    fig, axs = plt.subplots(figsize=(15, 10), dpi = 100)
    plt.plot(fpr, tpr, linestyle=':',color='darkorange',label='ROC curve train (area = %0.4f)' % roc_auc)
    plt.plot(fpr1, tpr1, color='green',label='ROC curve test (area = %0.4f)' % roc_auc1)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.scatter(fpr[xi], tpr[xi], marker='o', color='black', label= 'Best Threshold train set = '+"%.4f" % S0_best_threshold +'\n S0 = '+ "%.2f" % S0[xi])
    plt.scatter(fpr1[xi1], tpr1[xi1], marker='o', color='blue', label= 'Best Threshold test set = '+"%.4f" % S0_best_threshold1 +'\n S0 = '+ "%.2f" % S01[xi1])
    plt.xlabel('False Positive Rate', fontsize = 15)
    plt.ylabel('True Positive Rate', fontsize = 15)
    plt.legend(loc="lower right", fontsize = 15)
    plt.title('Receiver operating characteristic', fontsize = 15)
    plt.xlim([-0.01, 1.0])
    plt.ylim([0, 1.02])
    
    fig.tight_layout()
    plt.show()
    fig.savefig(directory+'img/xgb2nochi2geo/ams.pdf')
    fig.savefig(directory+'img/xgb2nochi2geo/ams.png')

    return S0_best_threshold, S0_best_threshold1

# %%
train_best, test_best = AMS(y_train, bst1, y_test, bst_test['xgb_preds'])
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_2219/830893230.py:4: RuntimeWarning: invalid value encountered in true_divide
#   S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_2219/830893230.py:11: RuntimeWarning: invalid value encountered in true_divide
#   S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))

# %% [markdown]
# When the AUC, best threshold and approximate median significance for train and test are nearly the same, we save that model and use it. This means that our model is general enough. In my opinion, if the test S0 is above 3.0 then it is a good enough model.

# %% [markdown]
# ## Applying the model on the 10k events data-set

# %%
df_clean['xgb_preds'] = bst.predict(dtest)

# %%
df_clean['xgb_preds'].hist(bins=300)
plt.yscale('log')

# %% [markdown]
# ## Confusion Matrix
#
# A **Confusion Matrix** $C$ is such that $C_{ij}$ is equal to the number of observations known to be in group $i$ and predicted to be in group $j$. Thus in binary classification, the count of true positives is $C_{00}$, false negatives $C_{01}$,false positives is $C_{10}$, and true neagtives is $C_{11}$.
#
# If $ y^{'}_{i} $ is the predicted value of the $ i$-th sample and $y_{i}$ is the corresponding true value, then the fraction of correct predictions over $ n_{samples}$ is defined as
# $$
# True \: positives (y,y^{'}) =  \sum_{i=1}^{n_{samples} } 1 (y^{'}_{i} = y_{i}=1)
# $$
#
# The following function prints and plots the confusion matrix. Normalization can be applied by setting `normalize=True`.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
#calculate efficency and false tu tru signal ratio
def confustion_stats(df, cm):
    all_signals = len(df.loc[df['issignal'] == 1])
    true_signal = cm[0][0]
    false_signal = cm[1][0]        
    reconstructed_signals = true_signal + false_signal
    false_to_true_signals = false_signal / true_signal
    efficiency = reconstructed_signals / all_signals * 100 #efficency in % for all
    efficiency_true = true_signal / all_signals * 100 #efficency in % for all
    print("Efficiency: " + str(round(efficiency, 2)) + "%")
    print("Efficiency of true signal candidates reconstruction: " + str(round(efficiency_true, 2)) + "%")
    print("False tu true reconstructed signal ratio: " + str(round(false_to_true_signals, 2)))

# %%
#lets take the best threshold and look at the confusion matrix
cut1 = test_best
df_clean['xgb_preds1'] = ((df_clean['xgb_preds']>cut1)*1)
cnf_matrix = confusion_matrix(y_whole, df_clean['xgb_preds1'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix, classes=['signal','background'], title='Confusion Matrix for XGB for cut > '+str(cut1))
fig.savefig(directory+'img/xgb2nochi2geo/confusion_matrix_extreme_gradient_boosting_whole_data.pdf')
fig.savefig(directory+'img/xgb2nochi2geo/confusion_matrix_extreme_gradient_boosting_whole_data.png')
# Out:
# Confusion matrix, without normalization
# [[   12872     1599]
#  [    3345 28722372]]

# %%
confustion_stats(df_clean, cnf_matrix)
# Out:
# Efficiency: 112.07%
# Efficiency of true signal candidates reconstruction: 88.95%
# False tu true reconstructed signal ratio: 0.26

# %%
# The following function will display the inavriant mass histogram of the original 10k event set along with the mass histoigram after we apply a cut
# on the probability prediction of xgb
def cut_visualization(cut, range1=(lowerMassCut, upperMassCut), bins1= 300 ):
    mask1 = df_clean['xgb_preds']>cut
    df3=df_clean[mask1]
    
    fig, ax2 = plt.subplots(figsize=(15, 10), dpi = 200)
    color = 'tab:blue'
    ax2.hist(df_clean['mass'],bins = bins1, range=range1, facecolor='blue',alpha = 0.35, label='before selection')
    ax2.set_ylabel('Counts', fontsize = 15, color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.legend( fontsize = 15, loc='upper left')
    
    color = 'tab:red'
    ax1 = ax2.twinx()
    ax1.hist(df3['mass'], bins = bins1, range=range1, facecolor='red',alpha = 0.35, label='XGB')
    ax1.set_xlabel('Mass in GeV', fontsize = 15)
    ax1.set_ylabel('Counts ', fontsize = 15, color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.legend( fontsize = 15,loc='upper right' )

    plt.title("The original sample's Invariant Mass along with mass after selection of XGB (with a cut > "+str(cut)+')', fontsize = 15)
    fig.tight_layout()
    fig.savefig(directory+'img/xgb2nochi2geo/whole_sample_invmass_with_ML.pdf')
    fig.savefig(directory+'img/xgb2nochi2geo/whole_sample_invmass_with_ML.png')

# %%
cut_visualization(test_best)

# %% [markdown]
# # Comparison with the manually optimized cuts of KFPF
# In the already existing Kalman Filter Particle Finder (KFPF) package for online reconstruction and selection of short-lived particles in CBM, these criteria have been manually optimized. These selection-cuts have been selected to maximize the signal to background ratio (S/B) of the $\Lambda$ for a certain energy on a collisions generator. The selection criteria mainly depends on the collision energy, decay channel and detector configuration.

# %%
#manually selected cuts
manCut_loverdl = 30
manCut_dca = 0.4
manCut_chi2topo = 20
manCut_chi2geo = 12

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
new_check_set= df_clean.copy()
new_check_set['new_signal']=0

mask1 = (new_check_set['loverdl'] > manCut_loverdl) & (new_check_set['distance'] < manCut_dca)

mask2 = (new_check_set['chi2topo'] < manCut_chi2topo) & (new_check_set['chi2geo'] < manCut_chi2geo) 

new_check_set = new_check_set[(mask1) & (mask2)] 

#After all these cuts, what is left is considered as signal, so we replace all the values in the 'new_signal'
# column by 1
new_check_set['new_signal'] = 1
cnf_matrix1 = confusion_matrix(new_check_set['issignal'], new_check_set['new_signal'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix1, classes=['signal','background'], title='Confusion Matrix for manually set cuts')
fig.savefig(directory+'img/xgb2nochi2geo/confusion_matrix_for_manually_set_cuts.pdf')
fig.savefig(directory+'img/xgb2nochi2geo/confusion_matrix_for_manually_set_cuts.png')
# Out:
# Confusion matrix, without normalization
# [[11112     0]
#  [ 4502     0]]

# %%
confustion_stats(df_clean, cnf_matrix1)
# Out:
# Efficiency: 107.9%
# Efficiency of true signal candidates reconstruction: 76.79%
# False tu true reconstructed signal ratio: 0.41

# %%
cut3 = test_best
mask1 = df_clean['xgb_preds']>cut3
df3=df_clean[mask1]

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=200)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=200)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
#axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb2nochi2geo/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb2nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
from matplotlib import gridspec

range1= (0.4, 0.6)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 100, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 100, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables (close up)", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=100)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=100)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb2nochi2geo/kaon_inv_mass_comparison_closeup.png')
fig.savefig(directory+'img/xgb2nochi2geo/kaon_inv_mass_comparison_closeup.pdf')

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
axs[0].set_yscale('log')
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=300)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=300)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].set_ylim([0.,2.])
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb2nochi2geo/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb2nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
#del x,y,x_test,y_test,x_whole,y_whole,
#del dtest,dtrain,dtest1,df3,df_clean,df_scaled
gc.collect()
# Out:
# 6044

# %% [markdown]
# # Importing the final predictor to root
# We will use the treelite library to transport the final predictor of our model to root

# %% [raw]
# #install treelite
# import treelite
# #create an object out of your model, bst in our case
# model = treelite.Model.from_xgboost(bst)
# #use GCC compiler
# toolchain = 'gcc'
# #parallel_comp can be changed upto as many processors as one have
# model.export_lib(toolchain=toolchain, libpath='./mymodel.so',
#                  params={'parallel_comp': 8}, verbose=True)
#
# # Operating system of the target machine
# platform = 'unix'
# # C compiler to use to compile prediction code on the target machine
# toolchain = 'gcc'
# # Save the source package as a zip archive named mymodel.zip
# # Later, we'll use this package to produce the library mymodel.so.
# model.export_srcpkg(platform=platform, toolchain=toolchain,
#                     pkgpath='./mymodel.zip', libname='mymodel.so',
#                     verbose=True)

# %% [raw]
# !unzip mymodel.zip

# %% [raw]
# #Build the source package (using GNU Make or NMake).
# %cd mymodel
# !make
#
# !ls

# %% [raw]
# If one wants to transfer this model to a different computer, target machine, then one should follow the following commands in command prompt

# %% [raw]
# sftp john@lxpool.gsi.de
# sftp> put mymodel.zip
# sftp> quit

# %% [raw]
# ssh john@lxpool.gsi.de
# unzip mymodel.zip
# cd mymodel
# make -j8

# %% [raw]
# The following C++ code can be the applied as a macro on some new data file

# %% [raw]
# %%writefile test.cpp
# #include "TROOT.h"
# #include "TFile.h"
# #include "TTree.h"
# #include "TH1F.h"
# #include <vector>
# #include "TString.h"
# #include "TMath.h"
# #include "TH1.h"
# #include "TF1.h"
# #include "TCanvas.h"
#
# #include <stdio.h>
# #include <stdlib.h>
# #include "main.c"
#
#
#
# void python_to_root(){
#   TCanvas* c1 = new TCanvas();
#   //c1->Divide(2,1);
#
#   //c1->cd(1);
#
#   /* Open the root file*/
#   TFile *f = new TFile("/gdrive/My Drive/presentations/treelite/10k_events_PFSimplePlainTree.root","UPDATE");
#   TTree *t1 = (TTree*)f->Get("PlainTree");
#
#
#   Float_t  LambdaCandidates_chi2primneg, LambdaCandidates_chi2primpos, LambdaCandidates_ldl, LambdaCandidates_distance, LambdaCandidates_chi2geo, LambdaCandidates_mass;
#
#   t1->SetBranchAddress("LambdaCandidates_chi2primneg",&LambdaCandidates_chi2primneg);
#   t1->SetBranchAddress("LambdaCandidates_chi2primpos",&LambdaCandidates_chi2primpos);
#   t1->SetBranchAddress("LambdaCandidates_ldl",&LambdaCandidates_ldl);
#   t1->SetBranchAddress("LambdaCandidates_distance",&LambdaCandidates_distance);
#   t1->SetBranchAddress("LambdaCandidates_chi2geo",&LambdaCandidates_chi2geo);
#   t1->SetBranchAddress("LambdaCandidates_mass",&LambdaCandidates_mass);
#
#
#   std::vector<float> output{};
#
#   const long n_entries = t1->GetEntries();
#   output.reserve(n_entries);
#
#   const size_t n_features = 5;
#   union Entry input[n_features];
#
#   //let's create a new branch which will store the probability returened for each proton-pion pair by our model
#   Float_t probab;
#   TBranch *bpt = t1->Branch("probab",&probab,"probabilities");
#   t1->SetBranchAddress("probab",&probab);
#
#   TH1F *h = new TH1F("h_prob", "This is the #Lambda invariant mass after the cut >0.918080", 300, 1.04, 1.4);
#   h->GetXaxis()->SetTitle("[GeV]");
#
#   for (long i = 0; i < n_entries; i++)
#    {
#      t1->GetEntry(i);
#
#     input[0].fvalue = LambdaCandidates_chi2primneg;
#     input[1].fvalue = LambdaCandidates_chi2primpos;
#     input[2].fvalue = LambdaCandidates_ldl;
#     input[3].fvalue = LambdaCandidates_distance;
#     input[4].fvalue = LambdaCandidates_chi2geo;
#
#     output.push_back(predict(input, 0));
#     probab= output.at(i);
#
#     if(probab > 0.918080){
#     h->Fill(LambdaCandidates_mass);}
#   }
#
#   h->Draw();
#
#
#
# }

# %% [raw]
# # Installing root
# !mkdir -p APPS
# !pwd
# !cd APPS && wget https://root.cern/download/root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
# !cd APPS && tar -xf root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
