# %% [markdown]
# Variables of filenames

# %% [markdown]
# Background comes from URQMD, signal from DCM, for test dataset for both bckgr and sign generated in urqmd

# %% [markdown]
# 4:1 background/signal ratio before cleaning, 5M sign, 15k bckgr, 30k ALL

# %%
#PLAINTREE FILES NAMES
directory='/Users/julnow/gsi/cbm/ML/JupyterNotebooks/'
signalFileName = directory + 'PlainTree_1mSign.root'
backgroundFileName = directory + 'PlainTree_6kBckgr_URQMD.root'
allFileName = directory + 'PlainTree_30kAll_URQMD.root'

# %%
# !git clone https://github.com/shahidzk1/CBM_ML_Lambda_Library.git
# %cd CBM_ML_Lambda_Library
# !git pull origin main
# !pip install -r requirements.txt
# !python setup.py install
# Out:
# fatal: destination path 'CBM_ML_Lambda_Library' already exists and is not an empty directory.
# /Users/julnow/gsi/cbm/ML/JupyterNotebooks/CBM_ML_Lambda_Library
# hint: Pulling without specifying how to reconcile divergent branches is
# hint: discouraged. You can squelch this message by running one of the following
# hint: commands sometime before your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# From https://github.com/shahidzk1/CBM_ML_Lambda_Library
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Requirement already satisfied: uproot in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.21.1)
# Requirement already satisfied: scikit-learn in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (0.24.2)
# Requirement already satisfied: xgboost in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (0.80)
# Requirement already satisfied: bayesian-optimization in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: scipy>=0.14.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from bayesian-optimization->-r requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (8.3.1)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 3)) (2021.1)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from uproot->-r requirements.txt (line 1)) (57.4.0)
# running install
# running bdist_egg
# running egg_info
# writing CBM_ML.egg-info/PKG-INFO
# writing dependency_links to CBM_ML.egg-info/dependency_links.txt
# writing top-level names to CBM_ML.egg-info/top_level.txt
# reading manifest file 'CBM_ML.egg-info/SOURCES.txt'
# writing manifest file 'CBM_ML.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-11.1-arm64/egg
# running install_lib
# running build_py
# creating build/bdist.macosx-11.1-arm64/egg
# creating build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/KFPF_lambda_cuts.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/__init__.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/plot_tools.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/root_functions.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/tree_importer.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/KFPF_lambda_cuts.py to KFPF_lambda_cuts.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/plot_tools.py to plot_tools.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/root_functions.py to root_functions.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/tree_importer.py to tree_importer.cpython-38.pyc
# creating build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/PKG-INFO -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/SOURCES.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/dependency_links.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/top_level.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/CBM_ML-0.1.0-py3.8.egg' and adding 'build/bdist.macosx-11.1-arm64/egg' to it
# removing 'build/bdist.macosx-11.1-arm64/egg' (and everything under it)
# Processing CBM_ML-0.1.0-py3.8.egg
# Removing /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/CBM_ML-0.1.0-py3.8.egg
# Copying CBM_ML-0.1.0-py3.8.egg to /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages
# CBM-ML 0.1.0 is already the active version in easy-install.pth
#
# Installed /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/CBM_ML-0.1.0-py3.8.egg
# Processing dependencies for CBM-ML==0.1.0
# Finished processing dependencies for CBM-ML==0.1.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
#from hipe4ml.model_handler import ModelHandler
#from hipe4ml.tree_handler import TreeHandler
from matplotlib.patches import ConnectionPatch
#from hipe4ml import plot_utils

import xgboost as xgb
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz

from sklearn.model_selection import cross_val_score
from scipy.stats import uniform

from numpy import sqrt, log, argmax

import weakref 
import itertools

from CBM_ML import tree_importer,  KFPF_lambda_cuts, plot_tools
from bayes_opt import BayesianOptimization
from bayes_opt import SequentialDomainReductionTransformer

import gc, os

# %% [markdown]
# # Selecting Background and Signal
# We generate PlainTrees from: 100k events (signal) and 20k evenents (background) with Au-Au @12A GeV/c, DCMQGSM-SMM generator passed through CBM setup in GEANT4, without any cuts
#
# To omit imbalance classification problem (event though there are 5 times more events for background, the number of entries is much smaller for signal) we resample the data. We're deleting instances from the over-represented class (in our case the background) - it's called under-sampling, one of the resampling methods.
#
# So for training and testing we will get signal candidates from the 5 sigma region and  background from outside this region (3 times signal size).

# %%
#CUTS FOR MASS SELECTION
#5 sigma region for signal
lower5SigmaCutSign = 0.43485
upper5SigmaCutSign = 0.56135
#mean invariant mass
invMass = 0.4981
# "5sigma" (not acutal 5 sigma) region for background
lower5SigmaCutBckgr = 0.1
upper5SigmaCutBckgr = 2

# %%
# We import three root files into our jupyter notebook
#sign - before cleaning but after 5sigma seletion, signal - cleaned
#so that we dont have to reimport everything with each change
sign = tree_importer.tree_importer(signalFileName,'PlainTree',7)

# We only select lambda candidates in the 5 sigma region around the kaon mass peak
#we preserve the cleaned dataframe with a changed name
sign = sign[(sign['Candidates_generation']==1) & (sign['Candidates_mass']>lower5SigmaCutSign) & (sign['Candidates_mass']<upper5SigmaCutSign)]

# Similarly for the background, we select background candidates which are not in the 5 sigma region of the kaon peak
bckgr = tree_importer.tree_importer(backgroundFileName,'PlainTree',7)
#we preserve the cleaned dataframe with a changed name
bckgr = bckgr[(bckgr['Candidates_generation'] < 1)
                 & ((bckgr['Candidates_mass'] > lower5SigmaCutBckgr)
                 & (bckgr['Candidates_mass'] < lower5SigmaCutSign) | (bckgr['Candidates_mass']>upper5SigmaCutSign) 
                    & (bckgr['Candidates_mass'] < upper5SigmaCutBckgr))
             ].sample(n=4*(sign.shape[0])) #we select bckgr so that we have 4*more entries that for signal (before cleaning)

#Also call the garbage collector of python to collect unused items to free memory
gc.collect()
# Out:
# 2506

# %%
#we remove name prefixes 'Candidates' and do some renaming
bckgr.columns = bckgr.columns.str.replace('Candidates_', '')
bckgr.columns = bckgr.columns.str.replace('_', '')
sign.columns = sign.columns.str.replace('Candidates_', '')
sign.columns = sign.columns.str.replace('_', '')
#we also get rid of coordinates errors
sign = sign.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
bckgr = bckgr.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
#let's check the name prefixes 
sign.iloc[0:10,:]
# Out:
#     chi2geo  chi2primfirst  chi2primsecond   chi2topo  cosinefirst  \
# 0  3.177823   4.262666e+05    6.868515e+05   1.855394     0.981525
# 1  0.004471   1.922697e+07    4.866396e+06   0.078657     0.986419
# 2  0.037329   2.605761e+06    6.498051e+05   0.189603     0.982620
# 3  2.102144   1.096114e+05    5.705017e+04   0.933712     0.967811
# 4  0.000447   1.199020e+06    1.193185e+06   0.018293     0.974159
# 5  1.266544   3.179119e+05    6.219582e+03   2.176297     0.996159
# 6  0.418754   4.053600e+04    3.514189e+04   0.248178     0.987535
# 7  0.468044   5.550384e+02    5.367957e+01  58.222015     0.998204
# 8  0.005368   1.575880e+04    7.143443e+06   0.266045     0.999529
# 9  0.329793   2.112292e+03    3.798389e+02   2.274386     0.993020
#
#    cosinesecond  cosinetopo  distance       eta          l  ...        pT  \
# 0      0.927626    0.999998  0.012591  2.585421   3.525622  ...  0.215543
# 1      0.992987    1.000000  0.000281  3.084208  17.471064  ...  0.266334
# 2      0.931113    0.999999  0.013215  3.106334   6.243536  ...  0.133220
# 3      0.948407    0.999990  0.032155  2.196439   1.923266  ...  0.304558
# 4      0.973658    1.000000  0.005114  1.529936   4.001441  ...  0.739413
# 5      0.974444    0.999978  0.363899  2.656654   8.770022  ...  0.375850
# 6      0.998955    1.000000  0.071856  3.680479  27.954142  ...  0.222652
# 7      0.963885    0.995840  0.012588  2.556761   0.317940  ...  0.413986
# 8      0.964272    1.000000  0.000168  2.076624   7.679552  ...  0.590756
# 9      0.977319    0.999733  0.136007  1.653662   1.479316  ...  0.942854
#
#         phi        px        py        pz  rapidity         x         y  \
# 0  1.600093 -0.006314  0.215451  1.421888  1.692228 -0.062903  0.429500
# 1  3.008031 -0.263962  0.035466  2.903631  2.339080 -1.634998  0.117869
# 2  1.340981  0.030347  0.129717  1.485018  1.777054 -0.071959  0.610075
# 3 -1.855907 -0.085661 -0.292263  1.352502  1.580162 -0.311639 -0.334688
# 4 -2.409410 -0.549914 -0.494294  1.627201  1.360794 -1.423880 -1.046450
# 5 -1.746762 -0.065796 -0.370046  2.664468  2.172429 -0.139905 -1.207917
# 6  1.350813  0.048586  0.217287  4.413034  2.781490  0.451521  1.372068
# 7  2.124509 -0.217694  0.352127  2.652908  2.119167 -0.070204  0.133495
# 8 -0.154107  0.583755 -0.090680  2.319347  1.820697  1.878005 -0.384331
# 9 -0.377130  0.876595 -0.347209  2.373510  1.539877  0.566548 -0.059377
#
#            z  issignal
# 0   3.485201       1.0
# 1  17.398438       1.0
# 2   6.220838       1.0
# 3   1.880640       1.0
# 4   3.644874       1.0
# 5   8.682734       1.0
# 6  27.921070       1.0
# 7   0.315944       1.0
# 8   7.442683       1.0
# 9   1.387693       1.0
#
# [10 rows x 23 columns]

# %% [markdown]
# The label 'issignal' tells us if an entry comes from signal (1) or background (0)

# %% [markdown]
# # Data Cleaning
# Sometimes a data set contains entries which are outliers or does not make sense. For example, infinite values or NaN entries. We clean the data by removing these entries.
#
# Similarly, CBM is a fixed target experiment so there are certain conditions which the data has to satisfy before it is considered as reliable data.So we apply certain limits on the data sets.
#
# The values of these cuts are described: https://drive.google.com/file/d/1tb0FBRq4KgVu-VQZgpjA8ONbIGVCNOnE/view?usp=sharing https://github.com/julnow/JupyterNotebooks/blob/kaon/CBM%20K-short%20data%20cleaning.pdf

# %%
#CUTS USED FOR DATA CLEANING
#mass cuts for both bckgr and sign
lowerMassCut = 0.279
upperMassCut = 1.5
#distance cuts
#DCA
lowerDcaCut = 0
upperDcaCut = 100
#l distance
lowerLCut = -5
upperLCut = 80
#loverdl
lowerLdlCut = -25
upperLdlCut = 15000
#coordinate cuts
absXCut = 50
absYCut = 50
lowerZCut = -1
upperZCut = 80
#momentums cuts
pzLowerCut = 0
pUpperCut = 20
ptUpperCut = 3
#chi2
#geo
lowerChi2GeoCut = 0
upperChi2GeoCut = 10000
#topo
lowerChi2TopoCut = 0
upperChi2TopoCut = 100000
#prim first
lowerChi2PrimFirstCut = 0
upperChi2PrimFirstCut = 3e7
#prim second
lowerChi2PrimSecondCut = 0
upperChi2PrimSecondCut = 3e7
#pseudorapidity cuts
lowerEtaCut = 1.
upperEtaCut = 6.5

# %%
def clean_df(df):
    # let's treat all the infinite, inf, values by nan and then we drop all the null entries
    with pd.option_context('mode.use_inf_as_na', True):
        df = df.dropna()
    #Experimental constraints
    is_good_mom = (df['pz'] > pzLowerCut) & (df['p']<pUpperCut) & (df['pT']<ptUpperCut)
    is_good_coord = (abs(df['x']) < absXCut) & (abs(df['y']) < absYCut) & (df['z']>lowerZCut) & (df['z']<upperZCut)
    is_good_params = (df['distance'] > lowerDcaCut) & (df['distance'] < upperDcaCut) & (df['chi2geo']>lowerChi2GeoCut) & (df['chi2geo'] < upperChi2GeoCut) & (df['chi2topo'] > lowerChi2TopoCut) & (df['chi2topo'] < upperChi2TopoCut) & (df['eta']>lowerEtaCut) & (df['eta']<upperEtaCut)& (df['l']>lowerLCut) & (df['l']<upperLCut) & (df['loverdl']>lowerLdlCut) & (df['loverdl']<upperLdlCut)
    is_good_daughters = (df['chi2primfirst']>lowerChi2PrimFirstCut) & (df['chi2primfirst'] < upperChi2PrimSecondCut) & (df['chi2primsecond']>lowerChi2PrimSecondCut) & (df['chi2primsecond']<upperChi2PrimFirstCut)
    is_good_mass = (df['mass']>lowerMassCut) & (df['mass']<upperMassCut)

    is_good_df = (is_good_mom) & (is_good_coord) & (is_good_params) & (is_good_daughters) & (is_good_mass)

    return df[is_good_df]

# %%
background = clean_df(bckgr)
signal = clean_df(sign)
print('size of:\nsignal: ' + str(len(signal)) + '\nbackground: ' + str(len(background)) 
      + '\nbackground to signal ratio: ' + str(round(len(background)/len(signal), 1)))
del sign, bckgr
# Out:
# size of:
# signal: 903730
# background: 3285070
# background to signal ratio: 3.6

# %% [markdown]
# We'll also import and clean dataset of 10k events for both background and signal (for testing our algorhitm)

# %%
#Let's combine signal and background
df_scaled = pd.concat([signal, background])
del signal, background
gc.collect()
# Out:
# 22

# %% [markdown]
# # Selecting Background and Signal
# After cleaning, our training data set contains 450442 background candidates and 1638402 signal candidates (background to signal ratio $\approx 3.6$). For testing, we'll use cleaned dataset containing 28740227 entries of signal and background (background to signal ratio $\approx 1985.1$)
#
# Here, we use under-sampling to tackle the problem with the classification of underrepresented class (normally, the signal is only approx. 0.05% of real data)

# %%
if not os.path.exists(directory+'img/xgb_v3'):
    os.makedirs(directory+'img/xgb_v3')
#lets draw sign to background ratio
def plt_sig_back(df):
    range1 = (lowerMassCut, upperMassCut)
    fig, axs = plt.subplots(figsize=(20, 10))
    #df_scaled['mass'].plot.hist(bins = 300, range=range1,grid=True,sharey=True)
    (df[df['issignal']==0])['mass'].plot.hist(bins = 300, facecolor='yellow',grid=True,range=range1, label='Background')
    (df[df['issignal']==1])['mass'].plot.hist(bins = 300, facecolor='magenta',grid=True, range=range1, label ='Signal')
    #plt.vlines(x=1.108,ymin=-1,ymax=48000, color='black', linestyle='-')
    #plt.vlines(x=1.1227,ymin=-1,ymax=48000, color='black', linestyle='-')
    plt.ylabel("Counts (log scale)", fontsize=15)
    plt.xlabel("Mass in GeV/$c^2$", fontsize= 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.title('Test and Train K-short Invariant Mass', fontsize = 15)
    plt.legend( fontsize = 15)
    axs.tick_params(axis='both', which='major', labelsize=18)
    plt.yscale("log")
    fig.tight_layout()
    fig.savefig(directory+'img/xgb_v3/inv_mass_trainset.pdf')
    fig.savefig(directory+'img/xgb_v3/inv_mass_trainset.png')

# %%
plt_sig_back(df_scaled)
gc.collect()
# Out:
# 2214

# %% [markdown]
# # Creating Train and Test sets
# To make machine learning algorithms more efficient on unseen data we divide our data into two sets. One set is for training the algorithm and the other is for testing the algorithm. If we don't do this then the algorithm can overfit and we will not capture the general trends in the data.

# %%
# The following columns will be used to predict whether a reconstructed candidate is a lambda particle or not
cuts = [ 'loverdl', 'distance', 'chi2geo', 'chi2topo', 'chi2primfirst', 'chi2primsecond']


x = df_scaled[cuts].copy()

# The MC information is saved in this y variable
y =pd.DataFrame(df_scaled['issignal'], dtype='int')

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=324)
del df_scaled, x, y

#DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed. 
dtrain = xgb.DMatrix(x_train, label = y_train)
dtest1=xgb.DMatrix(x_test, label = y_test)
del x_train, x_test
gc.collect()
# Out:
# 8

# %% [markdown]
# ## Bayesian optimization
# In order to find the best parameters of XGB for our data we use Bayesian optimization. Grid search and and random search could also do the same job but bayesian is more time efficient. For further reading visit [the git page](https://github.com/fmfn/BayesianOptimization) of the bayesian optimization used here.
#
# ### Hyper parameters
# Some of the following hyper parameters will be tuned for our algorithm:
#
#
# *subsample* [default=1]
# Subsample ratio of the training instances. Setting it to 0.5 means that XGBoost would randomly sample half of the training data prior to growing trees. and this will prevent overfitting. Subsampling will occur once in every boosting iteration.
# range: (0,1]
#
# *eta* [default=0.3, alias: learning_rate]
# Step size shrinkage used in update to prevents overfitting. After each boosting step, we can directly get the weights of new features, and eta shrinks the feature weights to make the boosting process more conservative.
# range: [0,1]
#
#
# *gamma* [default=0, alias: min_split_loss]
# Minimum loss reduction required to make a further partition on a leaf node of the tree. The larger gamma is, the more conservative the algorithm will be.
# range: [0,∞]
#
#
# *alpha* [default=0, alias: reg_alpha]
# L1 regularization term on weights. Increasing this value will make model more conservative.
#
# *Lasso Regression* (Least Absolute Shrinkage and Selection Operator) adds “absolute value of magnitude” of coefficient as penalty term to the loss function.

# %%
#Bayesian Optimization function for xgboost
#specify the parameters you want to tune as keyword arguments
def bo_tune_xgb(max_depth, gamma, alpha, n_estimators ,learning_rate):
    params = {'max_depth': int(max_depth),
              'gamma': gamma,
              'alpha':alpha,
              'n_estimators': n_estimators,
              'learning_rate':learning_rate,
              'subsample': 0.8,
              'eta': 0.1,
              'eval_metric': 'auc', 'nthread' : 7}
    cv_result = xgb.cv(params, dtrain, num_boost_round=70, nfold=5)
    return  cv_result['test-auc-mean'].iloc[-1]

bounds_transformer = SequentialDomainReductionTransformer()

# %%
#Invoking the Bayesian Optimizer with the specified parameters to tune
xgb_bo = BayesianOptimization(bo_tune_xgb, {'max_depth': (4, 10),
                                             'gamma': (0, 1),
                                            'alpha': (2,20),
                                             'learning_rate':(0,1),
                                             'n_estimators':(100,500)
                                            },
                             bounds_transformer=bounds_transformer)

# %%
#performing Bayesian optimization for 5 iterations with 8 steps of random exploration with an #acquisition function of expected improvement
xgb_bo.maximize(n_iter=5, init_points=5)
# Out:
# |   iter    |  target   |   alpha   |   gamma   | learni... | max_depth | n_esti... |
# -------------------------------------------------------------------------------------
# [19:10:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:10:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:10:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:10:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:10:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:11:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 4 pruned nodes, max_depth=5
# [19:11:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:11:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:12:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:12:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:12:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:12:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:12:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:12:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:12:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:13:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:13:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:13:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2 pruned nodes, max_depth=5
# [19:13:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:13:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:13:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 10 pruned nodes, max_depth=5
# [19:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:13:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:13:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=5
# [19:13:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:13:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:13:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:13:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:13:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [19:13:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:13:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:13:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:13:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=5
# [19:14:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:14:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:14:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:14:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:14:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:14:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:14:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 8 pruned nodes, max_depth=5
# [19:14:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:14:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:14:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:14:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 8 pruned nodes, max_depth=5
# [19:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=5
# [19:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=5
# [19:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=5
# [19:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:14:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:14:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:14:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:15:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:15:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:15:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=5
# [19:15:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:15:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:15:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:15:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:15:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [19:15:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 8 pruned nodes, max_depth=5
# [19:15:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=5
# [19:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=5
# [19:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=5
# [19:15:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:15:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=5
# [19:15:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:15:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 10 pruned nodes, max_depth=5
# [19:15:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=5
# [19:15:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 8 pruned nodes, max_depth=5
# [19:15:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 4 pruned nodes, max_depth=5
# [19:15:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:15:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:15:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=5
# [19:15:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 6 pruned nodes, max_depth=5
# [19:15:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19:15:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:15:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=5
# [19:15:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 12 pruned nodes, max_depth=5
# [19:16:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=5
# [19:16:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=5
# [19:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=5
# [19:16:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 14 pruned nodes, max_depth=5
# [19:16:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:16:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:16:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=5
# [19:16:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 10 pruned nodes, max_depth=5
# [19:16:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=5
# [19:16:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 18 pruned nodes, max_depth=5
# [19:16:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 8 pruned nodes, max_depth=5
# [19:16:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:16:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=5
# [19:16:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=5
# [19:16:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=5
# [19:16:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 14 pruned nodes, max_depth=5
# [19:16:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=5
# [19:16:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=5
# [19:16:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 18 pruned nodes, max_depth=5
# [19:16:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 8 pruned nodes, max_depth=5
# [19:16:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:16:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=5
# [19:16:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:16:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=5
# [19:16:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:16:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 16 pruned nodes, max_depth=5
# [19:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 30 pruned nodes, max_depth=5
# [19:17:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:17:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=5
# [19:17:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 10 pruned nodes, max_depth=5
# [19:17:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 18 pruned nodes, max_depth=5
# [19:17:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=5
# [19:17:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 10 pruned nodes, max_depth=5
# [19:17:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 14 pruned nodes, max_depth=5
# [19:17:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=5
# [19:17:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 8 pruned nodes, max_depth=5
# [19:17:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 14 pruned nodes, max_depth=5
# [19:17:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 14 pruned nodes, max_depth=5
# [19:17:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=5
# [19:17:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [19:17:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=5
# [19:17:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=5
# [19:17:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 18 pruned nodes, max_depth=5
# [19:17:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=5
# [19:17:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 12 pruned nodes, max_depth=5
# [19:17:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=5
# [19:17:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 14 pruned nodes, max_depth=5
# [19:17:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 22 pruned nodes, max_depth=5
# [19:17:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 12 pruned nodes, max_depth=5
# [19:17:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 26 pruned nodes, max_depth=5
# [19:17:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=5
# [19:17:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:17:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 10 pruned nodes, max_depth=5
# [19:18:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 16 pruned nodes, max_depth=5
# [19:18:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=5
# [19:18:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=5
# [19:18:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 18 pruned nodes, max_depth=5
# [19:18:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 18 pruned nodes, max_depth=5
# [19:18:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 20 pruned nodes, max_depth=5
# [19:18:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 16 pruned nodes, max_depth=5
# [19:18:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 14 pruned nodes, max_depth=5
# [19:18:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=5
# [19:18:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 10 pruned nodes, max_depth=5
# [19:18:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 16 pruned nodes, max_depth=5
# [19:18:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 6 pruned nodes, max_depth=5
# [19:18:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 26 pruned nodes, max_depth=5
# [19:18:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=5
# [19:18:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 8 pruned nodes, max_depth=5
# [19:18:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 18 pruned nodes, max_depth=5
# [19:18:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=5
# [19:18:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 14 pruned nodes, max_depth=5
# [19:18:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=5
# [19:18:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 16 pruned nodes, max_depth=5
# [19:18:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 22 pruned nodes, max_depth=5
# [19:18:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 12 pruned nodes, max_depth=5
# [19:18:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=5
# [19:18:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 24 pruned nodes, max_depth=5
# [19:18:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 26 pruned nodes, max_depth=5
# [19:18:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [19:18:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [19:19:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=5
# [19:19:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 12 pruned nodes, max_depth=5
# [19:19:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 14 pruned nodes, max_depth=5
# [19:19:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 26 pruned nodes, max_depth=5
# [19:19:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 16 pruned nodes, max_depth=5
# [19:19:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=5
# [19:19:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 14 pruned nodes, max_depth=5
# [19:19:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 22 pruned nodes, max_depth=5
# [19:19:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 14 pruned nodes, max_depth=5
# [19:19:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 18 pruned nodes, max_depth=5
# [19:19:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [19:19:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:19:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 10 pruned nodes, max_depth=5
# [19:19:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=5
# [19:19:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=5
# [19:19:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 28 pruned nodes, max_depth=5
# [19:19:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 12 pruned nodes, max_depth=5
# [19:19:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 28 pruned nodes, max_depth=5
# [19:19:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=5
# [19:19:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=5
# [19:19:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 20 pruned nodes, max_depth=5
# [19:19:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 16 pruned nodes, max_depth=5
# [19:19:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=5
# [19:19:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 24 pruned nodes, max_depth=5
# [19:19:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=5
# [19:19:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [19:20:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 18 pruned nodes, max_depth=5
# [19:20:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 24 pruned nodes, max_depth=5
# [19:20:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=5
# [19:20:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 20 pruned nodes, max_depth=5
# [19:20:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=5
# [19:20:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [19:20:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 26 pruned nodes, max_depth=5
# [19:20:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [19:20:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [19:20:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 16 pruned nodes, max_depth=5
# [19:20:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 30 pruned nodes, max_depth=5
# [19:20:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [19:20:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 22 pruned nodes, max_depth=5
# [19:20:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [19:20:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 20 pruned nodes, max_depth=5
# [19:20:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [19:20:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=5
# [19:20:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 20 pruned nodes, max_depth=5
# [19:20:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=5
# [19:20:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 30 pruned nodes, max_depth=5
# [19:20:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=5
# [19:20:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 10 pruned nodes, max_depth=5
# [19:20:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [19:20:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 22 pruned nodes, max_depth=5
# [19:20:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=5
# [19:20:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=5
# [19:20:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [19:21:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 16 pruned nodes, max_depth=5
# [19:21:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 18 pruned nodes, max_depth=5
# [19:21:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=5
# [19:21:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=5
# [19:21:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [19:21:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 18 pruned nodes, max_depth=5
# [19:21:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 20 pruned nodes, max_depth=5
# [19:21:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 20 pruned nodes, max_depth=5
# [19:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 22 pruned nodes, max_depth=5
# [19:21:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 12 pruned nodes, max_depth=5
# [19:21:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 14 pruned nodes, max_depth=5
# [19:21:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=5
# [19:21:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 22 pruned nodes, max_depth=5
# [19:21:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [19:21:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 28 pruned nodes, max_depth=5
# [19:21:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 28 pruned nodes, max_depth=5
# [19:21:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=5
# [19:21:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=5
# [19:21:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 16 pruned nodes, max_depth=5
# [19:21:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=5
# [19:21:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=5
# [19:21:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 34 pruned nodes, max_depth=5
# [19:21:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 18 pruned nodes, max_depth=5
# [19:21:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 34 pruned nodes, max_depth=5
# [19:21:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 18 pruned nodes, max_depth=5
# [19:21:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 24 pruned nodes, max_depth=5
# [19:22:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 26 pruned nodes, max_depth=5
# [19:22:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=5
# [19:22:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 12 pruned nodes, max_depth=5
# [19:22:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 14 pruned nodes, max_depth=5
# [19:22:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=5
# [19:22:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 36 pruned nodes, max_depth=5
# |  1        |  0.9971   |  3.981    |  0.3945   |  0.1537   |  5.744    |  205.9    |
# [19:22:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 44 pruned nodes, max_depth=9
# [19:22:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 48 pruned nodes, max_depth=9
# [19:22:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 40 pruned nodes, max_depth=9
# [19:22:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 42 pruned nodes, max_depth=9
# [19:22:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 32 pruned nodes, max_depth=9
# [19:22:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 32 pruned nodes, max_depth=9
# [19:22:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 64 pruned nodes, max_depth=9
# [19:22:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 36 pruned nodes, max_depth=9
# [19:22:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 50 pruned nodes, max_depth=9
# [19:22:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 28 pruned nodes, max_depth=9
# [19:22:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 32 pruned nodes, max_depth=9
# [19:22:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 58 pruned nodes, max_depth=9
# [19:23:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 48 pruned nodes, max_depth=9
# [19:23:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 42 pruned nodes, max_depth=9
# [19:23:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 58 pruned nodes, max_depth=9
# [19:23:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 46 pruned nodes, max_depth=9
# [19:23:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 64 pruned nodes, max_depth=9
# [19:23:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 48 pruned nodes, max_depth=9
# [19:23:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 66 pruned nodes, max_depth=9
# [19:23:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 66 pruned nodes, max_depth=9
# [19:23:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 54 pruned nodes, max_depth=9
# [19:23:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 56 pruned nodes, max_depth=9
# [19:23:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 68 pruned nodes, max_depth=9
# [19:23:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 62 pruned nodes, max_depth=9
# [19:23:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 64 pruned nodes, max_depth=9
# [19:23:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 62 pruned nodes, max_depth=9
# [19:23:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 60 pruned nodes, max_depth=9
# [19:23:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 74 pruned nodes, max_depth=9
# [19:23:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 58 pruned nodes, max_depth=9
# [19:23:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 60 pruned nodes, max_depth=9
# [19:23:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 50 pruned nodes, max_depth=9
# [19:24:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 46 pruned nodes, max_depth=9
# [19:24:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 44 pruned nodes, max_depth=9
# [19:24:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 62 pruned nodes, max_depth=9
# [19:24:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 62 pruned nodes, max_depth=9
# [19:24:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 50 pruned nodes, max_depth=9
# [19:24:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 50 pruned nodes, max_depth=9
# [19:24:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 68 pruned nodes, max_depth=9
# [19:24:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 54 pruned nodes, max_depth=9
# [19:24:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 60 pruned nodes, max_depth=9
# [19:24:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 40 pruned nodes, max_depth=9
# [19:24:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 78 pruned nodes, max_depth=9
# [19:24:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 52 pruned nodes, max_depth=9
# [19:24:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 60 pruned nodes, max_depth=9
# [19:24:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 64 pruned nodes, max_depth=9
# [19:24:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 50 pruned nodes, max_depth=9
# [19:24:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 80 pruned nodes, max_depth=9
# [19:24:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 80 pruned nodes, max_depth=9
# [19:24:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 62 pruned nodes, max_depth=9
# [19:24:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 98 pruned nodes, max_depth=9
# [19:25:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 104 pruned nodes, max_depth=9
# [19:25:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 82 pruned nodes, max_depth=9
# [19:25:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 58 pruned nodes, max_depth=9
# [19:25:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 76 pruned nodes, max_depth=9
# [19:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 70 pruned nodes, max_depth=8
# [19:25:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 84 pruned nodes, max_depth=9
# [19:25:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 60 pruned nodes, max_depth=9
# [19:25:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 58 pruned nodes, max_depth=9
# [19:25:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 72 pruned nodes, max_depth=9
# [19:25:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 64 pruned nodes, max_depth=9
# [19:25:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 64 pruned nodes, max_depth=9
# [19:25:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 70 pruned nodes, max_depth=9
# [19:25:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 102 pruned nodes, max_depth=9
# [19:25:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 72 pruned nodes, max_depth=9
# [19:25:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 106 pruned nodes, max_depth=9
# [19:25:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 82 pruned nodes, max_depth=9
# [19:25:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 102 pruned nodes, max_depth=9
# [19:25:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 94 pruned nodes, max_depth=9
# [19:25:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 116 pruned nodes, max_depth=9
# [19:26:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 98 pruned nodes, max_depth=9
# [19:26:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 108 pruned nodes, max_depth=9
# [19:26:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 116 pruned nodes, max_depth=9
# [19:26:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 110 pruned nodes, max_depth=9
# ...
# [21:45:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 262 pruned nodes, max_depth=9
# [21:45:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 268 pruned nodes, max_depth=9
# [21:45:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 182 pruned nodes, max_depth=9
# [21:46:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 272 pruned nodes, max_depth=9
# [21:46:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 200 pruned nodes, max_depth=9
# [21:46:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 278 pruned nodes, max_depth=9
# [21:46:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 246 pruned nodes, max_depth=9
# [21:46:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 220 pruned nodes, max_depth=9
# [21:46:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 260 pruned nodes, max_depth=9
# [21:46:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 178 pruned nodes, max_depth=9
# [21:46:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 168 pruned nodes, max_depth=0
# [21:46:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 120 pruned nodes, max_depth=9
# [21:46:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 332 pruned nodes, max_depth=7
# [21:46:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 226 pruned nodes, max_depth=9
# [21:46:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 292 pruned nodes, max_depth=9
# [21:46:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 350 pruned nodes, max_depth=6
# [21:46:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 182 pruned nodes, max_depth=7
# [21:46:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 286 pruned nodes, max_depth=9
# [21:46:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 288 pruned nodes, max_depth=9
# [21:46:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 188 pruned nodes, max_depth=0
# [21:46:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 198 pruned nodes, max_depth=9
# [21:46:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 192 pruned nodes, max_depth=0
# [21:47:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 286 pruned nodes, max_depth=5
# [21:47:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 294 pruned nodes, max_depth=9
# [21:47:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 178 pruned nodes, max_depth=9
# [21:47:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 370 pruned nodes, max_depth=0
# [21:47:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 242 pruned nodes, max_depth=8
# [21:47:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 230 pruned nodes, max_depth=0
# [21:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 190 pruned nodes, max_depth=3
# [21:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 148 pruned nodes, max_depth=6
# [21:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 134 pruned nodes, max_depth=8
# [21:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 252 pruned nodes, max_depth=9
# [21:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 180 pruned nodes, max_depth=9
# [21:47:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 258 pruned nodes, max_depth=9
# [21:47:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 302 pruned nodes, max_depth=8
# [21:47:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 380 pruned nodes, max_depth=0
# [21:47:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 268 pruned nodes, max_depth=8
# [21:47:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 166 pruned nodes, max_depth=0
# [21:47:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 258 pruned nodes, max_depth=9
# [21:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 236 pruned nodes, max_depth=9
# [21:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 290 pruned nodes, max_depth=9
# [21:48:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 182 pruned nodes, max_depth=0
# [21:48:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 216 pruned nodes, max_depth=9
# [21:48:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 218 pruned nodes, max_depth=9
# [21:48:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 126 pruned nodes, max_depth=9
# [21:48:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 156 pruned nodes, max_depth=0
# [21:48:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 264 pruned nodes, max_depth=9
# [21:48:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 176 pruned nodes, max_depth=9
# [21:48:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 338 pruned nodes, max_depth=9
# [21:48:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 320 pruned nodes, max_depth=9
# [21:48:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 220 pruned nodes, max_depth=0
# [21:48:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 172 pruned nodes, max_depth=8
# [21:48:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 304 pruned nodes, max_depth=0
# [21:48:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 346 pruned nodes, max_depth=0
# [21:48:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 150 pruned nodes, max_depth=0
# [21:48:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 318 pruned nodes, max_depth=6
# [21:48:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 170 pruned nodes, max_depth=0
# [21:48:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 320 pruned nodes, max_depth=9
# [21:49:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 184 pruned nodes, max_depth=7
# [21:49:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 200 pruned nodes, max_depth=5
# [21:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [21:49:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 226 pruned nodes, max_depth=8
# [21:49:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 218 pruned nodes, max_depth=5
# [21:49:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 236 pruned nodes, max_depth=7
# [21:49:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 188 pruned nodes, max_depth=9
# [21:49:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 186 pruned nodes, max_depth=9
# [21:49:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 204 pruned nodes, max_depth=7
# [21:49:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 224 pruned nodes, max_depth=9
# [21:49:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 262 pruned nodes, max_depth=9
# [21:49:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 232 pruned nodes, max_depth=8
# [21:49:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 166 pruned nodes, max_depth=9
# [21:49:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 142 pruned nodes, max_depth=0
# [21:49:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 172 pruned nodes, max_depth=9
# [21:49:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 202 pruned nodes, max_depth=9
# [21:49:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 248 pruned nodes, max_depth=8
# [21:49:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 138 pruned nodes, max_depth=8
# [21:49:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 220 pruned nodes, max_depth=9
# [21:49:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 154 pruned nodes, max_depth=9
# [21:50:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 244 pruned nodes, max_depth=9
# [21:50:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 158 pruned nodes, max_depth=0
# [21:50:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 326 pruned nodes, max_depth=0
# [21:50:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 160 pruned nodes, max_depth=9
# [21:50:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 274 pruned nodes, max_depth=8
# [21:50:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 210 pruned nodes, max_depth=8
# [21:50:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 282 pruned nodes, max_depth=9
# [21:50:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 238 pruned nodes, max_depth=0
# [21:50:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 306 pruned nodes, max_depth=9
# [21:50:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 344 pruned nodes, max_depth=6
# [21:50:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 214 pruned nodes, max_depth=6
# [21:50:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 116 pruned nodes, max_depth=8
# [21:50:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 374 pruned nodes, max_depth=9
# [21:50:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 200 pruned nodes, max_depth=8
# [21:50:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 150 pruned nodes, max_depth=8
# [21:50:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 152 pruned nodes, max_depth=0
# [21:50:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 164 pruned nodes, max_depth=0
# [21:50:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 274 pruned nodes, max_depth=8
# [21:50:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 268 pruned nodes, max_depth=6
# [21:51:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 188 pruned nodes, max_depth=9
# [21:51:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 244 pruned nodes, max_depth=0
# [21:51:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 320 pruned nodes, max_depth=9
# [21:51:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 358 pruned nodes, max_depth=8
# [21:51:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 248 pruned nodes, max_depth=0
# [21:51:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 226 pruned nodes, max_depth=0
# [21:51:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 166 pruned nodes, max_depth=7
# [21:51:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 208 pruned nodes, max_depth=7
# [21:51:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 224 pruned nodes, max_depth=0
# [21:51:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 178 pruned nodes, max_depth=0
# [21:51:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 234 pruned nodes, max_depth=9
# [21:51:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 222 pruned nodes, max_depth=6
# [21:51:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 214 pruned nodes, max_depth=9
# [21:51:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 274 pruned nodes, max_depth=8
# [21:51:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 298 pruned nodes, max_depth=8
# [21:51:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 208 pruned nodes, max_depth=8
# [21:51:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 172 pruned nodes, max_depth=0
# [21:51:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 128 pruned nodes, max_depth=9
# [21:51:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 222 pruned nodes, max_depth=9
# [21:52:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 188 pruned nodes, max_depth=9
# [21:52:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 234 pruned nodes, max_depth=9
# [21:52:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 172 pruned nodes, max_depth=0
# [21:52:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 184 pruned nodes, max_depth=8
# [21:52:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 150 pruned nodes, max_depth=8
# [21:52:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 290 pruned nodes, max_depth=8
# [21:52:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 190 pruned nodes, max_depth=9
# [21:52:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 250 pruned nodes, max_depth=0
# [21:52:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 232 pruned nodes, max_depth=9
# [21:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 292 pruned nodes, max_depth=9
# [21:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 180 pruned nodes, max_depth=5
# [21:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 188 pruned nodes, max_depth=9
# [21:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 168 pruned nodes, max_depth=0
# [21:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 292 pruned nodes, max_depth=7
# [21:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 152 pruned nodes, max_depth=8
# [21:52:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 316 pruned nodes, max_depth=0
# [21:52:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 280 pruned nodes, max_depth=9
# [21:52:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 198 pruned nodes, max_depth=6
# [21:52:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 238 pruned nodes, max_depth=8
# [21:53:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 262 pruned nodes, max_depth=5
# [21:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 218 pruned nodes, max_depth=0
# [21:53:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 284 pruned nodes, max_depth=7
# [21:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 224 pruned nodes, max_depth=8
# |  10       |  0.9974   |  12.44    |  0.8941   |  0.2525   |  9.464    |  139.5    |
# =====================================================================================

# %%
# best target so far 0.9974344
print(xgb_bo.max)
# Out:
# {'target': 0.9973946, 'params': {'alpha': 14.197629952547516, 'gamma': 0.9291842557745593, 'learning_rate': 0.20061899260807536, 'max_depth': 9.610101503835205, 'n_estimators': 117.85322044514936}}

# %%
max_params = {'target': 0.9973946, 'params': {'alpha': 14.197629952547516, 'gamma': 0.9291842557745593, 'learning_rate': 0.20061899260807536, 'max_depth': 9.610101503835205, 'n_estimators': 117.85322044514936}}

# %% [markdown]
# # XGB models
# Now let's take the parameters selected by the bayesian optimization and apply them in our training and testing.

# %%
#max_param = xgb_bo.max['params']
max_param = max_params['params']
param= {'alpha': max_param['alpha'], 'gamma': max_param['gamma'], 'learning_rate': max_param['learning_rate'], 'max_depth': int(round(max_param['max_depth'],0)), 'n_estimators': int(round(max_param['n_estimators'],0)), 'objective': 'reg:logistic'}

# %%
#To train the algorithm using the parameters selected by bayesian optimization
bst = xgb.train(param, dtrain)
# Out:
# [13:32:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 26 pruned nodes, max_depth=10
# [13:32:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 48 pruned nodes, max_depth=10
# [13:32:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 38 pruned nodes, max_depth=10
# [13:32:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 48 pruned nodes, max_depth=10
# [13:32:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 58 pruned nodes, max_depth=10
# [13:32:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 42 pruned nodes, max_depth=10
# [13:32:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 50 pruned nodes, max_depth=10
# [13:32:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 46 pruned nodes, max_depth=10
# [13:33:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 46 pruned nodes, max_depth=10
# [13:33:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 50 pruned nodes, max_depth=10

# %%
#We apply our model on the training data that was trained on the training data, this helps us to control overfitting
bst1= bst.predict(dtrain)

# %%
del dtrain 
gc.collect()
# Out:
# 25

# %%
# We apply our trained model on test data and store the predictions in a bst_test dataframe
bst_test = pd.DataFrame(data=bst.predict(dtest1),  columns=["xgb_preds"])
y_test=y_test.set_index(np.arange(0,bst_test.shape[0]))
# We also store the MC information in this dataFrame
bst_test['issignal']=y_test['issignal']

# %% [markdown]
# ## Whole set
# We also select the selected variables from the 10k events data set

# %%
df_origin = tree_importer.tree_importer(allFileName,'PlainTree',7)
df_origin.columns = df_origin.columns.str.replace('Candidates_', '')
df_origin.columns = df_origin.columns.str.replace('_', '')
df_origin = df_origin.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
df_clean = clean_df(df_origin)
del df_origin
gc.collect()
#lets look at impoted tree
df_clean.iloc[0:10,:]
print('test set (background to signal ratio): ' 
      + str(round(len(df_clean.loc[df_clean['issignal'] == 0])/len(df_clean.loc[df_clean['issignal'] == 1]), 1))
      + '\ntest set (both signal and background): ' + str(len(df_clean)))
# Out:
# test set (background to signal ratio): 1976.9
# test set (both signal and background): 59049485

# %%
x_whole = df_clean[cuts].copy()
y_whole = pd.DataFrame(df_clean['issignal'], dtype='int')
dtest = xgb.DMatrix(x_whole, label = y_whole)
del x_whole
gc.collect()
# Out:
# 4

# %%
#The following graph will show us that which features are important for the model
ax = xgb.plot_importance(bst)
plt.rcParams['figure.figsize'] = [5, 3]
plt.show()
ax.figure.tight_layout() 
ax.figure.savefig(directory+'img/xgb_v3/feature_importance.pdf')
ax.figure.savefig(directory+'img/xgb_v3/feature_importance.png')

# %% [markdown]
# ## AUC and ROC
#
# The function roc_curve computes the receiver operating characteristic curve, or ROC curve. Quoting Wikipedia :
#
# “A receiver operating characteristic (ROC), or simply ROC curve, is a graphical plot which illustrates the performance of a binary classifier system as its discrimination threshold is varied. It is created by plotting the fraction of true positives out of the positives (TPR = true positive rate) vs. the fraction of false positives out of the negatives (FPR = false positive rate), at various threshold settings. TPR is also known as sensitivity, and FPR is one minus the specificity or true negative rate.”
#
# This function requires the true binary value and the target scores, which can either be probability estimates of the positive class, confidence values, or binary decisions.
#
# Similarly, the function roc_auc_score computes Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.

# %% [markdown]
# To find the best threshold which results more signal to background ratio for lambda candidates we use the parameter S0 called the approximate median significance by the higgs boson  ML challenge (http://higgsml.lal.in2p3.fr/documentation,9.)

# %%
def AMS(y_true, y_predict, y_true1, y_predict1):
    roc_auc=roc_auc_score(y_true, y_predict)
    fpr, tpr, thresholds = roc_curve(y_true, y_predict,drop_intermediate=False ,pos_label=1)
    S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
    S0 = S0[~np.isnan(S0)]
    xi = argmax(S0)
    S0_best_threshold = (thresholds[xi])

    roc_auc1=roc_auc_score(y_true1, y_predict1)
    fpr1, tpr1, thresholds1 = roc_curve(y_true1, y_predict1,drop_intermediate=False ,pos_label=1)
    S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))
    S01 = S01[~np.isnan(S01)]
    xi1 = argmax(S01)
    S0_best_threshold1 = (thresholds[xi1])

    #plotting
    fig, axs = plt.subplots(figsize=(15, 10), dpi = 100)
    plt.plot(fpr, tpr, linestyle=':',color='darkorange',label='ROC curve train (area = %0.4f)' % roc_auc)
    plt.plot(fpr1, tpr1, color='green',label='ROC curve test (area = %0.4f)' % roc_auc1)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.scatter(fpr[xi], tpr[xi], marker='o', color='black', label= 'Best Threshold train set = '+"%.4f" % S0_best_threshold +'\n S0 = '+ "%.2f" % S0[xi])
    plt.scatter(fpr1[xi1], tpr1[xi1], marker='o', color='blue', label= 'Best Threshold test set = '+"%.4f" % S0_best_threshold1 +'\n S0 = '+ "%.2f" % S01[xi1])
    plt.xlabel('False Positive Rate', fontsize = 15)
    plt.ylabel('True Positive Rate', fontsize = 15)
    plt.legend(loc="lower right", fontsize = 15)
    plt.title('Receiver operating characteristic', fontsize = 15)
    plt.xlim([-0.01, 1.0])
    plt.ylim([0, 1.02])
    
    fig.tight_layout()
    plt.show()
    fig.savefig(directory+'img/xgb_v3/ams.pdf')
    fig.savefig(directory+'img/xgb_v3/ams.png')

    return S0_best_threshold, S0_best_threshold1

# %%
train_best, test_best = AMS(y_train, bst1, y_test, bst_test['xgb_preds'])
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_2490/2521277735.py:4: RuntimeWarning: invalid value encountered in true_divide
#   S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_2490/2521277735.py:11: RuntimeWarning: invalid value encountered in true_divide
#   S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))

# %% [markdown]
# When the AUC, best threshold and approximate median significance for train and test are nearly the same, we save that model and use it. This means that our model is general enough. In my opinion, if the test S0 is above 3.0 then it is a good enough model.

# %% [markdown]
# ## Applying the model on the 10k events data-set

# %%
df_clean['xgb_preds'] = bst.predict(dtest)

# %%
df_clean['xgb_preds'].hist(bins=300)
plt.yscale('log')

# %% [markdown]
# ## Confusion Matrix
#
# A **Confusion Matrix** $C$ is such that $C_{ij}$ is equal to the number of observations known to be in group $i$ and predicted to be in group $j$. Thus in binary classification, the count of true positives is $C_{00}$, false negatives $C_{01}$,false positives is $C_{10}$, and true neagtives is $C_{11}$.
#
# If $ y^{'}_{i} $ is the predicted value of the $ i$-th sample and $y_{i}$ is the corresponding true value, then the fraction of correct predictions over $ n_{samples}$ is defined as
# $$
# True \: positives (y,y^{'}) =  \sum_{i=1}^{n_{samples} } 1 (y^{'}_{i} = y_{i}=1)
# $$
#
# The following function prints and plots the confusion matrix. Normalization can be applied by setting `normalize=True`.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
#calculate efficency and false tu tru signal ratio
def confustion_stats(df, cm):
    all_signals = len(df.loc[df['issignal'] == 1])
    true_signal = cm[0][0]
    false_signal = cm[1][0]        
    reconstructed_signals = true_signal + false_signal
    false_to_true_signals = false_signal / true_signal
    efficiency = reconstructed_signals / all_signals * 100 #efficency in % for all
    efficiency_true = true_signal / all_signals * 100 #efficency in % for all
    print("Efficiency: " + str(round(efficiency, 2)) + "%")
    print("Efficiency of true signal candidates reconstruction: " + str(round(efficiency_true, 2)) + "%")
    print("False tu true reconstructed signal ratio: " + str(round(false_to_true_signals, 2)))

# %%
#lets take the best threshold and look at the confusion matrix
cut1 = test_best
df_clean['xgb_preds1'] = ((df_clean['xgb_preds']>cut1)*1)
cnf_matrix = confusion_matrix(y_whole, df_clean['xgb_preds1'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix, classes=['signal','background'], title='Confusion Matrix for XGB for cut > '+str(cut1))
fig.savefig(directory+'img/xgb_v3/confusion_matrix_extreme_gradient_boosting_whole_data.pdf')
fig.savefig(directory+'img/xgb_v3/confusion_matrix_extreme_gradient_boosting_whole_data.png')
# Out:
# Confusion matrix, without normalization
# [[   26868     2987]
#  [    4544 59015029]]

# %%
confustion_stats(df_clean, cnf_matrix)
# Out:
# Efficiency: 105.22%
# Efficiency of true signal candidates reconstruction: 89.99%
# False tu true reconstructed signal ratio: 0.17

# %%
# The following function will display the inavriant mass histogram of the original 10k event set along with the mass histoigram after we apply a cut
# on the probability prediction of xgb
def cut_visualization(cut, range1=(lowerMassCut, upperMassCut), bins1= 300 ):
    mask1 = df_clean['xgb_preds']>cut
    df3=df_clean[mask1]
    
    fig, ax2 = plt.subplots(figsize=(15, 10), dpi = 200)
    color = 'tab:blue'
    ax2.hist(df_clean['mass'],bins = bins1, range=range1, facecolor='blue',alpha = 0.35, label='before selection')
    ax2.set_ylabel('Counts', fontsize = 15, color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.legend( fontsize = 15, loc='upper left')
    
    color = 'tab:red'
    ax1 = ax2.twinx()
    ax1.hist(df3['mass'], bins = bins1, range=range1, facecolor='red',alpha = 0.35, label='XGB')
    ax1.set_xlabel('Mass in GeV', fontsize = 15)
    ax1.set_ylabel('Counts ', fontsize = 15, color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.legend( fontsize = 15,loc='upper right' )

    plt.title("The original sample's Invariant Mass along with mass after selection of XGB (with a cut > "+str(cut)+')', fontsize = 15)
    fig.tight_layout()
    fig.savefig(directory+'img/xgb_v3/whole_sample_invmass_with_ML.pdf')
    fig.savefig(directory+'img/xgb_v3/whole_sample_invmass_with_ML.png')

# %%
cut_visualization(test_best)

# %% [markdown]
# # Comparison with the manually optimized cuts of KFPF
# In the already existing Kalman Filter Particle Finder (KFPF) package for online reconstruction and selection of short-lived particles in CBM, these criteria have been manually optimized. These selection-cuts have been selected to maximize the signal to background ratio (S/B) of the $\Lambda$ for a certain energy on a collisions generator. The selection criteria mainly depends on the collision energy, decay channel and detector configuration.

# %%
#manually selected cuts
manCut_loverdl = 30
manCut_dca = 0.4
manCut_chi2topo = 20
manCut_chi2geo = 12

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
new_check_set= df_clean.copy()
new_check_set['new_signal']=0

mask1 = (new_check_set['loverdl'] > manCut_loverdl) & (new_check_set['distance'] < manCut_dca)

mask2 = (new_check_set['chi2topo'] < manCut_chi2topo) & (new_check_set['chi2geo'] < manCut_chi2geo) 

new_check_set = new_check_set[(mask1) & (mask2)] 

#After all these cuts, what is left is considered as signal, so we replace all the values in the 'new_signal'
# column by 1
new_check_set['new_signal'] = 1
cnf_matrix1 = confusion_matrix(new_check_set['issignal'], new_check_set['new_signal'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix1, classes=['signal','background'], title='Confusion Matrix for manually set cuts')
fig.savefig(directory+'img/xgb_v3/confusion_matrix_for_manually_set_cuts.pdf')
fig.savefig(directory+'img/xgb_v3/confusion_matrix_for_manually_set_cuts.png')
# Out:
# Confusion matrix, without normalization
# [[22921     0]
#  [ 9260     0]]

# %%
confustion_stats(df_clean, cnf_matrix1)
# Out:
# Efficiency: 107.79%
# Efficiency of true signal candidates reconstruction: 76.77%
# False tu true reconstructed signal ratio: 0.4

# %%
cut3 = test_best
mask1 = df_clean['xgb_preds']>cut3
df3=df_clean[mask1]

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=200)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=200)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
#axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb_v3/kaon_inv_mass_comparison.pdf')

# %%
from matplotlib import gridspec

range1= (0.4, 0.6)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 100, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 100, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables (close up)", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=100)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=100)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3/kaon_inv_mass_comparison_closeup.png')
fig.savefig(directory+'img/xgb_v3/kaon_inv_mass_comparison_closeup.pdf')

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
axs[0].set_yscale('log')
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=300)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=300)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].set_ylim([0.,2.])
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb_v3/kaon_inv_mass_comparison.pdf')

# %%
mask1 = df_clean['xgb_preds']>test_best
df3_base=df_clean[mask1]
fig, axs = plt.subplots(figsize=(12, 8))

range1= (1.105, 1.14)
bins1 = 150

df3_base['mass'].plot.hist(bins = bins1, range=range1, facecolor='red',alpha = 0.3,grid=True,sharey=True, label='XGB selected $\Lambda$s')
df3_base[df3_base['issignal']==0]['mass'].plot.hist(bins = bins1, range=range1,facecolor='green',alpha = 0.3,grid=True,sharey=True, label ='\n False positives = \n (MC =0)\n background in \n the distribution')

plt.legend( fontsize = 18, loc='upper right')
plt.title("XGB selected $\Lambda$ candidates with a cut of %.3f "%test_best +"on the XGB probability distribution", fontsize = 18)
axs.set_xlabel("Mass (GeV/${c^2}$)", fontsize = 18)
plt.ylabel("Counts", fontsize = 18)
axs.text(1.123, 400, 'CBM Performance', fontsize=18)
axs.tick_params(labelsize=18)
fig.tight_layout()
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_2490/2065662648.py:17: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     248
#     249     if 'png' in formats:
# --> 250         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     251     if 'retina' in formats or 'png2x' in formats:
#     252         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     132         FigureCanvasBase(fig)
#     133
# --> 134     fig.canvas.print_figure(bytes_io, **kw)
#     135     data = bytes_io.getvalue()
#     136     if fmt == 'svg':
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     506             *metadata*, including the default 'Software' key.
#     507         """
# --> 508         FigureCanvasAgg.draw(self)
#     509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     399     def draw(self):
#     400         # docstring inherited
# --> 401         self.renderer = self.get_renderer(cleared=True)
#     402         # Acquire a lock on the shared font cache.
#     403         with RendererAgg.lock, \
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     415                           and getattr(self, "_lastKey", None) == key)
#     416         if not reuse_renderer:
# --> 417             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     418             self._lastKey = key
#     419         elif cleared:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      89         self.width = width
#      90         self.height = height
# ---> 91         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      92         self._filter_renderers = []
#      93
#
# ValueError: Image size of 786x82913 pixels is too large. It must be less than 2^16 in each direction.

# %%
#del x,y,x_test,y_test,x_whole,y_whole,
#del dtest,dtrain,dtest1,df3,df_clean,df_scaled
gc.collect()
# Out:
# 9255

# %% [markdown]
# # Importing the final predictor to root
# We will use the treelite library to transport the final predictor of our model to root

# %% [raw]
# #install treelite
# import treelite
# #create an object out of your model, bst in our case
# model = treelite.Model.from_xgboost(bst)
# #use GCC compiler
# toolchain = 'gcc'
# #parallel_comp can be changed upto as many processors as one have
# model.export_lib(toolchain=toolchain, libpath='./mymodel.so',
#                  params={'parallel_comp': 8}, verbose=True)
#
# # Operating system of the target machine
# platform = 'unix'
# # C compiler to use to compile prediction code on the target machine
# toolchain = 'gcc'
# # Save the source package as a zip archive named mymodel.zip
# # Later, we'll use this package to produce the library mymodel.so.
# model.export_srcpkg(platform=platform, toolchain=toolchain,
#                     pkgpath='./mymodel.zip', libname='mymodel.so',
#                     verbose=True)

# %% [raw]
# !unzip mymodel.zip

# %% [raw]
# #Build the source package (using GNU Make or NMake).
# %cd mymodel
# !make
#
# !ls

# %% [raw]
# If one wants to transfer this model to a different computer, target machine, then one should follow the following commands in command prompt

# %% [raw]
# sftp john@lxpool.gsi.de
# sftp> put mymodel.zip
# sftp> quit

# %% [raw]
# ssh john@lxpool.gsi.de
# unzip mymodel.zip
# cd mymodel
# make -j8

# %% [raw]
# The following C++ code can be the applied as a macro on some new data file

# %% [raw]
# %%writefile test.cpp
# #include "TROOT.h"
# #include "TFile.h"
# #include "TTree.h"
# #include "TH1F.h"
# #include <vector>
# #include "TString.h"
# #include "TMath.h"
# #include "TH1.h"
# #include "TF1.h"
# #include "TCanvas.h"
#
# #include <stdio.h>
# #include <stdlib.h>
# #include "main.c"
#
#
#
# void python_to_root(){
#   TCanvas* c1 = new TCanvas();
#   //c1->Divide(2,1);
#
#   //c1->cd(1);
#
#   /* Open the root file*/
#   TFile *f = new TFile("/gdrive/My Drive/presentations/treelite/10k_events_PFSimplePlainTree.root","UPDATE");
#   TTree *t1 = (TTree*)f->Get("PlainTree");
#
#
#   Float_t  LambdaCandidates_chi2primneg, LambdaCandidates_chi2primpos, LambdaCandidates_ldl, LambdaCandidates_distance, LambdaCandidates_chi2geo, LambdaCandidates_mass;
#
#   t1->SetBranchAddress("LambdaCandidates_chi2primneg",&LambdaCandidates_chi2primneg);
#   t1->SetBranchAddress("LambdaCandidates_chi2primpos",&LambdaCandidates_chi2primpos);
#   t1->SetBranchAddress("LambdaCandidates_ldl",&LambdaCandidates_ldl);
#   t1->SetBranchAddress("LambdaCandidates_distance",&LambdaCandidates_distance);
#   t1->SetBranchAddress("LambdaCandidates_chi2geo",&LambdaCandidates_chi2geo);
#   t1->SetBranchAddress("LambdaCandidates_mass",&LambdaCandidates_mass);
#
#
#   std::vector<float> output{};
#
#   const long n_entries = t1->GetEntries();
#   output.reserve(n_entries);
#
#   const size_t n_features = 5;
#   union Entry input[n_features];
#
#   //let's create a new branch which will store the probability returened for each proton-pion pair by our model
#   Float_t probab;
#   TBranch *bpt = t1->Branch("probab",&probab,"probabilities");
#   t1->SetBranchAddress("probab",&probab);
#
#   TH1F *h = new TH1F("h_prob", "This is the #Lambda invariant mass after the cut >0.918080", 300, 1.04, 1.4);
#   h->GetXaxis()->SetTitle("[GeV]");
#
#   for (long i = 0; i < n_entries; i++)
#    {
#      t1->GetEntry(i);
#
#     input[0].fvalue = LambdaCandidates_chi2primneg;
#     input[1].fvalue = LambdaCandidates_chi2primpos;
#     input[2].fvalue = LambdaCandidates_ldl;
#     input[3].fvalue = LambdaCandidates_distance;
#     input[4].fvalue = LambdaCandidates_chi2geo;
#
#     output.push_back(predict(input, 0));
#     probab= output.at(i);
#
#     if(probab > 0.918080){
#     h->Fill(LambdaCandidates_mass);}
#   }
#
#   h->Draw();
#
#
#
# }

# %% [raw]
# # Installing root
# !mkdir -p APPS
# !pwd
# !cd APPS && wget https://root.cern/download/root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
# !cd APPS && tar -xf root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
