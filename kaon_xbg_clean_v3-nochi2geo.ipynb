# %% [markdown]
# Variables of filenames

# %% [markdown]
# Background comes from URQMD, signal from DCM, for test dataset for both bckgr and sign generated in urqmd

# %% [markdown]
# 4:1 background/signal ratio before cleaning, 5M sign, 15k bckgr, 30k ALL, nochi2geo

# %%
#PLAINTREE FILES NAMES
directory='/Users/julnow/gsi/cbm/ML/JupyterNotebooks/'
signalFileName = directory + 'PlainTree_5MSign.root'
#backgroundFileName = directory + 'PlainTree_15kBckgr_URQMD.root'
allFileName = directory + 'PlainTree_30kAll_URQMD.root'

# %%
# %%capture
# !git clone https://github.com/shahidzk1/CBM_ML_Lambda_Library.git
# %cd CBM_ML_Lambda_Library
# !git pull origin main
# !pip install -r requirements.txt
# !python setup.py install

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
#from hipe4ml.model_handler import ModelHandler
#from hipe4ml.tree_handler import TreeHandler
from matplotlib.patches import ConnectionPatch
#from hipe4ml import plot_utils

import xgboost as xgb
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz

from sklearn.model_selection import cross_val_score
from scipy.stats import uniform

from numpy import sqrt, log, argmax

import weakref 
import itertools

from CBM_ML import tree_importer,  KFPF_lambda_cuts, plot_tools
from bayes_opt import BayesianOptimization
from bayes_opt import SequentialDomainReductionTransformer

import gc, os

# %% [markdown]
# # Selecting Background and Signal
# We generate PlainTrees from: 100k events (signal) and 20k evenents (background) with Au-Au @12A GeV/c, DCMQGSM-SMM generator passed through CBM setup in GEANT4, without any cuts
#
# To omit imbalance classification problem (event though there are 5 times more events for background, the number of entries is much smaller for signal) we resample the data. We're deleting instances from the over-represented class (in our case the background) - it's called under-sampling, one of the resampling methods.
#
# So for training and testing we will get signal candidates from the 5 sigma region and  background from outside this region (3 times signal size).

# %%
#CUTS FOR MASS SELECTION
#5 sigma region for signal
lower5SigmaCutSign = 0.43485
upper5SigmaCutSign = 0.56135
#mean invariant mass
invMass = 0.4981
# "5sigma" (not acutal 5 sigma) region for background
lower5SigmaCutBckgr = 0.279
upper5SigmaCutBckgr = 1

# %%
# We import three root files into our jupyter notebook
#sign - before cleaning but after 5sigma seletion, signal - cleaned
#so that we dont have to reimport everything with each change
sign = tree_importer.tree_importer(signalFileName,'PlainTree',7)

# We only select lambda candidates in the 5 sigma region around the kaon mass peak
#we preserve the cleaned dataframe with a changed name
sign = sign[(sign['Candidates_generation']==1) & (sign['Candidates_mass']>lower5SigmaCutSign) & (sign['Candidates_mass']<upper5SigmaCutSign)]

# Similarly for the background, we select background candidates which are not in the 5 sigma region of the kaon peak
bckgr = tree_importer.tree_importer(allFileName,'PlainTree',7)
#we preserve the cleaned dataframe with a changed name
bckgr = bckgr[(bckgr['Candidates_generation'] < 1)
                 & ((bckgr['Candidates_mass'] > lower5SigmaCutBckgr)
                 & (bckgr['Candidates_mass'] < lower5SigmaCutSign) | (bckgr['Candidates_mass']>upper5SigmaCutSign) 
                    & (bckgr['Candidates_mass'] < upper5SigmaCutBckgr))
             ].sample(n=4*(sign.shape[0])) #we select bckgr so that we have 4*more entries that for signal (before cleaning)

#Also call the garbage collector of python to collect unused items to free memory
gc.collect()
# Out:
# 2506

# %%
#we remove name prefixes 'Candidates' and do some renaming
bckgr.columns = bckgr.columns.str.replace('Candidates_', '')
bckgr.columns = bckgr.columns.str.replace('_', '')
sign.columns = sign.columns.str.replace('Candidates_', '')
sign.columns = sign.columns.str.replace('_', '')
#we also get rid of coordinates errors
sign = sign.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
bckgr = bckgr.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
#let's check the name prefixes 
sign.iloc[0:10,:]
# Out:
#     chi2geo  chi2primfirst  chi2primsecond  chi2topo  cosinefirst  \
# 0  1.055125   1.191851e+03    2.418227e+03  1.382537     0.992775
# 1  1.675698   1.191851e+03    2.562767e+00  1.478705     0.992461
# 2  0.884655   7.708000e+05    6.868500e+03  0.525167     0.986342
# 3  0.005968   7.835867e+03    6.868500e+03  1.604101     0.986588
# 4  0.048226   1.085611e+07    9.202689e+05  0.103476     0.928590
# 5  1.564517   1.755055e+06    3.325792e+06  3.620159     0.986431
# 6  0.265824   1.272178e+06    1.287558e+04  6.075241     0.995461
# 7  0.022228   1.088933e+05    6.886050e+06  0.706851     0.992894
# 8  0.339643   1.089560e+05    5.384653e+05  1.219999     0.984684
# 9  0.230005   2.651816e+03    5.384653e+05  0.681214     0.984095
#
#    cosinesecond  cosinetopo  distance       eta          l  ...        pT  \
# 0      0.978738    0.999984  0.010199  1.767213   0.831264  ...  0.858095
# 1      0.979261    0.995678  0.176995  1.760604   0.462111  ...  0.872880
# 2      0.971431    0.999988  0.621583  3.087167   6.618644  ...  0.189899
# 3      0.972632    0.999912  0.122127  3.098664   6.632589  ...  0.185934
# 4      0.993457    1.000000  0.000261  2.737351   7.693739  ...  0.224500
# 5      0.917482    0.999995  0.005039  2.155051   6.028908  ...  0.337338
# 6      0.924863    0.999973  0.357877  2.018910  12.209123  ...  0.487980
# 7      0.945111    0.999997  0.002335  2.561906   4.082486  ...  0.296266
# 8      0.943475    0.999985  0.009880  2.285058   2.682313  ...  0.328416
# 9      0.943596    0.999702  0.039568  2.292220   2.849284  ...  0.322286
#
#         phi        px        py        pz  rapidity         x         y  \
# 0 -1.419017  0.129742 -0.848230  2.438579  1.629621 -0.138814 -0.281002
# 1 -1.416307  0.134315 -0.862485  2.463272  1.624846 -0.118300 -0.178443
# 2 -2.975034 -0.187271 -0.031483  2.076483  2.065397 -0.803517 -0.114543
# 3 -2.957098 -0.182778 -0.034110  2.056715  2.062181 -0.830276 -0.054652
# 4  2.629986 -0.195755  0.109911  1.726547  1.875214 -1.039354  0.486576
# 5  0.300585  0.322212  0.099879  1.435782  1.604478  1.300065  0.455394
# 6  0.198032  0.478443  0.096005  1.804870  1.678201  3.072731  0.596965
# 7  0.904720  0.183064  0.232940  1.908443  1.902381  0.388764  0.523826
# 8  0.141954  0.325112  0.046463  1.596834  1.708246  0.522859  0.109796
# 9  0.141475  0.319066  0.045444  1.578531  1.704835  0.505560  0.086819
#
#            z  issignal
# 0   0.784715       1.0
# 1   0.427863       1.0
# 2   6.589974       1.0
# 3   6.602469       1.0
# 4   7.631403       1.0
# 5   5.872846       1.0
# 6  11.803755       1.0
# 7   4.035477       1.0
# 8   2.630366       1.0
# 9   2.805001       1.0
#
# [10 rows x 23 columns]

# %% [markdown]
# The label 'issignal' tells us if an entry comes from signal (1) or background (0)

# %% [markdown]
# # Data Cleaning
# Sometimes a data set contains entries which are outliers or does not make sense. For example, infinite values or NaN entries. We clean the data by removing these entries.
#
# Similarly, CBM is a fixed target experiment so there are certain conditions which the data has to satisfy before it is considered as reliable data.So we apply certain limits on the data sets.
#
# The values of these cuts are described: https://drive.google.com/file/d/1tb0FBRq4KgVu-VQZgpjA8ONbIGVCNOnE/view?usp=sharing https://github.com/julnow/JupyterNotebooks/blob/kaon/CBM%20K-short%20data%20cleaning.pdf

# %%
#CUTS USED FOR DATA CLEANING
#mass cuts for both bckgr and sign
lowerMassCut = 0.279
upperMassCut = 1
#distance cuts
#DCA
lowerDcaCut = 0
upperDcaCut = 100
#l distance
lowerLCut = -5
upperLCut = 80
#loverdl
lowerLdlCut = -25
upperLdlCut = 15000
#coordinate cuts
absXCut = 50
absYCut = 50
lowerZCut = -1
upperZCut = 80
#momentums cuts
pzLowerCut = 0
pUpperCut = 20
ptUpperCut = 3
#chi2
#geo
lowerChi2GeoCut = 0
upperChi2GeoCut = 10000
#topo
lowerChi2TopoCut = 0
upperChi2TopoCut = 100000
#prim first
lowerChi2PrimFirstCut = 0
upperChi2PrimFirstCut = 3e7
#prim second
lowerChi2PrimSecondCut = 0
upperChi2PrimSecondCut = 3e7
#pseudorapidity cuts
lowerEtaCut = 1.
upperEtaCut = 6.5

# %%
def clean_df(df):
    # let's treat all the infinite, inf, values by nan and then we drop all the null entries
    with pd.option_context('mode.use_inf_as_na', True):
        df = df.dropna()
    #Experimental constraints
    is_good_mom = (df['pz'] > pzLowerCut) & (df['p']<pUpperCut) & (df['pT']<ptUpperCut)
    is_good_coord = (abs(df['x']) < absXCut) & (abs(df['y']) < absYCut) & (df['z']>lowerZCut) & (df['z']<upperZCut)
    is_good_params = (df['distance'] > lowerDcaCut) & (df['distance'] < upperDcaCut) & (df['chi2geo']>lowerChi2GeoCut) & (df['chi2geo'] < upperChi2GeoCut) & (df['chi2topo'] > lowerChi2TopoCut) & (df['chi2topo'] < upperChi2TopoCut) & (df['eta']>lowerEtaCut) & (df['eta']<upperEtaCut)& (df['l']>lowerLCut) & (df['l']<upperLCut) & (df['loverdl']>lowerLdlCut) & (df['loverdl']<upperLdlCut)
    is_good_daughters = (df['chi2primfirst']>lowerChi2PrimFirstCut) & (df['chi2primfirst'] < upperChi2PrimSecondCut) & (df['chi2primsecond']>lowerChi2PrimSecondCut) & (df['chi2primsecond']<upperChi2PrimFirstCut)
    is_good_mass = (df['mass']>lowerMassCut) & (df['mass']<upperMassCut)

    is_good_df = (is_good_mom) & (is_good_coord) & (is_good_params) & (is_good_daughters) & (is_good_mass)

    return df[is_good_df]

# %%
background = clean_df(bckgr)
signal = clean_df(sign)
print('size of:\nsignal: ' + str(len(signal)) + '\nbackground: ' + str(len(background)) 
      + '\nbackground to signal ratio: ' + str(round(len(background)/len(signal), 1)))
del sign, bckgr
# Out:
# size of:
# signal: 4521056
# background: 16712740
# background to signal ratio: 3.7

# %% [markdown]
# We'll also import and clean dataset of 10k events for both background and signal (for testing our algorhitm)

# %%
#Let's combine signal and background
df_scaled = pd.concat([signal, background])
del signal, background
gc.collect()
# Out:
# 22

# %% [markdown]
# # Selecting Background and Signal
# After cleaning, our training data set contains 450442 background candidates and 1638402 signal candidates (background to signal ratio $\approx 3.6$). For testing, we'll use cleaned dataset containing 28740227 entries of signal and background (background to signal ratio $\approx 1985.1$)
#
# Here, we use under-sampling to tackle the problem with the classification of underrepresented class (normally, the signal is only approx. 0.05% of real data)

# %%
if not os.path.exists(directory+'img/xgb_v3_nochi2geo'):
    os.makedirs(directory+'img/xgb_v3_nochi2geo')
#lets draw sign to background ratio
def plt_sig_back(df):
    range1 = (lowerMassCut, upperMassCut)
    fig, axs = plt.subplots(figsize=(20, 10))
    #df_scaled['mass'].plot.hist(bins = 300, range=range1,grid=True,sharey=True)
    (df[df['issignal']==0])['mass'].plot.hist(bins = 300, facecolor='yellow',grid=True,range=range1, label='Background')
    (df[df['issignal']==1])['mass'].plot.hist(bins = 300, facecolor='magenta',grid=True, range=range1, label ='Signal')
    #plt.vlines(x=1.108,ymin=-1,ymax=48000, color='black', linestyle='-')
    #plt.vlines(x=1.1227,ymin=-1,ymax=48000, color='black', linestyle='-')
    plt.ylabel("Counts (log scale)", fontsize=15)
    plt.xlabel("Mass in GeV/$c^2$", fontsize= 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.title('Test and Train K-short Invariant Mass', fontsize = 15)
    plt.legend( fontsize = 15)
    axs.tick_params(axis='both', which='major', labelsize=18)
    plt.yscale("log")
    fig.tight_layout()
    fig.savefig(directory+'img/xgb_v3_nochi2geo/inv_mass_trainset.pdf')
    fig.savefig(directory+'img/xgb_v3_nochi2geo/inv_mass_trainset.png')

# %%
plt_sig_back(df_scaled)
gc.collect()
# Out:
# 0

# %% [markdown]
# # Creating Train and Test sets
# To make machine learning algorithms more efficient on unseen data we divide our data into two sets. One set is for training the algorithm and the other is for testing the algorithm. If we don't do this then the algorithm can overfit and we will not capture the general trends in the data.

# %%
# The following columns will be used to predict whether a reconstructed candidate is a lambda particle or not
cuts = [ 'loverdl', 'distance', 'chi2topo', 'chi2primfirst', 'chi2primsecond']#'chi2geo', 


x = df_scaled[cuts].copy()

# The MC information is saved in this y variable
y =pd.DataFrame(df_scaled['issignal'], dtype='int')

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=324)
del df_scaled, x, y

#DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed. 
dtrain = xgb.DMatrix(x_train, label = y_train)
dtest1=xgb.DMatrix(x_test, label = y_test)
del x_test
gc.collect()
# Out:
# 44635

# %% [markdown]
# ## Bayesian optimization
# In order to find the best parameters of XGB for our data we use Bayesian optimization. Grid search and and random search could also do the same job but bayesian is more time efficient. For further reading visit [the git page](https://github.com/fmfn/BayesianOptimization) of the bayesian optimization used here.
#
# ### Hyper parameters
# Some of the following hyper parameters will be tuned for our algorithm:
#
#
# *subsample* [default=1]
# Subsample ratio of the training instances. Setting it to 0.5 means that XGBoost would randomly sample half of the training data prior to growing trees. and this will prevent overfitting. Subsampling will occur once in every boosting iteration.
# range: (0,1]
#
# *eta* [default=0.3, alias: learning_rate]
# Step size shrinkage used in update to prevents overfitting. After each boosting step, we can directly get the weights of new features, and eta shrinks the feature weights to make the boosting process more conservative.
# range: [0,1]
#
#
# *gamma* [default=0, alias: min_split_loss]
# Minimum loss reduction required to make a further partition on a leaf node of the tree. The larger gamma is, the more conservative the algorithm will be.
# range: [0,∞]
#
#
# *alpha* [default=0, alias: reg_alpha]
# L1 regularization term on weights. Increasing this value will make model more conservative.
#
# *Lasso Regression* (Least Absolute Shrinkage and Selection Operator) adds “absolute value of magnitude” of coefficient as penalty term to the loss function.

# %%
#Bayesian Optimization function for xgboost
#specify the parameters you want to tune as keyword arguments
def bo_tune_xgb(max_depth, gamma, alpha, n_estimators ,learning_rate):
    params = {'max_depth': int(max_depth),
              'gamma': gamma,
              'alpha':alpha,
              'n_estimators': n_estimators,
              'learning_rate':learning_rate,
              'subsample': 0.8,
              'eta': 0.1,
              'eval_metric': 'auc', 'nthread' : 8}
    cv_result = xgb.cv(params, dtrain, num_boost_round=10, nfold=5)
    return  cv_result['test-auc-mean'].iloc[-1]

bounds_transformer = SequentialDomainReductionTransformer()

# %%
#Invoking the Bayesian Optimizer with the specified parameters to tune
xgb_bo = BayesianOptimization(bo_tune_xgb, {'max_depth': (6, 16),
                                             'gamma': (0, 1),
                                            'alpha': (2,12),
                                             'learning_rate':(0,.5),
                                             'n_estimators':(300,1000)
                                            },
                             bounds_transformer=bounds_transformer)

# %%
#performing Bayesian optimization for 5 iterations with 8 steps of random exploration with an #acquisition function of expected improvement
#xgb_bo.maximize(n_iter=5, init_points=5)
# Out:
# |   iter    |  target   |   alpha   |   gamma   | learni... | max_depth | n_esti... |
# -------------------------------------------------------------------------------------
# [17:34:55] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [17:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 876 extra nodes, 174 pruned nodes, max_depth=12
# [17:35:20] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [17:35:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 882 extra nodes, 190 pruned nodes, max_depth=12
# [17:35:46] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [17:36:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 898 extra nodes, 184 pruned nodes, max_depth=12
# [17:36:14] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [17:36:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 914 extra nodes, 184 pruned nodes, max_depth=12
# [17:36:41] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [17:37:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 898 extra nodes, 172 pruned nodes, max_depth=12
# [17:37:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 834 extra nodes, 240 pruned nodes, max_depth=12
# [17:37:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 818 extra nodes, 206 pruned nodes, max_depth=12
# [17:38:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 810 extra nodes, 222 pruned nodes, max_depth=12
# [17:38:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 834 extra nodes, 190 pruned nodes, max_depth=12
# [17:38:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 806 extra nodes, 204 pruned nodes, max_depth=12
# [17:39:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 768 extra nodes, 288 pruned nodes, max_depth=12
# [17:39:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 712 extra nodes, 266 pruned nodes, max_depth=12
# [17:39:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 740 extra nodes, 268 pruned nodes, max_depth=12
# [17:40:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 700 extra nodes, 218 pruned nodes, max_depth=12
# [17:40:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 694 extra nodes, 272 pruned nodes, max_depth=12
# [17:40:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 592 extra nodes, 278 pruned nodes, max_depth=12
# [17:41:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 600 extra nodes, 278 pruned nodes, max_depth=12
# [17:41:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 680 extra nodes, 262 pruned nodes, max_depth=12
# [17:41:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 648 extra nodes, 274 pruned nodes, max_depth=12
# [17:42:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 622 extra nodes, 284 pruned nodes, max_depth=12
# [17:42:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 566 extra nodes, 304 pruned nodes, max_depth=12
# [17:42:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 594 extra nodes, 338 pruned nodes, max_depth=12
# [17:43:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 590 extra nodes, 322 pruned nodes, max_depth=12
# [17:43:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 588 extra nodes, 314 pruned nodes, max_depth=12
# [17:43:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 590 extra nodes, 314 pruned nodes, max_depth=12
# [17:44:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 382 pruned nodes, max_depth=12
# [17:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 562 extra nodes, 276 pruned nodes, max_depth=12
# [17:44:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 564 extra nodes, 326 pruned nodes, max_depth=12
# [17:45:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 534 extra nodes, 292 pruned nodes, max_depth=12
# [17:45:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 538 extra nodes, 294 pruned nodes, max_depth=12
# [17:45:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 510 extra nodes, 324 pruned nodes, max_depth=12
# [17:46:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 504 extra nodes, 344 pruned nodes, max_depth=12
# [17:46:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 334 pruned nodes, max_depth=12
# [17:46:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 570 extra nodes, 378 pruned nodes, max_depth=12
# [17:47:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 312 pruned nodes, max_depth=12
# [17:47:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 304 pruned nodes, max_depth=12
# [17:48:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 418 pruned nodes, max_depth=12
# [17:48:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 322 pruned nodes, max_depth=12
# [17:48:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 352 pruned nodes, max_depth=12
# [17:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 404 pruned nodes, max_depth=12
# [17:49:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 442 pruned nodes, max_depth=12
# [17:49:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 362 pruned nodes, max_depth=12
# [17:50:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 358 pruned nodes, max_depth=12
# [17:50:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 388 pruned nodes, max_depth=12
# [17:51:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 368 pruned nodes, max_depth=12
# [17:51:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 448 pruned nodes, max_depth=12
# [17:51:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 476 pruned nodes, max_depth=12
# [17:52:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 396 extra nodes, 400 pruned nodes, max_depth=12
# [17:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 478 pruned nodes, max_depth=12
# [17:52:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 506 pruned nodes, max_depth=12
# |  1        |  0.9973   |  11.66    |  0.5277   |  0.3202   |  12.39    |  818.5    |
# [17:53:23] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [17:53:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:53:41] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [17:53:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [17:53:59] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [17:54:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [17:54:17] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [17:54:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:54:36] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [17:54:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [17:55:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:55:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:55:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:55:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:56:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:56:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:56:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [17:56:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=6
# [17:56:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [17:57:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=6
# [17:57:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [17:57:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:57:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:58:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:58:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:58:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:58:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [17:59:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=6
# [17:59:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:59:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17:59:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=6
# [17:59:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:00:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:00:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:00:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:01:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=6
# [18:01:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [18:01:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [18:01:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=6
# [18:01:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:02:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 4 pruned nodes, max_depth=6
# [18:02:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:02:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:03:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [18:03:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:03:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 2 pruned nodes, max_depth=6
# [18:03:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=6
# [18:04:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [18:04:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:04:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 2 pruned nodes, max_depth=6
# [18:04:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [18:04:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 4 pruned nodes, max_depth=6
# [18:05:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=6
# [18:05:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# |  2        |  0.9969   |  2.499    |  0.4594   |  0.1512   |  6.372    |  431.7    |
# [18:05:52] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [18:06:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1410 extra nodes, 1128 pruned nodes, max_depth=15
# [18:06:21] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [18:06:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1370 extra nodes, 1184 pruned nodes, max_depth=15
# [18:06:51] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [18:07:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1406 extra nodes, 1172 pruned nodes, max_depth=15
# [18:07:21] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [18:07:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1408 extra nodes, 1128 pruned nodes, max_depth=15
# [18:07:51] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [18:08:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1368 extra nodes, 1132 pruned nodes, max_depth=15
# [18:08:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1282 extra nodes, 1330 pruned nodes, max_depth=15
# [18:09:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1258 extra nodes, 1402 pruned nodes, max_depth=15
# [18:09:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1292 extra nodes, 1336 pruned nodes, max_depth=15
# [18:09:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1310 extra nodes, 1348 pruned nodes, max_depth=15
# [18:10:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1332 extra nodes, 1382 pruned nodes, max_depth=15
# [18:10:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1154 extra nodes, 1462 pruned nodes, max_depth=15
# [18:11:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1234 extra nodes, 1384 pruned nodes, max_depth=15
# [18:11:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1198 extra nodes, 1504 pruned nodes, max_depth=15
# [18:11:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1140 extra nodes, 1434 pruned nodes, max_depth=15
# [18:12:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1178 extra nodes, 1522 pruned nodes, max_depth=15
# [18:12:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1098 extra nodes, 1652 pruned nodes, max_depth=15
# [18:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1086 extra nodes, 1658 pruned nodes, max_depth=15
# [18:13:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1002 extra nodes, 1564 pruned nodes, max_depth=15
# [18:14:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1088 extra nodes, 1606 pruned nodes, max_depth=15
# [18:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1084 extra nodes, 1764 pruned nodes, max_depth=15
# [18:15:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 938 extra nodes, 1706 pruned nodes, max_depth=15
# [18:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 962 extra nodes, 1700 pruned nodes, max_depth=15
# [18:15:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 972 extra nodes, 1684 pruned nodes, max_depth=15
# [18:16:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 964 extra nodes, 1840 pruned nodes, max_depth=15
# [18:16:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 898 extra nodes, 1802 pruned nodes, max_depth=15
# [18:17:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 866 extra nodes, 1772 pruned nodes, max_depth=15
# [18:17:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 872 extra nodes, 1874 pruned nodes, max_depth=15
# [18:17:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 846 extra nodes, 1684 pruned nodes, max_depth=15
# [18:18:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 810 extra nodes, 1748 pruned nodes, max_depth=15
# [18:18:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 802 extra nodes, 1786 pruned nodes, max_depth=15
# [18:19:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 768 extra nodes, 1916 pruned nodes, max_depth=15
# [18:19:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 790 extra nodes, 1960 pruned nodes, max_depth=15
# [18:19:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 810 extra nodes, 1814 pruned nodes, max_depth=15
# [18:20:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 770 extra nodes, 1978 pruned nodes, max_depth=15
# [18:20:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 762 extra nodes, 1814 pruned nodes, max_depth=15
# [18:21:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 742 extra nodes, 2012 pruned nodes, max_depth=15
# [18:21:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 668 extra nodes, 1736 pruned nodes, max_depth=15
# [18:22:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 670 extra nodes, 1744 pruned nodes, max_depth=15
# [18:22:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 722 extra nodes, 2064 pruned nodes, max_depth=15
# [18:22:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 684 extra nodes, 1954 pruned nodes, max_depth=15
# [18:23:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 628 extra nodes, 1924 pruned nodes, max_depth=15
# [18:23:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 648 extra nodes, 2172 pruned nodes, max_depth=15
# [18:24:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 600 extra nodes, 1950 pruned nodes, max_depth=15
# [18:24:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 682 extra nodes, 1998 pruned nodes, max_depth=15
# [18:24:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 630 extra nodes, 2152 pruned nodes, max_depth=15
# [18:25:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 592 extra nodes, 2170 pruned nodes, max_depth=15
# [18:25:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 2066 pruned nodes, max_depth=15
# [18:26:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 2008 pruned nodes, max_depth=15
# [18:26:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 512 extra nodes, 1954 pruned nodes, max_depth=15
# [18:26:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 644 extra nodes, 2158 pruned nodes, max_depth=15
# |  3        |  0.9973   |  5.754    |  0.9382   |  0.2633   |  15.57    |  881.8    |
# [18:27:30] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [18:27:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1652 extra nodes, 730 pruned nodes, max_depth=14
# [18:27:59] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [18:28:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1570 extra nodes, 816 pruned nodes, max_depth=14
# [18:28:28] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [18:28:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1640 extra nodes, 766 pruned nodes, max_depth=14
# [18:28:57] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [18:29:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1622 extra nodes, 742 pruned nodes, max_depth=14
# [18:29:26] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [18:29:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1606 extra nodes, 738 pruned nodes, max_depth=14
# [18:30:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1620 extra nodes, 796 pruned nodes, max_depth=14
# [18:30:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1580 extra nodes, 870 pruned nodes, max_depth=14
# [18:31:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1572 extra nodes, 822 pruned nodes, max_depth=14
# [18:31:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1570 extra nodes, 874 pruned nodes, max_depth=14
# [18:31:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1584 extra nodes, 800 pruned nodes, max_depth=14
# [18:32:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1450 extra nodes, 958 pruned nodes, max_depth=14
# [18:32:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1466 extra nodes, 936 pruned nodes, max_depth=14
# [18:33:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1528 extra nodes, 844 pruned nodes, max_depth=14
# [18:33:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1500 extra nodes, 862 pruned nodes, max_depth=14
# [18:33:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1508 extra nodes, 906 pruned nodes, max_depth=14
# [18:34:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1420 extra nodes, 970 pruned nodes, max_depth=14
# [18:34:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1406 extra nodes, 918 pruned nodes, max_depth=14
# [18:35:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1368 extra nodes, 960 pruned nodes, max_depth=14
# [18:35:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1430 extra nodes, 1008 pruned nodes, max_depth=14
# [18:35:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1484 extra nodes, 1008 pruned nodes, max_depth=14
# [18:36:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1394 extra nodes, 1120 pruned nodes, max_depth=14
# [18:36:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1326 extra nodes, 936 pruned nodes, max_depth=14
# [18:37:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1308 extra nodes, 1114 pruned nodes, max_depth=14
# [18:37:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1334 extra nodes, 998 pruned nodes, max_depth=14
# [18:37:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1374 extra nodes, 962 pruned nodes, max_depth=14
# [18:38:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1202 extra nodes, 1028 pruned nodes, max_depth=14
# [18:38:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1174 extra nodes, 944 pruned nodes, max_depth=14
# [18:39:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1300 extra nodes, 1128 pruned nodes, max_depth=14
# [18:39:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1268 extra nodes, 1210 pruned nodes, max_depth=14
# [18:39:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1278 extra nodes, 1070 pruned nodes, max_depth=14
# [18:40:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1218 extra nodes, 1084 pruned nodes, max_depth=14
# [18:40:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1192 extra nodes, 1116 pruned nodes, max_depth=14
# [18:41:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1218 extra nodes, 1134 pruned nodes, max_depth=14
# [18:41:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1158 extra nodes, 1036 pruned nodes, max_depth=14
# [18:42:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1126 extra nodes, 1142 pruned nodes, max_depth=14
# [18:42:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1090 extra nodes, 1214 pruned nodes, max_depth=14
# [18:42:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1082 extra nodes, 1132 pruned nodes, max_depth=14
# [18:43:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1106 extra nodes, 1118 pruned nodes, max_depth=14
# Exception ignored on calling ctypes callback function: <function _log_callback at 0x134013e50>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/xgboost/core.py", line 103, in _log_callback
#     def _log_callback(msg):
# KeyboardInterrupt:
# [18:44:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1178 extra nodes, 1090 pruned nodes, max_depth=14
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/bayes_opt/target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (5.859091905645627, 0.45529785621493635, 0.20045861509712382, 14.593072869119627, 453.85920732280715)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_48176/3210735658.py in <module>
#       1 #performing Bayesian optimization for 5 iterations with 8 steps of random exploration with an #acquisition function of expected improvement
# ----> 2 xgb_bo.maximize(n_iter=5, init_points=5)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/bayes_opt/bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/bayes_opt/target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_48176/3065015696.py in bo_tune_xgb(max_depth, gamma, alpha, n_estimators, learning_rate)
#      10               'eta': 0.1,
#      11               'eval_metric': 'auc', 'nthread' : 8}
# ---> 12     cv_result = xgb.cv(params, dtrain, num_boost_round=10, nfold=5)
#      13     return  cv_result['test-auc-mean'].iloc[-1]
#      14
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/xgboost/training.py in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, feval, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks, shuffle)
#     427         for fold in cvfolds:
#     428             fold.update(i, obj)
# --> 429         res = aggcv([f.eval(i, feval) for f in cvfolds])
#     430
#     431         for key, mean, std in res:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/xgboost/training.py in <listcomp>(.0)
#     427         for fold in cvfolds:
#     428             fold.update(i, obj)
# --> 429         res = aggcv([f.eval(i, feval) for f in cvfolds])
#     430
#     431         for key, mean, std in res:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/xgboost/training.py in eval(self, iteration, feval)
#     220     def eval(self, iteration, feval):
#     221         """"Evaluate the CVPack for one iteration."""
# --> 222         return self.bst.eval_set(self.watchlist, iteration, feval)
#     223
#     224
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/xgboost/core.py in eval_set(self, evals, iteration, feval)
#    1077         evnames = c_array(ctypes.c_char_p, [c_str(d[1]) for d in evals])
#    1078         msg = ctypes.c_char_p()
# -> 1079         _check_call(_LIB.XGBoosterEvalOneIter(self.handle, ctypes.c_int(iteration),
#    1080                                               dmats, evnames,
#    1081                                               c_bst_ulong(len(evals)),
#
# KeyboardInterrupt:

# %%
# best target so far 0.9974344
print(xgb_bo.max)
# Out:
# {'target': 0.997335, 'params': {'alpha': 5.753533575127802, 'gamma': 0.9381973111303026, 'learning_rate': 0.2632517674042119, 'max_depth': 15.56604307847495, 'n_estimators': 881.7816101314299}}

# %% [markdown]
# we got: {'target': 0.997335, 'params': {'alpha': 5.753533575127802, 'gamma': 0.9381973111303026, 'learning_rate': 0.2632517674042119, 'max_depth': 15.56604307847495, 'n_estimators': 881.7816101314299}}

# %% [markdown]
# # XGB models
# Now let's take the parameters selected by the bayesian optimization and apply them in our training and testing.

# %%
max_params = {'target': 0.997335, 'params': {'alpha': 5.753533575127802, 'gamma': 0.9381973111303026, 'learning_rate': 0.2632517674042119, 'max_depth': 15.56604307847495, 'n_estimators': 881.7816101314299}}
max_param = max_params['params']#xgb_bo.max['params']
param= {'alpha': max_param['alpha'], 'gamma': max_param['gamma'], 'learning_rate': max_param['learning_rate'],
        'max_depth': int(round(max_param['max_depth'],0)), 'n_estimators': int(round(max_param['n_estimators'],0))
        , 'objective': 'binary:logistic','nthread' : 8}

# %%
#To train the algorithm using the parameters selected by bayesian optimization
bst = xgb.train(param, dtrain)
# Out:
# [19:42:40] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [19:43:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2564 extra nodes, 958 pruned nodes, max_depth=16
# [19:43:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2754 extra nodes, 1038 pruned nodes, max_depth=16
# [19:44:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2882 extra nodes, 1260 pruned nodes, max_depth=16
# [19:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2808 extra nodes, 1312 pruned nodes, max_depth=16
# [19:45:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2884 extra nodes, 1466 pruned nodes, max_depth=16
# [19:45:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3112 extra nodes, 1556 pruned nodes, max_depth=16
# [19:46:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3014 extra nodes, 1604 pruned nodes, max_depth=16
# [19:46:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3224 extra nodes, 1704 pruned nodes, max_depth=16
# [19:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3306 extra nodes, 1840 pruned nodes, max_depth=16
# [19:48:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3252 extra nodes, 1772 pruned nodes, max_depth=16

# %%
#We apply our model on the training data that was trained on the training data, this helps us to control overfitting
bst1= bst.predict(dtrain)

# %%
#bstt = xgb.XGBClassifier(**param).fit(x_train, y_train) #this is the right way to use it but takes a lot of time

# %%
#bstt1= bstt.predict(dtrain)

# %%
del dtrain 
gc.collect()
# Out:
# 7

# %%
# We apply our trained model on test data and store the predictions in a bst_test dataframe
bst_test = pd.DataFrame(data=bst.predict(dtest1),  columns=["xgb_preds"])
y_test=y_test.set_index(np.arange(0,bst_test.shape[0]))
# We also store the MC information in this dataFrame
bst_test['issignal']=y_test['issignal']

# %% [markdown]
# ## Whole set
# We also select the selected variables from the 10k events data set

# %%
df_origin = tree_importer.tree_importer(allFileName,'PlainTree',7)
df_origin.columns = df_origin.columns.str.replace('Candidates_', '')
df_origin.columns = df_origin.columns.str.replace('_', '')
df_origin = df_origin.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
df_clean = clean_df(df_origin)
del df_origin
gc.collect()
#lets look at impoted tree
df_clean.iloc[0:10,:]
print('test set (background to signal ratio): ' 
      + str(round(len(df_clean.loc[df_clean['issignal'] == 0])/len(df_clean.loc[df_clean['issignal'] == 1]), 1))
      + '\ntest set (both signal and background): ' + str(len(df_clean)))
# Out:
# test set (background to signal ratio): 1858.5
# test set (both signal and background): 55509831

# %%
x_whole = df_clean[cuts].copy()
y_whole = pd.DataFrame(df_clean['issignal'], dtype='int')
dtest = xgb.DMatrix(x_whole, label = y_whole)
del x_whole
gc.collect()
# Out:
# 4

# %%
#The following graph will show us that which features are important for the model
ax = xgb.plot_importance(bst)
plt.rcParams['figure.figsize'] = [5, 3]
plt.show()
ax.figure.tight_layout() 
ax.figure.savefig(directory+'img/xgb_v3_nochi2geo/feature_importance.pdf')
ax.figure.savefig(directory+'img/xgb_v3_nochi2geo/feature_importance.png')

# %% [markdown]
# ## AUC and ROC
#
# The function roc_curve computes the receiver operating characteristic curve, or ROC curve. Quoting Wikipedia :
#
# “A receiver operating characteristic (ROC), or simply ROC curve, is a graphical plot which illustrates the performance of a binary classifier system as its discrimination threshold is varied. It is created by plotting the fraction of true positives out of the positives (TPR = true positive rate) vs. the fraction of false positives out of the negatives (FPR = false positive rate), at various threshold settings. TPR is also known as sensitivity, and FPR is one minus the specificity or true negative rate.”
#
# This function requires the true binary value and the target scores, which can either be probability estimates of the positive class, confidence values, or binary decisions.
#
# Similarly, the function roc_auc_score computes Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.

# %% [markdown]
# To find the best threshold which results more signal to background ratio for lambda candidates we use the parameter S0 called the approximate median significance by the higgs boson  ML challenge (http://higgsml.lal.in2p3.fr/documentation,9.)

# %%
def AMS(y_true, y_predict, y_true1, y_predict1):
    roc_auc=roc_auc_score(y_true, y_predict)
    fpr, tpr, thresholds = roc_curve(y_true, y_predict,drop_intermediate=False ,pos_label=1)
    S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
    S0 = S0[~np.isnan(S0)]
    xi = argmax(S0)
    S0_best_threshold = (thresholds[xi])

    roc_auc1=roc_auc_score(y_true1, y_predict1)
    fpr1, tpr1, thresholds1 = roc_curve(y_true1, y_predict1,drop_intermediate=False ,pos_label=1)
    S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))
    S01 = S01[~np.isnan(S01)]
    xi1 = argmax(S01)
    S0_best_threshold1 = (thresholds[xi1])

    #plotting
    fig, axs = plt.subplots(figsize=(15, 10), dpi = 100)
    plt.plot(fpr, tpr, linestyle=':',color='darkorange',label='ROC curve train (area = %0.4f)' % roc_auc)
    plt.plot(fpr1, tpr1, color='green',label='ROC curve test (area = %0.4f)' % roc_auc1)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.scatter(fpr[xi], tpr[xi], marker='o', color='black', label= 'Best Threshold train set = '+"%.4f" % S0_best_threshold +'\n S0 = '+ "%.2f" % S0[xi])
    plt.scatter(fpr1[xi1], tpr1[xi1], marker='o', color='blue', label= 'Best Threshold test set = '+"%.4f" % S0_best_threshold1 +'\n S0 = '+ "%.2f" % S01[xi1])
    plt.xlabel('False Positive Rate', fontsize = 15)
    plt.ylabel('True Positive Rate', fontsize = 15)
    plt.legend(loc="lower right", fontsize = 15)
    plt.title('Receiver operating characteristic', fontsize = 15)
    plt.xlim([-0.01, 1.0])
    plt.ylim([0, 1.02])
    
    fig.tight_layout()
    plt.show()
    fig.savefig(directory+'img/xgb_v3_nochi2geo/ams.pdf')
    fig.savefig(directory+'img/xgb_v3_nochi2geo/ams.png')

    return S0_best_threshold, S0_best_threshold1

# %%
train_best, test_best = AMS(y_train, bst1, y_test, bst_test['xgb_preds'])
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_50242/2770299599.py:4: RuntimeWarning: invalid value encountered in true_divide
#   S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_50242/2770299599.py:11: RuntimeWarning: invalid value encountered in true_divide
#   S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))

# %%
def preds_prob(df, preds, true, dataset):
    if dataset =='train':
        label1 = 'XGB Predictions on the training data set'
    else:
        label1 = 'XGB Predictions on the test data set'
    fig, ax = plt.subplots(figsize=(12, 8))
    bins1=100
    plt.hist(df[preds], bins=bins1,facecolor='green',alpha = 0.3, label=label1)
    TP = df[(df[true]==1)]
    TN = df[(df[true]==0)]
    #TP[preds].plot.hist(ax=ax, bins=bins1,facecolor='blue', histtype='stepfilled',alpha = 0.3, label='True Positives/signal in predictions')
    hist, bins = np.histogram(TP[preds], bins=bins1)
    err = np.sqrt(hist)
    center = (bins[:-1] + bins[1:]) / 2

    
    hist1, bins1 = np.histogram(TN[preds], bins=bins1)
    err1 = np.sqrt(hist1)
    plt.errorbar(center, hist1, yerr=err1, fmt='o',
                 c='Red', label='Background in predictions')
    
    plt.errorbar(center, hist, yerr=err, fmt='o',
                 c='blue', label='Signal in predictions')
    
    ax.set_yscale('log')
    plt.xlabel('Probability',fontsize=18)
    plt.ylabel('Counts', fontsize=18)
    plt.legend(fontsize=18)
    ax.set_xticks(np.arange(0,1.1,0.1))
    ax.tick_params(axis='both', which='major', labelsize=18)
    ax.tick_params(axis='both', which='minor', labelsize=16)
    plt.show()
    fig.tight_layout()
    fig.savefig('test_best.png')
preds_prob(bst_test,'xgb_preds', 'issignal','test')

# %% [markdown]
# When the AUC, best threshold and approximate median significance for train and test are nearly the same, we save that model and use it. This means that our model is general enough. In my opinion, if the test S0 is above 3.0 then it is a good enough model.

# %% [markdown]
# ## Applying the model on the 10k events data-set

# %%
df_clean['xgb_preds'] = bst.predict(dtest)

# %%
df_clean['xgb_preds'].hist(bins=300)
plt.yscale('log')

# %% [markdown]
# ## Confusion Matrix
#
# A **Confusion Matrix** $C$ is such that $C_{ij}$ is equal to the number of observations known to be in group $i$ and predicted to be in group $j$. Thus in binary classification, the count of true positives is $C_{00}$, false negatives $C_{01}$,false positives is $C_{10}$, and true neagtives is $C_{11}$.
#
# If $ y^{'}_{i} $ is the predicted value of the $ i$-th sample and $y_{i}$ is the corresponding true value, then the fraction of correct predictions over $ n_{samples}$ is defined as
# $$
# True \: positives (y,y^{'}) =  \sum_{i=1}^{n_{samples} } 1 (y^{'}_{i} = y_{i}=1)
# $$
#
# The following function prints and plots the confusion matrix. Normalization can be applied by setting `normalize=True`.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
#calculate efficency and false tu tru signal ratio
def confustion_stats(df, cm):
    all_signals = len(df.loc[df['issignal'] == 1])
    true_signal = cm[0][0]
    false_signal = cm[1][0]        
    reconstructed_signals = true_signal + false_signal
    false_to_true_signals = false_signal / true_signal
    efficiency = reconstructed_signals / all_signals * 100 #efficency in % for all
    efficiency_true = true_signal / all_signals * 100 #efficency in % for all
    print("Efficiency: " + str(round(efficiency, 2)) + "%")
    print("Efficiency of true signal candidates reconstruction: " + str(round(efficiency_true, 2)) + "%")
    print("False tu true reconstructed signal ratio: " + str(round(false_to_true_signals, 2)))

# %%
#lets take the best threshold and look at the confusion matrix
cut1 = test_best
df_clean['xgb_preds1'] = ((df_clean['xgb_preds']>cut1)*1)
cnf_matrix = confusion_matrix(y_whole, df_clean['xgb_preds1'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix, classes=['signal','background'], title='Confusion Matrix for XGB for cut > '+str(cut1))
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_extreme_gradient_boosting_whole_data.pdf')
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_extreme_gradient_boosting_whole_data.png')
# Out:
# Confusion matrix, without normalization
# [[   25831     4021]
#  [    1622 55478300]]

# %%
confustion_stats(df_clean, cnf_matrix)
# Out:
# Efficiency: 91.96%
# Efficiency of true signal candidates reconstruction: 86.53%
# False tu true reconstructed signal ratio: 0.06

# %%
# The following function will display the inavriant mass histogram of the original 10k event set along with the mass histoigram after we apply a cut
# on the probability prediction of xgb
def cut_visualization(cut, range1=(lowerMassCut, upperMassCut), bins1= 300 ):
    mask1 = df_clean['xgb_preds']>cut
    df3=df_clean[mask1]
    
    fig, ax2 = plt.subplots(figsize=(15, 10), dpi = 200)
    color = 'tab:blue'
    ax2.hist(df_clean['mass'],bins = bins1, range=range1, facecolor='blue',alpha = 0.35, label='before selection')
    ax2.set_ylabel('Counts', fontsize = 15, color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.legend( fontsize = 15, loc='upper left')
    
    color = 'tab:red'
    ax1 = ax2.twinx()
    ax1.hist(df3['mass'], bins = bins1, range=range1, facecolor='red',alpha = 0.35, label='XGB')
    ax1.set_xlabel('Mass in GeV', fontsize = 15)
    ax1.set_ylabel('Counts ', fontsize = 15, color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.legend( fontsize = 15,loc='upper right' )

    plt.title("The original sample's Invariant Mass along with mass after selection of XGB (with a cut > "+str(cut)+')', fontsize = 15)
    fig.tight_layout()
    fig.savefig(directory+'img/xgb_v3_nochi2geo/whole_sample_invmass_with_ML.pdf')
    fig.savefig(directory+'img/xgb_v3_nochi2geo/whole_sample_invmass_with_ML.png')

# %%
cut_visualization(test_best)

# %% [markdown]
# # Comparison with the manually optimized cuts of KFPF
# In the already existing Kalman Filter Particle Finder (KFPF) package for online reconstruction and selection of short-lived particles in CBM, these criteria have been manually optimized. These selection-cuts have been selected to maximize the signal to background ratio (S/B) of the $\Lambda$ for a certain energy on a collisions generator. The selection criteria mainly depends on the collision energy, decay channel and detector configuration.

# %%
#manually selected cuts
manCut_loverdl = 30
manCut_dca = 0.4
manCut_chi2topo = 20
manCut_chi2geo = 12

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
new_check_set= df_clean.copy()
new_check_set['new_signal']=0

mask1 = (new_check_set['loverdl'] > manCut_loverdl) & (new_check_set['distance'] < manCut_dca)

mask2 = (new_check_set['chi2topo'] < manCut_chi2topo) & (new_check_set['chi2geo'] < manCut_chi2geo) 

new_check_set = new_check_set[(mask1) & (mask2)] 

#After all these cuts, what is left is considered as signal, so we replace all the values in the 'new_signal'
# column by 1
new_check_set['new_signal'] = 1
cnf_matrix1 = confusion_matrix(new_check_set['issignal'], new_check_set['new_signal'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix1, classes=['signal','background'], title='Confusion Matrix for manually set cuts')
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_for_manually_set_cuts.pdf')
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_for_manually_set_cuts.png')
# Out:
# Confusion matrix, without normalization
# [[22921     0]
#  [ 9136     0]]

# %%
confustion_stats(df_clean, cnf_matrix1)
# Out:
# Efficiency: 107.39%
# Efficiency of true signal candidates reconstruction: 76.78%
# False tu true reconstructed signal ratio: 0.4

# %%
cut3 = test_best
mask1 = df_clean['xgb_preds']>cut3
df3=df_clean[mask1]

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=200)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=200)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
#axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
from matplotlib import gridspec

range1= (0.4, 0.6)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 100, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 100, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables (close up)", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=100)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=100)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison_closeup.png')
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison_closeup.pdf')

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
axs[0].set_yscale('log')
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=300)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=300)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].set_ylim([0.,2.])
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
mask1 = df_clean['xgb_preds']>test_best
df3_base=df_clean[mask1]
fig, axs = plt.subplots(figsize=(12, 8))

range1= (1.105, 1.14)
bins1 = 150

df3_base['mass'].plot.hist(bins = bins1, range=range1, facecolor='red',alpha = 0.3,grid=True,sharey=True, label='XGB selected K-short')
df3_base[df3_base['issignal']==0]['mass'].plot.hist(bins = bins1, range=range1,facecolor='green',alpha = 0.3,grid=True,sharey=True, label ='\n False positives = \n (MC =0)\n background in \n the distribution')

plt.legend( fontsize = 18, loc='upper right')
plt.title("XGB selected $\Lambda$ candidates with a cut of %.3f "%test_best +"on the XGB probability distribution", fontsize = 18)
axs.set_xlabel("Mass (GeV/${c^2}$)", fontsize = 18)
plt.ylabel("Counts", fontsize = 18)
axs.text(1.123, 400, 'CBM Performance', fontsize=18)
axs.tick_params(labelsize=18)
fig.tight_layout()
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_50242/1939761547.py:17: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     248
#     249     if 'png' in formats:
# --> 250         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     251     if 'retina' in formats or 'png2x' in formats:
#     252         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     132         FigureCanvasBase(fig)
#     133
# --> 134     fig.canvas.print_figure(bytes_io, **kw)
#     135     data = bytes_io.getvalue()
#     136     if fmt == 'svg':
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     506             *metadata*, including the default 'Software' key.
#     507         """
# --> 508         FigureCanvasAgg.draw(self)
#     509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     399     def draw(self):
#     400         # docstring inherited
# --> 401         self.renderer = self.get_renderer(cleared=True)
#     402         # Acquire a lock on the shared font cache.
#     403         with RendererAgg.lock, \
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     415                           and getattr(self, "_lastKey", None) == key)
#     416         if not reuse_renderer:
# --> 417             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     418             self._lastKey = key
#     419         elif cleared:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      89         self.width = width
#      90         self.height = height
# ---> 91         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      92         self._filter_renderers = []
#      93
#
# ValueError: Image size of 801x1581678 pixels is too large. It must be less than 2^16 in each direction.

# %%
from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True, gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 100,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 100,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("log (counts)", fontsize = 18)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 18, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 18)
#axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=18)
axs[0].set_yscale('log')
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3_base['mass'],range=(lowerMassCut, upperMassCut), bins=300)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=300)


#makes sense to have only positive values
diff = (hist1 - hist2)
#axs[1].bar((bins[:-1] + bins[1:]) / 2, # this is what makes it comparable
# ns / ns1, # maybe check for div-by-zero!
# width=0.001)
axs[1].hlines(y=1, xmin=lowerMassCut, xmax=upperMassCut, colors='r', linestyles='solid', label='')
center = (bins[:-1] + bins[1:]) / 2
plt.errorbar(center, ns / ns1, fmt='o',
                 c='Blue', label='Background in predictions')


    
    
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 18)
axs[1].set_ylabel("XGB / KFPF", fontsize = 18)
#axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=18)

plt.show()
fig.tight_layout()
#fig.savefig("whole_sample_invmass_with_ML.png")
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_50242/1702553448.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 100,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_50242/1702553448.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 100,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)

# %%
from matplotlib import gridspec

left = .42
right = .55
range1= (left, right)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True, gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 50,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 50,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("log (counts)", fontsize = 18)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 18, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 18)
#axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=18)
axs[0].set_yscale('log')
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3_base['mass'],range=(left, right), bins=50)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(left, right), bins=50)


#makes sense to have only positive values
diff = (hist1 - hist2)
#axs[1].bar((bins[:-1] + bins[1:]) / 2, # this is what makes it comparable
# ns / ns1, # maybe check for div-by-zero!
# width=0.001)
axs[1].hlines(y=1, xmin=left, xmax=right, colors='r', linestyles='solid', label='')
center = (bins[:-1] + bins[1:]) / 2
plt.errorbar(center, ns / ns1, fmt='o',
                 c='Blue', label='Background in predictions')


    
    
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 18)
axs[1].set_ylabel("XGB / KFPF", fontsize = 18)
#axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=18)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/circle_kshort_invmass_with_ML.png')
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_50242/692036573.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 50,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_50242/692036573.py:12: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 50,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)

# %%
from matplotlib import gridspec

left = .44
right = .55
range1= (left, right)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True, gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 50,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 50,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("log (counts)", fontsize = 18)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 18, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 18)
#axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=18)
axs[0].set_yscale('log')
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3_base['mass'],range=(left, right), bins=50)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(left, right), bins=50)


#makes sense to have only positive values
diff = (hist1 - hist2)
#axs[1].bar((bins[:-1] + bins[1:]) / 2, # this is what makes it comparable
# ns / ns1, # maybe check for div-by-zero!
# width=0.001)
axs[1].hlines(y=1, xmin=left, xmax=right, colors='r', linestyles='solid', label='')
center = (bins[:-1] + bins[1:]) / 2
plt.errorbar(center, ns / ns1, fmt='o',
                 c='Blue', label='Background in predictions')


    
    
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 18)
axs[1].set_ylabel("XGB / KFPF", fontsize = 18)
#axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=18)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/circle_kshort_invmass_with_ML.png')
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_50242/2429793760.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 50,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_50242/2429793760.py:12: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 50,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)

# %%
par = 'loverdl'
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','after selection', 'man selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'distance'
ranges = (0,5)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'chi2topo'
ranges = (0,100)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'chi2geo'
ranges = (0,100)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'chi2primfirst'
ranges = (0,100)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'chi2primsecond'
ranges = (0,100)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
#del x,y,x_test,y_test,x_whole,y_whole,
#del dtest,dtrain,dtest1,df3,df_clean,df_scaled
gc.collect()
# Out:
# 3610

# %% [markdown]
# # Importing the final predictor to root
# We will use the treelite library to transport the final predictor of our model to root

# %% [raw]
# #install treelite
# import treelite
# #create an object out of your model, bst in our case
# model = treelite.Model.from_xgboost(bst)
# #use GCC compiler
# toolchain = 'gcc'
# #parallel_comp can be changed upto as many processors as one have
# model.export_lib(toolchain=toolchain, libpath='./mymodel.so',
#                  params={'parallel_comp': 8}, verbose=True)
#
# # Operating system of the target machine
# platform = 'unix'
# # C compiler to use to compile prediction code on the target machine
# toolchain = 'gcc'
# # Save the source package as a zip archive named mymodel.zip
# # Later, we'll use this package to produce the library mymodel.so.
# model.export_srcpkg(platform=platform, toolchain=toolchain,
#                     pkgpath='./mymodel.zip', libname='mymodel.so',
#                     verbose=True)

# %% [raw]
# !unzip mymodel.zip

# %% [raw]
# #Build the source package (using GNU Make or NMake).
# %cd mymodel
# !make
#
# !ls

# %% [raw]
# If one wants to transfer this model to a different computer, target machine, then one should follow the following commands in command prompt

# %% [raw]
# sftp john@lxpool.gsi.de
# sftp> put mymodel.zip
# sftp> quit

# %% [raw]
# ssh john@lxpool.gsi.de
# unzip mymodel.zip
# cd mymodel
# make -j8

# %% [raw]
# The following C++ code can be the applied as a macro on some new data file

# %% [raw]
# %%writefile test.cpp
# #include "TROOT.h"
# #include "TFile.h"
# #include "TTree.h"
# #include "TH1F.h"
# #include <vector>
# #include "TString.h"
# #include "TMath.h"
# #include "TH1.h"
# #include "TF1.h"
# #include "TCanvas.h"
#
# #include <stdio.h>
# #include <stdlib.h>
# #include "main.c"
#
#
#
# void python_to_root(){
#   TCanvas* c1 = new TCanvas();
#   //c1->Divide(2,1);
#
#   //c1->cd(1);
#
#   /* Open the root file*/
#   TFile *f = new TFile("/gdrive/My Drive/presentations/treelite/10k_events_PFSimplePlainTree.root","UPDATE");
#   TTree *t1 = (TTree*)f->Get("PlainTree");
#
#
#   Float_t  LambdaCandidates_chi2primneg, LambdaCandidates_chi2primpos, LambdaCandidates_ldl, LambdaCandidates_distance, LambdaCandidates_chi2geo, LambdaCandidates_mass;
#
#   t1->SetBranchAddress("LambdaCandidates_chi2primneg",&LambdaCandidates_chi2primneg);
#   t1->SetBranchAddress("LambdaCandidates_chi2primpos",&LambdaCandidates_chi2primpos);
#   t1->SetBranchAddress("LambdaCandidates_ldl",&LambdaCandidates_ldl);
#   t1->SetBranchAddress("LambdaCandidates_distance",&LambdaCandidates_distance);
#   t1->SetBranchAddress("LambdaCandidates_chi2geo",&LambdaCandidates_chi2geo);
#   t1->SetBranchAddress("LambdaCandidates_mass",&LambdaCandidates_mass);
#
#
#   std::vector<float> output{};
#
#   const long n_entries = t1->GetEntries();
#   output.reserve(n_entries);
#
#   const size_t n_features = 5;
#   union Entry input[n_features];
#
#   //let's create a new branch which will store the probability returened for each proton-pion pair by our model
#   Float_t probab;
#   TBranch *bpt = t1->Branch("probab",&probab,"probabilities");
#   t1->SetBranchAddress("probab",&probab);
#
#   TH1F *h = new TH1F("h_prob", "This is the #Lambda invariant mass after the cut >0.918080", 300, 1.04, 1.4);
#   h->GetXaxis()->SetTitle("[GeV]");
#
#   for (long i = 0; i < n_entries; i++)
#    {
#      t1->GetEntry(i);
#
#     input[0].fvalue = LambdaCandidates_chi2primneg;
#     input[1].fvalue = LambdaCandidates_chi2primpos;
#     input[2].fvalue = LambdaCandidates_ldl;
#     input[3].fvalue = LambdaCandidates_distance;
#     input[4].fvalue = LambdaCandidates_chi2geo;
#
#     output.push_back(predict(input, 0));
#     probab= output.at(i);
#
#     if(probab > 0.918080){
#     h->Fill(LambdaCandidates_mass);}
#   }
#
#   h->Draw();
#
#
#
# }

# %% [raw]
# # Installing root
# !mkdir -p APPS
# !pwd
# !cd APPS && wget https://root.cern/download/root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
# !cd APPS && tar -xf root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
