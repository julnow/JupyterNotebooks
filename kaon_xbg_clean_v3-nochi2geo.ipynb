# %% [markdown]
# Variables of filenames

# %% [markdown]
# Background comes from URQMD, signal from DCM, for test dataset for both bckgr and sign generated in urqmd

# %% [markdown]
# 4:1 background/signal ratio before cleaning, 5M sign, 15k bckgr, 30k ALL, nochi2geo

# %%
#PLAINTREE FILES NAMES
directory='/Users/julnow/gsi/cbm/ML/JupyterNotebooks/'
signalFileName = directory + 'PlainTree_5MSign.root'
backgroundFileName = directory + 'PlainTree_15kBckgr_URQMD.root'
allFileName = directory + 'PlainTree_30kAll_URQMD.root'

# %%
# !git clone https://github.com/shahidzk1/CBM_ML_Lambda_Library.git
# %cd CBM_ML_Lambda_Library
# !git pull origin main
# !pip install -r requirements.txt
# !python setup.py install
# Out:
# fatal: destination path 'CBM_ML_Lambda_Library' already exists and is not an empty directory.
# /Users/julnow/gsi/cbm/ML/JupyterNotebooks/CBM_ML_Lambda_Library
# hint: Pulling without specifying how to reconcile divergent branches is
# hint: discouraged. You can squelch this message by running one of the following
# hint: commands sometime before your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# From https://github.com/shahidzk1/CBM_ML_Lambda_Library
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Requirement already satisfied: uproot in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.21.1)
# Requirement already satisfied: scikit-learn in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (0.24.2)
# Requirement already satisfied: xgboost in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (0.80)
# Requirement already satisfied: bayesian-optimization in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: scipy>=0.14.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from bayesian-optimization->-r requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: joblib>=0.11 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (8.3.1)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 3)) (2021.1)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages (from uproot->-r requirements.txt (line 1)) (57.4.0)
# running install
# running bdist_egg
# running egg_info
# writing CBM_ML.egg-info/PKG-INFO
# writing dependency_links to CBM_ML.egg-info/dependency_links.txt
# writing top-level names to CBM_ML.egg-info/top_level.txt
# reading manifest file 'CBM_ML.egg-info/SOURCES.txt'
# writing manifest file 'CBM_ML.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-11.1-arm64/egg
# running install_lib
# running build_py
# creating build/bdist.macosx-11.1-arm64/egg
# creating build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/KFPF_lambda_cuts.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/__init__.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/plot_tools.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/root_functions.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# copying build/lib/CBM_ML/tree_importer.py -> build/bdist.macosx-11.1-arm64/egg/CBM_ML
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/KFPF_lambda_cuts.py to KFPF_lambda_cuts.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/plot_tools.py to plot_tools.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/root_functions.py to root_functions.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/CBM_ML/tree_importer.py to tree_importer.cpython-38.pyc
# creating build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/PKG-INFO -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/SOURCES.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/dependency_links.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying CBM_ML.egg-info/top_level.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/CBM_ML-0.1.0-py3.8.egg' and adding 'build/bdist.macosx-11.1-arm64/egg' to it
# removing 'build/bdist.macosx-11.1-arm64/egg' (and everything under it)
# Processing CBM_ML-0.1.0-py3.8.egg
# Removing /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/CBM_ML-0.1.0-py3.8.egg
# Copying CBM_ML-0.1.0-py3.8.egg to /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages
# CBM-ML 0.1.0 is already the active version in easy-install.pth
#
# Installed /opt/homebrew/Caskroom/miniforge/base/envs/cbm21/lib/python3.8/site-packages/CBM_ML-0.1.0-py3.8.egg
# Processing dependencies for CBM-ML==0.1.0
# Finished processing dependencies for CBM-ML==0.1.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
#from hipe4ml.model_handler import ModelHandler
#from hipe4ml.tree_handler import TreeHandler
from matplotlib.patches import ConnectionPatch
#from hipe4ml import plot_utils

import xgboost as xgb
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz

from sklearn.model_selection import cross_val_score
from scipy.stats import uniform

from numpy import sqrt, log, argmax

import weakref 
import itertools

from CBM_ML import tree_importer,  KFPF_lambda_cuts, plot_tools
from bayes_opt import BayesianOptimization
from bayes_opt import SequentialDomainReductionTransformer

import gc, os

# %% [markdown]
# # Selecting Background and Signal
# We generate PlainTrees from: 100k events (signal) and 20k evenents (background) with Au-Au @12A GeV/c, DCMQGSM-SMM generator passed through CBM setup in GEANT4, without any cuts
#
# To omit imbalance classification problem (event though there are 5 times more events for background, the number of entries is much smaller for signal) we resample the data. We're deleting instances from the over-represented class (in our case the background) - it's called under-sampling, one of the resampling methods.
#
# So for training and testing we will get signal candidates from the 5 sigma region and  background from outside this region (3 times signal size).

# %%
#CUTS FOR MASS SELECTION
#5 sigma region for signal
lower5SigmaCutSign = 0.43485
upper5SigmaCutSign = 0.56135
#mean invariant mass
invMass = 0.4981
# "5sigma" (not acutal 5 sigma) region for background
lower5SigmaCutBckgr = 0.1
upper5SigmaCutBckgr = 2

# %%
# We import three root files into our jupyter notebook
#sign - before cleaning but after 5sigma seletion, signal - cleaned
#so that we dont have to reimport everything with each change
sign = tree_importer.tree_importer(signalFileName,'PlainTree',7)

# We only select lambda candidates in the 5 sigma region around the kaon mass peak
#we preserve the cleaned dataframe with a changed name
sign = sign[(sign['Candidates_generation']==1) & (sign['Candidates_mass']>lower5SigmaCutSign) & (sign['Candidates_mass']<upper5SigmaCutSign)]

# Similarly for the background, we select background candidates which are not in the 5 sigma region of the kaon peak
bckgr = tree_importer.tree_importer(backgroundFileName,'PlainTree',7)
#we preserve the cleaned dataframe with a changed name
bckgr = bckgr[(bckgr['Candidates_generation'] < 1)
                 & ((bckgr['Candidates_mass'] > lower5SigmaCutBckgr)
                 & (bckgr['Candidates_mass'] < lower5SigmaCutSign) | (bckgr['Candidates_mass']>upper5SigmaCutSign) 
                    & (bckgr['Candidates_mass'] < upper5SigmaCutBckgr))
             ].sample(n=4*(sign.shape[0])) #we select bckgr so that we have 4*more entries that for signal (before cleaning)

#Also call the garbage collector of python to collect unused items to free memory
gc.collect()
# Out:
# 2506

# %%
#we remove name prefixes 'Candidates' and do some renaming
bckgr.columns = bckgr.columns.str.replace('Candidates_', '')
bckgr.columns = bckgr.columns.str.replace('_', '')
sign.columns = sign.columns.str.replace('Candidates_', '')
sign.columns = sign.columns.str.replace('_', '')
#we also get rid of coordinates errors
sign = sign.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
bckgr = bckgr.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
#let's check the name prefixes 
sign.iloc[0:10,:]
# Out:
#     chi2geo  chi2primfirst  chi2primsecond  chi2topo  cosinefirst  \
# 0  1.055125   1.191851e+03    2.418227e+03  1.382537     0.992775
# 1  1.675698   1.191851e+03    2.562767e+00  1.478705     0.992461
# 2  0.884655   7.708000e+05    6.868500e+03  0.525167     0.986342
# 3  0.005968   7.835867e+03    6.868500e+03  1.604101     0.986588
# 4  0.048226   1.085611e+07    9.202689e+05  0.103476     0.928590
# 5  1.564517   1.755055e+06    3.325792e+06  3.620159     0.986431
# 6  0.265824   1.272178e+06    1.287558e+04  6.075241     0.995461
# 7  0.022228   1.088933e+05    6.886050e+06  0.706851     0.992894
# 8  0.339643   1.089560e+05    5.384653e+05  1.219999     0.984684
# 9  0.230005   2.651816e+03    5.384653e+05  0.681214     0.984095
#
#    cosinesecond  cosinetopo  distance       eta          l  ...        pT  \
# 0      0.978738    0.999984  0.010199  1.767213   0.831264  ...  0.858095
# 1      0.979261    0.995678  0.176995  1.760604   0.462111  ...  0.872880
# 2      0.971431    0.999988  0.621583  3.087167   6.618644  ...  0.189899
# 3      0.972632    0.999912  0.122127  3.098664   6.632589  ...  0.185934
# 4      0.993457    1.000000  0.000261  2.737351   7.693739  ...  0.224500
# 5      0.917482    0.999995  0.005039  2.155051   6.028908  ...  0.337338
# 6      0.924863    0.999973  0.357877  2.018910  12.209123  ...  0.487980
# 7      0.945111    0.999997  0.002335  2.561906   4.082486  ...  0.296266
# 8      0.943475    0.999985  0.009880  2.285058   2.682313  ...  0.328416
# 9      0.943596    0.999702  0.039568  2.292220   2.849284  ...  0.322286
#
#         phi        px        py        pz  rapidity         x         y  \
# 0 -1.419017  0.129742 -0.848230  2.438579  1.629621 -0.138814 -0.281002
# 1 -1.416307  0.134315 -0.862485  2.463272  1.624846 -0.118300 -0.178443
# 2 -2.975034 -0.187271 -0.031483  2.076483  2.065397 -0.803517 -0.114543
# 3 -2.957098 -0.182778 -0.034110  2.056715  2.062181 -0.830276 -0.054652
# 4  2.629986 -0.195755  0.109911  1.726547  1.875214 -1.039354  0.486576
# 5  0.300585  0.322212  0.099879  1.435782  1.604478  1.300065  0.455394
# 6  0.198032  0.478443  0.096005  1.804870  1.678201  3.072731  0.596965
# 7  0.904720  0.183064  0.232940  1.908443  1.902381  0.388764  0.523826
# 8  0.141954  0.325112  0.046463  1.596834  1.708246  0.522859  0.109796
# 9  0.141475  0.319066  0.045444  1.578531  1.704835  0.505560  0.086819
#
#            z  issignal
# 0   0.784715       1.0
# 1   0.427863       1.0
# 2   6.589974       1.0
# 3   6.602469       1.0
# 4   7.631403       1.0
# 5   5.872846       1.0
# 6  11.803755       1.0
# 7   4.035477       1.0
# 8   2.630366       1.0
# 9   2.805001       1.0
#
# [10 rows x 23 columns]

# %% [markdown]
# The label 'issignal' tells us if an entry comes from signal (1) or background (0)

# %% [markdown]
# # Data Cleaning
# Sometimes a data set contains entries which are outliers or does not make sense. For example, infinite values or NaN entries. We clean the data by removing these entries.
#
# Similarly, CBM is a fixed target experiment so there are certain conditions which the data has to satisfy before it is considered as reliable data.So we apply certain limits on the data sets.
#
# The values of these cuts are described: https://drive.google.com/file/d/1tb0FBRq4KgVu-VQZgpjA8ONbIGVCNOnE/view?usp=sharing https://github.com/julnow/JupyterNotebooks/blob/kaon/CBM%20K-short%20data%20cleaning.pdf

# %%
#CUTS USED FOR DATA CLEANING
#mass cuts for both bckgr and sign
lowerMassCut = 0.279
upperMassCut = 1.5
#distance cuts
#DCA
lowerDcaCut = 0
upperDcaCut = 100
#l distance
lowerLCut = -5
upperLCut = 80
#loverdl
lowerLdlCut = -25
upperLdlCut = 15000
#coordinate cuts
absXCut = 50
absYCut = 50
lowerZCut = -1
upperZCut = 80
#momentums cuts
pzLowerCut = 0
pUpperCut = 20
ptUpperCut = 3
#chi2
#geo
lowerChi2GeoCut = 0
upperChi2GeoCut = 10000
#topo
lowerChi2TopoCut = 0
upperChi2TopoCut = 100000
#prim first
lowerChi2PrimFirstCut = 0
upperChi2PrimFirstCut = 3e7
#prim second
lowerChi2PrimSecondCut = 0
upperChi2PrimSecondCut = 3e7
#pseudorapidity cuts
lowerEtaCut = 1.
upperEtaCut = 6.5

# %%
def clean_df(df):
    # let's treat all the infinite, inf, values by nan and then we drop all the null entries
    with pd.option_context('mode.use_inf_as_na', True):
        df = df.dropna()
    #Experimental constraints
    is_good_mom = (df['pz'] > pzLowerCut) & (df['p']<pUpperCut) & (df['pT']<ptUpperCut)
    is_good_coord = (abs(df['x']) < absXCut) & (abs(df['y']) < absYCut) & (df['z']>lowerZCut) & (df['z']<upperZCut)
    is_good_params = (df['distance'] > lowerDcaCut) & (df['distance'] < upperDcaCut) & (df['chi2geo']>lowerChi2GeoCut) & (df['chi2geo'] < upperChi2GeoCut) & (df['chi2topo'] > lowerChi2TopoCut) & (df['chi2topo'] < upperChi2TopoCut) & (df['eta']>lowerEtaCut) & (df['eta']<upperEtaCut)& (df['l']>lowerLCut) & (df['l']<upperLCut) & (df['loverdl']>lowerLdlCut) & (df['loverdl']<upperLdlCut)
    is_good_daughters = (df['chi2primfirst']>lowerChi2PrimFirstCut) & (df['chi2primfirst'] < upperChi2PrimSecondCut) & (df['chi2primsecond']>lowerChi2PrimSecondCut) & (df['chi2primsecond']<upperChi2PrimFirstCut)
    is_good_mass = (df['mass']>lowerMassCut) & (df['mass']<upperMassCut)

    is_good_df = (is_good_mom) & (is_good_coord) & (is_good_params) & (is_good_daughters) & (is_good_mass)

    return df[is_good_df]

# %%
background = clean_df(bckgr)
signal = clean_df(sign)
print('size of:\nsignal: ' + str(len(signal)) + '\nbackground: ' + str(len(background)) 
      + '\nbackground to signal ratio: ' + str(round(len(background)/len(signal), 1)))
del sign, bckgr
# Out:
# size of:
# signal: 4521056
# background: 16426572
# background to signal ratio: 3.6

# %% [markdown]
# We'll also import and clean dataset of 10k events for both background and signal (for testing our algorhitm)

# %%
#Let's combine signal and background
df_scaled = pd.concat([signal, background])
del signal, background
gc.collect()
# Out:
# 22

# %% [markdown]
# # Selecting Background and Signal
# After cleaning, our training data set contains 450442 background candidates and 1638402 signal candidates (background to signal ratio $\approx 3.6$). For testing, we'll use cleaned dataset containing 28740227 entries of signal and background (background to signal ratio $\approx 1985.1$)
#
# Here, we use under-sampling to tackle the problem with the classification of underrepresented class (normally, the signal is only approx. 0.05% of real data)

# %%
if not os.path.exists(directory+'img/xgb_v3_nochi2geo'):
    os.makedirs(directory+'img/xgb_v3_nochi2geo')
#lets draw sign to background ratio
def plt_sig_back(df):
    range1 = (lowerMassCut, upperMassCut)
    fig, axs = plt.subplots(figsize=(20, 10))
    #df_scaled['mass'].plot.hist(bins = 300, range=range1,grid=True,sharey=True)
    (df[df['issignal']==0])['mass'].plot.hist(bins = 300, facecolor='yellow',grid=True,range=range1, label='Background')
    (df[df['issignal']==1])['mass'].plot.hist(bins = 300, facecolor='magenta',grid=True, range=range1, label ='Signal')
    #plt.vlines(x=1.108,ymin=-1,ymax=48000, color='black', linestyle='-')
    #plt.vlines(x=1.1227,ymin=-1,ymax=48000, color='black', linestyle='-')
    plt.ylabel("Counts (log scale)", fontsize=15)
    plt.xlabel("Mass in GeV/$c^2$", fontsize= 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.title('Test and Train K-short Invariant Mass', fontsize = 15)
    plt.legend( fontsize = 15)
    axs.tick_params(axis='both', which='major', labelsize=18)
    plt.yscale("log")
    fig.tight_layout()
    fig.savefig(directory+'img/xgb_v3_nochi2geo/inv_mass_trainset.pdf')
    fig.savefig(directory+'img/xgb_v3_nochi2geo/inv_mass_trainset.png')

# %%
plt_sig_back(df_scaled)
gc.collect()
# Out:
# 2202

# %% [markdown]
# # Creating Train and Test sets
# To make machine learning algorithms more efficient on unseen data we divide our data into two sets. One set is for training the algorithm and the other is for testing the algorithm. If we don't do this then the algorithm can overfit and we will not capture the general trends in the data.

# %%
# The following columns will be used to predict whether a reconstructed candidate is a lambda particle or not
cuts = [ 'loverdl', 'distance', 'chi2topo', 'chi2primfirst', 'chi2primsecond']#'chi2geo', 


x = df_scaled[cuts].copy()

# The MC information is saved in this y variable
y =pd.DataFrame(df_scaled['issignal'], dtype='int')

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=324)
del df_scaled, x, y

#DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed. 
dtrain = xgb.DMatrix(x_train, label = y_train)
dtest1=xgb.DMatrix(x_test, label = y_test)
del x_train, x_test
gc.collect()
# Out:
# 43874

# %% [markdown]
# ## Bayesian optimization
# In order to find the best parameters of XGB for our data we use Bayesian optimization. Grid search and and random search could also do the same job but bayesian is more time efficient. For further reading visit [the git page](https://github.com/fmfn/BayesianOptimization) of the bayesian optimization used here.
#
# ### Hyper parameters
# Some of the following hyper parameters will be tuned for our algorithm:
#
#
# *subsample* [default=1]
# Subsample ratio of the training instances. Setting it to 0.5 means that XGBoost would randomly sample half of the training data prior to growing trees. and this will prevent overfitting. Subsampling will occur once in every boosting iteration.
# range: (0,1]
#
# *eta* [default=0.3, alias: learning_rate]
# Step size shrinkage used in update to prevents overfitting. After each boosting step, we can directly get the weights of new features, and eta shrinks the feature weights to make the boosting process more conservative.
# range: [0,1]
#
#
# *gamma* [default=0, alias: min_split_loss]
# Minimum loss reduction required to make a further partition on a leaf node of the tree. The larger gamma is, the more conservative the algorithm will be.
# range: [0,∞]
#
#
# *alpha* [default=0, alias: reg_alpha]
# L1 regularization term on weights. Increasing this value will make model more conservative.
#
# *Lasso Regression* (Least Absolute Shrinkage and Selection Operator) adds “absolute value of magnitude” of coefficient as penalty term to the loss function.

# %%
#Bayesian Optimization function for xgboost
#specify the parameters you want to tune as keyword arguments
def bo_tune_xgb(max_depth, gamma, alpha, n_estimators ,learning_rate):
    params = {'max_depth': int(max_depth),
              'gamma': gamma,
              'alpha':alpha,
              'n_estimators': n_estimators,
              'learning_rate':learning_rate,
              'subsample': 0.8,
              'eta': 0.1,
              'eval_metric': 'auc', 'nthread' : 7}
    cv_result = xgb.cv(params, dtrain, num_boost_round=70, nfold=5)
    return  cv_result['test-auc-mean'].iloc[-1]

bounds_transformer = SequentialDomainReductionTransformer()

# %%
#Invoking the Bayesian Optimizer with the specified parameters to tune
xgb_bo = BayesianOptimization(bo_tune_xgb, {'max_depth': (4, 10),
                                             'gamma': (0, 1),
                                            'alpha': (2,20),
                                             'learning_rate':(0,1),
                                             'n_estimators':(100,500)
                                            },
                             bounds_transformer=bounds_transformer)

# %%
#performing Bayesian optimization for 5 iterations with 8 steps of random exploration with an #acquisition function of expected improvement
xgb_bo.maximize(n_iter=5, init_points=5)
# Out:
# |   iter    |  target   |   alpha   |   gamma   | learni... | max_depth | n_esti... |
# -------------------------------------------------------------------------------------
# [14:56:07] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [14:56:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 534 extra nodes, 22 pruned nodes, max_depth=9
# [14:56:33] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [14:56:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 530 extra nodes, 16 pruned nodes, max_depth=9
# [14:57:00] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [14:57:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 22 pruned nodes, max_depth=9
# [14:57:24] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [14:57:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 540 extra nodes, 24 pruned nodes, max_depth=9
# [14:57:47] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [14:58:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 534 extra nodes, 22 pruned nodes, max_depth=9
# [14:58:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 538 extra nodes, 26 pruned nodes, max_depth=9
# [14:58:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 524 extra nodes, 14 pruned nodes, max_depth=9
# [14:59:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 526 extra nodes, 16 pruned nodes, max_depth=9
# [14:59:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 538 extra nodes, 20 pruned nodes, max_depth=9
# [14:59:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 20 pruned nodes, max_depth=9
# [15:00:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 18 pruned nodes, max_depth=9
# [15:00:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 30 pruned nodes, max_depth=9
# [15:00:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 498 extra nodes, 22 pruned nodes, max_depth=9
# [15:00:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 22 pruned nodes, max_depth=9
# [15:01:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 18 pruned nodes, max_depth=9
# [15:01:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 510 extra nodes, 20 pruned nodes, max_depth=9
# [15:01:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 510 extra nodes, 22 pruned nodes, max_depth=9
# [15:02:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 18 pruned nodes, max_depth=9
# [15:02:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 514 extra nodes, 24 pruned nodes, max_depth=9
# [15:02:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 512 extra nodes, 14 pruned nodes, max_depth=9
# [15:03:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 534 extra nodes, 22 pruned nodes, max_depth=9
# [15:03:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 512 extra nodes, 28 pruned nodes, max_depth=9
# [15:03:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 8 pruned nodes, max_depth=9
# [15:03:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 14 pruned nodes, max_depth=9
# [15:04:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 34 pruned nodes, max_depth=9
# [15:04:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 16 pruned nodes, max_depth=9
# [15:04:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 26 pruned nodes, max_depth=9
# [15:05:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 524 extra nodes, 16 pruned nodes, max_depth=9
# [15:05:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 524 extra nodes, 32 pruned nodes, max_depth=9
# [15:05:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 524 extra nodes, 16 pruned nodes, max_depth=9
# [15:05:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 18 pruned nodes, max_depth=9
# [15:06:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 488 extra nodes, 18 pruned nodes, max_depth=9
# [15:06:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 518 extra nodes, 14 pruned nodes, max_depth=9
# [15:06:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 516 extra nodes, 18 pruned nodes, max_depth=9
# [15:07:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 18 pruned nodes, max_depth=9
# [15:07:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 24 pruned nodes, max_depth=9
# [15:07:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 20 pruned nodes, max_depth=9
# [15:08:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 18 pruned nodes, max_depth=9
# [15:08:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 510 extra nodes, 28 pruned nodes, max_depth=9
# [15:08:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 16 pruned nodes, max_depth=9
# [15:08:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 32 pruned nodes, max_depth=9
# [15:09:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 26 pruned nodes, max_depth=9
# [15:09:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 26 pruned nodes, max_depth=9
# [15:09:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 16 pruned nodes, max_depth=9
# [15:10:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 18 pruned nodes, max_depth=9
# [15:10:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 524 extra nodes, 18 pruned nodes, max_depth=9
# [15:10:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 28 pruned nodes, max_depth=9
# [15:10:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 494 extra nodes, 14 pruned nodes, max_depth=9
# [15:11:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 16 pruned nodes, max_depth=9
# [15:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 522 extra nodes, 28 pruned nodes, max_depth=9
# [15:11:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 476 extra nodes, 22 pruned nodes, max_depth=9
# [15:12:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 516 extra nodes, 22 pruned nodes, max_depth=9
# [15:12:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 486 extra nodes, 16 pruned nodes, max_depth=9
# [15:12:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 24 pruned nodes, max_depth=9
# [15:12:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 20 pruned nodes, max_depth=9
# [15:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 20 pruned nodes, max_depth=9
# [15:13:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 494 extra nodes, 20 pruned nodes, max_depth=9
# [15:13:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 22 pruned nodes, max_depth=9
# [15:14:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 472 extra nodes, 14 pruned nodes, max_depth=9
# [15:14:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 488 extra nodes, 22 pruned nodes, max_depth=9
# [15:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 486 extra nodes, 34 pruned nodes, max_depth=9
# [15:15:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 494 extra nodes, 20 pruned nodes, max_depth=9
# [15:15:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 28 pruned nodes, max_depth=9
# [15:15:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 28 pruned nodes, max_depth=9
# [15:15:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 20 pruned nodes, max_depth=9
# [15:16:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 18 pruned nodes, max_depth=9
# [15:16:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 504 extra nodes, 32 pruned nodes, max_depth=9
# [15:16:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 18 pruned nodes, max_depth=9
# [15:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 486 extra nodes, 34 pruned nodes, max_depth=9
# [15:17:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 488 extra nodes, 22 pruned nodes, max_depth=9
# [15:17:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 510 extra nodes, 30 pruned nodes, max_depth=9
# [15:17:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 42 pruned nodes, max_depth=9
# [15:18:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 34 pruned nodes, max_depth=9
# [15:18:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 30 pruned nodes, max_depth=9
# [15:18:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 486 extra nodes, 12 pruned nodes, max_depth=9
# [15:19:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 16 pruned nodes, max_depth=9
# [15:19:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 18 pruned nodes, max_depth=9
# [15:19:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 24 pruned nodes, max_depth=9
# [15:19:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 516 extra nodes, 30 pruned nodes, max_depth=9
# [15:20:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 20 pruned nodes, max_depth=9
# [15:20:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 494 extra nodes, 34 pruned nodes, max_depth=9
# [15:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 20 pruned nodes, max_depth=9
# [15:21:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 476 extra nodes, 16 pruned nodes, max_depth=9
# [15:21:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 510 extra nodes, 34 pruned nodes, max_depth=9
# [15:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 30 pruned nodes, max_depth=9
# [15:22:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 32 pruned nodes, max_depth=9
# [15:22:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 30 pruned nodes, max_depth=9
# [15:22:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 28 pruned nodes, max_depth=9
# [15:22:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 24 pruned nodes, max_depth=9
# [15:23:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 498 extra nodes, 24 pruned nodes, max_depth=9
# [15:23:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 20 pruned nodes, max_depth=9
# [15:23:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 492 extra nodes, 10 pruned nodes, max_depth=9
# [15:24:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 22 pruned nodes, max_depth=9
# [15:24:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 472 extra nodes, 26 pruned nodes, max_depth=9
# [15:24:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 30 pruned nodes, max_depth=9
# [15:24:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 492 extra nodes, 28 pruned nodes, max_depth=9
# [15:25:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 494 extra nodes, 20 pruned nodes, max_depth=9
# [15:25:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 26 pruned nodes, max_depth=9
# [15:25:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 32 pruned nodes, max_depth=9
# [15:26:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 30 pruned nodes, max_depth=9
# [15:26:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 26 pruned nodes, max_depth=9
# [15:26:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 22 pruned nodes, max_depth=9
# [15:26:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 36 pruned nodes, max_depth=9
# [15:27:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 484 extra nodes, 30 pruned nodes, max_depth=9
# [15:27:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 476 extra nodes, 16 pruned nodes, max_depth=9
# [15:27:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 40 pruned nodes, max_depth=9
# [15:28:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 20 pruned nodes, max_depth=9
# [15:28:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 26 pruned nodes, max_depth=9
# [15:28:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 36 pruned nodes, max_depth=9
# [15:28:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 30 pruned nodes, max_depth=9
# [15:29:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 32 pruned nodes, max_depth=9
# [15:29:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 38 pruned nodes, max_depth=9
# [15:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 32 pruned nodes, max_depth=9
# [15:29:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 28 pruned nodes, max_depth=9
# [15:30:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 30 pruned nodes, max_depth=9
# [15:30:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 20 pruned nodes, max_depth=9
# [15:30:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 26 pruned nodes, max_depth=9
# [15:31:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 32 pruned nodes, max_depth=9
# [15:31:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 470 extra nodes, 36 pruned nodes, max_depth=9
# [15:31:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 38 pruned nodes, max_depth=9
# [15:31:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 470 extra nodes, 40 pruned nodes, max_depth=9
# [15:32:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 18 pruned nodes, max_depth=9
# [15:32:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 44 pruned nodes, max_depth=9
# [15:32:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 470 extra nodes, 36 pruned nodes, max_depth=9
# [15:33:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 498 extra nodes, 32 pruned nodes, max_depth=9
# [15:33:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 44 pruned nodes, max_depth=9
# [15:33:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 44 pruned nodes, max_depth=9
# [15:33:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 36 pruned nodes, max_depth=9
# [15:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 466 extra nodes, 34 pruned nodes, max_depth=9
# [15:34:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 30 pruned nodes, max_depth=9
# [15:34:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 38 pruned nodes, max_depth=9
# [15:35:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 36 pruned nodes, max_depth=9
# [15:35:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 36 pruned nodes, max_depth=9
# [15:35:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 40 pruned nodes, max_depth=9
# [15:35:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 24 pruned nodes, max_depth=9
# [15:36:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 470 extra nodes, 40 pruned nodes, max_depth=9
# [15:36:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 36 pruned nodes, max_depth=9
# [15:36:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 38 pruned nodes, max_depth=9
# [15:36:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 30 pruned nodes, max_depth=9
# [15:37:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 24 pruned nodes, max_depth=9
# [15:37:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 32 pruned nodes, max_depth=9
# [15:37:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 50 pruned nodes, max_depth=9
# [15:38:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 30 pruned nodes, max_depth=9
# [15:38:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 42 pruned nodes, max_depth=9
# [15:38:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 32 pruned nodes, max_depth=9
# [15:38:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 32 pruned nodes, max_depth=9
# [15:39:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 34 pruned nodes, max_depth=9
# [15:39:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 464 extra nodes, 36 pruned nodes, max_depth=9
# [15:39:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 42 pruned nodes, max_depth=9
# [15:40:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 30 pruned nodes, max_depth=9
# [15:40:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 36 pruned nodes, max_depth=9
# [15:40:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 38 pruned nodes, max_depth=9
# [15:41:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 20 pruned nodes, max_depth=9
# [15:41:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 26 pruned nodes, max_depth=9
# [15:41:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 42 pruned nodes, max_depth=9
# [15:41:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 36 pruned nodes, max_depth=9
# [15:42:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 34 pruned nodes, max_depth=9
# [15:42:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 36 pruned nodes, max_depth=9
# [15:42:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 28 pruned nodes, max_depth=9
# [15:43:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 32 pruned nodes, max_depth=9
# [15:43:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 36 pruned nodes, max_depth=9
# [15:43:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 28 pruned nodes, max_depth=9
# [15:43:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 32 pruned nodes, max_depth=9
# [15:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 20 pruned nodes, max_depth=9
# [15:44:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 38 pruned nodes, max_depth=9
# [15:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 36 pruned nodes, max_depth=9
# [15:45:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 28 pruned nodes, max_depth=9
# [15:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 428 extra nodes, 42 pruned nodes, max_depth=9
# [15:45:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 24 pruned nodes, max_depth=9
# [15:45:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 56 pruned nodes, max_depth=9
# [15:46:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 20 pruned nodes, max_depth=9
# [15:46:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 40 pruned nodes, max_depth=9
# [15:46:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 30 pruned nodes, max_depth=9
# [15:47:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 38 pruned nodes, max_depth=9
# [15:47:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 34 pruned nodes, max_depth=9
# [15:47:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 36 pruned nodes, max_depth=9
# [15:47:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 28 pruned nodes, max_depth=9
# [15:48:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 54 pruned nodes, max_depth=9
# [15:48:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 38 pruned nodes, max_depth=9
# [15:48:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 26 pruned nodes, max_depth=9
# [15:49:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 46 pruned nodes, max_depth=9
# [15:49:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 38 pruned nodes, max_depth=9
# [15:49:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 396 extra nodes, 50 pruned nodes, max_depth=9
# [15:49:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 36 pruned nodes, max_depth=9
# [15:50:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 42 pruned nodes, max_depth=9
# [15:50:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 34 pruned nodes, max_depth=9
# [15:50:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 44 pruned nodes, max_depth=9
# [15:51:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 30 pruned nodes, max_depth=9
# [15:51:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 32 pruned nodes, max_depth=9
# [15:51:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 46 pruned nodes, max_depth=9
# [15:51:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 50 pruned nodes, max_depth=9
# [15:52:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 36 pruned nodes, max_depth=9
# [15:52:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 34 pruned nodes, max_depth=9
# [15:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 46 pruned nodes, max_depth=9
# [15:52:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 40 pruned nodes, max_depth=9
# [15:53:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 54 pruned nodes, max_depth=9
# [15:53:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 26 pruned nodes, max_depth=9
# [15:53:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 40 pruned nodes, max_depth=9
# [15:54:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 24 pruned nodes, max_depth=9
# [15:54:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 40 pruned nodes, max_depth=9
# [15:54:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 54 pruned nodes, max_depth=9
# [15:55:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 58 pruned nodes, max_depth=9
# [15:55:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 48 pruned nodes, max_depth=9
# [15:55:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 34 pruned nodes, max_depth=9
# [15:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 34 pruned nodes, max_depth=9
# [15:56:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 46 pruned nodes, max_depth=9
# [15:56:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 44 pruned nodes, max_depth=9
# [15:56:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 42 pruned nodes, max_depth=9
# [15:57:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 42 pruned nodes, max_depth=9
# [15:57:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 28 pruned nodes, max_depth=9
# [15:57:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 50 pruned nodes, max_depth=9
# [15:57:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 46 pruned nodes, max_depth=9
# [15:58:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 38 pruned nodes, max_depth=9
# [15:58:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 396 extra nodes, 32 pruned nodes, max_depth=9
# [15:58:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 30 pruned nodes, max_depth=9
# [15:59:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 48 pruned nodes, max_depth=9
# [15:59:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 52 pruned nodes, max_depth=9
# [15:59:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 42 pruned nodes, max_depth=9
# [15:59:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 36 pruned nodes, max_depth=9
# [16:00:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 396 extra nodes, 34 pruned nodes, max_depth=9
# [16:00:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 52 pruned nodes, max_depth=9
# [16:00:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 34 pruned nodes, max_depth=9
# [16:01:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 36 pruned nodes, max_depth=9
# [16:01:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 48 pruned nodes, max_depth=9
# [16:01:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 40 pruned nodes, max_depth=9
# [16:01:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 64 pruned nodes, max_depth=9
# [16:02:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 44 pruned nodes, max_depth=9
# [16:02:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 396 extra nodes, 48 pruned nodes, max_depth=9
# [16:02:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 50 pruned nodes, max_depth=9
# [16:03:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 48 pruned nodes, max_depth=9
# [16:03:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 58 pruned nodes, max_depth=9
# [16:03:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 46 pruned nodes, max_depth=9
# [16:03:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 58 pruned nodes, max_depth=9
# [16:04:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 44 pruned nodes, max_depth=9
# [16:04:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 38 pruned nodes, max_depth=9
# [16:04:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 50 pruned nodes, max_depth=9
# [16:05:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 46 pruned nodes, max_depth=9
# [16:05:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 52 pruned nodes, max_depth=9
# [16:05:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 50 pruned nodes, max_depth=9
# [16:05:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 34 pruned nodes, max_depth=9
# [16:06:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 44 pruned nodes, max_depth=9
# [16:06:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 40 pruned nodes, max_depth=9
# [16:06:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 44 pruned nodes, max_depth=9
# [16:06:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 46 pruned nodes, max_depth=9
# [16:07:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 64 pruned nodes, max_depth=9
# [16:07:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 56 pruned nodes, max_depth=9
# [16:07:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 54 pruned nodes, max_depth=9
# [16:08:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 58 pruned nodes, max_depth=9
# [16:08:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 42 pruned nodes, max_depth=9
# [16:08:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 42 pruned nodes, max_depth=9
# [16:09:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 48 pruned nodes, max_depth=9
# [16:09:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 42 pruned nodes, max_depth=9
# [16:09:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 40 pruned nodes, max_depth=9
# [16:10:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 46 pruned nodes, max_depth=9
# [16:10:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 58 pruned nodes, max_depth=9
# [16:10:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 48 pruned nodes, max_depth=9
# [16:10:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 52 pruned nodes, max_depth=9
# [16:11:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 354 extra nodes, 40 pruned nodes, max_depth=9
# [16:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 44 pruned nodes, max_depth=9
# [16:11:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 42 pruned nodes, max_depth=9
# [16:12:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 68 pruned nodes, max_depth=9
# [16:12:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 48 pruned nodes, max_depth=9
# [16:12:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 52 pruned nodes, max_depth=9
# [16:12:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 396 extra nodes, 44 pruned nodes, max_depth=9
# [16:13:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 44 pruned nodes, max_depth=9
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 32 pruned nodes, max_depth=9
# [16:13:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 62 pruned nodes, max_depth=9
# [16:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 58 pruned nodes, max_depth=9
# [16:14:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 72 pruned nodes, max_depth=9
# [16:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 50 pruned nodes, max_depth=9
# [16:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 306 extra nodes, 52 pruned nodes, max_depth=9
# [16:15:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 42 pruned nodes, max_depth=9
# [16:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 30 pruned nodes, max_depth=9
# [16:15:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 36 pruned nodes, max_depth=9
# [16:15:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 50 pruned nodes, max_depth=9
# [16:16:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 38 pruned nodes, max_depth=9
# [16:16:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 46 pruned nodes, max_depth=9
# [16:16:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 62 pruned nodes, max_depth=9
# [16:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 56 pruned nodes, max_depth=9
# [16:17:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 52 pruned nodes, max_depth=9
# [16:17:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 66 pruned nodes, max_depth=9
# [16:17:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 66 pruned nodes, max_depth=9
# [16:18:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 36 pruned nodes, max_depth=9
# [16:18:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 58 pruned nodes, max_depth=9
# [16:18:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 56 pruned nodes, max_depth=9
# [16:19:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 44 pruned nodes, max_depth=9
# [16:19:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 56 pruned nodes, max_depth=9
# [16:19:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 58 pruned nodes, max_depth=9
# [16:19:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 42 pruned nodes, max_depth=9
# [16:20:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 66 pruned nodes, max_depth=9
# [16:20:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 44 pruned nodes, max_depth=9
# [16:20:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 52 pruned nodes, max_depth=9
# [16:20:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 62 pruned nodes, max_depth=9
# [16:21:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 42 pruned nodes, max_depth=9
# [16:21:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 60 pruned nodes, max_depth=9
# [16:21:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 38 pruned nodes, max_depth=9
# [16:22:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 44 pruned nodes, max_depth=9
# [16:22:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 52 pruned nodes, max_depth=9
# [16:22:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 48 pruned nodes, max_depth=9
# [16:22:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 354 extra nodes, 66 pruned nodes, max_depth=9
# [16:23:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 48 pruned nodes, max_depth=9
# [16:23:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 72 pruned nodes, max_depth=9
# [16:23:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 64 pruned nodes, max_depth=9
# [16:24:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 54 pruned nodes, max_depth=9
# [16:24:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 60 pruned nodes, max_depth=9
# [16:24:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 50 pruned nodes, max_depth=9
# [16:24:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 40 pruned nodes, max_depth=9
# [16:25:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 38 pruned nodes, max_depth=9
# [16:25:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 66 pruned nodes, max_depth=9
# [16:25:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 56 pruned nodes, max_depth=9
# [16:26:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 50 pruned nodes, max_depth=9
# [16:26:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 40 pruned nodes, max_depth=9
# [16:26:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 56 pruned nodes, max_depth=9
# [16:26:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 58 pruned nodes, max_depth=9
# [16:27:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 60 pruned nodes, max_depth=9
# [16:27:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 76 pruned nodes, max_depth=9
# [16:27:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 46 pruned nodes, max_depth=9
# [16:27:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 66 pruned nodes, max_depth=9
# [16:28:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 58 pruned nodes, max_depth=9
# [16:28:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 60 pruned nodes, max_depth=9
# [16:28:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 56 pruned nodes, max_depth=9
# [16:29:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 46 pruned nodes, max_depth=9
# [16:29:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 64 pruned nodes, max_depth=9
# [16:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 52 pruned nodes, max_depth=9
# [16:29:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 70 pruned nodes, max_depth=9
# [16:30:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 50 pruned nodes, max_depth=9
# [16:30:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 62 pruned nodes, max_depth=9
# [16:30:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 56 pruned nodes, max_depth=9
# [16:31:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 70 pruned nodes, max_depth=9
# [16:31:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 66 pruned nodes, max_depth=9
# [16:31:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 42 pruned nodes, max_depth=9
# [16:31:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 66 pruned nodes, max_depth=9
# [16:32:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 46 pruned nodes, max_depth=9
# [16:32:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 50 pruned nodes, max_depth=9
# [16:32:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 68 pruned nodes, max_depth=9
# [16:33:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 70 pruned nodes, max_depth=9
# [16:33:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 52 pruned nodes, max_depth=9
# [16:33:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 66 pruned nodes, max_depth=9
# [16:33:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 62 pruned nodes, max_depth=9
# [16:34:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 72 pruned nodes, max_depth=9
# [16:34:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 52 pruned nodes, max_depth=9
# [16:34:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 38 pruned nodes, max_depth=9
# [16:35:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 70 pruned nodes, max_depth=9
# [16:35:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 58 pruned nodes, max_depth=9
# [16:35:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 72 pruned nodes, max_depth=9
# [16:35:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 58 pruned nodes, max_depth=9
# [16:36:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 54 pruned nodes, max_depth=9
# [16:36:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 58 pruned nodes, max_depth=9
# [16:36:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 80 pruned nodes, max_depth=9
# [16:37:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 76 pruned nodes, max_depth=9
# |  1        |  0.9973   |  13.72    |  0.3136   |  0.03492  |  9.583    |  329.9    |
# [16:37:32] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [16:37:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:37:46] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [16:37:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:38:00] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [16:38:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:38:14] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [16:38:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:38:28] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [16:38:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:38:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:39:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:39:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:39:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:39:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:39:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:39:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:40:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:40:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:40:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:40:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:40:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:40:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:40:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:41:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:41:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:41:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:41:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:41:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:41:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:41:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:42:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:42:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:42:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:42:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:42:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:42:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:42:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:43:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:43:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:43:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:43:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:43:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:43:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:44:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:44:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:44:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:44:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:44:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:44:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:45:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:45:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:45:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:45:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [16:45:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# ...
# [22:02:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 350 pruned nodes, max_depth=9
# [22:02:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 302 pruned nodes, max_depth=9
# [22:02:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 470 extra nodes, 252 pruned nodes, max_depth=9
# [22:03:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 210 pruned nodes, max_depth=9
# [22:03:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 314 pruned nodes, max_depth=9
# [22:03:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 280 pruned nodes, max_depth=9
# [22:04:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 302 pruned nodes, max_depth=9
# [22:04:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 258 pruned nodes, max_depth=9
# [22:04:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 200 pruned nodes, max_depth=9
# [22:05:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 342 pruned nodes, max_depth=9
# [22:05:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 294 pruned nodes, max_depth=9
# [22:05:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 268 pruned nodes, max_depth=9
# [22:05:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 272 pruned nodes, max_depth=9
# [22:06:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 284 pruned nodes, max_depth=9
# [22:06:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 204 pruned nodes, max_depth=9
# [22:06:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 206 pruned nodes, max_depth=9
# [22:07:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 208 pruned nodes, max_depth=9
# [22:07:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 320 pruned nodes, max_depth=9
# [22:07:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 326 pruned nodes, max_depth=9
# [22:08:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 290 pruned nodes, max_depth=9
# [22:08:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 238 pruned nodes, max_depth=9
# [22:08:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 332 pruned nodes, max_depth=9
# [22:09:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 200 pruned nodes, max_depth=9
# [22:09:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 310 pruned nodes, max_depth=9
# [22:09:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 288 pruned nodes, max_depth=9
# [22:10:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 212 pruned nodes, max_depth=9
# [22:10:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 282 pruned nodes, max_depth=9
# [22:10:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 338 pruned nodes, max_depth=9
# [22:11:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 190 pruned nodes, max_depth=9
# [22:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 214 pruned nodes, max_depth=9
# [22:11:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 306 pruned nodes, max_depth=9
# [22:12:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 306 pruned nodes, max_depth=9
# [22:12:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 248 pruned nodes, max_depth=9
# [22:12:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 346 pruned nodes, max_depth=9
# [22:13:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 246 pruned nodes, max_depth=9
# [22:13:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 296 pruned nodes, max_depth=9
# [22:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 336 pruned nodes, max_depth=9
# [22:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 236 pruned nodes, max_depth=9
# [22:14:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 256 pruned nodes, max_depth=9
# [22:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 272 extra nodes, 262 pruned nodes, max_depth=9
# [22:14:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 286 extra nodes, 262 pruned nodes, max_depth=9
# [22:15:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 238 pruned nodes, max_depth=9
# [22:15:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 272 pruned nodes, max_depth=9
# [22:15:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 284 pruned nodes, max_depth=9
# [22:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 298 pruned nodes, max_depth=9
# [22:16:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 256 pruned nodes, max_depth=9
# [22:16:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 268 pruned nodes, max_depth=9
# [22:17:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 286 extra nodes, 214 pruned nodes, max_depth=9
# [22:17:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 270 pruned nodes, max_depth=9
# [22:17:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 308 pruned nodes, max_depth=9
# [22:18:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 280 pruned nodes, max_depth=9
# [22:18:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 182 pruned nodes, max_depth=9
# [22:18:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 256 pruned nodes, max_depth=9
# [22:19:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 238 pruned nodes, max_depth=9
# [22:19:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 306 extra nodes, 340 pruned nodes, max_depth=9
# [22:19:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 314 pruned nodes, max_depth=9
# [22:20:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 268 pruned nodes, max_depth=9
# [22:20:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 264 pruned nodes, max_depth=9
# [22:20:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 348 pruned nodes, max_depth=9
# [22:21:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 204 pruned nodes, max_depth=9
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 256 pruned nodes, max_depth=9
# [22:21:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 228 pruned nodes, max_depth=9
# [22:21:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 184 pruned nodes, max_depth=9
# [22:22:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 212 pruned nodes, max_depth=9
# [22:22:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 220 pruned nodes, max_depth=9
# [22:22:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 222 pruned nodes, max_depth=9
# [22:23:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 314 pruned nodes, max_depth=9
# [22:23:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 228 pruned nodes, max_depth=9
# [22:23:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 294 pruned nodes, max_depth=9
# [22:24:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 286 pruned nodes, max_depth=9
# [22:24:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 270 pruned nodes, max_depth=9
# [22:24:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 198 pruned nodes, max_depth=9
# [22:25:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 192 pruned nodes, max_depth=9
# [22:25:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 248 pruned nodes, max_depth=9
# [22:25:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 256 pruned nodes, max_depth=9
# [22:26:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 252 pruned nodes, max_depth=9
# [22:26:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 168 pruned nodes, max_depth=9
# [22:26:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 306 pruned nodes, max_depth=9
# [22:27:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 354 pruned nodes, max_depth=9
# [22:27:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 234 pruned nodes, max_depth=9
# [22:27:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 342 pruned nodes, max_depth=9
# [22:28:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 254 pruned nodes, max_depth=9
# [22:28:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 214 pruned nodes, max_depth=9
# [22:28:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 272 pruned nodes, max_depth=9
# [22:29:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 214 pruned nodes, max_depth=9
# [22:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 208 pruned nodes, max_depth=9
# [22:29:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 150 pruned nodes, max_depth=9
# [22:30:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 290 pruned nodes, max_depth=9
# [22:30:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 220 pruned nodes, max_depth=9
# [22:31:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 354 extra nodes, 228 pruned nodes, max_depth=9
# [22:31:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 204 pruned nodes, max_depth=9
# [22:31:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 302 pruned nodes, max_depth=9
# [22:31:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 230 pruned nodes, max_depth=9
# [22:32:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 302 pruned nodes, max_depth=9
# [22:32:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 132 pruned nodes, max_depth=9
# [22:33:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 258 pruned nodes, max_depth=9
# [22:33:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 290 pruned nodes, max_depth=9
# [22:33:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 244 pruned nodes, max_depth=9
# [22:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 268 pruned nodes, max_depth=9
# [22:34:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 208 pruned nodes, max_depth=9
# [22:34:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 224 pruned nodes, max_depth=9
# [22:35:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 262 pruned nodes, max_depth=9
# [22:35:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 246 pruned nodes, max_depth=9
# [22:35:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 250 pruned nodes, max_depth=9
# [22:36:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 280 pruned nodes, max_depth=9
# [22:36:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 274 pruned nodes, max_depth=9
# [22:36:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 210 pruned nodes, max_depth=9
# [22:37:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 252 pruned nodes, max_depth=9
# [22:37:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 260 pruned nodes, max_depth=9
# [22:37:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 172 pruned nodes, max_depth=9
# [22:38:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 428 pruned nodes, max_depth=9
# [22:38:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 270 pruned nodes, max_depth=9
# [22:38:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 140 pruned nodes, max_depth=9
# [22:39:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 310 pruned nodes, max_depth=9
# [22:39:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 246 pruned nodes, max_depth=9
# [22:40:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 320 pruned nodes, max_depth=9
# [22:40:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 210 pruned nodes, max_depth=9
# [22:40:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 266 pruned nodes, max_depth=9
# [22:41:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 322 pruned nodes, max_depth=9
# [22:41:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 254 pruned nodes, max_depth=9
# [22:41:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 418 pruned nodes, max_depth=9
# [22:42:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 132 pruned nodes, max_depth=9
# [22:42:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 514 pruned nodes, max_depth=9
# [22:42:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 164 pruned nodes, max_depth=9
# [22:43:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 240 pruned nodes, max_depth=9
# [22:43:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 216 pruned nodes, max_depth=9
# [22:43:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 478 pruned nodes, max_depth=9
# [22:44:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 212 pruned nodes, max_depth=9
# [22:44:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 260 pruned nodes, max_depth=9
# [22:44:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 240 pruned nodes, max_depth=9
# [22:45:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 180 pruned nodes, max_depth=9
# [22:45:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 240 pruned nodes, max_depth=9
# [22:45:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 298 pruned nodes, max_depth=9
# [22:46:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 348 pruned nodes, max_depth=9
# [22:46:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 276 pruned nodes, max_depth=9
# [22:47:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 338 pruned nodes, max_depth=9
# [22:47:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 254 pruned nodes, max_depth=9
# [22:47:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 382 pruned nodes, max_depth=9
# [22:49:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 276 pruned nodes, max_depth=9

# %%
# best target so far 0.9974344
print(xgb_bo.max)

# %% [markdown]
# # XGB models
# Now let's take the parameters selected by the bayesian optimization and apply them in our training and testing.

# %%
max_param = xgb_bo.max['params']
param= {'alpha': max_param['alpha'], 'gamma': max_param['gamma'], 'learning_rate': max_param['learning_rate'], 'max_depth': int(round(max_param['max_depth'],0)), 'n_estimators': int(round(max_param['n_estimators'],0)), 'objective': 'reg:logistic'}

# %%
#To train the algorithm using the parameters selected by bayesian optimization
bst = xgb.train(param, dtrain)

# %%
#We apply our model on the training data that was trained on the training data, this helps us to control overfitting
bst1= bst.predict(dtrain)

# %%
del dtrain 
gc.collect()

# %%
# We apply our trained model on test data and store the predictions in a bst_test dataframe
bst_test = pd.DataFrame(data=bst.predict(dtest1),  columns=["xgb_preds"])
y_test=y_test.set_index(np.arange(0,bst_test.shape[0]))
# We also store the MC information in this dataFrame
bst_test['issignal']=y_test['issignal']

# %% [markdown]
# ## Whole set
# We also select the selected variables from the 10k events data set

# %%
df_origin = tree_importer.tree_importer(allFileName,'PlainTree',7)
df_origin.columns = df_origin.columns.str.replace('Candidates_', '')
df_origin.columns = df_origin.columns.str.replace('_', '')
df_origin = df_origin.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
df_clean = clean_df(df_origin)
del df_origin
gc.collect()
#lets look at impoted tree
df_clean.iloc[0:10,:]
print('test set (background to signal ratio): ' 
      + str(round(len(df_clean.loc[df_clean['issignal'] == 0])/len(df_clean.loc[df_clean['issignal'] == 1]), 1))
      + '\ntest set (both signal and background): ' + str(len(df_clean)))

# %%
x_whole = df_clean[cuts].copy()
y_whole = pd.DataFrame(df_clean['issignal'], dtype='int')
dtest = xgb.DMatrix(x_whole, label = y_whole)
del x_whole
gc.collect()

# %%
#The following graph will show us that which features are important for the model
ax = xgb.plot_importance(bst)
plt.rcParams['figure.figsize'] = [5, 3]
plt.show()
ax.figure.tight_layout() 
ax.figure.savefig(directory+'img/xgb_v3_nochi2geo/feature_importance.pdf')
ax.figure.savefig(directory+'img/xgb_v3_nochi2geo/feature_importance.png')

# %% [markdown]
# ## AUC and ROC
#
# The function roc_curve computes the receiver operating characteristic curve, or ROC curve. Quoting Wikipedia :
#
# “A receiver operating characteristic (ROC), or simply ROC curve, is a graphical plot which illustrates the performance of a binary classifier system as its discrimination threshold is varied. It is created by plotting the fraction of true positives out of the positives (TPR = true positive rate) vs. the fraction of false positives out of the negatives (FPR = false positive rate), at various threshold settings. TPR is also known as sensitivity, and FPR is one minus the specificity or true negative rate.”
#
# This function requires the true binary value and the target scores, which can either be probability estimates of the positive class, confidence values, or binary decisions.
#
# Similarly, the function roc_auc_score computes Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.

# %% [markdown]
# To find the best threshold which results more signal to background ratio for lambda candidates we use the parameter S0 called the approximate median significance by the higgs boson  ML challenge (http://higgsml.lal.in2p3.fr/documentation,9.)

# %%
def AMS(y_true, y_predict, y_true1, y_predict1):
    roc_auc=roc_auc_score(y_true, y_predict)
    fpr, tpr, thresholds = roc_curve(y_true, y_predict,drop_intermediate=False ,pos_label=1)
    S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
    S0 = S0[~np.isnan(S0)]
    xi = argmax(S0)
    S0_best_threshold = (thresholds[xi])

    roc_auc1=roc_auc_score(y_true1, y_predict1)
    fpr1, tpr1, thresholds1 = roc_curve(y_true1, y_predict1,drop_intermediate=False ,pos_label=1)
    S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))
    S01 = S01[~np.isnan(S01)]
    xi1 = argmax(S01)
    S0_best_threshold1 = (thresholds[xi1])

    #plotting
    fig, axs = plt.subplots(figsize=(15, 10), dpi = 100)
    plt.plot(fpr, tpr, linestyle=':',color='darkorange',label='ROC curve train (area = %0.4f)' % roc_auc)
    plt.plot(fpr1, tpr1, color='green',label='ROC curve test (area = %0.4f)' % roc_auc1)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.scatter(fpr[xi], tpr[xi], marker='o', color='black', label= 'Best Threshold train set = '+"%.4f" % S0_best_threshold +'\n S0 = '+ "%.2f" % S0[xi])
    plt.scatter(fpr1[xi1], tpr1[xi1], marker='o', color='blue', label= 'Best Threshold test set = '+"%.4f" % S0_best_threshold1 +'\n S0 = '+ "%.2f" % S01[xi1])
    plt.xlabel('False Positive Rate', fontsize = 15)
    plt.ylabel('True Positive Rate', fontsize = 15)
    plt.legend(loc="lower right", fontsize = 15)
    plt.title('Receiver operating characteristic', fontsize = 15)
    plt.xlim([-0.01, 1.0])
    plt.ylim([0, 1.02])
    
    fig.tight_layout()
    plt.show()
    fig.savefig(directory+'img/xgb_v3_nochi2geo/ams.pdf')
    fig.savefig(directory+'img/xgb_v3_nochi2geo/ams.png')

    return S0_best_threshold, S0_best_threshold1

# %%
train_best, test_best = AMS(y_train, bst1, y_test, bst_test['xgb_preds'])

# %% [markdown]
# When the AUC, best threshold and approximate median significance for train and test are nearly the same, we save that model and use it. This means that our model is general enough. In my opinion, if the test S0 is above 3.0 then it is a good enough model.

# %% [markdown]
# ## Applying the model on the 10k events data-set

# %%
df_clean['xgb_preds'] = bst.predict(dtest)

# %%
df_clean['xgb_preds'].hist(bins=300)
plt.yscale('log')

# %% [markdown]
# ## Confusion Matrix
#
# A **Confusion Matrix** $C$ is such that $C_{ij}$ is equal to the number of observations known to be in group $i$ and predicted to be in group $j$. Thus in binary classification, the count of true positives is $C_{00}$, false negatives $C_{01}$,false positives is $C_{10}$, and true neagtives is $C_{11}$.
#
# If $ y^{'}_{i} $ is the predicted value of the $ i$-th sample and $y_{i}$ is the corresponding true value, then the fraction of correct predictions over $ n_{samples}$ is defined as
# $$
# True \: positives (y,y^{'}) =  \sum_{i=1}^{n_{samples} } 1 (y^{'}_{i} = y_{i}=1)
# $$
#
# The following function prints and plots the confusion matrix. Normalization can be applied by setting `normalize=True`.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
#calculate efficency and false tu tru signal ratio
def confustion_stats(df, cm):
    all_signals = len(df.loc[df['issignal'] == 1])
    true_signal = cm[0][0]
    false_signal = cm[1][0]        
    reconstructed_signals = true_signal + false_signal
    false_to_true_signals = false_signal / true_signal
    efficiency = reconstructed_signals / all_signals * 100 #efficency in % for all
    efficiency_true = true_signal / all_signals * 100 #efficency in % for all
    print("Efficiency: " + str(round(efficiency, 2)) + "%")
    print("Efficiency of true signal candidates reconstruction: " + str(round(efficiency_true, 2)) + "%")
    print("False tu true reconstructed signal ratio: " + str(round(false_to_true_signals, 2)))

# %%
#lets take the best threshold and look at the confusion matrix
cut1 = test_best
df_clean['xgb_preds1'] = ((df_clean['xgb_preds']>cut1)*1)
cnf_matrix = confusion_matrix(y_whole, df_clean['xgb_preds1'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix, classes=['signal','background'], title='Confusion Matrix for XGB for cut > '+str(cut1))
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_extreme_gradient_boosting_whole_data.pdf')
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_extreme_gradient_boosting_whole_data.png')

# %%
confustion_stats(df_clean, cnf_matrix)

# %%
# The following function will display the inavriant mass histogram of the original 10k event set along with the mass histoigram after we apply a cut
# on the probability prediction of xgb
def cut_visualization(cut, range1=(lowerMassCut, upperMassCut), bins1= 300 ):
    mask1 = df_clean['xgb_preds']>cut
    df3=df_clean[mask1]
    
    fig, ax2 = plt.subplots(figsize=(15, 10), dpi = 200)
    color = 'tab:blue'
    ax2.hist(df_clean['mass'],bins = bins1, range=range1, facecolor='blue',alpha = 0.35, label='before selection')
    ax2.set_ylabel('Counts', fontsize = 15, color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.legend( fontsize = 15, loc='upper left')
    
    color = 'tab:red'
    ax1 = ax2.twinx()
    ax1.hist(df3['mass'], bins = bins1, range=range1, facecolor='red',alpha = 0.35, label='XGB')
    ax1.set_xlabel('Mass in GeV', fontsize = 15)
    ax1.set_ylabel('Counts ', fontsize = 15, color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.legend( fontsize = 15,loc='upper right' )

    plt.title("The original sample's Invariant Mass along with mass after selection of XGB (with a cut > "+str(cut)+')', fontsize = 15)
    fig.tight_layout()
    fig.savefig(directory+'img/xgb_v3_nochi2geo/whole_sample_invmass_with_ML.pdf')
    fig.savefig(directory+'img/xgb_v3_nochi2geo/whole_sample_invmass_with_ML.png')

# %%
cut_visualization(test_best)

# %% [markdown]
# # Comparison with the manually optimized cuts of KFPF
# In the already existing Kalman Filter Particle Finder (KFPF) package for online reconstruction and selection of short-lived particles in CBM, these criteria have been manually optimized. These selection-cuts have been selected to maximize the signal to background ratio (S/B) of the $\Lambda$ for a certain energy on a collisions generator. The selection criteria mainly depends on the collision energy, decay channel and detector configuration.

# %%
#manually selected cuts
manCut_loverdl = 30
manCut_dca = 0.4
manCut_chi2topo = 20
manCut_chi2geo = 12

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
new_check_set= df_clean.copy()
new_check_set['new_signal']=0

mask1 = (new_check_set['loverdl'] > manCut_loverdl) & (new_check_set['distance'] < manCut_dca)

mask2 = (new_check_set['chi2topo'] < manCut_chi2topo) & (new_check_set['chi2geo'] < manCut_chi2geo) 

new_check_set = new_check_set[(mask1) & (mask2)] 

#After all these cuts, what is left is considered as signal, so we replace all the values in the 'new_signal'
# column by 1
new_check_set['new_signal'] = 1
cnf_matrix1 = confusion_matrix(new_check_set['issignal'], new_check_set['new_signal'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix1, classes=['signal','background'], title='Confusion Matrix for manually set cuts')
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_for_manually_set_cuts.pdf')
fig.savefig(directory+'img/xgb_v3_nochi2geo/confusion_matrix_for_manually_set_cuts.png')

# %%
confustion_stats(df_clean, cnf_matrix1)

# %%
cut3 = test_best
mask1 = df_clean['xgb_preds']>cut3
df3=df_clean[mask1]

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=200)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=200)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
#axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
from matplotlib import gridspec

range1= (0.4, 0.6)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 100, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 100, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables (close up)", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=100)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=100)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison_closeup.png')
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison_closeup.pdf')

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
axs[0].set_yscale('log')
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=300)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=300)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].set_ylim([0.,2.])
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb_v3_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
from matplotlib import gridspec

left = .425
right = .7
range1= (left, right)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True, gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 50,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 50,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("log (counts)", fontsize = 18)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 18, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 18)
#axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=18)
axs[0].set_yscale('log')
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3_base['mass'],range=(left, right), bins=50)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(left, right), bins=50)


#makes sense to have only positive values
diff = (hist1 - hist2)
#axs[1].bar((bins[:-1] + bins[1:]) / 2, # this is what makes it comparable
# ns / ns1, # maybe check for div-by-zero!
# width=0.001)
axs[1].hlines(y=1, xmin=left, xmax=right, colors='r', linestyles='solid', label='')
center = (bins[:-1] + bins[1:]) / 2
plt.errorbar(center, ns / ns1, fmt='o',
                 c='Blue', label='Background in predictions')


    
    
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 18)
axs[1].set_ylabel("XGB / KFPF", fontsize = 18)
#axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=18)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/circle_kshort_invmass_with_ML.png')

# %%
#del x,y,x_test,y_test,x_whole,y_whole,
#del dtest,dtrain,dtest1,df3,df_clean,df_scaled
gc.collect()

# %% [markdown]
# # Importing the final predictor to root
# We will use the treelite library to transport the final predictor of our model to root

# %% [raw]
# #install treelite
# import treelite
# #create an object out of your model, bst in our case
# model = treelite.Model.from_xgboost(bst)
# #use GCC compiler
# toolchain = 'gcc'
# #parallel_comp can be changed upto as many processors as one have
# model.export_lib(toolchain=toolchain, libpath='./mymodel.so',
#                  params={'parallel_comp': 8}, verbose=True)
#
# # Operating system of the target machine
# platform = 'unix'
# # C compiler to use to compile prediction code on the target machine
# toolchain = 'gcc'
# # Save the source package as a zip archive named mymodel.zip
# # Later, we'll use this package to produce the library mymodel.so.
# model.export_srcpkg(platform=platform, toolchain=toolchain,
#                     pkgpath='./mymodel.zip', libname='mymodel.so',
#                     verbose=True)

# %% [raw]
# !unzip mymodel.zip

# %% [raw]
# #Build the source package (using GNU Make or NMake).
# %cd mymodel
# !make
#
# !ls

# %% [raw]
# If one wants to transfer this model to a different computer, target machine, then one should follow the following commands in command prompt

# %% [raw]
# sftp john@lxpool.gsi.de
# sftp> put mymodel.zip
# sftp> quit

# %% [raw]
# ssh john@lxpool.gsi.de
# unzip mymodel.zip
# cd mymodel
# make -j8

# %% [raw]
# The following C++ code can be the applied as a macro on some new data file

# %% [raw]
# %%writefile test.cpp
# #include "TROOT.h"
# #include "TFile.h"
# #include "TTree.h"
# #include "TH1F.h"
# #include <vector>
# #include "TString.h"
# #include "TMath.h"
# #include "TH1.h"
# #include "TF1.h"
# #include "TCanvas.h"
#
# #include <stdio.h>
# #include <stdlib.h>
# #include "main.c"
#
#
#
# void python_to_root(){
#   TCanvas* c1 = new TCanvas();
#   //c1->Divide(2,1);
#
#   //c1->cd(1);
#
#   /* Open the root file*/
#   TFile *f = new TFile("/gdrive/My Drive/presentations/treelite/10k_events_PFSimplePlainTree.root","UPDATE");
#   TTree *t1 = (TTree*)f->Get("PlainTree");
#
#
#   Float_t  LambdaCandidates_chi2primneg, LambdaCandidates_chi2primpos, LambdaCandidates_ldl, LambdaCandidates_distance, LambdaCandidates_chi2geo, LambdaCandidates_mass;
#
#   t1->SetBranchAddress("LambdaCandidates_chi2primneg",&LambdaCandidates_chi2primneg);
#   t1->SetBranchAddress("LambdaCandidates_chi2primpos",&LambdaCandidates_chi2primpos);
#   t1->SetBranchAddress("LambdaCandidates_ldl",&LambdaCandidates_ldl);
#   t1->SetBranchAddress("LambdaCandidates_distance",&LambdaCandidates_distance);
#   t1->SetBranchAddress("LambdaCandidates_chi2geo",&LambdaCandidates_chi2geo);
#   t1->SetBranchAddress("LambdaCandidates_mass",&LambdaCandidates_mass);
#
#
#   std::vector<float> output{};
#
#   const long n_entries = t1->GetEntries();
#   output.reserve(n_entries);
#
#   const size_t n_features = 5;
#   union Entry input[n_features];
#
#   //let's create a new branch which will store the probability returened for each proton-pion pair by our model
#   Float_t probab;
#   TBranch *bpt = t1->Branch("probab",&probab,"probabilities");
#   t1->SetBranchAddress("probab",&probab);
#
#   TH1F *h = new TH1F("h_prob", "This is the #Lambda invariant mass after the cut >0.918080", 300, 1.04, 1.4);
#   h->GetXaxis()->SetTitle("[GeV]");
#
#   for (long i = 0; i < n_entries; i++)
#    {
#      t1->GetEntry(i);
#
#     input[0].fvalue = LambdaCandidates_chi2primneg;
#     input[1].fvalue = LambdaCandidates_chi2primpos;
#     input[2].fvalue = LambdaCandidates_ldl;
#     input[3].fvalue = LambdaCandidates_distance;
#     input[4].fvalue = LambdaCandidates_chi2geo;
#
#     output.push_back(predict(input, 0));
#     probab= output.at(i);
#
#     if(probab > 0.918080){
#     h->Fill(LambdaCandidates_mass);}
#   }
#
#   h->Draw();
#
#
#
# }

# %% [raw]
# # Installing root
# !mkdir -p APPS
# !pwd
# !cd APPS && wget https://root.cern/download/root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
# !cd APPS && tar -xf root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
