# %% [markdown]
# Variables of filenames

# %% [markdown]
# Background comes from URQMD, signal from DCM, for test dataset for both bckgr and sign generated in urqmd

# %% [markdown]
# 4:1 background/signal ratio before cleaning, 5M sign, 15k bckgr, 30k ALL, nochi2geo

# %%
#PLAINTREE FILES NAMES
directory='/Users/julnow/gsi/cbm/ML/JupyterNotebooks/'
signalFileName = directory + 'PlainTree_2.352MSign_33gev.root'
#backgroundFileName = directory + 'PlainTree_15kBckgr_URQMD.root'
allFileName = directory + 'PlainTree_100kAll_URQMD_33gev.root'

# %%
# %%capture
# !git clone https://github.com/shahidzk1/CBM_ML_Lambda_Library.git
# %cd CBM_ML_Lambda_Library
# !git pull origin main
# !pip install -r requirements.txt
# !python setup.py install

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
#from hipe4ml.model_handler import ModelHandler
#from hipe4ml.tree_handler import TreeHandler
from matplotlib.patches import ConnectionPatch
#from hipe4ml import plot_utils

import xgboost as xgb
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz

from sklearn.model_selection import cross_val_score
from scipy.stats import uniform

from numpy import sqrt, log, argmax

import weakref 
import itertools

from CBM_ML import tree_importer,  KFPF_lambda_cuts, plot_tools
from bayes_opt import BayesianOptimization
from bayes_opt import SequentialDomainReductionTransformer

import gc, os

# %% [markdown]
# # Selecting Background and Signal
# We generate PlainTrees from: 100k events (signal) and 20k evenents (background) with Au-Au @12A GeV/c, DCMQGSM-SMM generator passed through CBM setup in GEANT4, without any cuts
#
# To omit imbalance classification problem (event though there are 5 times more events for background, the number of entries is much smaller for signal) we resample the data. We're deleting instances from the over-represented class (in our case the background) - it's called under-sampling, one of the resampling methods.
#
# So for training and testing we will get signal candidates from the 5 sigma region and  background from outside this region (3 times signal size).

# %%
#CUTS FOR MASS SELECTION
#5 sigma region for signal
lower5SigmaCutSign = 0.43485
upper5SigmaCutSign = 0.56135
#mean invariant mass
invMass = 0.4981
# "5sigma" (not acutal 5 sigma) region for background
lower5SigmaCutBckgr = 0.279
upper5SigmaCutBckgr = 1

# %%
# We import three root files into our jupyter notebook
#sign - before cleaning but after 5sigma seletion, signal - cleaned
#so that we dont have to reimport everything with each change
sign = tree_importer.tree_importer(signalFileName,'PlainTree',7)

# We only select lambda candidates in the 5 sigma region around the kaon mass peak
#we preserve the cleaned dataframe with a changed name
sign = sign[(sign['Candidates_generation']==1) & (sign['Candidates_mass']>lower5SigmaCutSign) & (sign['Candidates_mass']<upper5SigmaCutSign)]

# Similarly for the background, we select background candidates which are not in the 5 sigma region of the kaon peak
bckgr = tree_importer.tree_importer(allFileName,'PlainTree',7)
#we preserve the cleaned dataframe with a changed name
bckgr = bckgr[(bckgr['Candidates_generation'] < 1)
                 & ((bckgr['Candidates_mass'] > lower5SigmaCutBckgr)
                 & (bckgr['Candidates_mass'] < lower5SigmaCutSign) | (bckgr['Candidates_mass']>upper5SigmaCutSign) 
                    & (bckgr['Candidates_mass'] < upper5SigmaCutBckgr))
             ].sample(n=4*(sign.shape[0])) #we select bckgr so that we have 4*more entries that for signal (before cleaning)

#Also call the garbage collector of python to collect unused items to free memory
gc.collect()
# Out:
# 2506

# %%
#we remove name prefixes 'Candidates' and do some renaming
bckgr.columns = bckgr.columns.str.replace('Candidates_', '')
bckgr.columns = bckgr.columns.str.replace('_', '')
sign.columns = sign.columns.str.replace('Candidates_', '')
sign.columns = sign.columns.str.replace('_', '')
#we also get rid of coordinates errors
sign = sign.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
bckgr = bckgr.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
#let's check the name prefixes 
sign.iloc[0:10,:]
# Out:
#     chi2geo  chi2primfirst  chi2primsecond  chi2topo  cosinefirst  \
# 0  0.002304   1.629013e+07    2.912710e+06  0.991212     0.977013
# 1  0.007207   4.801999e+05    2.640682e+05  0.453785     0.967864
# 2  0.149361   2.779927e+04    3.242117e+05  9.035224     0.985714
# 3  6.273228   2.893971e+01    4.402070e+02  2.233228     0.989202
# 4  6.110103   1.044091e+08    4.661313e+04  9.374912     0.958878
# 5  0.076187   1.249708e+06    9.610366e+05  0.198769     0.929859
# 6  5.106295   8.604573e+01    4.934224e+00  3.606672     0.993960
# 7  1.251263   1.890013e+05    2.635342e+06  0.849994     0.996442
# 8  0.196356   9.794180e+06    2.163978e+07  9.743909     0.909814
# 9  0.038709   9.200256e+04    8.565177e+04  3.618178     0.893415
#
#    cosinesecond  cosinetopo  distance       eta          l  ...        pT  \
# 0      0.988708    0.999994  0.000040  2.288947   7.903877  ...  0.447989
# 1      0.977731    0.999995  0.011313  1.600970   2.916338  ...  0.675615
# 2      0.860810    0.999856  0.067658  4.108774   7.023232  ...  0.039518
# 3      0.780584    0.999771  0.094524  1.986155   0.286921  ...  0.292030
# 4      0.987414    0.999988  0.051548  3.980021  14.941236  ...  0.068161
# 5      0.882592    0.999993  0.012087  2.738950   3.089246  ...  0.116832
# 6      0.800618    0.879064  0.220202  3.033920   0.047981  ...  0.113593
# 7      0.916532    1.000000  0.005812  2.329906   6.377717  ...  0.346901
# 8      0.898341    0.999932  0.017719  1.950401   4.649182  ...  0.243375
# 9      0.997924    0.999991  0.007131  2.896031  17.076031  ...  0.181453
#
#         phi        px        py        pz  rapidity         x         y  \
# 0 -3.094823 -0.447499 -0.020944  2.186893  1.902274 -1.540590  0.034428
# 1 -1.970869 -0.263142 -0.622263  1.606658  1.404559 -0.405514 -1.076905
# 2 -1.735946 -0.006497 -0.038980  1.202475  1.621418  0.003439 -0.166376
# 3  2.968023 -0.287643  0.050434  1.044044  1.353945 -0.026837 -0.091917
# 4 -3.113403 -0.068134 -0.001921  1.823328  2.012764 -0.430716 -0.112550
# 5  2.641489 -0.102524  0.056023  0.899960  1.324160 -0.364943  0.357460
# 6  1.279717  0.032600  0.108815  1.177409  1.578876 -0.076639 -0.101441
# 7  0.051608  0.346439  0.017895  1.765670  1.789533  1.079767  0.120096
# 8 -0.180645  0.239415 -0.043726  0.838340  1.202408  1.252132 -0.166099
# 9 -2.300661 -0.120987 -0.135230  1.637333  1.842790 -1.178931 -1.574403
#
#            z  issignal
# 0   7.746151       1.0
# 1   2.692302       1.0
# 2   7.021122       1.0
# 3   0.274347       1.0
# 4  14.932716       1.0
# 5   3.061521       1.0
# 6   0.049707       1.0
# 7   6.258076       1.0
# 8   4.463722       1.0
# 9  16.961086       1.0
#
# [10 rows x 23 columns]

# %% [markdown]
# The label 'issignal' tells us if an entry comes from signal (1) or background (0)

# %% [markdown]
# # Data Cleaning
# Sometimes a data set contains entries which are outliers or does not make sense. For example, infinite values or NaN entries. We clean the data by removing these entries.
#
# Similarly, CBM is a fixed target experiment so there are certain conditions which the data has to satisfy before it is considered as reliable data.So we apply certain limits on the data sets.
#
# The values of these cuts are described: https://drive.google.com/file/d/1tb0FBRq4KgVu-VQZgpjA8ONbIGVCNOnE/view?usp=sharing https://github.com/julnow/JupyterNotebooks/blob/kaon/CBM%20K-short%20data%20cleaning.pdf

# %%
#CUTS USED FOR DATA CLEANING
#mass cuts for both bckgr and sign
lowerMassCut = 0.279
upperMassCut = 1
#distance cuts
#DCA
lowerDcaCut = 0
upperDcaCut = 100
#l distance
lowerLCut = -5
upperLCut = 80
#loverdl
lowerLdlCut = -25
upperLdlCut = 15000
#coordinate cuts
absXCut = 50
absYCut = 50
lowerZCut = -1
upperZCut = 80
#momentums cuts
pzLowerCut = 0
pUpperCut = 20
ptUpperCut = 3
#chi2
#geo
lowerChi2GeoCut = 0
upperChi2GeoCut = 10000
#topo
lowerChi2TopoCut = 0
upperChi2TopoCut = 100000
#prim first
lowerChi2PrimFirstCut = 0
upperChi2PrimFirstCut = 3e7
#prim second
lowerChi2PrimSecondCut = 0
upperChi2PrimSecondCut = 3e7
#pseudorapidity cuts
lowerEtaCut = 1.
upperEtaCut = 6.5

# %%
def clean_df(df):
    # let's treat all the infinite, inf, values by nan and then we drop all the null entries
    with pd.option_context('mode.use_inf_as_na', True):
        df = df.dropna()
    #Experimental constraints
    is_good_mom = (df['pz'] > pzLowerCut) & (df['p']<pUpperCut) & (df['pT']<ptUpperCut)
    is_good_coord = (abs(df['x']) < absXCut) & (abs(df['y']) < absYCut) & (df['z']>lowerZCut) & (df['z']<upperZCut)
    is_good_params = (df['distance'] > lowerDcaCut) & (df['distance'] < upperDcaCut) & (df['chi2geo']>lowerChi2GeoCut) & (df['chi2geo'] < upperChi2GeoCut) & (df['chi2topo'] > lowerChi2TopoCut) & (df['chi2topo'] < upperChi2TopoCut) & (df['eta']>lowerEtaCut) & (df['eta']<upperEtaCut)& (df['l']>lowerLCut) & (df['l']<upperLCut) & (df['loverdl']>lowerLdlCut) & (df['loverdl']<upperLdlCut)
    is_good_daughters = (df['chi2primfirst']>lowerChi2PrimFirstCut) & (df['chi2primfirst'] < upperChi2PrimSecondCut) & (df['chi2primsecond']>lowerChi2PrimSecondCut) & (df['chi2primsecond']<upperChi2PrimFirstCut)
    is_good_mass = (df['mass']>lowerMassCut) & (df['mass']<upperMassCut)

    is_good_df = (is_good_mom) & (is_good_coord) & (is_good_params) & (is_good_daughters) & (is_good_mass)

    return df[is_good_df]

# %%
background = clean_df(bckgr)
signal = clean_df(sign)
print('size of:\nsignal: ' + str(len(signal)) + '\nbackground: ' + str(len(background)) 
      + '\nbackground to signal ratio: ' + str(round(len(background)/len(signal), 1)))
del sign, bckgr
# Out:
# size of:
# signal: 141768
# background: 541245
# background to signal ratio: 3.8

# %% [markdown]
# We'll also import and clean dataset of 10k events for both background and signal (for testing our algorhitm)

# %%
#Let's combine signal and background
df_scaled = pd.concat([signal, background])
del signal, background
gc.collect()
# Out:
# 22

# %% [markdown]
# # Selecting Background and Signal
# After cleaning, our training data set contains 450442 background candidates and 1638402 signal candidates (background to signal ratio $\approx 3.6$). For testing, we'll use cleaned dataset containing 28740227 entries of signal and background (background to signal ratio $\approx 1985.1$)
#
# Here, we use under-sampling to tackle the problem with the classification of underrepresented class (normally, the signal is only approx. 0.05% of real data)

# %%
if not os.path.exists(directory+'img/xgb_33gev_nochi2geo'):
    os.makedirs(directory+'img/xgb_33gev_nochi2geo')
#lets draw sign to background ratio
def plt_sig_back(df):
    range1 = (lowerMassCut, upperMassCut)
    fig, axs = plt.subplots(figsize=(20, 10))
    #df_scaled['mass'].plot.hist(bins = 300, range=range1,grid=True,sharey=True)
    (df[df['issignal']==0])['mass'].plot.hist(bins = 300, facecolor='yellow',grid=True,range=range1, label='Background')
    (df[df['issignal']==1])['mass'].plot.hist(bins = 300, facecolor='magenta',grid=True, range=range1, label ='Signal')
    #plt.vlines(x=1.108,ymin=-1,ymax=48000, color='black', linestyle='-')
    #plt.vlines(x=1.1227,ymin=-1,ymax=48000, color='black', linestyle='-')
    plt.ylabel("Counts (log scale)", fontsize=15)
    plt.xlabel("Mass in GeV/$c^2$", fontsize= 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.title('Test and Train K-short Invariant Mass', fontsize = 15)
    plt.legend( fontsize = 15)
    axs.tick_params(axis='both', which='major', labelsize=18)
    plt.yscale("log")
    fig.tight_layout()
    fig.savefig(directory+'img/xgb_33gev_nochi2geo/inv_mass_trainset.pdf')
    fig.savefig(directory+'img/xgb_33gev_nochi2geo/inv_mass_trainset.png')

# %%
plt_sig_back(df_scaled)
gc.collect()
# Out:
# 2207

# %% [markdown]
# # Creating Train and Test sets
# To make machine learning algorithms more efficient on unseen data we divide our data into two sets. One set is for training the algorithm and the other is for testing the algorithm. If we don't do this then the algorithm can overfit and we will not capture the general trends in the data.

# %%
# The following columns will be used to predict whether a reconstructed candidate is a lambda particle or not
cuts = [ 'loverdl', 'distance', 'chi2topo', 'chi2primfirst', 'chi2primsecond']#'chi2geo', 


x = df_scaled[cuts].copy()

# The MC information is saved in this y variable
y =pd.DataFrame(df_scaled['issignal'], dtype='int')

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=324)
del df_scaled, x, y

#DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed. 
dtrain = xgb.DMatrix(x_train, label = y_train)
dtest1=xgb.DMatrix(x_test, label = y_test)
del x_train, x_test
gc.collect()
# Out:
# 43984

# %% [markdown]
# ## Bayesian optimization
# In order to find the best parameters of XGB for our data we use Bayesian optimization. Grid search and and random search could also do the same job but bayesian is more time efficient. For further reading visit [the git page](https://github.com/fmfn/BayesianOptimization) of the bayesian optimization used here.
#
# ### Hyper parameters
# Some of the following hyper parameters will be tuned for our algorithm:
#
#
# *subsample* [default=1]
# Subsample ratio of the training instances. Setting it to 0.5 means that XGBoost would randomly sample half of the training data prior to growing trees. and this will prevent overfitting. Subsampling will occur once in every boosting iteration.
# range: (0,1]
#
# *eta* [default=0.3, alias: learning_rate]
# Step size shrinkage used in update to prevents overfitting. After each boosting step, we can directly get the weights of new features, and eta shrinks the feature weights to make the boosting process more conservative.
# range: [0,1]
#
#
# *gamma* [default=0, alias: min_split_loss]
# Minimum loss reduction required to make a further partition on a leaf node of the tree. The larger gamma is, the more conservative the algorithm will be.
# range: [0,∞]
#
#
# *alpha* [default=0, alias: reg_alpha]
# L1 regularization term on weights. Increasing this value will make model more conservative.
#
# *Lasso Regression* (Least Absolute Shrinkage and Selection Operator) adds “absolute value of magnitude” of coefficient as penalty term to the loss function.

# %%
#Bayesian Optimization function for xgboost
#specify the parameters you want to tune as keyword arguments
def bo_tune_xgb(max_depth, gamma, alpha, n_estimators ,learning_rate):
    params = {'max_depth': int(max_depth),
              'gamma': gamma,
              'alpha':alpha,
              'n_estimators': n_estimators,
              'learning_rate':learning_rate,
              'subsample': 0.8,
              'eta': 0.1,
              'eval_metric': 'auc', 'nthread' : 15}
    cv_result = xgb.cv(params, dtrain, num_boost_round=70, nfold=5)
    return  cv_result['test-auc-mean'].iloc[-1]

bounds_transformer = SequentialDomainReductionTransformer()

# %%
#Invoking the Bayesian Optimizer with the specified parameters to tune
xgb_bo = BayesianOptimization(bo_tune_xgb, {'max_depth': (6, 16),
                                             'gamma': (0, 1),
                                            'alpha': (2,12),
                                             'learning_rate':(0,.5),
                                             'n_estimators':(300,1000)
                                            },
                             bounds_transformer=bounds_transformer)

# %%
#performing Bayesian optimization for 5 iterations with 8 steps of random exploration with an #acquisition function of expected improvement
xgb_bo.maximize(n_iter=5, init_points=5)
# Out:
# |   iter    |  target   |   alpha   |   gamma   | learni... | max_depth | n_esti... |
# -------------------------------------------------------------------------------------
# [10:47:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 14 pruned nodes, max_depth=9
# [10:47:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 12 pruned nodes, max_depth=8
# [10:47:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 6 pruned nodes, max_depth=8
# [10:47:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 22 pruned nodes, max_depth=10
# [10:47:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 18 pruned nodes, max_depth=9
# [10:47:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 14 pruned nodes, max_depth=8
# [10:47:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 12 pruned nodes, max_depth=8
# [10:47:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 22 pruned nodes, max_depth=9
# [10:47:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 14 pruned nodes, max_depth=8
# [10:47:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 14 pruned nodes, max_depth=8
# [10:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 22 pruned nodes, max_depth=8
# [10:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 12 pruned nodes, max_depth=8
# [10:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 18 pruned nodes, max_depth=10
# [10:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 12 pruned nodes, max_depth=8
# [10:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 16 pruned nodes, max_depth=9
# [10:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 20 pruned nodes, max_depth=10
# [10:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 30 pruned nodes, max_depth=8
# [10:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 18 pruned nodes, max_depth=8
# [10:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 20 pruned nodes, max_depth=10
# [10:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 30 pruned nodes, max_depth=9
# [10:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 38 pruned nodes, max_depth=10
# [10:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 56 pruned nodes, max_depth=10
# [10:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 24 pruned nodes, max_depth=10
# [10:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 28 pruned nodes, max_depth=10
# [10:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 24 pruned nodes, max_depth=8
# [10:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 58 pruned nodes, max_depth=9
# [10:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 44 pruned nodes, max_depth=10
# [10:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 42 pruned nodes, max_depth=9
# [10:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 60 pruned nodes, max_depth=8
# [10:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 44 pruned nodes, max_depth=10
# [10:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 86 pruned nodes, max_depth=9
# [10:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 62 pruned nodes, max_depth=8
# [10:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 68 pruned nodes, max_depth=10
# [10:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 56 pruned nodes, max_depth=10
# [10:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 58 pruned nodes, max_depth=10
# [10:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 84 pruned nodes, max_depth=9
# [10:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 86 pruned nodes, max_depth=9
# [10:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 80 pruned nodes, max_depth=10
# [10:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 76 pruned nodes, max_depth=8
# [10:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 94 pruned nodes, max_depth=9
# [10:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 116 pruned nodes, max_depth=8
# [10:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 128 pruned nodes, max_depth=10
# [10:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 106 pruned nodes, max_depth=10
# [10:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 88 pruned nodes, max_depth=7
# [10:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 80 pruned nodes, max_depth=7
# [10:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 102 pruned nodes, max_depth=10
# [10:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 136 pruned nodes, max_depth=9
# [10:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 130 pruned nodes, max_depth=9
# [10:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 90 pruned nodes, max_depth=10
# [10:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 126 pruned nodes, max_depth=8
# [10:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 154 pruned nodes, max_depth=7
# [10:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 92 pruned nodes, max_depth=10
# [10:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 140 pruned nodes, max_depth=6
# [10:47:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 102 pruned nodes, max_depth=9
# [10:47:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 164 pruned nodes, max_depth=6
# [10:47:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 132 pruned nodes, max_depth=10
# [10:47:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 124 pruned nodes, max_depth=9
# [10:47:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 184 pruned nodes, max_depth=7
# [10:47:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 148 pruned nodes, max_depth=5
# [10:47:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 114 pruned nodes, max_depth=10
# [10:47:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 114 pruned nodes, max_depth=7
# [10:47:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 152 pruned nodes, max_depth=8
# [10:47:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 108 pruned nodes, max_depth=10
# [10:47:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 162 pruned nodes, max_depth=9
# [10:47:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 114 pruned nodes, max_depth=7
# [10:47:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 114 pruned nodes, max_depth=10
# [10:47:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 158 pruned nodes, max_depth=7
# [10:47:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 112 pruned nodes, max_depth=9
# [10:47:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 162 pruned nodes, max_depth=7
# [10:47:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 160 pruned nodes, max_depth=7
# [10:47:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 180 pruned nodes, max_depth=8
# [10:47:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 130 pruned nodes, max_depth=10
# [10:47:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 132 pruned nodes, max_depth=10
# [10:47:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 120 pruned nodes, max_depth=10
# [10:47:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 144 pruned nodes, max_depth=10
# [10:47:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 108 pruned nodes, max_depth=9
# [10:47:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 138 pruned nodes, max_depth=10
# [10:47:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 116 pruned nodes, max_depth=10
# [10:47:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 90 pruned nodes, max_depth=10
# [10:47:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 166 pruned nodes, max_depth=8
# [10:47:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 128 pruned nodes, max_depth=10
# [10:47:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 96 pruned nodes, max_depth=5
# [10:47:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 152 pruned nodes, max_depth=9
# [10:47:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 142 pruned nodes, max_depth=8
# [10:47:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 146 pruned nodes, max_depth=8
# [10:47:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 152 pruned nodes, max_depth=5
# [10:47:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 178 pruned nodes, max_depth=7
# [10:47:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 180 pruned nodes, max_depth=8
# [10:47:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 186 pruned nodes, max_depth=7
# [10:47:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 118 pruned nodes, max_depth=10
# [10:47:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 178 pruned nodes, max_depth=4
# [10:47:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 162 pruned nodes, max_depth=9
# [10:47:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 140 pruned nodes, max_depth=5
# [10:47:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 162 pruned nodes, max_depth=9
# [10:47:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 166 pruned nodes, max_depth=6
# [10:47:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 152 pruned nodes, max_depth=8
# [10:47:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 170 pruned nodes, max_depth=7
# [10:47:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 168 pruned nodes, max_depth=2
# [10:47:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 104 pruned nodes, max_depth=10
# [10:47:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 162 pruned nodes, max_depth=0
# [10:47:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:47:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 174 pruned nodes, max_depth=0
# [10:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 122 pruned nodes, max_depth=10
# [10:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 152 pruned nodes, max_depth=8
# [10:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 134 pruned nodes, max_depth=10
# [10:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 142 pruned nodes, max_depth=7
# [10:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 136 pruned nodes, max_depth=10
# [10:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 158 pruned nodes, max_depth=9
# [10:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 174 pruned nodes, max_depth=10
# [10:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 146 pruned nodes, max_depth=6
# [10:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 126 pruned nodes, max_depth=9
# [10:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 116 pruned nodes, max_depth=8
# [10:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 172 pruned nodes, max_depth=8
# [10:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 158 pruned nodes, max_depth=5
# [10:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 156 pruned nodes, max_depth=9
# [10:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 150 pruned nodes, max_depth=9
# [10:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 146 pruned nodes, max_depth=0
# [10:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 166 pruned nodes, max_depth=9
# [10:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 146 pruned nodes, max_depth=7
# [10:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 114 pruned nodes, max_depth=5
# [10:48:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 180 pruned nodes, max_depth=6
# [10:48:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 174 pruned nodes, max_depth=5
# [10:48:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 142 pruned nodes, max_depth=7
# [10:48:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 144 pruned nodes, max_depth=8
# [10:48:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 162 pruned nodes, max_depth=7
# [10:48:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 132 pruned nodes, max_depth=0
# [10:48:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 178 pruned nodes, max_depth=0
# [10:48:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 194 pruned nodes, max_depth=7
# [10:48:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 198 pruned nodes, max_depth=0
# [10:48:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 168 pruned nodes, max_depth=0
# [10:48:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 136 pruned nodes, max_depth=0
# [10:48:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 162 pruned nodes, max_depth=9
# [10:48:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 166 pruned nodes, max_depth=8
# [10:48:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 114 pruned nodes, max_depth=9
# [10:48:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 188 pruned nodes, max_depth=7
# [10:48:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 164 pruned nodes, max_depth=8
# [10:48:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 166 pruned nodes, max_depth=0
# [10:48:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 134 pruned nodes, max_depth=7
# [10:48:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 142 pruned nodes, max_depth=8
# [10:48:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 104 pruned nodes, max_depth=10
# [10:48:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 146 pruned nodes, max_depth=9
# [10:48:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 140 pruned nodes, max_depth=10
# [10:48:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 210 pruned nodes, max_depth=0
# [10:48:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 154 pruned nodes, max_depth=8
# [10:48:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 148 pruned nodes, max_depth=7
# [10:48:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 172 pruned nodes, max_depth=6
# [10:48:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 168 pruned nodes, max_depth=0
# [10:48:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 144 pruned nodes, max_depth=7
# [10:48:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:48:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 130 pruned nodes, max_depth=7
# [10:48:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 150 pruned nodes, max_depth=7
# [10:48:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 122 pruned nodes, max_depth=9
# [10:48:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 146 pruned nodes, max_depth=10
# [10:48:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 152 pruned nodes, max_depth=6
# [10:48:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 150 pruned nodes, max_depth=8
# [10:48:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 128 pruned nodes, max_depth=6
# [10:48:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 176 pruned nodes, max_depth=8
# [10:48:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:48:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 170 pruned nodes, max_depth=9
# [10:48:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 140 pruned nodes, max_depth=8
# [10:48:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 172 pruned nodes, max_depth=0
# [10:48:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 186 pruned nodes, max_depth=0
# [10:48:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 166 pruned nodes, max_depth=0
# [10:48:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 152 pruned nodes, max_depth=0
# [10:48:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 142 pruned nodes, max_depth=7
# [10:48:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 182 pruned nodes, max_depth=9
# [10:48:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 154 pruned nodes, max_depth=3
# [10:48:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 166 pruned nodes, max_depth=6
# [10:48:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 160 pruned nodes, max_depth=0
# [10:48:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 140 pruned nodes, max_depth=9
# [10:48:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 176 pruned nodes, max_depth=4
# [10:48:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 124 pruned nodes, max_depth=7
# [10:48:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 144 pruned nodes, max_depth=7
# [10:48:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:48:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 160 pruned nodes, max_depth=0
# [10:48:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 90 pruned nodes, max_depth=10
# [10:48:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 144 pruned nodes, max_depth=0
# [10:48:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 154 pruned nodes, max_depth=9
# [10:48:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 158 pruned nodes, max_depth=7
# [10:48:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 170 pruned nodes, max_depth=0
# [10:48:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 130 pruned nodes, max_depth=10
# [10:48:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 164 pruned nodes, max_depth=0
# [10:48:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 168 pruned nodes, max_depth=9
# [10:48:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 196 pruned nodes, max_depth=8
# [10:48:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 164 pruned nodes, max_depth=9
# [10:48:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 168 pruned nodes, max_depth=8
# [10:48:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 126 pruned nodes, max_depth=5
# [10:48:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 178 pruned nodes, max_depth=0
# [10:48:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 194 pruned nodes, max_depth=8
# [10:48:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 122 pruned nodes, max_depth=10
# [10:48:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 182 pruned nodes, max_depth=0
# [10:48:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 128 pruned nodes, max_depth=0
# [10:48:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 150 pruned nodes, max_depth=0
# [10:48:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 146 pruned nodes, max_depth=6
# [10:48:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 162 pruned nodes, max_depth=0
# [10:48:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 150 pruned nodes, max_depth=0
# [10:48:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 172 pruned nodes, max_depth=7
# [10:48:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 146 pruned nodes, max_depth=7
# [10:48:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 90 pruned nodes, max_depth=10
# [10:48:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 184 pruned nodes, max_depth=0
# [10:48:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 154 pruned nodes, max_depth=9
# [10:48:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 178 pruned nodes, max_depth=9
# [10:48:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 114 pruned nodes, max_depth=0
# [10:48:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 160 pruned nodes, max_depth=0
# [10:48:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 160 pruned nodes, max_depth=8
# [10:48:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 158 pruned nodes, max_depth=9
# [10:48:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 182 pruned nodes, max_depth=0
# [10:48:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 116 pruned nodes, max_depth=0
# [10:48:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 96 pruned nodes, max_depth=0
# [10:48:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 170 pruned nodes, max_depth=8
# [10:48:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 160 pruned nodes, max_depth=0
# [10:48:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:48:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 154 pruned nodes, max_depth=0
# [10:48:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 112 pruned nodes, max_depth=8
# [10:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 132 pruned nodes, max_depth=5
# [10:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 116 pruned nodes, max_depth=8
# [10:48:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 160 pruned nodes, max_depth=0
# [10:48:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 128 pruned nodes, max_depth=10
# [10:48:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 174 pruned nodes, max_depth=0
# [10:48:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 164 pruned nodes, max_depth=0
# [10:48:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 148 pruned nodes, max_depth=7
# [10:48:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 160 pruned nodes, max_depth=9
# [10:48:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 158 pruned nodes, max_depth=0
# [10:48:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 152 pruned nodes, max_depth=7
# [10:48:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 154 pruned nodes, max_depth=0
# [10:48:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 170 pruned nodes, max_depth=8
# [10:48:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 186 pruned nodes, max_depth=0
# [10:48:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 178 pruned nodes, max_depth=0
# [10:48:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 168 pruned nodes, max_depth=6
# [10:48:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 166 pruned nodes, max_depth=0
# [10:48:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 160 pruned nodes, max_depth=7
# [10:48:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 140 pruned nodes, max_depth=7
# [10:48:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 156 pruned nodes, max_depth=8
# [10:48:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 118 pruned nodes, max_depth=0
# [10:48:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 164 pruned nodes, max_depth=9
# [10:48:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 140 pruned nodes, max_depth=7
# [10:48:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 174 pruned nodes, max_depth=9
# [10:48:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 134 pruned nodes, max_depth=0
# [10:48:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 200 pruned nodes, max_depth=0
# [10:48:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 160 pruned nodes, max_depth=6
# [10:48:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 164 pruned nodes, max_depth=0
# [10:48:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 156 pruned nodes, max_depth=9
# [10:48:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 152 pruned nodes, max_depth=6
# [10:48:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 102 pruned nodes, max_depth=7
# [10:48:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 180 pruned nodes, max_depth=0
# [10:49:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 146 pruned nodes, max_depth=7
# [10:49:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 166 pruned nodes, max_depth=8
# [10:49:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 140 pruned nodes, max_depth=9
# [10:49:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 172 pruned nodes, max_depth=4
# [10:49:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 126 pruned nodes, max_depth=8
# [10:49:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 172 pruned nodes, max_depth=0
# [10:49:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 170 pruned nodes, max_depth=0
# [10:49:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 148 pruned nodes, max_depth=5
# [10:49:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 156 pruned nodes, max_depth=0
# [10:49:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 146 pruned nodes, max_depth=9
# [10:49:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 168 pruned nodes, max_depth=7
# [10:49:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 178 pruned nodes, max_depth=0
# [10:49:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 188 pruned nodes, max_depth=0
# [10:49:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 188 pruned nodes, max_depth=0
# [10:49:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:49:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 178 pruned nodes, max_depth=0
# [10:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 132 pruned nodes, max_depth=9
# [10:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 100 pruned nodes, max_depth=7
# [10:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 154 pruned nodes, max_depth=0
# [10:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 128 pruned nodes, max_depth=0
# [10:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 162 pruned nodes, max_depth=0
# [10:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 190 pruned nodes, max_depth=0
# [10:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 122 pruned nodes, max_depth=0
# [10:49:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 142 pruned nodes, max_depth=6
# [10:49:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 146 pruned nodes, max_depth=0
# [10:49:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 162 pruned nodes, max_depth=0
# [10:49:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 166 pruned nodes, max_depth=6
# [10:49:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 166 pruned nodes, max_depth=0
# [10:49:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 180 pruned nodes, max_depth=0
# [10:49:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 178 pruned nodes, max_depth=5
# [10:49:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 166 pruned nodes, max_depth=0
# [10:49:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 154 pruned nodes, max_depth=0
# [10:49:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 124 pruned nodes, max_depth=7
# [10:49:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 190 pruned nodes, max_depth=8
# [10:49:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 166 pruned nodes, max_depth=0
# [10:49:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 162 pruned nodes, max_depth=7
# [10:49:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 154 pruned nodes, max_depth=6
# [10:49:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 138 pruned nodes, max_depth=4
# [10:49:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 156 pruned nodes, max_depth=0
# [10:49:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 152 pruned nodes, max_depth=5
# [10:49:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 152 pruned nodes, max_depth=8
# [10:49:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 118 pruned nodes, max_depth=9
# [10:49:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 138 pruned nodes, max_depth=0
# [10:49:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 168 pruned nodes, max_depth=10
# [10:49:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 126 pruned nodes, max_depth=0
# [10:49:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 174 pruned nodes, max_depth=0
# [10:49:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 160 pruned nodes, max_depth=0
# [10:49:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:49:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:49:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 202 pruned nodes, max_depth=0
# [10:49:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 140 pruned nodes, max_depth=4
# [10:49:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:49:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 168 pruned nodes, max_depth=0
# [10:49:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 172 pruned nodes, max_depth=0
# [10:49:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 92 pruned nodes, max_depth=7
# [10:49:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 162 pruned nodes, max_depth=7
# [10:49:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 180 pruned nodes, max_depth=3
# [10:49:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 156 pruned nodes, max_depth=9
# [10:49:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 144 pruned nodes, max_depth=0
# [10:49:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 144 pruned nodes, max_depth=5
# [10:49:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:49:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 142 pruned nodes, max_depth=0
# [10:49:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 188 pruned nodes, max_depth=0
# [10:49:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 148 pruned nodes, max_depth=0
# [10:49:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 182 pruned nodes, max_depth=0
# [10:49:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 144 pruned nodes, max_depth=8
# [10:49:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 170 pruned nodes, max_depth=0
# [10:49:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 140 pruned nodes, max_depth=8
# [10:49:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 174 pruned nodes, max_depth=0
# [10:49:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 180 pruned nodes, max_depth=0
# [10:49:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 198 pruned nodes, max_depth=0
# [10:49:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 176 pruned nodes, max_depth=9
# [10:49:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 184 pruned nodes, max_depth=0
# [10:49:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 170 pruned nodes, max_depth=0
# [10:49:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 180 pruned nodes, max_depth=7
# [10:49:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 194 pruned nodes, max_depth=0
# [10:49:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 168 pruned nodes, max_depth=8
# [10:49:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 136 pruned nodes, max_depth=0
# [10:49:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 182 pruned nodes, max_depth=7
# [10:49:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 196 pruned nodes, max_depth=0
# [10:49:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 174 pruned nodes, max_depth=9
# [10:49:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 172 pruned nodes, max_depth=0
# [10:49:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 170 pruned nodes, max_depth=7
# [10:49:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [10:49:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 140 pruned nodes, max_depth=6
# [10:49:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 184 pruned nodes, max_depth=0
# [10:49:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 154 pruned nodes, max_depth=4
# [10:49:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 146 pruned nodes, max_depth=0
# [10:49:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 174 pruned nodes, max_depth=0
# [10:49:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 178 pruned nodes, max_depth=0
# [10:49:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 202 pruned nodes, max_depth=0
# [10:49:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 168 pruned nodes, max_depth=0
# [10:49:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 190 pruned nodes, max_depth=3
# [10:49:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 118 pruned nodes, max_depth=0
# [10:49:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 158 pruned nodes, max_depth=7
# [10:49:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 158 pruned nodes, max_depth=4
# [10:49:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 210 pruned nodes, max_depth=0
# [10:49:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 170 pruned nodes, max_depth=9
# [10:49:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 168 pruned nodes, max_depth=0
# [10:49:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 180 pruned nodes, max_depth=0
# [10:49:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 142 pruned nodes, max_depth=8
# [10:49:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 152 pruned nodes, max_depth=8
# [10:49:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 168 pruned nodes, max_depth=5
# [10:49:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 158 pruned nodes, max_depth=9
# [10:49:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 156 pruned nodes, max_depth=0
# |  1        |  0.9955   |  9.748    |  0.339    |  0.4936   |  10.51    |  563.4    |
# [10:49:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 2 pruned nodes, max_depth=8
# [10:49:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=8
# [10:49:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=8
# [10:49:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=8
# [10:49:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=8
# [10:49:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 2 pruned nodes, max_depth=8
# [10:49:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 2 pruned nodes, max_depth=8
# [10:49:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 6 pruned nodes, max_depth=8
# [10:49:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 2 pruned nodes, max_depth=8
# [10:49:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=8
# [10:49:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 8 pruned nodes, max_depth=8
# [10:49:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=8
# [10:49:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 6 pruned nodes, max_depth=8
# [10:49:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 2 pruned nodes, max_depth=8
# [10:49:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 10 pruned nodes, max_depth=8
# [10:49:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 2 pruned nodes, max_depth=8
# [10:49:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 6 pruned nodes, max_depth=8
# [10:49:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 2 pruned nodes, max_depth=8
# [10:49:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 2 pruned nodes, max_depth=8
# [10:49:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 6 pruned nodes, max_depth=8
# [10:49:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 6 pruned nodes, max_depth=8
# [10:49:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=8
# [10:49:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 2 pruned nodes, max_depth=8
# [10:49:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=8
# [10:49:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 4 pruned nodes, max_depth=8
# [10:49:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 8 pruned nodes, max_depth=8
# [10:49:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 10 pruned nodes, max_depth=8
# [10:49:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=8
# [10:49:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 6 pruned nodes, max_depth=8
# [10:49:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=8
# [10:50:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 8 pruned nodes, max_depth=8
# [10:50:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 8 pruned nodes, max_depth=8
# [10:50:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 2 pruned nodes, max_depth=8
# [10:50:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 4 pruned nodes, max_depth=8
# [10:50:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 2 pruned nodes, max_depth=8
# [10:50:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 8 pruned nodes, max_depth=8
# [10:50:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 2 pruned nodes, max_depth=8
# [10:50:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 2 pruned nodes, max_depth=8
# [10:50:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 6 pruned nodes, max_depth=8
# [10:50:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 8 pruned nodes, max_depth=8
# [10:50:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 6 pruned nodes, max_depth=8
# [10:50:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 2 pruned nodes, max_depth=8
# [10:50:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 8 pruned nodes, max_depth=8
# [10:50:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 12 pruned nodes, max_depth=8
# [10:50:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 2 pruned nodes, max_depth=8
# [10:50:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 4 pruned nodes, max_depth=8
# [10:50:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 14 pruned nodes, max_depth=8
# [10:50:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 8 pruned nodes, max_depth=8
# [10:50:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=8
# [10:50:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 6 pruned nodes, max_depth=8
# [10:50:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 12 pruned nodes, max_depth=8
# [10:50:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 12 pruned nodes, max_depth=8
# [10:50:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 12 pruned nodes, max_depth=8
# [10:50:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 10 pruned nodes, max_depth=8
# [10:50:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 6 pruned nodes, max_depth=8
# [10:50:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 8 pruned nodes, max_depth=8
# [10:50:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 16 pruned nodes, max_depth=8
# [10:50:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 14 pruned nodes, max_depth=8
# ...
# [11:06:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 164 pruned nodes, max_depth=7
# [11:06:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 126 pruned nodes, max_depth=7
# [11:06:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 108 pruned nodes, max_depth=7
# [11:06:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 110 pruned nodes, max_depth=0
# [11:06:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 112 pruned nodes, max_depth=7
# [11:06:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 134 pruned nodes, max_depth=6
# [11:06:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 106 pruned nodes, max_depth=0
# [11:06:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 88 pruned nodes, max_depth=7
# [11:06:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 98 pruned nodes, max_depth=7
# [11:06:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 96 pruned nodes, max_depth=0
# [11:06:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 120 pruned nodes, max_depth=0
# [11:06:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 142 pruned nodes, max_depth=7
# [11:06:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 126 pruned nodes, max_depth=6
# [11:06:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 180 pruned nodes, max_depth=0
# [11:06:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 128 pruned nodes, max_depth=7
# [11:06:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 134 pruned nodes, max_depth=0
# [11:06:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 158 pruned nodes, max_depth=0
# [11:06:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 148 pruned nodes, max_depth=4
# [11:06:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 144 pruned nodes, max_depth=5
# [11:06:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 102 pruned nodes, max_depth=5
# [11:06:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 108 pruned nodes, max_depth=0
# [11:06:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 126 pruned nodes, max_depth=0
# [11:06:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 60 pruned nodes, max_depth=0
# [11:06:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 136 pruned nodes, max_depth=0
# [11:06:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 110 pruned nodes, max_depth=7
# [11:06:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 156 pruned nodes, max_depth=6
# [11:06:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 140 pruned nodes, max_depth=0
# [11:06:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 92 pruned nodes, max_depth=7
# [11:06:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 134 pruned nodes, max_depth=7
# [11:06:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 82 pruned nodes, max_depth=7
# [11:06:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 84 pruned nodes, max_depth=0
# [11:06:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 106 pruned nodes, max_depth=6
# [11:06:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 130 pruned nodes, max_depth=6
# [11:06:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 70 pruned nodes, max_depth=7
# [11:06:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 96 pruned nodes, max_depth=0
# [11:06:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 116 pruned nodes, max_depth=7
# [11:06:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 144 pruned nodes, max_depth=7
# [11:06:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 130 pruned nodes, max_depth=6
# [11:06:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 62 pruned nodes, max_depth=7
# [11:06:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 154 pruned nodes, max_depth=7
# [11:06:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 124 pruned nodes, max_depth=0
# [11:06:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 92 pruned nodes, max_depth=6
# [11:06:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 146 pruned nodes, max_depth=6
# [11:06:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 134 pruned nodes, max_depth=7
# [11:06:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 142 pruned nodes, max_depth=0
# [11:06:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 146 pruned nodes, max_depth=0
# [11:06:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 78 pruned nodes, max_depth=7
# [11:06:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 72 pruned nodes, max_depth=7
# [11:06:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 100 pruned nodes, max_depth=0
# [11:06:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 130 pruned nodes, max_depth=0
# [11:06:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 130 pruned nodes, max_depth=0
# [11:06:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 84 pruned nodes, max_depth=6
# [11:06:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 62 pruned nodes, max_depth=0
# [11:06:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 122 pruned nodes, max_depth=6
# [11:06:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 106 pruned nodes, max_depth=6
# [11:06:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 120 pruned nodes, max_depth=0
# [11:06:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 112 pruned nodes, max_depth=0
# [11:06:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 106 pruned nodes, max_depth=5
# [11:06:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 108 pruned nodes, max_depth=7
# [11:06:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 72 pruned nodes, max_depth=6
# [11:06:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 84 pruned nodes, max_depth=0
# [11:06:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 102 pruned nodes, max_depth=0
# [11:06:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 148 pruned nodes, max_depth=0
# [11:06:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 106 pruned nodes, max_depth=0
# [11:06:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 156 pruned nodes, max_depth=7
# [11:06:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 154 pruned nodes, max_depth=0
# [11:06:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 88 pruned nodes, max_depth=7
# [11:06:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 92 pruned nodes, max_depth=0
# [11:06:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 70 pruned nodes, max_depth=7
# [11:06:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 92 pruned nodes, max_depth=0
# [11:06:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 170 pruned nodes, max_depth=0
# [11:06:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 70 pruned nodes, max_depth=7
# [11:06:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 114 pruned nodes, max_depth=0
# [11:06:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 122 pruned nodes, max_depth=6
# [11:06:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 74 pruned nodes, max_depth=7
# [11:06:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 110 pruned nodes, max_depth=0
# [11:06:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 100 pruned nodes, max_depth=7
# [11:06:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 98 pruned nodes, max_depth=6
# [11:06:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 100 pruned nodes, max_depth=0
# [11:06:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 104 pruned nodes, max_depth=7
# [11:06:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 98 pruned nodes, max_depth=0
# [11:06:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 144 pruned nodes, max_depth=7
# [11:06:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 130 pruned nodes, max_depth=0
# [11:06:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 94 pruned nodes, max_depth=0
# [11:06:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 104 pruned nodes, max_depth=0
# [11:06:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 146 pruned nodes, max_depth=6
# [11:06:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 146 pruned nodes, max_depth=7
# [11:06:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 88 pruned nodes, max_depth=7
# [11:06:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 164 pruned nodes, max_depth=0
# [11:06:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 110 pruned nodes, max_depth=7
# [11:06:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 158 pruned nodes, max_depth=6
# [11:06:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 124 pruned nodes, max_depth=0
# [11:06:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 144 pruned nodes, max_depth=0
# [11:06:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 100 pruned nodes, max_depth=7
# [11:06:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 148 pruned nodes, max_depth=6
# [11:06:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 76 pruned nodes, max_depth=0
# [11:06:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 74 pruned nodes, max_depth=6
# [11:06:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 130 pruned nodes, max_depth=5
# [11:06:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 130 pruned nodes, max_depth=0
# [11:06:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 104 pruned nodes, max_depth=7
# [11:06:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 134 pruned nodes, max_depth=7
# [11:06:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 124 pruned nodes, max_depth=7
# [11:06:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 98 pruned nodes, max_depth=0
# [11:06:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 112 pruned nodes, max_depth=0
# [11:06:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 124 pruned nodes, max_depth=7
# [11:06:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 92 pruned nodes, max_depth=5
# [11:06:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 114 pruned nodes, max_depth=7
# [11:06:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 130 pruned nodes, max_depth=0
# [11:06:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 70 pruned nodes, max_depth=7
# [11:06:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 182 pruned nodes, max_depth=0
# [11:06:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 56 pruned nodes, max_depth=7
# [11:06:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 132 pruned nodes, max_depth=0
# [11:06:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 110 pruned nodes, max_depth=0
# [11:06:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 108 pruned nodes, max_depth=6
# [11:06:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 106 pruned nodes, max_depth=0
# [11:06:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 118 pruned nodes, max_depth=0
# [11:06:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 140 pruned nodes, max_depth=7
# [11:06:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 96 pruned nodes, max_depth=7
# [11:06:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 144 pruned nodes, max_depth=7
# [11:06:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 142 pruned nodes, max_depth=7
# [11:06:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 176 pruned nodes, max_depth=0
# [11:06:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 148 pruned nodes, max_depth=5
# [11:06:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 98 pruned nodes, max_depth=0
# [11:06:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 142 pruned nodes, max_depth=0
# [11:06:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 76 pruned nodes, max_depth=7
# [11:06:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 102 pruned nodes, max_depth=0
# [11:07:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 102 pruned nodes, max_depth=0
# [11:07:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 110 pruned nodes, max_depth=0
# [11:07:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 110 pruned nodes, max_depth=0
# [11:07:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 164 pruned nodes, max_depth=6
# [11:07:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 126 pruned nodes, max_depth=7
# [11:07:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 158 pruned nodes, max_depth=0
# [11:07:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 96 pruned nodes, max_depth=7
# [11:07:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 106 pruned nodes, max_depth=0
# [11:07:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 84 pruned nodes, max_depth=0
# [11:07:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 70 pruned nodes, max_depth=0
# [11:07:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 104 pruned nodes, max_depth=7
# [11:07:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 102 pruned nodes, max_depth=7
# [11:07:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 122 pruned nodes, max_depth=0
# |  10       |  0.9962   |  5.498    |  0.4639   |  0.2156   |  7.212    |  679.8    |
# =====================================================================================

# %%
# best target so far 0.9974344
print(xgb_bo.max)
# Out:
# {'target': 0.9962132, 'params': {'alpha': 6.606279956924187, 'gamma': 0.4326963005252439, 'learning_rate': 0.19984520898318486, 'max_depth': 7.654206335725146, 'n_estimators': 679.354653850241}}

# %% [markdown]
# {'target': 0.997437, 'params': {'alpha': 4.518524359415941, 'gamma': 0.6156693234583547, 'learning_rate': 0.17259291537998744, 'max_depth': 9.947095447639079, 'n_estimators': 685.9050232008782}}

# %% [markdown]
# # XGB models
# Now let's take the parameters selected by the bayesian optimization and apply them in our training and testing.

# %%
max_param = xgb_bo.max['params']
param= {'alpha': max_param['alpha'], 'gamma': max_param['gamma'], 'learning_rate': max_param['learning_rate'], 'max_depth': int(round(max_param['max_depth'],0)), 'n_estimators': int(round(max_param['n_estimators'],0)), 'objective': 'reg:logistic'}

# %%
#To train the algorithm using the parameters selected by bayesian optimization
bst = xgb.train(param, dtrain)
# Out:
# [11:07:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 8 pruned nodes, max_depth=8
# [11:07:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 14 pruned nodes, max_depth=8
# [11:07:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 22 pruned nodes, max_depth=8
# [11:07:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 12 pruned nodes, max_depth=8
# [11:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 8 pruned nodes, max_depth=8
# [11:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 6 pruned nodes, max_depth=8
# [11:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 10 pruned nodes, max_depth=8
# [11:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 10 pruned nodes, max_depth=8
# [11:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 10 pruned nodes, max_depth=8
# [11:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 12 pruned nodes, max_depth=8

# %%
#We apply our model on the training data that was trained on the training data, this helps us to control overfitting
bst1= bst.predict(dtrain)

# %%
del dtrain 
gc.collect()
# Out:
# 418

# %%
# We apply our trained model on test data and store the predictions in a bst_test dataframe
bst_test = pd.DataFrame(data=bst.predict(dtest1),  columns=["xgb_preds"])
y_test=y_test.set_index(np.arange(0,bst_test.shape[0]))
# We also store the MC information in this dataFrame
bst_test['issignal']=y_test['issignal']

# %% [markdown]
# ## Whole set
# We also select the selected variables from the 10k events data set

# %%
df_origin = tree_importer.tree_importer(allFileName,'PlainTree',7)
df_origin.columns = df_origin.columns.str.replace('Candidates_', '')
df_origin.columns = df_origin.columns.str.replace('_', '')
df_origin = df_origin.drop(columns=['xerror', 'yerror', 'zerror', 'daughter1id', 'daughter2id', 'pid', 'pTerr', 'etaerr', 'masserr', 'phierr']).rename(columns={'generation' : 'issignal'})
df_clean = clean_df(df_origin)
del df_origin
gc.collect()
#lets look at impoted tree
df_clean.iloc[0:10,:]
print('test set (background to signal ratio): ' 
      + str(round(len(df_clean.loc[df_clean['issignal'] == 0])/len(df_clean.loc[df_clean['issignal'] == 1]), 1))
      + '\ntest set (both signal and background): ' + str(len(df_clean)))
# Out:
# test set (background to signal ratio): 1099.1
# test set (both signal and background): 3176112

# %%
x_whole = df_clean[cuts].copy()
y_whole = pd.DataFrame(df_clean['issignal'], dtype='int')
dtest = xgb.DMatrix(x_whole, label = y_whole)
del x_whole
gc.collect()
# Out:
# 4

# %%
#The following graph will show us that which features are important for the model
ax = xgb.plot_importance(bst)
plt.rcParams['figure.figsize'] = [5, 3]
plt.show()
ax.figure.tight_layout() 
ax.figure.savefig(directory+'img/xgb_33gev_nochi2geo/feature_importance.pdf')
ax.figure.savefig(directory+'img/xgb_33gev_nochi2geo/feature_importance.png')

# %% [markdown]
# ## AUC and ROC
#
# The function roc_curve computes the receiver operating characteristic curve, or ROC curve. Quoting Wikipedia :
#
# “A receiver operating characteristic (ROC), or simply ROC curve, is a graphical plot which illustrates the performance of a binary classifier system as its discrimination threshold is varied. It is created by plotting the fraction of true positives out of the positives (TPR = true positive rate) vs. the fraction of false positives out of the negatives (FPR = false positive rate), at various threshold settings. TPR is also known as sensitivity, and FPR is one minus the specificity or true negative rate.”
#
# This function requires the true binary value and the target scores, which can either be probability estimates of the positive class, confidence values, or binary decisions.
#
# Similarly, the function roc_auc_score computes Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.

# %% [markdown]
# To find the best threshold which results more signal to background ratio for lambda candidates we use the parameter S0 called the approximate median significance by the higgs boson  ML challenge (http://higgsml.lal.in2p3.fr/documentation,9.)

# %%
def AMS(y_true, y_predict, y_true1, y_predict1):
    roc_auc=roc_auc_score(y_true, y_predict)
    fpr, tpr, thresholds = roc_curve(y_true, y_predict,drop_intermediate=False ,pos_label=1)
    S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
    S0 = S0[~np.isnan(S0)]
    xi = argmax(S0)
    S0_best_threshold = (thresholds[xi])

    roc_auc1=roc_auc_score(y_true1, y_predict1)
    fpr1, tpr1, thresholds1 = roc_curve(y_true1, y_predict1,drop_intermediate=False ,pos_label=1)
    S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))
    S01 = S01[~np.isnan(S01)]
    xi1 = argmax(S01)
    S0_best_threshold1 = (thresholds[xi1])

    #plotting
    fig, axs = plt.subplots(figsize=(15, 10), dpi = 100)
    plt.plot(fpr, tpr, linestyle=':',color='darkorange',label='ROC curve train (area = %0.4f)' % roc_auc)
    plt.plot(fpr1, tpr1, color='green',label='ROC curve test (area = %0.4f)' % roc_auc1)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.scatter(fpr[xi], tpr[xi], marker='o', color='black', label= 'Best Threshold train set = '+"%.4f" % S0_best_threshold +'\n S0 = '+ "%.2f" % S0[xi])
    plt.scatter(fpr1[xi1], tpr1[xi1], marker='o', color='blue', label= 'Best Threshold test set = '+"%.4f" % S0_best_threshold1 +'\n S0 = '+ "%.2f" % S01[xi1])
    plt.xlabel('False Positive Rate', fontsize = 15)
    plt.ylabel('True Positive Rate', fontsize = 15)
    plt.legend(loc="lower right", fontsize = 15)
    plt.title('Receiver operating characteristic', fontsize = 15)
    plt.xlim([-0.01, 1.0])
    plt.ylim([0, 1.02])
    
    fig.tight_layout()
    plt.show()
    fig.savefig(directory+'img/xgb_33gev_nochi2geo/ams.pdf')
    fig.savefig(directory+'img/xgb_33gev_nochi2geo/ams.png')

    return S0_best_threshold, S0_best_threshold1

# %%
train_best, test_best = AMS(y_train, bst1, y_test, bst_test['xgb_preds'])
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_43340/2326318440.py:4: RuntimeWarning: invalid value encountered in true_divide
#   S0 = sqrt(2 * ((tpr + fpr) * log((1 + tpr/fpr)) - tpr))
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_43340/2326318440.py:11: RuntimeWarning: invalid value encountered in true_divide
#   S01 = sqrt(2 * ((tpr1 + fpr1) * log((1 + tpr1/fpr1)) - tpr1))

# %%
def preds_prob(df, preds, true, dataset):
    if dataset =='train':
        label1 = 'XGB Predictions on the training data set'
    else:
        label1 = 'XGB Predictions on the test data set'
    fig, ax = plt.subplots(figsize=(12, 8))
    bins1=100
    plt.hist(df[preds], bins=bins1,facecolor='green',alpha = 0.3, label=label1)
    TP = df[(df[true]==1)]
    TN = df[(df[true]==0)]
    #TP[preds].plot.hist(ax=ax, bins=bins1,facecolor='blue', histtype='stepfilled',alpha = 0.3, label='True Positives/signal in predictions')
    hist, bins = np.histogram(TP[preds], bins=bins1)
    err = np.sqrt(hist)
    center = (bins[:-1] + bins[1:]) / 2

    
    hist1, bins1 = np.histogram(TN[preds], bins=bins1)
    err1 = np.sqrt(hist1)
    plt.errorbar(center, hist1, yerr=err1, fmt='o',
                 c='Red', label='Background in predictions')
    
    plt.errorbar(center, hist, yerr=err, fmt='o',
                 c='blue', label='Signal in predictions')
    
    ax.set_yscale('log')
    plt.xlabel('Probability',fontsize=18)
    plt.ylabel('Counts', fontsize=18)
    plt.legend(fontsize=18)
    ax.set_xticks(np.arange(0,1.1,0.1))
    ax.tick_params(axis='both', which='major', labelsize=18)
    ax.tick_params(axis='both', which='minor', labelsize=16)
    plt.show()
    fig.tight_layout()
    fig.savefig('test_best.png')
preds_prob(bst_test,'xgb_preds', 'issignal','test')

# %% [markdown]
# When the AUC, best threshold and approximate median significance for train and test are nearly the same, we save that model and use it. This means that our model is general enough. In my opinion, if the test S0 is above 3.0 then it is a good enough model.

# %% [markdown]
# ## Applying the model on the 10k events data-set

# %%
df_clean['xgb_preds'] = bst.predict(dtest)

# %%
df_clean['xgb_preds'].hist(bins=300)
plt.yscale('log')

# %% [markdown]
# ## Confusion Matrix
#
# A **Confusion Matrix** $C$ is such that $C_{ij}$ is equal to the number of observations known to be in group $i$ and predicted to be in group $j$. Thus in binary classification, the count of true positives is $C_{00}$, false negatives $C_{01}$,false positives is $C_{10}$, and true neagtives is $C_{11}$.
#
# If $ y^{'}_{i} $ is the predicted value of the $ i$-th sample and $y_{i}$ is the corresponding true value, then the fraction of correct predictions over $ n_{samples}$ is defined as
# $$
# True \: positives (y,y^{'}) =  \sum_{i=1}^{n_{samples} } 1 (y^{'}_{i} = y_{i}=1)
# $$
#
# The following function prints and plots the confusion matrix. Normalization can be applied by setting `normalize=True`.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
#calculate efficency and false tu tru signal ratio
def confustion_stats(df, cm):
    all_signals = len(df.loc[df['issignal'] == 1])
    true_signal = cm[0][0]
    false_signal = cm[1][0]        
    reconstructed_signals = true_signal + false_signal
    false_to_true_signals = false_signal / true_signal
    efficiency = reconstructed_signals / all_signals * 100 #efficency in % for all
    efficiency_true = true_signal / all_signals * 100 #efficency in % for all
    print("Efficiency: " + str(round(efficiency, 2)) + "%")
    print("Efficiency of true signal candidates reconstruction: " + str(round(efficiency_true, 2)) + "%")
    print("False tu true reconstructed signal ratio: " + str(round(false_to_true_signals, 2)))

# %%
#lets take the best threshold and look at the confusion matrix
cut1 = test_best
df_clean['xgb_preds1'] = ((df_clean['xgb_preds']>cut1)*1)
cnf_matrix = confusion_matrix(y_whole, df_clean['xgb_preds1'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix, classes=['signal','background'], title='Confusion Matrix for XGB for cut > '+str(cut1))
fig.savefig(directory+'img/xgb_33gev_nochi2geo/confusion_matrix_extreme_gradient_boosting_whole_data.pdf')
fig.savefig(directory+'img/xgb_33gev_nochi2geo/confusion_matrix_extreme_gradient_boosting_whole_data.png')
# Out:
# Confusion matrix, without normalization
# [[   2664     223]
#  [    458 3172756]]

# %%
confustion_stats(df_clean, cnf_matrix)
# Out:
# Efficiency: 108.14%
# Efficiency of true signal candidates reconstruction: 92.28%
# False tu true reconstructed signal ratio: 0.17

# %%
# The following function will display the inavriant mass histogram of the original 10k event set along with the mass histoigram after we apply a cut
# on the probability prediction of xgb
def cut_visualization(cut, range1=(lowerMassCut, upperMassCut), bins1= 300 ):
    mask1 = df_clean['xgb_preds']>cut
    df3=df_clean[mask1]
    
    fig, ax2 = plt.subplots(figsize=(15, 10), dpi = 200)
    color = 'tab:blue'
    ax2.hist(df_clean['mass'],bins = bins1, range=range1, facecolor='blue',alpha = 0.35, label='before selection')
    ax2.set_ylabel('Counts', fontsize = 15, color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.legend( fontsize = 15, loc='upper left')
    
    color = 'tab:red'
    ax1 = ax2.twinx()
    ax1.hist(df3['mass'], bins = bins1, range=range1, facecolor='red',alpha = 0.35, label='XGB')
    ax1.set_xlabel('Mass in GeV', fontsize = 15)
    ax1.set_ylabel('Counts ', fontsize = 15, color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.legend( fontsize = 15,loc='upper right' )

    plt.title("The original sample's Invariant Mass along with mass after selection of XGB (with a cut > "+str(cut)+')', fontsize = 15)
    fig.tight_layout()
    fig.savefig(directory+'img/xgb_33gev_nochi2geo/whole_sample_invmass_with_ML.pdf')
    fig.savefig(directory+'img/xgb_33gev_nochi2geo/whole_sample_invmass_with_ML.png')

# %%
cut_visualization(test_best)

# %% [markdown]
# # Comparison with the manually optimized cuts of KFPF
# In the already existing Kalman Filter Particle Finder (KFPF) package for online reconstruction and selection of short-lived particles in CBM, these criteria have been manually optimized. These selection-cuts have been selected to maximize the signal to background ratio (S/B) of the $\Lambda$ for a certain energy on a collisions generator. The selection criteria mainly depends on the collision energy, decay channel and detector configuration.

# %%
#manually selected cuts
manCut_loverdl = 30
manCut_dca = 0.4
manCut_chi2topo = 20
manCut_chi2geo = 12

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',fontsize = 15)
    plt.xlabel('Predicted label',fontsize = 15)

# %%
new_check_set= df_clean.copy()
new_check_set['new_signal']=0

mask1 = (new_check_set['loverdl'] > manCut_loverdl) & (new_check_set['distance'] < manCut_dca)

mask2 = (new_check_set['chi2topo'] < manCut_chi2topo) & (new_check_set['chi2geo'] < manCut_chi2geo) 

new_check_set = new_check_set[(mask1) & (mask2)] 

#After all these cuts, what is left is considered as signal, so we replace all the values in the 'new_signal'
# column by 1
new_check_set['new_signal'] = 1
cnf_matrix1 = confusion_matrix(new_check_set['issignal'], new_check_set['new_signal'], labels=[1,0])
np.set_printoptions(precision=2)
fig, axs = plt.subplots(figsize=(10, 8))
axs.yaxis.set_label_coords(-0.04,.5)
axs.xaxis.set_label_coords(0.5,-.005)
plot_confusion_matrix(cnf_matrix1, classes=['signal','background'], title='Confusion Matrix for manually set cuts')
fig.savefig(directory+'img/xgb_33gev_nochi2geo/confusion_matrix_for_manually_set_cuts.pdf')
fig.savefig(directory+'img/xgb_33gev_nochi2geo/confusion_matrix_for_manually_set_cuts.png')
# Out:
# Confusion matrix, without normalization
# [[2092    0]
#  [  87    0]]

# %%
confustion_stats(df_clean, cnf_matrix1)
# Out:
# Efficiency: 75.48%
# Efficiency of true signal candidates reconstruction: 72.46%
# False tu true reconstructed signal ratio: 0.04

# %%
cut3 = test_best
mask1 = df_clean['xgb_preds']>cut3
df3=df_clean[mask1]

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=200)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=200)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
#axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
from matplotlib import gridspec

range1= (0.4, 0.6)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 100, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 100, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables (close up)", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=100)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=100)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].grid()
axs[1].set_ylim([0.,2.5])
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison_closeup.png')
fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison_closeup.pdf')

# %%
# from matplotlib import gridspec

range1= (lowerMassCut, upperMassCut)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True,  gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3['mass']),bins = 300, range=range1, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 300, range=range1,facecolor='blue',alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("counts", fontsize = 15)
axs[0].set_yscale('log')
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 15)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=15)
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3['mass'],range=(lowerMassCut, upperMassCut), bins=300)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(lowerMassCut, upperMassCut), bins=300)

#ratio checked with division by 0
ratioBlue = [] #ratio smaller than 1
ratioRed = [] # ratio bigger than 1
for i in range(len(ns1)):
    if (ns1[i] != 0):
        ratio = ns[i] / ns1[i]
        if (ratio < 1):
            ratioBlue.append(ratio)
            ratioRed.append(0)
        else:
            ratioBlue.append(0)
            ratioRed.append(ratio)
    else:
        ratioBlue.append(0)
        ratioRed.append(0)
#col = []
# for val in ratio:
#     if val < 1:
#         col.append('blue')
#     else:
#         col.append('red')        
axs[1].bar(bins[:-1],     
        ratioBlue, 
        width=0.001,
        color = 'blue',
        label='ratio < 1')
axs[1].bar(bins[:-1],     
        ratioRed, 
        width=0.001,
        color = 'red',
        label='ratio >= 1')
axs[1].legend( loc='upper right')
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 15)
axs[1].set_ylabel("XGB / KFPF", fontsize = 15)
axs[1].set_ylim([0.,2.])
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=15)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
from matplotlib import gridspec

left = .44
right = .55
range1= (left, right)


fig, axs = plt.subplots(2, 1,figsize=(15,10), sharex=True, gridspec_kw={'width_ratios': [10],
                           'height_ratios': [8,4]})

ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 50,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 50,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs[0].set_ylabel("log (counts)", fontsize = 18)
#axs[0].grid()
axs[0].legend(('XGBoost Selected K-short','KFPF selected K-short'), fontsize = 18, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs[0].set_title("The K-short Invariant Mass histogram with KFPF and XGB selection criteria on KFPF variables", fontsize = 18)
#axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=18)
axs[0].set_yscale('log')
#fig.savefig("whole_sample_invmass_with_ML.png")


hist1, bin_edges1 = np.histogram(df3_base['mass'],range=(left, right), bins=50)
hist2, bin_edges2 = np.histogram(new_check_set['mass'],range=(left, right), bins=50)


#makes sense to have only positive values
diff = (hist1 - hist2)
#axs[1].bar((bins[:-1] + bins[1:]) / 2, # this is what makes it comparable
# ns / ns1, # maybe check for div-by-zero!
# width=0.001)
axs[1].hlines(y=1, xmin=left, xmax=right, colors='r', linestyles='solid', label='')
center = (bins[:-1] + bins[1:]) / 2
plt.errorbar(center, ns / ns1, fmt='o',
                 c='Blue', label='Background in predictions')


    
    
plt.xlabel("Mass in $\dfrac{GeV}{c^2}$", fontsize = 18)
axs[1].set_ylabel("XGB / KFPF", fontsize = 18)
#axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=18)

plt.show()
fig.tight_layout()
fig.savefig(directory+'img/circle_kshort_invmass_with_ML.png')
# Out:
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_43340/2429793760.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ns, bins, patches=axs[0].hist((df3_base['mass']),bins = 50,histtype='step', range=range1,Fill=False, color='red', facecolor='red', linewidth=2)
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_43340/2429793760.py:12: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ns1, bins1, patches1=axs[0].hist((new_check_set['mass']),bins = 50,histtype='step', Fill=False, range=range1,facecolor='blue',linewidth=2)
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_43340/2429793760.py:37: RuntimeWarning: divide by zero encountered in true_divide
#   plt.errorbar(center, ns / ns1, fmt='o',
# /var/folders/_8/1pnnpyz111s3q4bf02xypbgc0000gn/T/ipykernel_43340/2429793760.py:37: RuntimeWarning: invalid value encountered in true_divide
#   plt.errorbar(center, ns / ns1, fmt='o',

# %%
par = 'loverdl'
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','after selection', 'man selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'distance'
ranges = (0,5)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'chi2topo'
ranges = (0,100)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
par = 'chi2geo'
ranges = (0,100)
fig, axs = plt.subplots(figsize=(15, 10))
ns1, bins1, patches1=axs.hist((df_clean[par]),bins = 300, facecolor='blue',alpha = 0.3, range=ranges)
ns, bins, patches=axs.hist((df3[par]),bins = 300, facecolor='red',alpha = 0.3, range=ranges)
ns1, bins1, patches1=axs.hist((new_check_set[par]),bins = 300, facecolor='yellow', alpha = 0.3, range=ranges)
#plt.xlabel("Mass in GeV", fontsize = 15)
axs.set_ylabel("counts", fontsize = 15)
axs.set_yscale('log')
axs.legend(('before selection','xgb selection', 'manual selection'), fontsize = 15, loc='upper right')

#plt.rcParams["legend.loc"] = 'upper right'
axs.set_title(par + " before and after XGB selection", fontsize = 15)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=15)
    #fig.savefig("whole_sample_invmass_with_ML.png")

# plt.show()
# fig.tight_layout()
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.png')
# fig.savefig(directory+'img/xgb_33gev_nochi2geo/kaon_inv_mass_comparison.pdf')

# %%
#del x,y,x_test,y_test,x_whole,y_whole,
#del dtest,dtrain,dtest1,df3,df_clean,df_scaled
gc.collect()
# Out:
# 7428

# %% [markdown]
# # Importing the final predictor to root
# We will use the treelite library to transport the final predictor of our model to root

# %% [raw]
# #install treelite
# import treelite
# #create an object out of your model, bst in our case
# model = treelite.Model.from_xgboost(bst)
# #use GCC compiler
# toolchain = 'gcc'
# #parallel_comp can be changed upto as many processors as one have
# model.export_lib(toolchain=toolchain, libpath='./mymodel.so',
#                  params={'parallel_comp': 8}, verbose=True)
#
# # Operating system of the target machine
# platform = 'unix'
# # C compiler to use to compile prediction code on the target machine
# toolchain = 'gcc'
# # Save the source package as a zip archive named mymodel.zip
# # Later, we'll use this package to produce the library mymodel.so.
# model.export_srcpkg(platform=platform, toolchain=toolchain,
#                     pkgpath='./mymodel.zip', libname='mymodel.so',
#                     verbose=True)

# %% [raw]
# !unzip mymodel.zip

# %% [raw]
# #Build the source package (using GNU Make or NMake).
# %cd mymodel
# !make
#
# !ls

# %% [raw]
# If one wants to transfer this model to a different computer, target machine, then one should follow the following commands in command prompt

# %% [raw]
# sftp john@lxpool.gsi.de
# sftp> put mymodel.zip
# sftp> quit

# %% [raw]
# ssh john@lxpool.gsi.de
# unzip mymodel.zip
# cd mymodel
# make -j8

# %% [raw]
# The following C++ code can be the applied as a macro on some new data file

# %% [raw]
# %%writefile test.cpp
# #include "TROOT.h"
# #include "TFile.h"
# #include "TTree.h"
# #include "TH1F.h"
# #include <vector>
# #include "TString.h"
# #include "TMath.h"
# #include "TH1.h"
# #include "TF1.h"
# #include "TCanvas.h"
#
# #include <stdio.h>
# #include <stdlib.h>
# #include "main.c"
#
#
#
# void python_to_root(){
#   TCanvas* c1 = new TCanvas();
#   //c1->Divide(2,1);
#
#   //c1->cd(1);
#
#   /* Open the root file*/
#   TFile *f = new TFile("/gdrive/My Drive/presentations/treelite/10k_events_PFSimplePlainTree.root","UPDATE");
#   TTree *t1 = (TTree*)f->Get("PlainTree");
#
#
#   Float_t  LambdaCandidates_chi2primneg, LambdaCandidates_chi2primpos, LambdaCandidates_ldl, LambdaCandidates_distance, LambdaCandidates_chi2geo, LambdaCandidates_mass;
#
#   t1->SetBranchAddress("LambdaCandidates_chi2primneg",&LambdaCandidates_chi2primneg);
#   t1->SetBranchAddress("LambdaCandidates_chi2primpos",&LambdaCandidates_chi2primpos);
#   t1->SetBranchAddress("LambdaCandidates_ldl",&LambdaCandidates_ldl);
#   t1->SetBranchAddress("LambdaCandidates_distance",&LambdaCandidates_distance);
#   t1->SetBranchAddress("LambdaCandidates_chi2geo",&LambdaCandidates_chi2geo);
#   t1->SetBranchAddress("LambdaCandidates_mass",&LambdaCandidates_mass);
#
#
#   std::vector<float> output{};
#
#   const long n_entries = t1->GetEntries();
#   output.reserve(n_entries);
#
#   const size_t n_features = 5;
#   union Entry input[n_features];
#
#   //let's create a new branch which will store the probability returened for each proton-pion pair by our model
#   Float_t probab;
#   TBranch *bpt = t1->Branch("probab",&probab,"probabilities");
#   t1->SetBranchAddress("probab",&probab);
#
#   TH1F *h = new TH1F("h_prob", "This is the #Lambda invariant mass after the cut >0.918080", 300, 1.04, 1.4);
#   h->GetXaxis()->SetTitle("[GeV]");
#
#   for (long i = 0; i < n_entries; i++)
#    {
#      t1->GetEntry(i);
#
#     input[0].fvalue = LambdaCandidates_chi2primneg;
#     input[1].fvalue = LambdaCandidates_chi2primpos;
#     input[2].fvalue = LambdaCandidates_ldl;
#     input[3].fvalue = LambdaCandidates_distance;
#     input[4].fvalue = LambdaCandidates_chi2geo;
#
#     output.push_back(predict(input, 0));
#     probab= output.at(i);
#
#     if(probab > 0.918080){
#     h->Fill(LambdaCandidates_mass);}
#   }
#
#   h->Draw();
#
#
#
# }

# %% [raw]
# # Installing root
# !mkdir -p APPS
# !pwd
# !cd APPS && wget https://root.cern/download/root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
# !cd APPS && tar -xf root_v6.22.00.Linux-ubuntu19-x86_64-gcc9.2.tar.gz
